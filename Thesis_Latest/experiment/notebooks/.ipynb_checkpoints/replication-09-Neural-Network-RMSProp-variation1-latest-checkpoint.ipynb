# %% [markdown]
# - mean_test_auc_roc using Logistic Regression:
# - mean_test_auc_roc using KNN:0.631033
# - mean_test_auc_roc using SVM:0.658805
# - mean_test_auc_roc using Random Forest:0.657398
# - mean_test_auc_roc using Decision Tree:0.640888
# - mean_test_auc_roc using **Naive Bayes:0.659468**
# - mean_test_auc_roc using Neural Network(Adam):0.634302
# - mean_test_auc_roc using Neural Network(SGD):0.630862
# - mean_test_auc_roc using Neural Network(RMSprop):0.629448

# %%
# globally useful imports of standard libraries needed in this notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os.path
from datetime import datetime

# specific libraries or classes needed for the work in this notebook
#from sklearn.linear_model import LogisticRegression
#from sklearn.linear_model import LogisticRegressionCV
#from sklearn.svm import SVC
#from sklearn.naive_bayes import GaussianNB
#from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GroupKFold
from sklearn.model_selection import LeaveOneGroupOut
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import SelectKBest, f_classif, chi2, SelectFpr, f_regression, mutual_info_classif
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import RFE
from sklearn.feature_selection import VarianceThreshold
from sklearn.ensemble import ExtraTreesClassifier
#from sklearn.pipeline import Pipeline
# need to use Pipeline from imblearn to add in a downsample or upsample
# to cross validation training
from imblearn.pipeline import Pipeline

# import project specific modules used in this notebook
import sys
sys.path.append('../src')
import mindwandering.data
import mindwandering.features
import mindwandering.evaluate
from mindwandering.data import FeatureScalerTransformer
from mindwandering.data import WinsorizationOutlierTransformer
from mindwandering.data import VIFThresholdTransformer
from mindwandering.data import FeatureSelectionTransformer
from mindwandering.data import ClassImbalanceTransformer
from mindwandering.data import GridSearchProgressHack

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.layers import Input, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import SGD,Adam,RMSprop

# %%
# Load Data and Features
df_features = mindwandering.data.get_df_features()
mind_wandered_label = mindwandering.data.get_mind_wandered_label()
participant_ids = mindwandering.data.get_participant_ids()

# %%
inputs_shape=df_features.shape[1]

# %%
import tensorflow
auc_roc = tensorflow.keras.metrics.AUC(name='auc_roc',num_thresholds=20000,curve='ROC')
#auc_roc = tensorflow.keras.metrics.AUC(name='auc_roc',curve='ROC')

# %%
# preliminary test, see if it looks like we have gpu and cpu devices available to use
# introspect tensorflow to see if gpu devices available or not
# https://www.tensorflow.org/guide/gpu
# https://www.tensorflow.org/api_docs/python/tf/config/list_physical_devices
print("Num GPUs Available: ", len(tensorflow.config.list_physical_devices('GPU')))
print("Num CPUs Available: ", len(tensorflow.config.list_physical_devices('CPU')))

# display all of the device information
for device in tensorflow.config.list_physical_devices():
    print(device)
# Out:
# Num GPUs Available:  0
# Num CPUs Available:  1
# PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')

# %%
def create_model(optimizer='RMSprop'):
    model = Sequential()
    model.add(Dense(512, activation='relu',kernel_regularizer=regularizers.l1_l2(l1=0.1, l2=0.01), input_shape=(inputs_shape,)))
    model.add(Dropout(0.3))
    model.add(Dense(256,activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(128,activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(1, activation='sigmoid'))
    #optimizer=RMSprop(lr=0.001)
    model.compile(loss='binary_crossentropy', optimizer=optimizer,metrics=['accuracy',auc_roc])
    return model

# %%
# Wrap Keras model so it can be used by scikit-learn
kears_estimator = KerasClassifier(build_fn=create_model,epochs=100, batch_size=10, verbose=1)

# %%
# vif thresholds to apply to data and labels before grid search pipeline
#vif_thresholds = [0, 5]
vif_thresholds = [0]

# we want to actually select a certain percentage of features of whatever remains
# after vif thresholding.  So we will calculate these in the loop based on the number
# of features in data, and add to the parameters dictionary before the grid search
#features__k_ratios = np.array([0.25, 0.5, 0.75, 1.0])
#features__k_ratios = np.array([0.2, 0.25, 0.3, 0.35, 0.4, 0.5])

# Empty dataframe to gather grid search results into 1 place
best_estimator = None
best_score = 0.0
best_params = {}
best_index = 0
df_result = None

# search over vif threshold meta parameters, create separate df from vif_threshold
# for otherwise identical grid searches
for vif_threshold in vif_thresholds:
    # display progress
    print('')
    print('=' * 50)
    print('Starting vif meta-parameter condition: vif_threshold: ', vif_threshold)
    
    # pipeline to apply vif threshold selection
    vif_pipeline = Pipeline(
      [
        ('vif',      VIFThresholdTransformer(score_threshold=vif_threshold)),
      ]
    )
 
    df_vif_features = vif_pipeline.transform(df_features)
    num_trials, num_features = df_vif_features.shape
    print('   Number of trials: ', num_trials, ' Number of Features: ', num_features)
    
    parameters = {
        'scaling__type_of_scaling': ['standard'],
        'outlier__outlier_threshold': [0.0, 3.0],
        #'features__score_func': [f_classif],
        #'balance__balancer_type': ['random-undersampler', 'allknn', 'nearmiss', 'instance-hardness-threshold'],
        #'balance__balancer_type': ['allknn', 'condensed-nn', 'neighbourhood-cleaning', 'one-sided-selection'],
        #'balance__balancer_type': ['allknn', 'one-sided-selection'],
        'balance__balancer_type': ['allknn', 'smote-enn'],
        #'model__var_smoothing': [1e-6,1e-7,1e-8,1e-9,1e-10,1e-11,1e-12],
        #'model__batch_size': [10, 20, 40, 60, 80, 100],
        #'model__epochs':[10, 50, 100],
        #'model__batch_size': [60],
        #'model__epochs':[10],
        'model__optimizer' : ['SGD', 'RMSprop', 'Adagrad', 'Adadelta', 'Adam', 'Adamax', 'Nadam']
    }

    # set feature selection k correctly
    #features__k = features__k_ratios * num_features
    #features__k = features__k.astype(int) 
    #parameters['features__k'] = features__k.tolist()

    # Estimator Pipeline
    pipeline = Pipeline(
      [
        ('progress', GridSearchProgressHack(verbose=False)),
        ('scaling',  FeatureScalerTransformer()),
        ('outlier',  WinsorizationOutlierTransformer()),
        #('features', SelectKBest()),
        #('features', SelectFromModel(estimator=LogisticRegression(solver='liblinear', penalty='l1', C=0.1), threshold=-np.inf)),
        ('balance',  ClassImbalanceTransformer()),
        ('model',    kears_estimator)
      ]
    )
    
    # Cross Validation Splitter
    cv_group_splitter = GroupKFold(n_splits=5)
    #cv_group_splitter = LeaveOneGroupOut()

    # perform the grid search for this vif selection
    # set up the search
    search = GridSearchCV(
        estimator = pipeline,
        param_grid = parameters,
        scoring = ['roc_auc','accuracy'],
        cv = cv_group_splitter,
        refit = 'roc_auc',
        verbose = 1
    )
    search.fit(df_vif_features, mind_wandered_label, groups=participant_ids)
    
    # append results onto the dataframe collecting the results.  Need to add
    # a feature column to this dataframe for the vif vit condition here
    df = pd.DataFrame(data=search.cv_results_)
    df['param__vif_score_threshold'] = vif_threshold
    
    if best_estimator is None:
        df_result = df
        best_estimator = search.best_estimator_
        best_score = search.best_score_
        best_params = search.best_params_
        best_index = search.best_index_
    else:
        df_result = df_result.append(df, ignore_index=True)
        if search.best_score_ > best_score:
            best_estimator = search.best_estimator_
            best_score = search.best_score_
            best_params = search.best_params_
            best_index = search.best_index_  # todo this is only the index of this search
# Out:
# ==================================================
# Starting vif meta-parameter condition: vif_threshold:  0
#    Number of trials:  4076  Number of Features:  62
# Fitting 5 folds for each of 28 candidates, totalling 140 fits
# 0001 Epoch 1/100
# 174/174 [==============================] - 1s 2ms/step - loss: 76.7142 - accuracy: 0.5115 - auc_roc: 0.5051
# Epoch 2/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.2883 - accuracy: 0.5057 - auc_roc: 0.5257
# Epoch 3/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.2889 - accuracy: 0.5143 - auc_roc: 0.5133
# Epoch 4/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.2897 - accuracy: 0.5085 - auc_roc: 0.5152
# Epoch 5/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.2903 - accuracy: 0.5216 - auc_roc: 0.5477
# Epoch 6/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.2904 - accuracy: 0.5241 - auc_roc: 0.5393
# Epoch 7/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.2907 - accuracy: 0.5387 - auc_roc: 0.5363
# Epoch 8/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.2913 - accuracy: 0.5255 - auc_roc: 0.5277
# Epoch 9/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.2924 - accuracy: 0.5133 - auc_roc: 0.5304
# Epoch 10/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.2932 - accuracy: 0.5183 - auc_roc: 0.5596
# Epoch 11/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.2952 - accuracy: 0.5103 - auc_roc: 0.5333
# Epoch 12/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.2940 - accuracy: 0.5217 - auc_roc: 0.5575
# Epoch 13/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.2941 - accuracy: 0.5229 - auc_roc: 0.5250
# Epoch 14/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.2950 - accuracy: 0.5194 - auc_roc: 0.5608
# Epoch 15/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.2943 - accuracy: 0.5369 - auc_roc: 0.5651
# Epoch 16/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.2952 - accuracy: 0.5320 - auc_roc: 0.5676
# Epoch 17/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.2991 - accuracy: 0.4900 - auc_roc: 0.5478
# Epoch 18/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.2994 - accuracy: 0.5075 - auc_roc: 0.5352
# Epoch 19/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3022 - accuracy: 0.5027 - auc_roc: 0.5358
# Epoch 20/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.2981 - accuracy: 0.5292 - auc_roc: 0.5198
# Epoch 21/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3008 - accuracy: 0.5247 - auc_roc: 0.5658
# Epoch 22/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3011 - accuracy: 0.5053 - auc_roc: 0.5185
# Epoch 23/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3016 - accuracy: 0.5076 - auc_roc: 0.5534
# Epoch 24/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3025 - accuracy: 0.5325 - auc_roc: 0.5641
# Epoch 25/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.2998 - accuracy: 0.5305 - auc_roc: 0.5491
# Epoch 26/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3017 - accuracy: 0.5212 - auc_roc: 0.5817
# Epoch 27/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3028 - accuracy: 0.5282 - auc_roc: 0.5857
# Epoch 28/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3027 - accuracy: 0.5363 - auc_roc: 0.5635
# Epoch 29/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3026 - accuracy: 0.5415 - auc_roc: 0.5761
# Epoch 30/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3030 - accuracy: 0.5328 - auc_roc: 0.5761
# Epoch 31/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3053 - accuracy: 0.5306 - auc_roc: 0.5870
# Epoch 32/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3079 - accuracy: 0.5187 - auc_roc: 0.5485
# Epoch 33/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3074 - accuracy: 0.5341 - auc_roc: 0.5780
# Epoch 34/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3084 - accuracy: 0.5435 - auc_roc: 0.5798
# Epoch 35/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3091 - accuracy: 0.5234 - auc_roc: 0.5500
# Epoch 36/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3090 - accuracy: 0.5382 - auc_roc: 0.5627
# Epoch 37/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3117 - accuracy: 0.5549 - auc_roc: 0.5727
# Epoch 38/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3103 - accuracy: 0.5557 - auc_roc: 0.5792
# Epoch 39/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3147 - accuracy: 0.5346 - auc_roc: 0.5452
# Epoch 40/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3140 - accuracy: 0.5365 - auc_roc: 0.5655
# Epoch 41/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3114 - accuracy: 0.5547 - auc_roc: 0.5949
# Epoch 42/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3141 - accuracy: 0.5199 - auc_roc: 0.5550
# Epoch 43/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3150 - accuracy: 0.5411 - auc_roc: 0.5588
# Epoch 44/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3164 - accuracy: 0.5278 - auc_roc: 0.5602
# Epoch 45/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3181 - accuracy: 0.5249 - auc_roc: 0.5743
# Epoch 46/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3198 - accuracy: 0.5306 - auc_roc: 0.5606
# Epoch 47/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3197 - accuracy: 0.5293 - auc_roc: 0.5784
# Epoch 48/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3227 - accuracy: 0.5268 - auc_roc: 0.5531
# Epoch 49/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3202 - accuracy: 0.5420 - auc_roc: 0.5760
# Epoch 50/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3226 - accuracy: 0.5554 - auc_roc: 0.5852
# Epoch 51/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3251 - accuracy: 0.5429 - auc_roc: 0.5621
# Epoch 52/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3242 - accuracy: 0.5520 - auc_roc: 0.5543
# Epoch 53/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3246 - accuracy: 0.5418 - auc_roc: 0.5794
# Epoch 54/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3268 - accuracy: 0.5429 - auc_roc: 0.5746
# Epoch 55/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3305 - accuracy: 0.5356 - auc_roc: 0.5864
# Epoch 56/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3331 - accuracy: 0.5509 - auc_roc: 0.5662
# Epoch 57/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3319 - accuracy: 0.5437 - auc_roc: 0.5772
# Epoch 58/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3358 - accuracy: 0.5349 - auc_roc: 0.5694
# Epoch 59/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3356 - accuracy: 0.5720 - auc_roc: 0.5976
# Epoch 60/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3384 - accuracy: 0.5697 - auc_roc: 0.5823
# Epoch 61/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3418 - accuracy: 0.5476 - auc_roc: 0.5791
# Epoch 62/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3398 - accuracy: 0.5547 - auc_roc: 0.5719
# Epoch 63/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3466 - accuracy: 0.5401 - auc_roc: 0.5521
# Epoch 64/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3504 - accuracy: 0.5323 - auc_roc: 0.5669
# Epoch 65/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3459 - accuracy: 0.5633 - auc_roc: 0.6014
# Epoch 66/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3519 - accuracy: 0.5332 - auc_roc: 0.5619
# Epoch 67/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3470 - accuracy: 0.5673 - auc_roc: 0.6052
# Epoch 68/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3569 - accuracy: 0.5363 - auc_roc: 0.5489
# Epoch 69/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3522 - accuracy: 0.5556 - auc_roc: 0.5627
# Epoch 70/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3547 - accuracy: 0.5477 - auc_roc: 0.5786
# Epoch 71/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3566 - accuracy: 0.5631 - auc_roc: 0.5768
# Epoch 72/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3558 - accuracy: 0.5692 - auc_roc: 0.6039
# Epoch 73/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3706 - accuracy: 0.5282 - auc_roc: 0.5411
# Epoch 74/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3654 - accuracy: 0.5297 - auc_roc: 0.5645
# Epoch 75/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3521 - accuracy: 0.5669 - auc_roc: 0.5897
# Epoch 76/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3657 - accuracy: 0.5665 - auc_roc: 0.5703
# Epoch 77/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3661 - accuracy: 0.5785 - auc_roc: 0.5862
# Epoch 78/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3695 - accuracy: 0.5429 - auc_roc: 0.5965
# Epoch 79/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3729 - accuracy: 0.5639 - auc_roc: 0.6029
# Epoch 80/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3755 - accuracy: 0.5696 - auc_roc: 0.5881
# Epoch 81/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3851 - accuracy: 0.5589 - auc_roc: 0.5598
# Epoch 82/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3765 - accuracy: 0.5454 - auc_roc: 0.5800
# Epoch 83/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3775 - accuracy: 0.5804 - auc_roc: 0.6088
# Epoch 84/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3782 - accuracy: 0.5785 - auc_roc: 0.6070
# Epoch 85/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3887 - accuracy: 0.5716 - auc_roc: 0.6091
# Epoch 86/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3914 - accuracy: 0.5500 - auc_roc: 0.5833
# Epoch 87/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3938 - accuracy: 0.5869 - auc_roc: 0.6073
# Epoch 88/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3932 - accuracy: 0.5531 - auc_roc: 0.5800
# Epoch 89/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3944 - accuracy: 0.5761 - auc_roc: 0.6191
# Epoch 90/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.4006 - accuracy: 0.5783 - auc_roc: 0.5903
# Epoch 91/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.4065 - accuracy: 0.5806 - auc_roc: 0.6136
# Epoch 92/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.4024 - accuracy: 0.5985 - auc_roc: 0.6232
# Epoch 93/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.4093 - accuracy: 0.5776 - auc_roc: 0.6118
# Epoch 94/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.4121 - accuracy: 0.5507 - auc_roc: 0.5803
# Epoch 95/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.4104 - accuracy: 0.5617 - auc_roc: 0.5844
# Epoch 96/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.4280 - accuracy: 0.5391 - auc_roc: 0.5582
# Epoch 97/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.4112 - accuracy: 0.5919 - auc_roc: 0.6234
# Epoch 98/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.4151 - accuracy: 0.5781 - auc_roc: 0.6150
# Epoch 99/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.4228 - accuracy: 0.5602 - auc_roc: 0.5856
# Epoch 100/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.4215 - accuracy: 0.5494 - auc_roc: 0.5869
# 82/82 [==============================] - 0s 470us/step
#  1/82 [..............................] - ETA: 0s
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# 82/82 [==============================] - 0s 465us/step
# 0002 Epoch 1/100
# 178/178 [==============================] - 1s 2ms/step - loss: 75.6659 - accuracy: 0.5123 - auc_roc: 0.5714
# Epoch 2/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.2932 - accuracy: 0.5213 - auc_roc: 0.5197
# Epoch 3/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.2956 - accuracy: 0.4957 - auc_roc: 0.5174
# Epoch 4/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.2945 - accuracy: 0.5145 - auc_roc: 0.5381
# Epoch 5/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3008 - accuracy: 0.5235 - auc_roc: 0.5215
# Epoch 6/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3017 - accuracy: 0.5309 - auc_roc: 0.5340
# Epoch 7/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3055 - accuracy: 0.5380 - auc_roc: 0.5753
# Epoch 8/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3151 - accuracy: 0.5363 - auc_roc: 0.5609
# Epoch 9/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3067 - accuracy: 0.5365 - auc_roc: 0.5819
# Epoch 10/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3134 - accuracy: 0.5589 - auc_roc: 0.5880
# Epoch 11/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3068 - accuracy: 0.5443 - auc_roc: 0.5702
# Epoch 12/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3122 - accuracy: 0.5373 - auc_roc: 0.5629
# Epoch 13/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3122 - accuracy: 0.5355 - auc_roc: 0.5711
# Epoch 14/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3161 - accuracy: 0.5493 - auc_roc: 0.5686
# Epoch 15/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3162 - accuracy: 0.5395 - auc_roc: 0.5635
# Epoch 16/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3140 - accuracy: 0.5501 - auc_roc: 0.5836
# Epoch 17/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3145 - accuracy: 0.5669 - auc_roc: 0.5848
# Epoch 18/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3209 - accuracy: 0.5161 - auc_roc: 0.5385
# Epoch 19/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3242 - accuracy: 0.5350 - auc_roc: 0.5432
# Epoch 20/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3247 - accuracy: 0.5137 - auc_roc: 0.5579
# Epoch 21/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3318 - accuracy: 0.5588 - auc_roc: 0.5882
# Epoch 22/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3201 - accuracy: 0.5656 - auc_roc: 0.5927
# Epoch 23/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3424 - accuracy: 0.5614 - auc_roc: 0.5666
# Epoch 24/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3288 - accuracy: 0.5355 - auc_roc: 0.5698
# Epoch 25/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3315 - accuracy: 0.5480 - auc_roc: 0.5642
# Epoch 26/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3436 - accuracy: 0.5743 - auc_roc: 0.5953
# Epoch 27/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3342 - accuracy: 0.5281 - auc_roc: 0.5748
# Epoch 28/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3727 - accuracy: 0.5627 - auc_roc: 0.5864
# Epoch 29/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3371 - accuracy: 0.5450 - auc_roc: 0.5876
# Epoch 30/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3349 - accuracy: 0.5554 - auc_roc: 0.5709
# Epoch 31/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3347 - accuracy: 0.5532 - auc_roc: 0.5839
# Epoch 32/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3437 - accuracy: 0.5278 - auc_roc: 0.5329
# Epoch 33/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3397 - accuracy: 0.5748 - auc_roc: 0.6086
# Epoch 34/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3410 - accuracy: 0.5586 - auc_roc: 0.5820
# Epoch 35/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3405 - accuracy: 0.5428 - auc_roc: 0.5592
# Epoch 36/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3400 - accuracy: 0.5561 - auc_roc: 0.5700
# Epoch 37/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3518 - accuracy: 0.5462 - auc_roc: 0.5657
# Epoch 38/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3536 - accuracy: 0.5499 - auc_roc: 0.5831
# Epoch 39/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3619 - accuracy: 0.5895 - auc_roc: 0.6347
# Epoch 40/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3781 - accuracy: 0.5523 - auc_roc: 0.5724
# Epoch 41/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.6144 - accuracy: 0.5677 - auc_roc: 0.6041
# Epoch 42/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3750 - accuracy: 0.5747 - auc_roc: 0.5976
# Epoch 43/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3732 - accuracy: 0.5381 - auc_roc: 0.5583
# Epoch 44/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4058 - accuracy: 0.5685 - auc_roc: 0.5775
# Epoch 45/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3921 - accuracy: 0.5691 - auc_roc: 0.5964
# Epoch 46/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3803 - accuracy: 0.5805 - auc_roc: 0.5991
# Epoch 47/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3914 - accuracy: 0.5713 - auc_roc: 0.5934
# Epoch 48/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3807 - accuracy: 0.5576 - auc_roc: 0.5846
# Epoch 49/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3930 - accuracy: 0.5757 - auc_roc: 0.6061
# Epoch 50/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4068 - accuracy: 0.5476 - auc_roc: 0.5664
# Epoch 51/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3947 - accuracy: 0.5302 - auc_roc: 0.5699
# Epoch 52/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3816 - accuracy: 0.5439 - auc_roc: 0.5637
# Epoch 53/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3885 - accuracy: 0.5810 - auc_roc: 0.5977
# Epoch 54/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3952 - accuracy: 0.5798 - auc_roc: 0.6043
# Epoch 55/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4086 - accuracy: 0.5417 - auc_roc: 0.5666
# Epoch 56/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4065 - accuracy: 0.5932 - auc_roc: 0.6304
# Epoch 57/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4093 - accuracy: 0.5628 - auc_roc: 0.5861
# Epoch 58/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4048 - accuracy: 0.5998 - auc_roc: 0.6215
# Epoch 59/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4197 - accuracy: 0.5784 - auc_roc: 0.6000
# Epoch 60/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4474 - accuracy: 0.5440 - auc_roc: 0.5830
# Epoch 61/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4588 - accuracy: 0.5246 - auc_roc: 0.5442
# Epoch 62/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4602 - accuracy: 0.5489 - auc_roc: 0.5633
# Epoch 63/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4517 - accuracy: 0.5642 - auc_roc: 0.5915
# Epoch 64/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4850 - accuracy: 0.5578 - auc_roc: 0.5928
# Epoch 65/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4137 - accuracy: 0.5970 - auc_roc: 0.6140
# Epoch 66/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4391 - accuracy: 0.6118 - auc_roc: 0.6430
# Epoch 67/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4372 - accuracy: 0.6167 - auc_roc: 0.6478
# Epoch 68/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.5027 - accuracy: 0.5856 - auc_roc: 0.6197
# Epoch 69/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4441 - accuracy: 0.5680 - auc_roc: 0.5980
# Epoch 70/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4490 - accuracy: 0.5805 - auc_roc: 0.6152
# Epoch 71/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4255 - accuracy: 0.6197 - auc_roc: 0.6475
# Epoch 72/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4934 - accuracy: 0.5703 - auc_roc: 0.6008
# Epoch 73/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4761 - accuracy: 0.6025 - auc_roc: 0.6448
# Epoch 74/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4380 - accuracy: 0.5998 - auc_roc: 0.6453
# Epoch 75/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.5175 - accuracy: 0.6052 - auc_roc: 0.6310
# Epoch 76/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4303 - accuracy: 0.6189 - auc_roc: 0.6508
# Epoch 77/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.5668 - accuracy: 0.5991 - auc_roc: 0.6325
# Epoch 78/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4650 - accuracy: 0.5961 - auc_roc: 0.6295
# Epoch 79/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4664 - accuracy: 0.6069 - auc_roc: 0.6253
# Epoch 80/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4332 - accuracy: 0.6136 - auc_roc: 0.6762
# Epoch 81/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4389 - accuracy: 0.5991 - auc_roc: 0.6166
# Epoch 82/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4734 - accuracy: 0.5968 - auc_roc: 0.6349
# Epoch 83/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4312 - accuracy: 0.6312 - auc_roc: 0.6672
# Epoch 84/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4818 - accuracy: 0.6271 - auc_roc: 0.6558
# Epoch 85/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4865 - accuracy: 0.6189 - auc_roc: 0.6748
# Epoch 86/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4626 - accuracy: 0.6216 - auc_roc: 0.6653
# Epoch 87/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4566 - accuracy: 0.6219 - auc_roc: 0.6394
# Epoch 88/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4319 - accuracy: 0.6197 - auc_roc: 0.6559
# Epoch 89/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4505 - accuracy: 0.6294 - auc_roc: 0.6696
# Epoch 90/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4592 - accuracy: 0.5957 - auc_roc: 0.6253
# Epoch 91/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4256 - accuracy: 0.5973 - auc_roc: 0.6386
# Epoch 92/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4457 - accuracy: 0.5933 - auc_roc: 0.6306
# Epoch 93/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4700 - accuracy: 0.6098 - auc_roc: 0.6205
# Epoch 94/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4602 - accuracy: 0.6233 - auc_roc: 0.6333
# Epoch 95/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4693 - accuracy: 0.6200 - auc_roc: 0.6477
# Epoch 96/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4773 - accuracy: 0.6055 - auc_roc: 0.6180
# Epoch 97/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4330 - accuracy: 0.6203 - auc_roc: 0.6584
# Epoch 98/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4453 - accuracy: 0.6174 - auc_roc: 0.6626
# Epoch 99/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4490 - accuracy: 0.5739 - auc_roc: 0.5972
# Epoch 100/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4449 - accuracy: 0.6304 - auc_roc: 0.6613
# 82/82 [==============================] - 0s 458us/step
# 82/82 [==============================] - 0s 448us/step
# 0003
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Epoch 1/100
# 174/174 [==============================] - 1s 2ms/step - loss: 76.4889 - accuracy: 0.5301 - auc_roc: 0.6198
# Epoch 2/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.2941 - accuracy: 0.4964 - auc_roc: 0.5100
# Epoch 3/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.2952 - accuracy: 0.4825 - auc_roc: 0.5176
# Epoch 4/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.2970 - accuracy: 0.5040 - auc_roc: 0.5156
# Epoch 5/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.2983 - accuracy: 0.5121 - auc_roc: 0.5281
# Epoch 6/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3004 - accuracy: 0.5111 - auc_roc: 0.5459
# Epoch 7/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.2997 - accuracy: 0.5102 - auc_roc: 0.5451
# Epoch 8/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3022 - accuracy: 0.5055 - auc_roc: 0.5487
# Epoch 9/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3023 - accuracy: 0.5130 - auc_roc: 0.5243
# Epoch 10/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3035 - accuracy: 0.5006 - auc_roc: 0.5242
# Epoch 11/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3034 - accuracy: 0.5321 - auc_roc: 0.5602
# Epoch 12/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3040 - accuracy: 0.5183 - auc_roc: 0.5522
# Epoch 13/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3066 - accuracy: 0.5043 - auc_roc: 0.5193
# Epoch 14/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3059 - accuracy: 0.5180 - auc_roc: 0.5398
# Epoch 15/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3060 - accuracy: 0.5162 - auc_roc: 0.5074
# Epoch 16/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3059 - accuracy: 0.4936 - auc_roc: 0.5147
# Epoch 17/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3105 - accuracy: 0.5334 - auc_roc: 0.5697
# Epoch 18/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3062 - accuracy: 0.5335 - auc_roc: 0.5522
# Epoch 19/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3086 - accuracy: 0.5146 - auc_roc: 0.5594
# Epoch 20/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3093 - accuracy: 0.5217 - auc_roc: 0.5394
# Epoch 21/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3111 - accuracy: 0.5183 - auc_roc: 0.5648
# Epoch 22/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3104 - accuracy: 0.5357 - auc_roc: 0.5895
# Epoch 23/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3139 - accuracy: 0.5301 - auc_roc: 0.5594
# Epoch 24/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3128 - accuracy: 0.5402 - auc_roc: 0.5601
# Epoch 25/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3138 - accuracy: 0.5297 - auc_roc: 0.5449
# Epoch 26/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3152 - accuracy: 0.5077 - auc_roc: 0.5420
# Epoch 27/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3151 - accuracy: 0.5159 - auc_roc: 0.5190
# Epoch 28/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3163 - accuracy: 0.5444 - auc_roc: 0.5381
# Epoch 29/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3146 - accuracy: 0.5515 - auc_roc: 0.5776
# Epoch 30/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3147 - accuracy: 0.5231 - auc_roc: 0.5472
# Epoch 31/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3182 - accuracy: 0.5304 - auc_roc: 0.5729
# Epoch 32/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3186 - accuracy: 0.5395 - auc_roc: 0.5671
# Epoch 33/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3213 - accuracy: 0.4931 - auc_roc: 0.5121
# Epoch 34/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3201 - accuracy: 0.5296 - auc_roc: 0.5413
# Epoch 35/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3215 - accuracy: 0.5382 - auc_roc: 0.5679
# Epoch 36/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3217 - accuracy: 0.5302 - auc_roc: 0.5464
# Epoch 37/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3237 - accuracy: 0.5203 - auc_roc: 0.5391
# Epoch 38/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3267 - accuracy: 0.5186 - auc_roc: 0.4846
# Epoch 39/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3218 - accuracy: 0.5524 - auc_roc: 0.5746
# Epoch 40/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3218 - accuracy: 0.5352 - auc_roc: 0.5570
# Epoch 41/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3336 - accuracy: 0.5455 - auc_roc: 0.5479
# Epoch 42/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3300 - accuracy: 0.5448 - auc_roc: 0.5735
# Epoch 43/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3295 - accuracy: 0.5574 - auc_roc: 0.5700
# Epoch 44/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3328 - accuracy: 0.5409 - auc_roc: 0.5645
# Epoch 45/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3315 - accuracy: 0.5555 - auc_roc: 0.5815
# Epoch 46/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3342 - accuracy: 0.5377 - auc_roc: 0.5759
# Epoch 47/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3338 - accuracy: 0.5472 - auc_roc: 0.5634
# Epoch 48/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3366 - accuracy: 0.5496 - auc_roc: 0.5783
# Epoch 49/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3402 - accuracy: 0.5288 - auc_roc: 0.5448
# Epoch 50/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3382 - accuracy: 0.5612 - auc_roc: 0.5696
# Epoch 51/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3400 - accuracy: 0.5096 - auc_roc: 0.5761
# Epoch 52/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3425 - accuracy: 0.5510 - auc_roc: 0.5727
# Epoch 53/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3412 - accuracy: 0.5246 - auc_roc: 0.5593
# Epoch 54/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3494 - accuracy: 0.5147 - auc_roc: 0.5534
# Epoch 55/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3469 - accuracy: 0.5395 - auc_roc: 0.5566
# Epoch 56/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3515 - accuracy: 0.5228 - auc_roc: 0.5352
# Epoch 57/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3559 - accuracy: 0.5248 - auc_roc: 0.5414
# Epoch 58/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3550 - accuracy: 0.5142 - auc_roc: 0.5182
# Epoch 59/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3549 - accuracy: 0.5315 - auc_roc: 0.5417
# Epoch 60/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3474 - accuracy: 0.5464 - auc_roc: 0.5697
# Epoch 61/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3455 - accuracy: 0.5358 - auc_roc: 0.5305
# Epoch 62/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3479 - accuracy: 0.5538 - auc_roc: 0.5839
# Epoch 63/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3485 - accuracy: 0.5409 - auc_roc: 0.5620
# Epoch 64/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3534 - accuracy: 0.5309 - auc_roc: 0.5609
# Epoch 65/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3555 - accuracy: 0.5471 - auc_roc: 0.5614
# Epoch 66/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3600 - accuracy: 0.5452 - auc_roc: 0.5691
# Epoch 67/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3550 - accuracy: 0.5563 - auc_roc: 0.5705
# Epoch 68/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3701 - accuracy: 0.5223 - auc_roc: 0.5428
# Epoch 69/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3648 - accuracy: 0.5252 - auc_roc: 0.5518
# Epoch 70/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3644 - accuracy: 0.5590 - auc_roc: 0.5796
# Epoch 71/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3694 - accuracy: 0.5543 - auc_roc: 0.5733
# Epoch 72/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3714 - accuracy: 0.5340 - auc_roc: 0.5565
# Epoch 73/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3717 - accuracy: 0.5363 - auc_roc: 0.5483
# Epoch 74/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3719 - accuracy: 0.5391 - auc_roc: 0.5467
# Epoch 75/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3700 - accuracy: 0.5364 - auc_roc: 0.5653
# Epoch 76/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3736 - accuracy: 0.5458 - auc_roc: 0.5701
# Epoch 77/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3765 - accuracy: 0.5517 - auc_roc: 0.5807
# Epoch 78/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3767 - accuracy: 0.5198 - auc_roc: 0.5610
# Epoch 79/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3758 - accuracy: 0.5542 - auc_roc: 0.5875
# Epoch 80/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3730 - accuracy: 0.5595 - auc_roc: 0.5803
# Epoch 81/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3813 - accuracy: 0.5504 - auc_roc: 0.5625
# Epoch 82/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3821 - accuracy: 0.4990 - auc_roc: 0.5310
# Epoch 83/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3770 - accuracy: 0.5703 - auc_roc: 0.5952
# Epoch 84/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3823 - accuracy: 0.5389 - auc_roc: 0.5389
# Epoch 85/100
# 174/174 [==============================] - 0s 3ms/step - loss: 2.3821 - accuracy: 0.5435 - auc_roc: 0.5850
# Epoch 86/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3907 - accuracy: 0.5423 - auc_roc: 0.5871
# Epoch 87/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3946 - accuracy: 0.5363 - auc_roc: 0.5591
# Epoch 88/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3856 - accuracy: 0.5509 - auc_roc: 0.5839
# Epoch 89/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3972 - accuracy: 0.5556 - auc_roc: 0.5861
# Epoch 90/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3987 - accuracy: 0.5674 - auc_roc: 0.5728
# Epoch 91/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3961 - accuracy: 0.5711 - auc_roc: 0.6155
# Epoch 92/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3939 - accuracy: 0.5757 - auc_roc: 0.6148
# Epoch 93/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.4110 - accuracy: 0.5409 - auc_roc: 0.5630
# Epoch 94/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.4013 - accuracy: 0.5616 - auc_roc: 0.5919
# Epoch 95/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.4059 - accuracy: 0.5634 - auc_roc: 0.6081
# Epoch 96/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.3914 - accuracy: 0.6103 - auc_roc: 0.6507
# Epoch 97/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.4075 - accuracy: 0.5990 - auc_roc: 0.6117
# Epoch 98/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.4018 - accuracy: 0.5893 - auc_roc: 0.6127
# Epoch 99/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.4073 - accuracy: 0.5961 - auc_roc: 0.6259
# Epoch 100/100
# 174/174 [==============================] - 0s 2ms/step - loss: 2.4082 - accuracy: 0.6002 - auc_roc: 0.6386
# 82/82 [==============================] - 0s 452us/step
# 82/82 [==============================] - 0s 419us/step
# 0004
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Epoch 1/100
# 178/178 [==============================] - 1s 2ms/step - loss: 75.9934 - accuracy: 0.5182 - auc_roc: 0.5950
# Epoch 2/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.2958 - accuracy: 0.5105 - auc_roc: 0.5231
# Epoch 3/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.2968 - accuracy: 0.4972 - auc_roc: 0.5273
# Epoch 4/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.2963 - accuracy: 0.5237 - auc_roc: 0.5539
# Epoch 5/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.2999 - accuracy: 0.4938 - auc_roc: 0.5379
# Epoch 6/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.2994 - accuracy: 0.5223 - auc_roc: 0.5497
# Epoch 7/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3012 - accuracy: 0.5293 - auc_roc: 0.5607
# Epoch 8/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3054 - accuracy: 0.5224 - auc_roc: 0.5996
# Epoch 9/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3034 - accuracy: 0.5242 - auc_roc: 0.5570
# Epoch 10/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3032 - accuracy: 0.5370 - auc_roc: 0.5776
# Epoch 11/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3080 - accuracy: 0.5450 - auc_roc: 0.5629
# Epoch 12/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3061 - accuracy: 0.5587 - auc_roc: 0.5814
# Epoch 13/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3151 - accuracy: 0.5225 - auc_roc: 0.5305
# Epoch 14/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3106 - accuracy: 0.5320 - auc_roc: 0.5651
# Epoch 15/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3196 - accuracy: 0.5068 - auc_roc: 0.5497
# Epoch 16/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3093 - accuracy: 0.5343 - auc_roc: 0.5622
# Epoch 17/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3208 - accuracy: 0.5267 - auc_roc: 0.5573
# Epoch 18/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3128 - accuracy: 0.5468 - auc_roc: 0.5604
# Epoch 19/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3175 - accuracy: 0.5126 - auc_roc: 0.5529
# Epoch 20/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3147 - accuracy: 0.5546 - auc_roc: 0.5908
# Epoch 21/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3215 - accuracy: 0.5318 - auc_roc: 0.5670
# Epoch 22/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3245 - accuracy: 0.5447 - auc_roc: 0.5659
# Epoch 23/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3211 - accuracy: 0.5476 - auc_roc: 0.5788
# Epoch 24/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3267 - accuracy: 0.5670 - auc_roc: 0.5822
# Epoch 25/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3284 - accuracy: 0.5474 - auc_roc: 0.5787
# Epoch 26/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3307 - accuracy: 0.5312 - auc_roc: 0.5276
# Epoch 27/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3274 - accuracy: 0.5678 - auc_roc: 0.5904
# Epoch 28/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3276 - accuracy: 0.5451 - auc_roc: 0.5898
# Epoch 29/100
# 178/178 [==============================] - 1s 3ms/step - loss: 2.3347 - accuracy: 0.5360 - auc_roc: 0.5745
# Epoch 30/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3367 - accuracy: 0.5381 - auc_roc: 0.5773
# Epoch 31/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3300 - accuracy: 0.5709 - auc_roc: 0.5948
# Epoch 32/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3366 - accuracy: 0.5493 - auc_roc: 0.6029
# Epoch 33/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3350 - accuracy: 0.5473 - auc_roc: 0.5546
# Epoch 34/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3477 - accuracy: 0.5357 - auc_roc: 0.5614
# Epoch 35/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3571 - accuracy: 0.5446 - auc_roc: 0.5862
# Epoch 36/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3616 - accuracy: 0.5254 - auc_roc: 0.5397
# Epoch 37/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3449 - accuracy: 0.5575 - auc_roc: 0.5839
# Epoch 38/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3536 - accuracy: 0.5229 - auc_roc: 0.5528
# Epoch 39/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3458 - accuracy: 0.5520 - auc_roc: 0.5781
# Epoch 40/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3504 - accuracy: 0.5603 - auc_roc: 0.6094
# Epoch 41/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3488 - accuracy: 0.5390 - auc_roc: 0.5497
# Epoch 42/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3499 - accuracy: 0.5623 - auc_roc: 0.5833
# Epoch 43/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3620 - accuracy: 0.5411 - auc_roc: 0.5771
# Epoch 44/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3716 - accuracy: 0.5801 - auc_roc: 0.6100
# Epoch 45/100
# 178/178 [==============================] - 0s 3ms/step - loss: 2.3672 - accuracy: 0.5598 - auc_roc: 0.5930
# Epoch 46/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3668 - accuracy: 0.5537 - auc_roc: 0.5738
# Epoch 47/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3764 - accuracy: 0.5204 - auc_roc: 0.5532
# Epoch 48/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3586 - accuracy: 0.5718 - auc_roc: 0.5962
# Epoch 49/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3724 - accuracy: 0.5474 - auc_roc: 0.5626
# Epoch 50/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3827 - accuracy: 0.5409 - auc_roc: 0.5620
# Epoch 51/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3770 - accuracy: 0.5526 - auc_roc: 0.5817
# Epoch 52/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3911 - accuracy: 0.5571 - auc_roc: 0.5689
# Epoch 53/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3683 - accuracy: 0.5964 - auc_roc: 0.6013
# Epoch 54/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3894 - accuracy: 0.5562 - auc_roc: 0.5864
# Epoch 55/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3981 - accuracy: 0.5767 - auc_roc: 0.6064
# Epoch 56/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3984 - accuracy: 0.5574 - auc_roc: 0.5899
# Epoch 57/100
# 178/178 [==============================] - 0s 3ms/step - loss: 2.4034 - accuracy: 0.5822 - auc_roc: 0.5936
# Epoch 58/100
# 178/178 [==============================] - 0s 3ms/step - loss: 2.4116 - accuracy: 0.5729 - auc_roc: 0.5942
# Epoch 59/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4001 - accuracy: 0.5764 - auc_roc: 0.6115
# Epoch 60/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4062 - accuracy: 0.5704 - auc_roc: 0.6028
# Epoch 61/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.3989 - accuracy: 0.5742 - auc_roc: 0.6160
# Epoch 62/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4088 - accuracy: 0.5680 - auc_roc: 0.6199
# Epoch 63/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4143 - accuracy: 0.5896 - auc_roc: 0.6035
# Epoch 64/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4204 - accuracy: 0.5841 - auc_roc: 0.6178
# Epoch 65/100
# 178/178 [==============================] - 0s 3ms/step - loss: 2.4220 - accuracy: 0.5973 - auc_roc: 0.6437
# Epoch 66/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4110 - accuracy: 0.5923 - auc_roc: 0.6487
# Epoch 67/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4205 - accuracy: 0.6044 - auc_roc: 0.6483
# Epoch 68/100
# 178/178 [==============================] - 0s 3ms/step - loss: 2.4553 - accuracy: 0.6083 - auc_roc: 0.6405
# Epoch 69/100
# 178/178 [==============================] - 1s 3ms/step - loss: 2.4321 - accuracy: 0.6001 - auc_roc: 0.6444
# Epoch 70/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4283 - accuracy: 0.6317 - auc_roc: 0.6663
# Epoch 71/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4431 - accuracy: 0.6272 - auc_roc: 0.6760
# Epoch 72/100
# 178/178 [==============================] - 0s 3ms/step - loss: 2.4297 - accuracy: 0.6231 - auc_roc: 0.6704
# Epoch 73/100
# 178/178 [==============================] - 0s 2ms/step - loss: 2.4146 - accuracy: 0.6299 - auc_roc: 0.6657
# Epoch 74/100
# ...
# Epoch 76/100
# 264/264 [==============================] - 1s 3ms/step - loss: 0.9034 - accuracy: 0.7258 - auc_roc: 0.6940
# Epoch 77/100
# 264/264 [==============================] - 1s 3ms/step - loss: 0.8997 - accuracy: 0.7249 - auc_roc: 0.6946
# Epoch 78/100
# 264/264 [==============================] - 1s 3ms/step - loss: 0.9061 - accuracy: 0.7197 - auc_roc: 0.6696
# Epoch 79/100
# 264/264 [==============================] - 1s 3ms/step - loss: 0.9011 - accuracy: 0.7235 - auc_roc: 0.6910
# Epoch 80/100
# 264/264 [==============================] - 1s 3ms/step - loss: 0.9033 - accuracy: 0.7187 - auc_roc: 0.6880
# Epoch 81/100
# 264/264 [==============================] - 1s 3ms/step - loss: 0.8734 - accuracy: 0.7416 - auc_roc: 0.7186
# Epoch 82/100
# 264/264 [==============================] - 1s 3ms/step - loss: 0.8987 - accuracy: 0.7310 - auc_roc: 0.6745
# Epoch 83/100
# 264/264 [==============================] - 1s 3ms/step - loss: 0.9026 - accuracy: 0.7124 - auc_roc: 0.7000
# Epoch 84/100
# 264/264 [==============================] - 1s 3ms/step - loss: 0.8760 - accuracy: 0.7364 - auc_roc: 0.6989
# Epoch 85/100
# 264/264 [==============================] - 1s 3ms/step - loss: 0.9020 - accuracy: 0.7135 - auc_roc: 0.6913
# Epoch 86/100
# 264/264 [==============================] - 1s 3ms/step - loss: 0.9007 - accuracy: 0.7238 - auc_roc: 0.6724
# Epoch 87/100
# 264/264 [==============================] - 1s 3ms/step - loss: 0.8874 - accuracy: 0.7327 - auc_roc: 0.6763
# Epoch 88/100
# 264/264 [==============================] - 1s 3ms/step - loss: 0.8722 - accuracy: 0.7473 - auc_roc: 0.6912
# Epoch 89/100
# 264/264 [==============================] - 1s 3ms/step - loss: 0.9187 - accuracy: 0.7099 - auc_roc: 0.6706
# Epoch 90/100
# 264/264 [==============================] - 1s 3ms/step - loss: 0.8919 - accuracy: 0.7244 - auc_roc: 0.6724
# Epoch 91/100
# 264/264 [==============================] - 1s 3ms/step - loss: 0.8819 - accuracy: 0.7319 - auc_roc: 0.6919
# Epoch 92/100
# 264/264 [==============================] - 1s 3ms/step - loss: 0.9035 - accuracy: 0.7154 - auc_roc: 0.6566
# Epoch 93/100
# 264/264 [==============================] - 1s 3ms/step - loss: 0.8866 - accuracy: 0.7403 - auc_roc: 0.6743
# Epoch 94/100
# 264/264 [==============================] - 1s 3ms/step - loss: 0.8904 - accuracy: 0.7230 - auc_roc: 0.6734
# Epoch 95/100
# 264/264 [==============================] - 1s 3ms/step - loss: 0.8979 - accuracy: 0.7165 - auc_roc: 0.6847
# Epoch 96/100
# 264/264 [==============================] - 1s 3ms/step - loss: 0.9036 - accuracy: 0.7236 - auc_roc: 0.6674
# Epoch 97/100
# 264/264 [==============================] - 1s 3ms/step - loss: 0.9158 - accuracy: 0.6995 - auc_roc: 0.6753
# Epoch 98/100
# 264/264 [==============================] - 1s 3ms/step - loss: 0.8827 - accuracy: 0.7295 - auc_roc: 0.6892
# Epoch 99/100
# 264/264 [==============================] - 1s 3ms/step - loss: 0.8880 - accuracy: 0.7215 - auc_roc: 0.6966
# Epoch 100/100
# 264/264 [==============================] - 1s 3ms/step - loss: 0.8923 - accuracy: 0.7094 - auc_roc: 0.6895
# 82/82 [==============================] - 0s 460us/step
# 82/82 [==============================] - 0s 434us/step
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# 0141 Epoch 1/100
# 221/221 [==============================] - 1s 2ms/step - loss: 56.3416 - accuracy: 0.6150 - auc_roc: 0.7151
# Epoch 2/100
# 221/221 [==============================] - 0s 2ms/step - loss: 2.3757 - accuracy: 0.6182 - auc_roc: 0.6618
# Epoch 3/100
# 221/221 [==============================] - 0s 2ms/step - loss: 2.3498 - accuracy: 0.6389 - auc_roc: 0.6751
# Epoch 4/100
# 221/221 [==============================] - 0s 2ms/step - loss: 2.3598 - accuracy: 0.6547 - auc_roc: 0.7074
# Epoch 5/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3387 - accuracy: 0.6546 - auc_roc: 0.6978
# Epoch 6/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3509 - accuracy: 0.6606 - auc_roc: 0.7006
# Epoch 7/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3658 - accuracy: 0.6365 - auc_roc: 0.6677
# Epoch 8/100
# 221/221 [==============================] - 0s 2ms/step - loss: 2.3483 - accuracy: 0.6552 - auc_roc: 0.6878
# Epoch 9/100
# 221/221 [==============================] - 0s 2ms/step - loss: 2.3570 - accuracy: 0.6589 - auc_roc: 0.6955
# Epoch 10/100
# 221/221 [==============================] - 0s 2ms/step - loss: 2.3401 - accuracy: 0.6675 - auc_roc: 0.7027
# Epoch 11/100
# 221/221 [==============================] - 0s 2ms/step - loss: 2.3472 - accuracy: 0.6647 - auc_roc: 0.7149
# Epoch 12/100
# 221/221 [==============================] - 0s 2ms/step - loss: 2.3784 - accuracy: 0.6420 - auc_roc: 0.6991
# Epoch 13/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3623 - accuracy: 0.6516 - auc_roc: 0.7018
# Epoch 14/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3703 - accuracy: 0.6721 - auc_roc: 0.7135
# Epoch 15/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3610 - accuracy: 0.6569 - auc_roc: 0.6939
# Epoch 16/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3677 - accuracy: 0.6485 - auc_roc: 0.7018
# Epoch 17/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3616 - accuracy: 0.6595 - auc_roc: 0.7092
# Epoch 18/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3977 - accuracy: 0.6670 - auc_roc: 0.7181
# Epoch 19/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3741 - accuracy: 0.6612 - auc_roc: 0.7035
# Epoch 20/100
# 221/221 [==============================] - 1s 3ms/step - loss: 2.3538 - accuracy: 0.6540 - auc_roc: 0.7032
# Epoch 21/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3519 - accuracy: 0.6783 - auc_roc: 0.7051
# Epoch 22/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3602 - accuracy: 0.6594 - auc_roc: 0.7057
# Epoch 23/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3844 - accuracy: 0.6583 - auc_roc: 0.7151
# Epoch 24/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3535 - accuracy: 0.6440 - auc_roc: 0.6930
# Epoch 25/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3489 - accuracy: 0.6479 - auc_roc: 0.6869
# Epoch 26/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3702 - accuracy: 0.6536 - auc_roc: 0.7005
# Epoch 27/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3368 - accuracy: 0.6713 - auc_roc: 0.7162
# Epoch 28/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3381 - accuracy: 0.6587 - auc_roc: 0.7151
# Epoch 29/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3584 - accuracy: 0.6629 - auc_roc: 0.6977
# Epoch 30/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3622 - accuracy: 0.6698 - auc_roc: 0.7003
# Epoch 31/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3580 - accuracy: 0.6603 - auc_roc: 0.7066
# Epoch 32/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3667 - accuracy: 0.6584 - auc_roc: 0.7058
# Epoch 33/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3642 - accuracy: 0.6607 - auc_roc: 0.6936
# Epoch 34/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3534 - accuracy: 0.6669 - auc_roc: 0.7057
# Epoch 35/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3301 - accuracy: 0.6724 - auc_roc: 0.7169
# Epoch 36/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3715 - accuracy: 0.6502 - auc_roc: 0.6839
# Epoch 37/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3408 - accuracy: 0.6700 - auc_roc: 0.7283
# Epoch 38/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3542 - accuracy: 0.6599 - auc_roc: 0.7077
# Epoch 39/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3692 - accuracy: 0.6426 - auc_roc: 0.6874
# Epoch 40/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3601 - accuracy: 0.6672 - auc_roc: 0.7059
# Epoch 41/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3624 - accuracy: 0.6695 - auc_roc: 0.7157
# Epoch 42/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3502 - accuracy: 0.6748 - auc_roc: 0.7149
# Epoch 43/100
# 221/221 [==============================] - 0s 2ms/step - loss: 2.3390 - accuracy: 0.6674 - auc_roc: 0.7211
# Epoch 44/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3506 - accuracy: 0.6817 - auc_roc: 0.7169
# Epoch 45/100
# 221/221 [==============================] - 0s 2ms/step - loss: 2.3731 - accuracy: 0.6465 - auc_roc: 0.6874
# Epoch 46/100
# 221/221 [==============================] - 0s 2ms/step - loss: 2.3880 - accuracy: 0.6390 - auc_roc: 0.6910
# Epoch 47/100
# 221/221 [==============================] - 0s 2ms/step - loss: 2.3505 - accuracy: 0.6826 - auc_roc: 0.7372
# Epoch 48/100
# 221/221 [==============================] - 0s 2ms/step - loss: 2.3606 - accuracy: 0.6529 - auc_roc: 0.6930
# Epoch 49/100
# 221/221 [==============================] - 0s 2ms/step - loss: 2.3405 - accuracy: 0.6661 - auc_roc: 0.7212
# Epoch 50/100
# 221/221 [==============================] - 0s 2ms/step - loss: 2.3547 - accuracy: 0.6845 - auc_roc: 0.7209
# Epoch 51/100
# 221/221 [==============================] - 0s 2ms/step - loss: 2.3652 - accuracy: 0.6532 - auc_roc: 0.7010
# Epoch 52/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3510 - accuracy: 0.6623 - auc_roc: 0.7006
# Epoch 53/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3599 - accuracy: 0.6725 - auc_roc: 0.7028
# Epoch 54/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3321 - accuracy: 0.6764 - auc_roc: 0.7142
# Epoch 55/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3446 - accuracy: 0.6751 - auc_roc: 0.7114
# Epoch 56/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3295 - accuracy: 0.6616 - auc_roc: 0.7099
# Epoch 57/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3449 - accuracy: 0.6592 - auc_roc: 0.6926
# Epoch 58/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3441 - accuracy: 0.6599 - auc_roc: 0.6952
# Epoch 59/100
# 221/221 [==============================] - 0s 2ms/step - loss: 2.3438 - accuracy: 0.6656 - auc_roc: 0.6824
# Epoch 60/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3499 - accuracy: 0.6483 - auc_roc: 0.6918
# Epoch 61/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3529 - accuracy: 0.6779 - auc_roc: 0.7144
# Epoch 62/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3512 - accuracy: 0.6643 - auc_roc: 0.7148
# Epoch 63/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3513 - accuracy: 0.6698 - auc_roc: 0.7112
# Epoch 64/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3431 - accuracy: 0.6834 - auc_roc: 0.7293
# Epoch 65/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3803 - accuracy: 0.6676 - auc_roc: 0.7014
# Epoch 66/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3356 - accuracy: 0.6761 - auc_roc: 0.7125
# Epoch 67/100
# 221/221 [==============================] - 1s 3ms/step - loss: 2.3287 - accuracy: 0.6703 - auc_roc: 0.7230
# Epoch 68/100
# 221/221 [==============================] - 1s 3ms/step - loss: 2.3481 - accuracy: 0.6550 - auc_roc: 0.6989
# Epoch 69/100
# 221/221 [==============================] - 1s 3ms/step - loss: 2.3706 - accuracy: 0.6611 - auc_roc: 0.6944
# Epoch 70/100
# 221/221 [==============================] - 1s 3ms/step - loss: 2.3553 - accuracy: 0.6733 - auc_roc: 0.7061
# Epoch 71/100
# 221/221 [==============================] - 1s 3ms/step - loss: 2.3579 - accuracy: 0.6470 - auc_roc: 0.6918
# Epoch 72/100
# 221/221 [==============================] - 1s 3ms/step - loss: 2.3619 - accuracy: 0.6518 - auc_roc: 0.7033
# Epoch 73/100
# 221/221 [==============================] - 1s 3ms/step - loss: 2.3800 - accuracy: 0.6621 - auc_roc: 0.7085
# Epoch 74/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3507 - accuracy: 0.6780 - auc_roc: 0.7132
# Epoch 75/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3482 - accuracy: 0.6716 - auc_roc: 0.6983
# Epoch 76/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3614 - accuracy: 0.6828 - auc_roc: 0.7246
# Epoch 77/100
# 221/221 [==============================] - 1s 3ms/step - loss: 2.3567 - accuracy: 0.6793 - auc_roc: 0.7274
# Epoch 78/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3641 - accuracy: 0.6561 - auc_roc: 0.7112
# Epoch 79/100
# 221/221 [==============================] - 0s 2ms/step - loss: 2.3446 - accuracy: 0.6568 - auc_roc: 0.6854
# Epoch 80/100
# 221/221 [==============================] - 0s 2ms/step - loss: 2.4075 - accuracy: 0.6654 - auc_roc: 0.7058
# Epoch 81/100
# 221/221 [==============================] - 0s 2ms/step - loss: 2.3550 - accuracy: 0.6581 - auc_roc: 0.7135
# Epoch 82/100
# 221/221 [==============================] - 0s 2ms/step - loss: 2.3374 - accuracy: 0.6605 - auc_roc: 0.7183
# Epoch 83/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3520 - accuracy: 0.6681 - auc_roc: 0.7079
# Epoch 84/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3474 - accuracy: 0.6409 - auc_roc: 0.6876
# Epoch 85/100
# 221/221 [==============================] - 1s 3ms/step - loss: 2.3486 - accuracy: 0.6653 - auc_roc: 0.7110
# Epoch 86/100
# 221/221 [==============================] - 1s 3ms/step - loss: 2.3490 - accuracy: 0.6471 - auc_roc: 0.7022
# Epoch 87/100
# 221/221 [==============================] - 1s 3ms/step - loss: 2.3422 - accuracy: 0.6651 - auc_roc: 0.7110
# Epoch 88/100
# 221/221 [==============================] - 1s 3ms/step - loss: 2.3700 - accuracy: 0.6643 - auc_roc: 0.7076
# Epoch 89/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3364 - accuracy: 0.6447 - auc_roc: 0.6842
# Epoch 90/100
# 221/221 [==============================] - 1s 3ms/step - loss: 2.3485 - accuracy: 0.6617 - auc_roc: 0.6954
# Epoch 91/100
# 221/221 [==============================] - 0s 2ms/step - loss: 2.3451 - accuracy: 0.6561 - auc_roc: 0.6927
# Epoch 92/100
# 221/221 [==============================] - 0s 2ms/step - loss: 2.3607 - accuracy: 0.6502 - auc_roc: 0.6999
# Epoch 93/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3539 - accuracy: 0.6750 - auc_roc: 0.7154
# Epoch 94/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3187 - accuracy: 0.6820 - auc_roc: 0.7413
# Epoch 95/100
# 221/221 [==============================] - 0s 2ms/step - loss: 2.3636 - accuracy: 0.6464 - auc_roc: 0.6944
# Epoch 96/100
# 221/221 [==============================] - 0s 2ms/step - loss: 2.3348 - accuracy: 0.6595 - auc_roc: 0.7104
# Epoch 97/100
# 221/221 [==============================] - 0s 2ms/step - loss: 2.3384 - accuracy: 0.6591 - auc_roc: 0.7111
# Epoch 98/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3408 - accuracy: 0.6669 - auc_roc: 0.7124
# Epoch 99/100
# 221/221 [==============================] - 0s 2ms/step - loss: 2.3271 - accuracy: 0.6667 - auc_roc: 0.7082
# Epoch 100/100
# 221/221 [==============================] - 1s 2ms/step - loss: 2.3481 - accuracy: 0.6561 - auc_roc: 0.6954

# %%
# top 20 performers by the test_roc_auc score
#,'param_model__max_features'
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
#res_cols = ['mean_test_roc_auc', 'mean_test_accuracy', 'param_balance__balancer_type', 'param_features__k', 
#            'param_features__score_func', 'param_model__C', 'param_model__solver', 
#            'param_outlier__outlier_threshold', 'param__vif_score_threshold']
#res_cols = ['mean_test_roc_auc','mean_test_accuracy', 'param_balance__balancer_type', 'param_model__batch_size','param_model__epochs','param_model__optimizer',
            #'param_outlier__outlier_threshold']
res_cols = ['mean_test_roc_auc','mean_test_accuracy', 'param_balance__balancer_type','param_model__optimizer',
            'param_outlier__outlier_threshold']
df_sorted = df_result[res_cols].reset_index(drop=True).sort_values('mean_test_roc_auc', axis=0, ascending=False)
df_sorted.index = pd.RangeIndex(1, len(df_sorted.index)+1)
df_sorted
# Out:
#     mean_test_roc_auc  mean_test_accuracy param_balance__balancer_type  \
# 1            0.638202            0.593717                       allknn
# 2            0.624293            0.617778                       allknn
# 3            0.623800            0.345190                    smote-enn
# 4            0.615825            0.345885                    smote-enn
# 5            0.615038            0.273060                    smote-enn
# 6            0.614866            0.291442                    smote-enn
# 7            0.609630            0.284839                    smote-enn
# 8            0.606852            0.618003                       allknn
# 9            0.603253            0.276001                    smote-enn
# 10           0.600799            0.273060                    smote-enn
# 11           0.599107            0.574706                       allknn
# 12           0.591507            0.282886                    smote-enn
# 13           0.582298            0.557738                       allknn
# 14           0.581673            0.425452                       allknn
# 15           0.581287            0.273060                    smote-enn
# 16           0.571299            0.273060                    smote-enn
# 17           0.566331            0.273060                    smote-enn
# 18           0.565877            0.273060                    smote-enn
# 19           0.564654            0.495225                       allknn
# 20           0.555204            0.457887                       allknn
# 21           0.542828            0.547147                       allknn
# 22           0.540849            0.544661                       allknn
# 23           0.533658            0.419808                       allknn
# 24           0.529364            0.359686                       allknn
# 25           0.512796            0.361649                       allknn
# 26           0.511576            0.359686                       allknn
# 27           0.507545            0.273060                    smote-enn
# 28           0.493980            0.273060                    smote-enn
#
#    param_model__optimizer param_outlier__outlier_threshold
# 1                 RMSprop                                0
# 2                 RMSprop                                3
# 3                  Adamax                                0
# 4                  Adamax                                3
# 5                 RMSprop                                3
# 6                    Adam                                3
# 7                    Adam                                0
# 8                   Nadam                                3
# 9                   Nadam                                3
# 10                RMSprop                                0
# 11               Adadelta                                3
# 12                  Nadam                                0
# 13                   Adam                                3
# 14                 Adamax                                0
# 15               Adadelta                                3
# 16               Adadelta                                0
# 17                Adagrad                                3
# 18                    SGD                                3
# 19                  Nadam                                0
# 20               Adadelta                                0
# 21                    SGD                                0
# 22                    SGD                                3
# 23                   Adam                                0
# 24                Adagrad                                3
# 25                Adagrad                                0
# 26                 Adamax                                3
# 27                Adagrad                                0
# 28                    SGD                                0

# %%
# the average roc-auc and accuracy scores of just completed search.
# these are the averages of each model over the convolution folds.
#print(df_result['mean_test_roc_auc'])
#print(df_result['mean_test_accuracy'])
print(best_params)
# Out:
# {'balance__balancer_type': 'allknn', 'model__optimizer': 'RMSprop', 'outlier__outlier_threshold': 0.0, 'scaling__type_of_scaling': 'standard'}

# %%
# display results for the best estimator we found
predictions = best_estimator.predict(df_features)
probabilities = best_estimator.predict_proba(df_features)[:,1]
mindwandering.evaluate.evaluate_model_results(mind_wandered_label, predictions, probabilities)
# Out:
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# 408/408 [==============================] - 0s 443us/step
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# 408/408 [==============================] - 0s 439us/step
# Accuracy score:         0.6081943081452404
# Recall (TPR) score:     0.5876010781671159
# Precision score:        0.36495535714285715
# AUC-ROC score:          0.6017654395223024
#
# True positives:   654
# True negatives:   1825
# False positives:  1138
# False negatives:  459
# True Positive Rate (recall):  0.5876010781671159
# False Positive Rate:          0.38407019912251095
# Specificity:                  0.615929800877489
#
# [[1825 1138]
#  [ 459  654]]

# %%
"""# save the results and preliminary figures in the following cells

# create base save file name for this file, use datetime to keep a unique file name
now = datetime.now()
date_time = now.strftime('%Y%m%d-%H%M')
result_file_basename = 'replication-09-Neural-Network-RMSProp-variation1-latest' + date_time
print(result_file_basename)"""
# Out:
# "# save the results and preliminary figures in the following cells\n\n# create base save file name for this file, use datetime to keep a unique file name\nnow = datetime.now()\ndate_time = now.strftime('%Y%m%d-%H%M')\nresult_file_basename = 'replication-09-Neural-Network-RMSProp-variation1-latest' + date_time\nprint(result_file_basename)"

# %%
# A quick histogram of this search auc-roc scores.  Basically the figure 1 from the paper.
plt.figure(figsize=(12,8))

#bins = np.linspace(0.605, 0.612, 8)
plt.hist(df_result.mean_test_roc_auc, 
         bins=20,
         color='lightblue',
         rwidth=0.9);
#plt.xlabel('Area under the receiver operating characteristic (AUC-ROC)');
plt.xlabel('Area under the receiver operating characteristic (AUC-ROC)');
plt.ylabel('Number of models');
plt.title('Neural Network Replication Experiment using RMSProp variation1 Latest: ' + result_file_basename);

"""result_dir = '../figures'
result_file_name = result_file_basename + '.eps'
result_file_path = os.path.join(result_dir, result_file_name)
plt.savefig(result_file_path)"""
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-2d037b96a64c> in <module>
#      10 plt.xlabel('Area under the receiver operating characteristic (AUC-ROC)');
#      11 plt.ylabel('Number of models');
# ---> 12 plt.title('Neural Network Replication Experiment using RMSProp variation1 Latest: ' + result_file_basename);
#      13
#      14 """result_dir = '../figures'
#
# NameError: name 'result_file_basename' is not defined
