# %% [markdown]
# - mean_test_auc_roc using Logistic Regression:
# - mean_test_auc_roc using KNN:0.631033
# - mean_test_auc_roc using SVM:0.658805
# - mean_test_auc_roc using Random Forest:0.657398
# - mean_test_auc_roc using Decision Tree:0.640888
# - mean_test_auc_roc using **Naive Bayes:0.659468**
# - mean_test_auc_roc using Neural Network(Adam):0.634302
# - mean_test_auc_roc using Neural Network(SGD):0.630862
# - mean_test_auc_roc using Neural Network(RMSprop):0.629448

# %%
# globally useful imports of standard libraries needed in this notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os.path
from datetime import datetime

# specific libraries or classes needed for the work in this notebook
#from sklearn.linear_model import LogisticRegression
#from sklearn.linear_model import LogisticRegressionCV
#from sklearn.svm import SVC
#from sklearn.naive_bayes import GaussianNB
#from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GroupKFold
from sklearn.model_selection import LeaveOneGroupOut
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import SelectKBest, f_classif, chi2, SelectFpr, f_regression, mutual_info_classif
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import RFE
from sklearn.feature_selection import VarianceThreshold
from sklearn.ensemble import ExtraTreesClassifier
#from sklearn.pipeline import Pipeline
# need to use Pipeline from imblearn to add in a downsample or upsample
# to cross validation training
from imblearn.pipeline import Pipeline

# import project specific modules used in this notebook
import sys
sys.path.append('../src')
import mindwandering.data
import mindwandering.features
import mindwandering.evaluate
from mindwandering.data import FeatureScalerTransformer
from mindwandering.data import WinsorizationOutlierTransformer
from mindwandering.data import VIFThresholdTransformer
from mindwandering.data import FeatureSelectionTransformer
from mindwandering.data import ClassImbalanceTransformer
from mindwandering.data import GridSearchProgressHack


from sklearn.preprocessing import StandardScaler

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.layers import Input, Dense, Activation, Dropout, BatchNormalization,Flatten
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import SGD,Adam,RMSprop
from tensorflow.keras.layers import Conv1D,GRU,TimeDistributed,MaxPooling1D

# %%
# Load Data and Features
df_features = mindwandering.data.get_df_features()
mind_wandered_label = mindwandering.data.get_mind_wandered_label()
participant_ids = mindwandering.data.get_participant_ids()

# %%
df_features = df_features.to_numpy()
df_features=df_features.reshape((df_features.shape[0], df_features.shape[1], 1))
df_features.shape
# Out:
# (4076, 62, 1)

# %%
import tensorflow
auc_roc = tensorflow.keras.metrics.AUC(name='auc_roc',num_thresholds=20000,curve='ROC')

# %%
def create_model():
    model = Sequential([
    Conv1D(filters=64, kernel_size=5, activation='tanh',padding='same', input_shape=(df_features.shape[1], 1)),
    MaxPooling1D(pool_size=2), 
    GRU(20, return_sequences=True),
    GRU(20, return_sequences=True),
    Conv1D(filters=32, kernel_size=3, activation='tanh'),
    Flatten(),
    Dense(1, activation='swish'),
    Activation('sigmoid')])
    optimizer=SGD(lr=0.001)
    model.compile(loss='binary_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy', auc_roc])
    return model

# %%
# Wrap Keras model so it can be used by scikit-learn
#kears_estimator = KerasClassifier(build_fn=create_model,epochs=100, batch_size=32, verbose=1)
kears_estimator = KerasClassifier(build_fn=create_model,epochs=50, batch_size=32, verbose=1)
#kears_estimator = KerasClassifier(build_fn=create_model, verbose=1)

# %%
# Empty dataframe to gather grid search results into 1 place
best_estimator = None
best_score = 0.0
best_params = {}
best_index = 0
df_result = None


parameters = {
        #'scaling__type_of_scaling': ['standard'],
        #'outlier__outlier_threshold': [0.0, 3.0],
        #'features__k': [12],
        #'balance__balancer_type': ['random-undersampler', 'allknn', 'nearmiss', 'instance-hardness-threshold'],
        #'balance__balancer_type': ['allknn', 'condensed-nn', 'neighbourhood-cleaning', 'one-sided-selection'],
        #'balance__balancer_type': ['allknn', 'one-sided-selection'],
        #'balance__balancer_type': ['allknn', 'smote-enn'],
        #'model__var_smoothing': [1e-6,1e-7,1e-8,1e-9,1e-10,1e-11,1e-12],
        #'model__batch_size': [8, 16, 24, 32, 40, 48],#usually multiple of 8
        'model__epochs':[50],
        #'model__batch_size': [60],
        #'model__epochs':[10],
        #'model__optimizer' : ['RMSprop', 'Adagrad', 'Adadelta','Adam']
    }

# Estimator Pipeline
pipeline = Pipeline(
      [
        #('progress', GridSearchProgressHack(verbose=False)),
        #('scaling',  FeatureScalerTransformer()),
        #('outlier',  WinsorizationOutlierTransformer()),
        #('features', SelectKBest()),
        #('features', SelectFromModel(estimator=LogisticRegression(solver='liblinear', penalty='l1', C=0.1), threshold=-np.inf)),
        #('balance',  ClassImbalanceTransformer()),
        ('model',    kears_estimator)
      ]
    )
    
# Cross Validation Splitter
cv_group_splitter = GroupKFold(n_splits=5)
    #cv_group_splitter = LeaveOneGroupOut()

    # perform the grid search for this vif selection
    # set up the search
search = GridSearchCV(
        estimator = pipeline,
        param_grid = parameters,
        scoring = ['roc_auc','accuracy'],
        cv = cv_group_splitter,
        refit = 'roc_auc',
        verbose = 1)

search.fit(df_features, mind_wandered_label, groups=participant_ids)

df = pd.DataFrame(data=search.cv_results_)
    
    
if best_estimator is None:
    df_result = df
    best_estimator = search.best_estimator_
    best_score = search.best_score_
    best_params = search.best_params_
    best_index = search.best_index_
else:
    df_result = df_result.append(df, ignore_index=True)
    if search.best_score_ > best_score:
        best_estimator = search.best_estimator_
        best_score = search.best_score_
        best_params = search.best_params_
        best_index = search.best_index_  # todo this is only the index of this search
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Epoch 1/50
# 102/102 [==============================] - 4s 21ms/step - loss: 0.6493 - accuracy: 0.7160 - auc_roc: 0.5099
# Epoch 2/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6408 - accuracy: 0.7292 - auc_roc: 0.5295
# Epoch 3/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6400 - accuracy: 0.7280 - auc_roc: 0.5008
# Epoch 4/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6401 - accuracy: 0.7263 - auc_roc: 0.5213
# Epoch 5/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6434 - accuracy: 0.7140 - auc_roc: 0.5081
# Epoch 6/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6390 - accuracy: 0.7296 - auc_roc: 0.5401
# Epoch 7/50
# 102/102 [==============================] - 2s 21ms/step - loss: 0.6396 - accuracy: 0.7273 - auc_roc: 0.5163
# Epoch 8/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6404 - accuracy: 0.7244 - auc_roc: 0.5283
# Epoch 9/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6461 - accuracy: 0.7040 - auc_roc: 0.5054
# Epoch 10/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6390 - accuracy: 0.7293 - auc_roc: 0.5044
# Epoch 11/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6386 - accuracy: 0.7310 - auc_roc: 0.5079
# Epoch 12/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6361 - accuracy: 0.7398 - auc_roc: 0.5187
# Epoch 13/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6384 - accuracy: 0.7317 - auc_roc: 0.5079
# Epoch 14/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6407 - accuracy: 0.7231 - auc_roc: 0.5091
# Epoch 15/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6390 - accuracy: 0.7294 - auc_roc: 0.4948
# Epoch 16/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6393 - accuracy: 0.7282 - auc_roc: 0.5064
# Epoch 17/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6408 - accuracy: 0.7228 - auc_roc: 0.5218
# Epoch 18/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6363 - accuracy: 0.7390 - auc_roc: 0.5265
# Epoch 19/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6422 - accuracy: 0.7179 - auc_roc: 0.5122
# Epoch 20/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6444 - accuracy: 0.7098 - auc_roc: 0.5190
# Epoch 21/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6425 - accuracy: 0.7168 - auc_roc: 0.5027
# Epoch 22/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6380 - accuracy: 0.7328 - auc_roc: 0.5054
# Epoch 23/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6400 - accuracy: 0.7257 - auc_roc: 0.5251
# Epoch 24/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6404 - accuracy: 0.7245 - auc_roc: 0.5121
# Epoch 25/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6417 - accuracy: 0.7198 - auc_roc: 0.5365
# Epoch 26/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6348 - accuracy: 0.7445 - auc_roc: 0.5056
# Epoch 27/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6391 - accuracy: 0.7290 - auc_roc: 0.5239
# Epoch 28/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6412 - accuracy: 0.7213 - auc_roc: 0.5115
# Epoch 29/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6447 - accuracy: 0.7087 - auc_roc: 0.4985
# Epoch 30/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6397 - accuracy: 0.7269 - auc_roc: 0.5152
# Epoch 31/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6405 - accuracy: 0.7238 - auc_roc: 0.5106
# Epoch 32/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6400 - accuracy: 0.7257 - auc_roc: 0.5139
# Epoch 33/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6401 - accuracy: 0.7254 - auc_roc: 0.5204
# Epoch 34/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6409 - accuracy: 0.7226 - auc_roc: 0.5005
# Epoch 35/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6371 - accuracy: 0.7363 - auc_roc: 0.4987
# Epoch 36/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6403 - accuracy: 0.7247 - auc_roc: 0.5074
# Epoch 37/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6416 - accuracy: 0.7199 - auc_roc: 0.5024
# Epoch 38/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6409 - accuracy: 0.7224 - auc_roc: 0.4976
# Epoch 39/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6396 - accuracy: 0.7270 - auc_roc: 0.5109
# Epoch 40/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6395 - accuracy: 0.7277 - auc_roc: 0.5185
# Epoch 41/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6378 - accuracy: 0.7335 - auc_roc: 0.5107
# Epoch 42/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6414 - accuracy: 0.7207 - auc_roc: 0.5086
# Epoch 43/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6384 - accuracy: 0.7314 - auc_roc: 0.5217
# Epoch 44/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6395 - accuracy: 0.7274 - auc_roc: 0.5006
# Epoch 45/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6372 - accuracy: 0.7358 - auc_roc: 0.5098
# Epoch 46/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6412 - accuracy: 0.7215 - auc_roc: 0.5069
# Epoch 47/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6390 - accuracy: 0.7294 - auc_roc: 0.5320
# Epoch 48/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6430 - accuracy: 0.7150 - auc_roc: 0.5000
# Epoch 49/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6412 - accuracy: 0.7213 - auc_roc: 0.5112
# Epoch 50/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6379 - accuracy: 0.7334 - auc_roc: 0.5302
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# 26/26 [==============================] - 1s 3ms/step
# 26/26 [==============================] - 0s 3ms/step
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Epoch 1/50
# 102/102 [==============================] - 4s 20ms/step - loss: 0.6941 - accuracy: 0.5285 - auc_roc: 0.5094
# Epoch 2/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6472 - accuracy: 0.7236 - auc_roc: 0.5086
# Epoch 3/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6439 - accuracy: 0.7180 - auc_roc: 0.5207
# Epoch 4/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6400 - accuracy: 0.7274 - auc_roc: 0.5358
# Epoch 5/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6389 - accuracy: 0.7304 - auc_roc: 0.5390
# Epoch 6/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6399 - accuracy: 0.7263 - auc_roc: 0.5367
# Epoch 7/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6395 - accuracy: 0.7279 - auc_roc: 0.5421
# Epoch 8/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6385 - accuracy: 0.7313 - auc_roc: 0.5387
# Epoch 9/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6390 - accuracy: 0.7293 - auc_roc: 0.5247
# Epoch 10/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6407 - accuracy: 0.7235 - auc_roc: 0.5230
# Epoch 11/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6427 - accuracy: 0.7160 - auc_roc: 0.5467
# Epoch 12/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6409 - accuracy: 0.7227 - auc_roc: 0.5276
# Epoch 13/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6384 - accuracy: 0.7316 - auc_roc: 0.5361
# Epoch 14/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6436 - accuracy: 0.7130 - auc_roc: 0.5277
# Epoch 15/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6392 - accuracy: 0.7288 - auc_roc: 0.5349
# Epoch 16/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6372 - accuracy: 0.7358 - auc_roc: 0.5273
# Epoch 17/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6380 - accuracy: 0.7330 - auc_roc: 0.5286
# Epoch 18/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6393 - accuracy: 0.7285 - auc_roc: 0.5429
# Epoch 19/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6415 - accuracy: 0.7203 - auc_roc: 0.5200
# Epoch 20/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6403 - accuracy: 0.7248 - auc_roc: 0.5266
# Epoch 21/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6372 - accuracy: 0.7359 - auc_roc: 0.5145
# Epoch 22/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6370 - accuracy: 0.7367 - auc_roc: 0.5057
# Epoch 23/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6368 - accuracy: 0.7373 - auc_roc: 0.5154
# Epoch 24/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6384 - accuracy: 0.7315 - auc_roc: 0.5258
# Epoch 25/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6371 - accuracy: 0.7363 - auc_roc: 0.5257
# Epoch 26/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6372 - accuracy: 0.7359 - auc_roc: 0.5359
# Epoch 27/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6370 - accuracy: 0.7365 - auc_roc: 0.5300
# Epoch 28/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6392 - accuracy: 0.7286 - auc_roc: 0.5340
# Epoch 29/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6354 - accuracy: 0.7425 - auc_roc: 0.5377
# Epoch 30/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6363 - accuracy: 0.7391 - auc_roc: 0.5106
# Epoch 31/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6405 - accuracy: 0.7238 - auc_roc: 0.5383
# Epoch 32/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6365 - accuracy: 0.7385 - auc_roc: 0.5140
# Epoch 33/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6421 - accuracy: 0.7182 - auc_roc: 0.5255
# Epoch 34/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6398 - accuracy: 0.7267 - auc_roc: 0.5265
# Epoch 35/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6423 - accuracy: 0.7177 - auc_roc: 0.5230
# Epoch 36/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6397 - accuracy: 0.7268 - auc_roc: 0.5365
# Epoch 37/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6388 - accuracy: 0.7300 - auc_roc: 0.5226
# Epoch 38/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6373 - accuracy: 0.7357 - auc_roc: 0.5023
# Epoch 39/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6439 - accuracy: 0.7118 - auc_roc: 0.5358
# Epoch 40/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6372 - accuracy: 0.7359 - auc_roc: 0.5200
# Epoch 41/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6388 - accuracy: 0.7300 - auc_roc: 0.5253
# Epoch 42/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6385 - accuracy: 0.7312 - auc_roc: 0.5121
# Epoch 43/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6404 - accuracy: 0.7245 - auc_roc: 0.5212
# Epoch 44/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6357 - accuracy: 0.7413 - auc_roc: 0.5197
# Epoch 45/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6404 - accuracy: 0.7245 - auc_roc: 0.5445
# Epoch 46/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6405 - accuracy: 0.7241 - auc_roc: 0.5215
# Epoch 47/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6417 - accuracy: 0.7198 - auc_roc: 0.5319
# Epoch 48/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6358 - accuracy: 0.7410 - auc_roc: 0.5112
# Epoch 49/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6418 - accuracy: 0.7192 - auc_roc: 0.5343
# Epoch 50/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6397 - accuracy: 0.7269 - auc_roc: 0.5341
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# 26/26 [==============================] - 1s 3ms/step
# 26/26 [==============================] - 0s 3ms/step
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Epoch 1/50
# 102/102 [==============================] - 5s 20ms/step - loss: 0.7038 - accuracy: 0.4762 - auc_roc: 0.5177
# Epoch 2/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6459 - accuracy: 0.7329 - auc_roc: 0.5202
# Epoch 3/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6421 - accuracy: 0.7262 - auc_roc: 0.5377
# Epoch 4/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6403 - accuracy: 0.7285 - auc_roc: 0.5149
# Epoch 5/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6367 - accuracy: 0.7394 - auc_roc: 0.5294
# Epoch 6/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6436 - accuracy: 0.7135 - auc_roc: 0.5251
# Epoch 7/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6407 - accuracy: 0.7239 - auc_roc: 0.5353
# Epoch 8/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6397 - accuracy: 0.7271 - auc_roc: 0.5313
# Epoch 9/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6389 - accuracy: 0.7299 - auc_roc: 0.5270
# Epoch 10/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6344 - accuracy: 0.7462 - auc_roc: 0.5233
# Epoch 11/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6391 - accuracy: 0.7293 - auc_roc: 0.5432
# Epoch 12/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6369 - accuracy: 0.7373 - auc_roc: 0.5208
# Epoch 13/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6413 - accuracy: 0.7212 - auc_roc: 0.5253
# Epoch 14/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6397 - accuracy: 0.7271 - auc_roc: 0.5303
# Epoch 15/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6416 - accuracy: 0.7203 - auc_roc: 0.5131
# Epoch 16/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6402 - accuracy: 0.7250 - auc_roc: 0.5356
# Epoch 17/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6383 - accuracy: 0.7322 - auc_roc: 0.5261
# Epoch 18/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6409 - accuracy: 0.7227 - auc_roc: 0.5453
# Epoch 19/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6375 - accuracy: 0.7349 - auc_roc: 0.5317
# Epoch 20/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6410 - accuracy: 0.7222 - auc_roc: 0.5335
# Epoch 21/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6409 - accuracy: 0.7227 - auc_roc: 0.5347
# Epoch 22/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6398 - accuracy: 0.7266 - auc_roc: 0.5267
# Epoch 23/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6390 - accuracy: 0.7296 - auc_roc: 0.5284
# Epoch 24/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6378 - accuracy: 0.7338 - auc_roc: 0.5181
# Epoch 25/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6403 - accuracy: 0.7248 - auc_roc: 0.5173
# Epoch 26/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6372 - accuracy: 0.7358 - auc_roc: 0.5272
# Epoch 27/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6383 - accuracy: 0.7321 - auc_roc: 0.5106
# Epoch 28/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6419 - accuracy: 0.7190 - auc_roc: 0.5177
# Epoch 29/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6385 - accuracy: 0.7312 - auc_roc: 0.5386
# Epoch 30/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6426 - accuracy: 0.7165 - auc_roc: 0.5442
# Epoch 31/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6378 - accuracy: 0.7339 - auc_roc: 0.5242
# Epoch 32/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6399 - accuracy: 0.7263 - auc_roc: 0.5255
# Epoch 33/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6384 - accuracy: 0.7315 - auc_roc: 0.5211
# Epoch 34/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6388 - accuracy: 0.7301 - auc_roc: 0.5217
# Epoch 35/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6399 - accuracy: 0.7261 - auc_roc: 0.5338
# Epoch 36/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6391 - accuracy: 0.7292 - auc_roc: 0.5396
# Epoch 37/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6400 - accuracy: 0.7259 - auc_roc: 0.5293
# Epoch 38/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6419 - accuracy: 0.7189 - auc_roc: 0.5298
# Epoch 39/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6400 - accuracy: 0.7258 - auc_roc: 0.5309
# Epoch 40/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6377 - accuracy: 0.7342 - auc_roc: 0.5281
# Epoch 41/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6431 - accuracy: 0.7148 - auc_roc: 0.5224
# Epoch 42/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6398 - accuracy: 0.7265 - auc_roc: 0.5206
# Epoch 43/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6395 - accuracy: 0.7275 - auc_roc: 0.5260
# Epoch 44/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6368 - accuracy: 0.7372 - auc_roc: 0.5496
# Epoch 45/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6381 - accuracy: 0.7325 - auc_roc: 0.5365
# Epoch 46/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6392 - accuracy: 0.7287 - auc_roc: 0.5186
# Epoch 47/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6376 - accuracy: 0.7346 - auc_roc: 0.5328
# Epoch 48/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6411 - accuracy: 0.7219 - auc_roc: 0.5237
# Epoch 49/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6407 - accuracy: 0.7234 - auc_roc: 0.5145
# Epoch 50/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6361 - accuracy: 0.7400 - auc_roc: 0.5308
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# 26/26 [==============================] - 1s 3ms/step
# 26/26 [==============================] - 0s 3ms/step
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Epoch 1/50
# 102/102 [==============================] - 4s 20ms/step - loss: 0.6654 - accuracy: 0.7168 - auc_roc: 0.5209
# Epoch 2/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6444 - accuracy: 0.7310 - auc_roc: 0.4839
# Epoch 3/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6445 - accuracy: 0.7167 - auc_roc: 0.4892
# Epoch 4/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6459 - accuracy: 0.7071 - auc_roc: 0.4948
# Epoch 5/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6426 - accuracy: 0.7179 - auc_roc: 0.4907
# Epoch 6/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6419 - accuracy: 0.7198 - auc_roc: 0.5140
# Epoch 7/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6416 - accuracy: 0.7203 - auc_roc: 0.5040
# Epoch 8/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6424 - accuracy: 0.7175 - auc_roc: 0.5158
# Epoch 9/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6414 - accuracy: 0.7209 - auc_roc: 0.5021
# Epoch 10/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6399 - accuracy: 0.7264 - auc_roc: 0.5199
# Epoch 11/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6402 - accuracy: 0.7254 - auc_roc: 0.5045
# Epoch 12/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6415 - accuracy: 0.7208 - auc_roc: 0.5047
# Epoch 13/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6398 - accuracy: 0.7267 - auc_roc: 0.5116
# Epoch 14/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6369 - accuracy: 0.7371 - auc_roc: 0.5196
# Epoch 15/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6421 - accuracy: 0.7183 - auc_roc: 0.5228
# Epoch 16/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6400 - accuracy: 0.7259 - auc_roc: 0.5342
# Epoch 17/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6426 - accuracy: 0.7166 - auc_roc: 0.5325
# Epoch 18/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6419 - accuracy: 0.7192 - auc_roc: 0.5082
# Epoch 19/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6369 - accuracy: 0.7370 - auc_roc: 0.5065
# Epoch 20/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6388 - accuracy: 0.7304 - auc_roc: 0.5148
# Epoch 21/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6418 - accuracy: 0.7193 - auc_roc: 0.5328
# Epoch 22/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6424 - accuracy: 0.7174 - auc_roc: 0.5260
# Epoch 23/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6396 - accuracy: 0.7274 - auc_roc: 0.5280
# Epoch 24/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6425 - accuracy: 0.7170 - auc_roc: 0.5090
# Epoch 25/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6415 - accuracy: 0.7205 - auc_roc: 0.5234
# Epoch 26/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6407 - accuracy: 0.7233 - auc_roc: 0.5295
# Epoch 27/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6405 - accuracy: 0.7242 - auc_roc: 0.5252
# Epoch 28/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6398 - accuracy: 0.7265 - auc_roc: 0.5228
# Epoch 29/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6410 - accuracy: 0.7224 - auc_roc: 0.5155
# Epoch 30/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6377 - accuracy: 0.7343 - auc_roc: 0.5331
# Epoch 31/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6415 - accuracy: 0.7205 - auc_roc: 0.5117
# Epoch 32/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6424 - accuracy: 0.7174 - auc_roc: 0.5107
# Epoch 33/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6379 - accuracy: 0.7333 - auc_roc: 0.5203
# Epoch 34/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6384 - accuracy: 0.7315 - auc_roc: 0.5092
# Epoch 35/50
# 102/102 [==============================] - 2s 23ms/step - loss: 0.6390 - accuracy: 0.7296 - auc_roc: 0.5244
# Epoch 36/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6389 - accuracy: 0.7298 - auc_roc: 0.5297
# Epoch 37/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6390 - accuracy: 0.7294 - auc_roc: 0.5420
# Epoch 38/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6428 - accuracy: 0.7157 - auc_roc: 0.5150
# Epoch 39/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6426 - accuracy: 0.7164 - auc_roc: 0.5211
# Epoch 40/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6416 - accuracy: 0.7199 - auc_roc: 0.5146
# Epoch 41/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6430 - accuracy: 0.7152 - auc_roc: 0.5341
# Epoch 42/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6399 - accuracy: 0.7263 - auc_roc: 0.5219
# Epoch 43/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6416 - accuracy: 0.7202 - auc_roc: 0.5459
# Epoch 44/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6419 - accuracy: 0.7188 - auc_roc: 0.5368
# Epoch 45/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6389 - accuracy: 0.7297 - auc_roc: 0.5394
# Epoch 46/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6378 - accuracy: 0.7339 - auc_roc: 0.5437
# Epoch 47/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6401 - accuracy: 0.7256 - auc_roc: 0.4987
# Epoch 48/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6366 - accuracy: 0.7382 - auc_roc: 0.5227
# Epoch 49/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6385 - accuracy: 0.7314 - auc_roc: 0.5246
# Epoch 50/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6410 - accuracy: 0.7223 - auc_roc: 0.5242
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# 26/26 [==============================] - 0s 3ms/step
# 26/26 [==============================] - 0s 3ms/step
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Epoch 1/50
# 102/102 [==============================] - 4s 20ms/step - loss: 0.6577 - accuracy: 0.7370 - auc_roc: 0.5070
# Epoch 2/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6448 - accuracy: 0.7332 - auc_roc: 0.5056
# Epoch 3/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6407 - accuracy: 0.7346 - auc_roc: 0.4984
# Epoch 4/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6407 - accuracy: 0.7285 - auc_roc: 0.5238
# Epoch 5/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6375 - accuracy: 0.7376 - auc_roc: 0.5274
# Epoch 6/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6394 - accuracy: 0.7295 - auc_roc: 0.5418
# Epoch 7/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6390 - accuracy: 0.7304 - auc_roc: 0.5147
# Epoch 8/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6391 - accuracy: 0.7299 - auc_roc: 0.4981
# Epoch 9/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6381 - accuracy: 0.7332 - auc_roc: 0.5111
# Epoch 10/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6375 - accuracy: 0.7354 - auc_roc: 0.4957
# Epoch 11/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6419 - accuracy: 0.7194 - auc_roc: 0.5045
# Epoch 12/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6399 - accuracy: 0.7267 - auc_roc: 0.5107
# Epoch 13/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6360 - accuracy: 0.7407 - auc_roc: 0.5052
# Epoch 14/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6421 - accuracy: 0.7185 - auc_roc: 0.4955
# Epoch 15/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6404 - accuracy: 0.7247 - auc_roc: 0.5203
# Epoch 16/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6369 - accuracy: 0.7373 - auc_roc: 0.5118
# Epoch 17/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6404 - accuracy: 0.7247 - auc_roc: 0.5143
# Epoch 18/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6414 - accuracy: 0.7210 - auc_roc: 0.5303
# Epoch 19/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6383 - accuracy: 0.7324 - auc_roc: 0.4951
# Epoch 20/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6388 - accuracy: 0.7303 - auc_roc: 0.5126
# Epoch 21/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6396 - accuracy: 0.7275 - auc_roc: 0.4910
# Epoch 22/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6420 - accuracy: 0.7188 - auc_roc: 0.4990
# Epoch 23/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6382 - accuracy: 0.7327 - auc_roc: 0.5193
# Epoch 24/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6386 - accuracy: 0.7310 - auc_roc: 0.5174
# Epoch 25/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6400 - accuracy: 0.7261 - auc_roc: 0.5146
# Epoch 26/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6408 - accuracy: 0.7230 - auc_roc: 0.5166
# Epoch 27/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6374 - accuracy: 0.7352 - auc_roc: 0.5096
# Epoch 28/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6414 - accuracy: 0.7208 - auc_roc: 0.5073
# Epoch 29/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6422 - accuracy: 0.7181 - auc_roc: 0.5165
# Epoch 30/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6371 - accuracy: 0.7364 - auc_roc: 0.5203
# Epoch 31/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6381 - accuracy: 0.7329 - auc_roc: 0.5277
# Epoch 32/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6404 - accuracy: 0.7245 - auc_roc: 0.5262
# Epoch 33/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6369 - accuracy: 0.7372 - auc_roc: 0.5081
# Epoch 34/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6364 - accuracy: 0.7388 - auc_roc: 0.5122
# Epoch 35/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6365 - accuracy: 0.7386 - auc_roc: 0.5110
# Epoch 36/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6381 - accuracy: 0.7329 - auc_roc: 0.5021
# Epoch 37/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6414 - accuracy: 0.7208 - auc_roc: 0.5081
# Epoch 38/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6385 - accuracy: 0.7315 - auc_roc: 0.5087
# Epoch 39/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6407 - accuracy: 0.7235 - auc_roc: 0.5335
# Epoch 40/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6418 - accuracy: 0.7196 - auc_roc: 0.5235
# Epoch 41/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6372 - accuracy: 0.7359 - auc_roc: 0.5044
# Epoch 42/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6460 - accuracy: 0.7043 - auc_roc: 0.5280
# Epoch 43/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6422 - accuracy: 0.7181 - auc_roc: 0.5345
# Epoch 44/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6386 - accuracy: 0.7309 - auc_roc: 0.5336
# Epoch 45/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6445 - accuracy: 0.7098 - auc_roc: 0.5286
# Epoch 46/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6394 - accuracy: 0.7282 - auc_roc: 0.5154
# Epoch 47/50
# 102/102 [==============================] - 2s 20ms/step - loss: 0.6391 - accuracy: 0.7291 - auc_roc: 0.5183
# Epoch 48/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6371 - accuracy: 0.7364 - auc_roc: 0.5336
# Epoch 49/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6386 - accuracy: 0.7309 - auc_roc: 0.5252
# Epoch 50/50
# 102/102 [==============================] - 2s 19ms/step - loss: 0.6372 - accuracy: 0.7360 - auc_roc: 0.5192
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# 26/26 [==============================] - 0s 3ms/step
# 26/26 [==============================] - 0s 3ms/step
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Epoch 1/50
# 128/128 [==============================] - 5s 20ms/step - loss: 0.6885 - accuracy: 0.5436 - auc_roc: 0.5172
# Epoch 2/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6483 - accuracy: 0.7252 - auc_roc: 0.5380
# Epoch 3/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6423 - accuracy: 0.7278 - auc_roc: 0.5262
# Epoch 4/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6406 - accuracy: 0.7275 - auc_roc: 0.5426
# Epoch 5/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6386 - accuracy: 0.7326 - auc_roc: 0.5377
# Epoch 6/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6379 - accuracy: 0.7341 - auc_roc: 0.5406
# Epoch 7/50
# 128/128 [==============================] - 3s 20ms/step - loss: 0.6367 - accuracy: 0.7379 - auc_roc: 0.5271
# Epoch 8/50
# 128/128 [==============================] - 3s 20ms/step - loss: 0.6393 - accuracy: 0.7285 - auc_roc: 0.5240
# Epoch 9/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6407 - accuracy: 0.7232 - auc_roc: 0.5325
# Epoch 10/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6382 - accuracy: 0.7321 - auc_roc: 0.5360
# Epoch 11/50
# 128/128 [==============================] - 2s 20ms/step - loss: 0.6430 - accuracy: 0.7147 - auc_roc: 0.5440
# Epoch 12/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6378 - accuracy: 0.7336 - auc_roc: 0.5330
# Epoch 13/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6390 - accuracy: 0.7293 - auc_roc: 0.5275
# Epoch 14/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6387 - accuracy: 0.7303 - auc_roc: 0.5347
# Epoch 15/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6364 - accuracy: 0.7386 - auc_roc: 0.5166
# Epoch 16/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6406 - accuracy: 0.7237 - auc_roc: 0.5225
# Epoch 17/50
# 128/128 [==============================] - 2s 20ms/step - loss: 0.6404 - accuracy: 0.7241 - auc_roc: 0.5453
# Epoch 18/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6382 - accuracy: 0.7322 - auc_roc: 0.5161
# Epoch 19/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6379 - accuracy: 0.7333 - auc_roc: 0.5209
# Epoch 20/50
# 128/128 [==============================] - 3s 20ms/step - loss: 0.6393 - accuracy: 0.7282 - auc_roc: 0.5410
# Epoch 21/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6398 - accuracy: 0.7265 - auc_roc: 0.5171
# Epoch 22/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6432 - accuracy: 0.7142 - auc_roc: 0.5090
# Epoch 23/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6400 - accuracy: 0.7256 - auc_roc: 0.5395
# Epoch 24/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6391 - accuracy: 0.7289 - auc_roc: 0.5421
# Epoch 25/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6381 - accuracy: 0.7325 - auc_roc: 0.5215
# Epoch 26/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6391 - accuracy: 0.7290 - auc_roc: 0.5152
# Epoch 27/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6381 - accuracy: 0.7327 - auc_roc: 0.5339
# Epoch 28/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6407 - accuracy: 0.7230 - auc_roc: 0.5376
# Epoch 29/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6393 - accuracy: 0.7281 - auc_roc: 0.5412
# Epoch 30/50
# 128/128 [==============================] - 3s 20ms/step - loss: 0.6398 - accuracy: 0.7265 - auc_roc: 0.5230
# Epoch 31/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6386 - accuracy: 0.7308 - auc_roc: 0.5379
# Epoch 32/50
# 128/128 [==============================] - 3s 20ms/step - loss: 0.6423 - accuracy: 0.7174 - auc_roc: 0.5186
# Epoch 33/50
# 128/128 [==============================] - 2s 20ms/step - loss: 0.6409 - accuracy: 0.7226 - auc_roc: 0.5385
# Epoch 34/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6406 - accuracy: 0.7235 - auc_roc: 0.5287
# Epoch 35/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6345 - accuracy: 0.7454 - auc_roc: 0.5289
# Epoch 36/50
# 128/128 [==============================] - 3s 20ms/step - loss: 0.6364 - accuracy: 0.7385 - auc_roc: 0.5208
# Epoch 37/50
# 128/128 [==============================] - 3s 20ms/step - loss: 0.6377 - accuracy: 0.7339 - auc_roc: 0.5269
# Epoch 38/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6371 - accuracy: 0.7361 - auc_roc: 0.5407
# Epoch 39/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6428 - accuracy: 0.7155 - auc_roc: 0.5367
# Epoch 40/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6409 - accuracy: 0.7223 - auc_roc: 0.5275
# Epoch 41/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6415 - accuracy: 0.7200 - auc_roc: 0.5459
# Epoch 42/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6404 - accuracy: 0.7242 - auc_roc: 0.5438
# Epoch 43/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6421 - accuracy: 0.7180 - auc_roc: 0.5337
# Epoch 44/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6427 - accuracy: 0.7159 - auc_roc: 0.5268
# Epoch 45/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6413 - accuracy: 0.7209 - auc_roc: 0.5171
# Epoch 46/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6400 - accuracy: 0.7257 - auc_roc: 0.5432
# Epoch 47/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6403 - accuracy: 0.7247 - auc_roc: 0.5456
# Epoch 48/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6362 - accuracy: 0.7395 - auc_roc: 0.5134
# Epoch 49/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6418 - accuracy: 0.7191 - auc_roc: 0.5263
# Epoch 50/50
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6420 - accuracy: 0.7186 - auc_roc: 0.5396

# %%
# top 20 performers by the test_roc_auc score
#,'param_model__max_features'
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
#res_cols = ['mean_test_roc_auc', 'mean_test_accuracy', 'param_balance__balancer_type', 'param_features__k', 
#            'param_features__score_func', 'param_model__C', 'param_model__solver', 
#            'param_outlier__outlier_threshold', 'param__vif_score_threshold']
#res_cols = ['mean_test_roc_auc','mean_test_accuracy', 'param_balance__balancer_type', 'param_model__batch_size','param_model__epochs',
            #'param_outlier__outlier_threshold']
res_cols = ['mean_test_roc_auc','mean_test_accuracy','param_model__epochs']
#res_cols = ['mean_test_roc_auc','mean_test_accuracy', 'param_balance__balancer_type','param_model__optimizer',
            #'param_outlier__outlier_threshold']
df_sorted = df_result[res_cols].reset_index(drop=True).sort_values('mean_test_roc_auc', axis=0, ascending=False)
df_sorted.index = pd.RangeIndex(1, len(df_sorted.index)+1)
df_sorted
# Out:
#    mean_test_roc_auc  mean_test_accuracy param_model__epochs
# 1           0.540089             0.72694                  50

# %%
# the average roc-auc and accuracy scores of just completed search.
# these are the averages of each model over the convolution folds.
#print(df_result['mean_test_roc_auc'])
#print(df_result['mean_test_accuracy'])
print(best_params)
# Out:
# {'model__epochs': 50}

# %%
# display results for the best estimator we found
predictions = best_estimator.predict(df_features)
probabilities = best_estimator.predict_proba(df_features)[:,1]
mindwandering.evaluate.evaluate_model_results(mind_wandered_label, predictions, probabilities)
# Out:
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# 128/128 [==============================] - 1s 3ms/step
#  52/128 [===========>..................] - ETA: 0s
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# 128/128 [==============================] - 0s 3ms/step
# Accuracy score:         0.7269381746810598
# Recall (TPR) score:     0.0
# Precision score:        0.0
# AUC-ROC score:          0.5
#
# True positives:   0
# True negatives:   2963
# False positives:  0
# False negatives:  1113
# True Positive Rate (recall):  0.0
# False Positive Rate:          0.0
# Specificity:                  1.0
#
# [[2963    0]
#  [1113    0]]

# %%
# save the results and preliminary figures in the following cells

# create base save file name for this file, use datetime to keep a unique file name
"""now = datetime.now()
date_time = now.strftime('%Y%m%d-%H%M')
result_file_basename = 'replication-07-Neural-Network-using-Conv1D-v2' + date_time
print(result_file_basename)"""
# Out:
# "now = datetime.now()\ndate_time = now.strftime('%Y%m%d-%H%M')\nresult_file_basename = 'replication-07-Neural-Network-using-SGD' + date_time\nprint(result_file_basename)"

# %%
# A quick histogram of this search auc-roc scores.  Basically the figure 1 from the paper.
plt.figure(figsize=(12,8))

#bins = np.linspace(0.605, 0.612, 8)
plt.hist(df_result.mean_test_roc_auc, 
         bins=20,
         color='lightblue',
         rwidth=0.9);
#plt.xlabel('Area under the receiver operating characteristic (AUC-ROC)');
plt.xlabel('Area under the receiver operating characteristic (AUC-ROC)');
plt.ylabel('Number of models');
plt.title('Neural Network Replication using Conv1D V2: ' + result_file_basename);

"""result_dir = '../figures'
result_file_name = result_file_basename + '.eps'
result_file_path = os.path.join(result_dir, result_file_name)
plt.savefig(result_file_path)"""
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-f7b514368911> in <module>
#      10 plt.xlabel('Area under the receiver operating characteristic (AUC-ROC)');
#      11 plt.ylabel('Number of models');
# ---> 12 plt.title('Neural Network Replication using SGD: ' + result_file_basename);
#      13
#      14 """result_dir = '../figures'
#
# NameError: name 'result_file_basename' is not defined
