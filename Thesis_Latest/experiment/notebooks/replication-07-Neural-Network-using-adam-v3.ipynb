# %% [markdown]
# - mean_test_auc_roc using Logistic Regression:
# - mean_test_auc_roc using KNN:0.631033
# - mean_test_auc_roc using SVM:0.658805
# - mean_test_auc_roc using Random Forest:0.657398
# - mean_test_auc_roc using Decision Tree:0.640888
# - mean_test_auc_roc using **Naive Bayes:0.659468**
# - mean_test_auc_roc using Neural Network(Adam):0.634302
# - mean_test_auc_roc using Neural Network(SGD):0.630862
# - mean_test_auc_roc using Neural Network(RMSprop):0.629448

# %%
# globally useful imports of standard libraries needed in this notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os.path
from datetime import datetime

# specific libraries or classes needed for the work in this notebook
#from sklearn.linear_model import LogisticRegression
#from sklearn.linear_model import LogisticRegressionCV
#from sklearn.svm import SVC
#from sklearn.naive_bayes import GaussianNB
#from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GroupKFold
from sklearn.model_selection import LeaveOneGroupOut
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import SelectKBest, f_classif, chi2, SelectFpr, f_regression, mutual_info_classif
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import RFE
from sklearn.feature_selection import VarianceThreshold
from sklearn.ensemble import ExtraTreesClassifier
#from sklearn.pipeline import Pipeline
# need to use Pipeline from imblearn to add in a downsample or upsample
# to cross validation training
from imblearn.pipeline import Pipeline

# import project specific modules used in this notebook
import sys
sys.path.append('../src')
import mindwandering.data
import mindwandering.features
import mindwandering.evaluate
from mindwandering.data import FeatureScalerTransformer
from mindwandering.data import WinsorizationOutlierTransformer
from mindwandering.data import VIFThresholdTransformer
from mindwandering.data import FeatureSelectionTransformer
from mindwandering.data import ClassImbalanceTransformer
from mindwandering.data import GridSearchProgressHack

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.layers import Input, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import SGD,Adam,RMSprop

# %%
# Load Data and Features
df_features = mindwandering.data.get_df_features()
mind_wandered_label = mindwandering.data.get_mind_wandered_label()
participant_ids = mindwandering.data.get_participant_ids()

# %%
import tensorflow
auc_roc = tensorflow.keras.metrics.AUC(name='auc_roc',num_thresholds=20000,curve='ROC')

# %%
#First Model
def create_model():
    model = Sequential()
    model.add(Dense(
        32, 
        activation='swish', 
        kernel_initializer='normal',
        #kernel_regularizer=regularizers.l1_l2(l1=1e-6, l2=1e-5))),
        kernel_regularizer=regularizers.l1_l2(l1=1e-6),
        bias_regularizer=regularizers.l2(1e-4),
        activity_regularizer=regularizers.l2(1e-5)))
    #model.add(Dense(32, activation='relu'))
    #model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(64,activation='swish'))
    #model.add(Dropout(0.2))
    #model.add(Dense(128,activation='relu'))
    #model.add(Dropout(0.3))
    model.add(Dense(1, activation='sigmoid'))
    
    optimizer=Adam(learning_rate=0.0001,
                   beta_1=0.99,
                   beta_2=0.1,
                   epsilon=1e-06)
    model.compile(loss='binary_crossentropy', optimizer=optimizer,metrics=['accuracy',auc_roc])
    return model

# %%
# Wrap Keras model so it can be used by scikit-learn
kears_estimator = KerasClassifier(build_fn=create_model,epochs=100, batch_size=128, verbose=1)
#kears_estimator = KerasClassifier(build_fn=create_model,epochs=200, batch_size=512, verbose=1)
#kears_estimator = KerasClassifier(build_fn=create_model, verbose=1)

# %%
# vif thresholds to apply to data and labels before grid search pipeline
#vif_thresholds = [0, 5]
vif_thresholds = [0]

# we want to actually select a certain percentage of features of whatever remains
# after vif thresholding.  So we will calculate these in the loop based on the number
# of features in data, and add to the parameters dictionary before the grid search
#features__k_ratios = np.array([0.25, 0.5, 0.75, 1.0])
features__k_ratios = np.array([0.2, 0.25, 0.3, 0.35, 0.4, 0.5])

# Empty dataframe to gather grid search results into 1 place
best_estimator = None
best_score = 0.0
best_params = {}
best_index = 0
df_result = None

# search over vif threshold meta parameters, create separate df from vif_threshold
# for otherwise identical grid searches
for vif_threshold in vif_thresholds:
    # display progress
    print('')
    print('=' * 50)
    print('Starting vif meta-parameter condition: vif_threshold: ', vif_threshold)
    
    # pipeline to apply vif threshold selection
    vif_pipeline = Pipeline(
      [
        ('vif',      VIFThresholdTransformer(score_threshold=vif_threshold)),
      ]
    )
 
    df_vif_features = vif_pipeline.transform(df_features)
    num_trials, num_features = df_vif_features.shape
    print('   Number of trials: ', num_trials, ' Number of Features: ', num_features)
    
    parameters = {
        'scaling__type_of_scaling': ['standard'],
        'outlier__outlier_threshold': [0.0, 3.0],
        'features__k': [12],
        #'balance__balancer_type': ['random-undersampler', 'allknn', 'nearmiss', 'instance-hardness-threshold'],
        #'balance__balancer_type': ['allknn', 'condensed-nn', 'neighbourhood-cleaning', 'one-sided-selection'],
        #'balance__balancer_type': ['allknn', 'one-sided-selection'],
        'balance__balancer_type': ['allknn', 'smote-enn'],
        #'balance__balancer_type': ['allknn'],
        #'model__var_smoothing': [1e-6,1e-7,1e-8,1e-9,1e-10,1e-11,1e-12],
        #'model__batch_size': [8, 16, 24, 32, 40, 48],#usually multiple of 8
        #'model__epochs':[100,150,200],
        #'model__batch_size': [128],
        #'model__epochs':[10],
        #'model__optimizer' : ['RMSprop', 'Adagrad', 'Adadelta','Adam']
    }

    # set feature selection k correctly
    features__k = features__k_ratios * num_features
    features__k = features__k.astype(int) 
    parameters['features__k'] = features__k.tolist()

    # Estimator Pipeline
    pipeline = Pipeline(
      [
        ('progress', GridSearchProgressHack(verbose=False)),
        ('scaling',  FeatureScalerTransformer()),
        ('outlier',  WinsorizationOutlierTransformer()),
        ('features', SelectKBest()),
        #('features', SelectFromModel(estimator=LogisticRegression(solver='liblinear', penalty='l1', C=0.1), threshold=-np.inf)),
        ('balance',  ClassImbalanceTransformer()),
        ('model',    kears_estimator)
      ]
    )
    
    # Cross Validation Splitter
    cv_group_splitter = GroupKFold(n_splits=5)
    #cv_group_splitter = LeaveOneGroupOut()

    # perform the grid search for this vif selection
    # set up the search
    search = GridSearchCV(
        estimator = pipeline,
        param_grid = parameters,
        scoring = ['roc_auc','accuracy'],
        cv = cv_group_splitter,
        refit = 'roc_auc',
        verbose = 1
    )
    search.fit(df_vif_features, mind_wandered_label, groups=participant_ids)
    
    # append results onto the dataframe collecting the results.  Need to add
    # a feature column to this dataframe for the vif vit condition here
    df = pd.DataFrame(data=search.cv_results_)
    df['param__vif_score_threshold'] = vif_threshold
    
    if best_estimator is None:
        df_result = df
        best_estimator = search.best_estimator_
        best_score = search.best_score_
        best_params = search.best_params_
        best_index = search.best_index_
    else:
        df_result = df_result.append(df, ignore_index=True)
        if search.best_score_ > best_score:
            best_estimator = search.best_estimator_
            best_score = search.best_score_
            best_params = search.best_params_
            best_index = search.best_index_  # todo this is only the index of this search
# Out:
# ==================================================
# Starting vif meta-parameter condition: vif_threshold:  0
#    Number of trials:  4076  Number of Features:  62
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# 0001 Epoch 1/100
# 14/14 [==============================] - 1s 15ms/step - loss: 0.7009 - accuracy: 0.5459 - auc_roc: 0.5766
# Epoch 2/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6956 - accuracy: 0.6145 - auc_roc: 0.6634
# Epoch 3/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6919 - accuracy: 0.6435 - auc_roc: 0.6950
# Epoch 4/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6871 - accuracy: 0.6857 - auc_roc: 0.7180
# Epoch 5/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6814 - accuracy: 0.6834 - auc_roc: 0.7296
# Epoch 6/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6781 - accuracy: 0.6811 - auc_roc: 0.7212
# Epoch 7/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6732 - accuracy: 0.6962 - auc_roc: 0.7385
# Epoch 8/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6673 - accuracy: 0.6984 - auc_roc: 0.7502
# Epoch 9/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6658 - accuracy: 0.6995 - auc_roc: 0.7432
# Epoch 10/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6644 - accuracy: 0.6851 - auc_roc: 0.7188
# Epoch 11/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6580 - accuracy: 0.6912 - auc_roc: 0.7329
# Epoch 12/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6533 - accuracy: 0.7046 - auc_roc: 0.7417
# Epoch 13/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6494 - accuracy: 0.6917 - auc_roc: 0.7290
# Epoch 14/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6371 - accuracy: 0.7039 - auc_roc: 0.7511
# Epoch 15/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6361 - accuracy: 0.7060 - auc_roc: 0.7544
# Epoch 16/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6349 - accuracy: 0.6891 - auc_roc: 0.7374
# Epoch 17/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6256 - accuracy: 0.6993 - auc_roc: 0.7475
# Epoch 18/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6231 - accuracy: 0.7048 - auc_roc: 0.7434
# Epoch 19/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6157 - accuracy: 0.6973 - auc_roc: 0.7521
# Epoch 20/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6182 - accuracy: 0.7097 - auc_roc: 0.7489
# Epoch 21/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6263 - accuracy: 0.6927 - auc_roc: 0.7269
# Epoch 22/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6108 - accuracy: 0.7141 - auc_roc: 0.7543
# Epoch 23/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6163 - accuracy: 0.7017 - auc_roc: 0.7438
# Epoch 24/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6058 - accuracy: 0.7071 - auc_roc: 0.7559
# Epoch 25/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6145 - accuracy: 0.7065 - auc_roc: 0.7428
# Epoch 26/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6045 - accuracy: 0.7166 - auc_roc: 0.7590
# Epoch 27/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6182 - accuracy: 0.6995 - auc_roc: 0.7418
# Epoch 28/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6129 - accuracy: 0.6990 - auc_roc: 0.7431
# Epoch 29/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6192 - accuracy: 0.6963 - auc_roc: 0.7379
# Epoch 30/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6088 - accuracy: 0.7041 - auc_roc: 0.7482
# Epoch 31/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6174 - accuracy: 0.6924 - auc_roc: 0.7346
# Epoch 32/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.5975 - accuracy: 0.7099 - auc_roc: 0.7588
# Epoch 33/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.5923 - accuracy: 0.7105 - auc_roc: 0.7640
# Epoch 34/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6042 - accuracy: 0.7012 - auc_roc: 0.7508
# Epoch 35/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.5916 - accuracy: 0.6959 - auc_roc: 0.7633
# Epoch 36/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6024 - accuracy: 0.6915 - auc_roc: 0.7506
# Epoch 37/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6046 - accuracy: 0.7052 - auc_roc: 0.7509
# Epoch 38/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.5979 - accuracy: 0.6970 - auc_roc: 0.7596
# Epoch 39/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.5986 - accuracy: 0.7076 - auc_roc: 0.7609
# Epoch 40/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.5968 - accuracy: 0.7077 - auc_roc: 0.7599
# Epoch 41/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6034 - accuracy: 0.7013 - auc_roc: 0.7537
# Epoch 42/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5939 - accuracy: 0.7241 - auc_roc: 0.7734
# Epoch 43/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.5946 - accuracy: 0.7096 - auc_roc: 0.7663
# Epoch 44/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6034 - accuracy: 0.7126 - auc_roc: 0.7590
# Epoch 45/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5989 - accuracy: 0.7105 - auc_roc: 0.7557
# Epoch 46/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6062 - accuracy: 0.6978 - auc_roc: 0.7486
# Epoch 47/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6046 - accuracy: 0.7098 - auc_roc: 0.7531
# Epoch 48/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.5862 - accuracy: 0.7186 - auc_roc: 0.7748
# Epoch 49/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.5938 - accuracy: 0.7087 - auc_roc: 0.7601
# Epoch 50/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5941 - accuracy: 0.7102 - auc_roc: 0.7641
# Epoch 51/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.5923 - accuracy: 0.6926 - auc_roc: 0.7603
# Epoch 52/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5996 - accuracy: 0.7088 - auc_roc: 0.7598
# Epoch 53/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5837 - accuracy: 0.7163 - auc_roc: 0.7744
# Epoch 54/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5985 - accuracy: 0.7049 - auc_roc: 0.7615
# Epoch 55/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5822 - accuracy: 0.7218 - auc_roc: 0.7727
# Epoch 56/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5846 - accuracy: 0.7258 - auc_roc: 0.7767
# Epoch 57/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5763 - accuracy: 0.7135 - auc_roc: 0.7775
# Epoch 58/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5882 - accuracy: 0.7174 - auc_roc: 0.7670
# Epoch 59/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5863 - accuracy: 0.7142 - auc_roc: 0.7686
# Epoch 60/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5709 - accuracy: 0.7351 - auc_roc: 0.7917
# Epoch 61/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5766 - accuracy: 0.7153 - auc_roc: 0.7805
# Epoch 62/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5857 - accuracy: 0.7050 - auc_roc: 0.7684
# Epoch 63/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5832 - accuracy: 0.7219 - auc_roc: 0.7769
# Epoch 64/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5918 - accuracy: 0.7050 - auc_roc: 0.7604
# Epoch 65/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5810 - accuracy: 0.7170 - auc_roc: 0.7782
# Epoch 66/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5747 - accuracy: 0.7197 - auc_roc: 0.7797
# Epoch 67/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5668 - accuracy: 0.7440 - auc_roc: 0.7942
# Epoch 68/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5785 - accuracy: 0.7107 - auc_roc: 0.7758
# Epoch 69/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5883 - accuracy: 0.7141 - auc_roc: 0.7686
# Epoch 70/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5682 - accuracy: 0.7271 - auc_roc: 0.7893
# Epoch 71/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5818 - accuracy: 0.7071 - auc_roc: 0.7723
# Epoch 72/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5797 - accuracy: 0.7199 - auc_roc: 0.7741
# Epoch 73/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5763 - accuracy: 0.7129 - auc_roc: 0.7820
# Epoch 74/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5823 - accuracy: 0.7070 - auc_roc: 0.7698
# Epoch 75/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5898 - accuracy: 0.7086 - auc_roc: 0.7617
# Epoch 76/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5658 - accuracy: 0.7257 - auc_roc: 0.7882
# Epoch 77/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5778 - accuracy: 0.7102 - auc_roc: 0.7776
# Epoch 78/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5736 - accuracy: 0.7231 - auc_roc: 0.7838
# Epoch 79/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5735 - accuracy: 0.7250 - auc_roc: 0.7832
# Epoch 80/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5788 - accuracy: 0.7249 - auc_roc: 0.7781
# Epoch 81/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5820 - accuracy: 0.7193 - auc_roc: 0.7727
# Epoch 82/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5807 - accuracy: 0.7159 - auc_roc: 0.7755
# Epoch 83/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5837 - accuracy: 0.7153 - auc_roc: 0.7671
# Epoch 84/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5781 - accuracy: 0.7118 - auc_roc: 0.7745
# Epoch 85/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5789 - accuracy: 0.7162 - auc_roc: 0.7800
# Epoch 86/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5905 - accuracy: 0.6988 - auc_roc: 0.7636
# Epoch 87/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5945 - accuracy: 0.7041 - auc_roc: 0.7593
# Epoch 88/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5806 - accuracy: 0.7122 - auc_roc: 0.7723
# Epoch 89/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5711 - accuracy: 0.7365 - auc_roc: 0.7899
# Epoch 90/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5775 - accuracy: 0.7051 - auc_roc: 0.7726
# Epoch 91/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5821 - accuracy: 0.7246 - auc_roc: 0.7735
# Epoch 92/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5514 - accuracy: 0.7384 - auc_roc: 0.8031
# Epoch 93/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5709 - accuracy: 0.7208 - auc_roc: 0.7791
# Epoch 94/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5778 - accuracy: 0.7271 - auc_roc: 0.7766
# Epoch 95/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5641 - accuracy: 0.7230 - auc_roc: 0.7835
# Epoch 96/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5763 - accuracy: 0.7136 - auc_roc: 0.7751
# Epoch 97/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5572 - accuracy: 0.7404 - auc_roc: 0.7953
# Epoch 98/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5855 - accuracy: 0.7026 - auc_roc: 0.7635
# Epoch 99/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5582 - accuracy: 0.7318 - auc_roc: 0.7967
# Epoch 100/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5805 - accuracy: 0.7027 - auc_roc: 0.7700
# 7/7 [==============================] - 0s 568us/step
# 7/7 [==============================] - 0s 585us/step
# 0002
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Epoch 1/100
# 15/15 [==============================] - 1s 14ms/step - loss: 0.7021 - accuracy: 0.5280 - auc_roc: 0.7153
# Epoch 2/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6980 - accuracy: 0.5861 - auc_roc: 0.6024
# Epoch 3/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6932 - accuracy: 0.6524 - auc_roc: 0.6735
# Epoch 4/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6897 - accuracy: 0.6611 - auc_roc: 0.6749
# Epoch 5/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6839 - accuracy: 0.6771 - auc_roc: 0.7111
# Epoch 6/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6809 - accuracy: 0.6749 - auc_roc: 0.7105
# Epoch 7/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6771 - accuracy: 0.6894 - auc_roc: 0.7072
# Epoch 8/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6748 - accuracy: 0.6611 - auc_roc: 0.7066
# Epoch 9/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6698 - accuracy: 0.6751 - auc_roc: 0.7186
# Epoch 10/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6632 - accuracy: 0.6736 - auc_roc: 0.7210
# Epoch 11/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6599 - accuracy: 0.6766 - auc_roc: 0.7211
# Epoch 12/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6568 - accuracy: 0.6661 - auc_roc: 0.7185
# Epoch 13/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6517 - accuracy: 0.6724 - auc_roc: 0.7199
# Epoch 14/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6454 - accuracy: 0.6778 - auc_roc: 0.7269
# Epoch 15/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6443 - accuracy: 0.6747 - auc_roc: 0.7215
# Epoch 16/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6348 - accuracy: 0.6911 - auc_roc: 0.7298
# Epoch 17/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6413 - accuracy: 0.6714 - auc_roc: 0.7078
# Epoch 18/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6200 - accuracy: 0.6864 - auc_roc: 0.7459
# Epoch 19/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6212 - accuracy: 0.6917 - auc_roc: 0.7452
# Epoch 20/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6198 - accuracy: 0.6896 - auc_roc: 0.7413
# Epoch 21/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6303 - accuracy: 0.6740 - auc_roc: 0.7158
# Epoch 22/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6096 - accuracy: 0.6924 - auc_roc: 0.7452
# Epoch 23/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6256 - accuracy: 0.6816 - auc_roc: 0.7281
# Epoch 24/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6189 - accuracy: 0.6890 - auc_roc: 0.7331
# Epoch 25/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6196 - accuracy: 0.6893 - auc_roc: 0.7298
# Epoch 26/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6255 - accuracy: 0.6936 - auc_roc: 0.7302
# Epoch 27/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6178 - accuracy: 0.6884 - auc_roc: 0.7321
# Epoch 28/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6182 - accuracy: 0.6896 - auc_roc: 0.7311
# Epoch 29/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6048 - accuracy: 0.7038 - auc_roc: 0.7452
# Epoch 30/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6318 - accuracy: 0.6729 - auc_roc: 0.7166
# Epoch 31/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6175 - accuracy: 0.6908 - auc_roc: 0.7292
# Epoch 32/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6026 - accuracy: 0.7022 - auc_roc: 0.7513
# Epoch 33/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6039 - accuracy: 0.7097 - auc_roc: 0.7532
# Epoch 34/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5962 - accuracy: 0.7185 - auc_roc: 0.7619
# Epoch 35/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5965 - accuracy: 0.7055 - auc_roc: 0.7546
# Epoch 36/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6036 - accuracy: 0.7150 - auc_roc: 0.7557
# Epoch 37/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5945 - accuracy: 0.7016 - auc_roc: 0.7628
# Epoch 38/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6212 - accuracy: 0.6796 - auc_roc: 0.7323
# Epoch 39/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6189 - accuracy: 0.6866 - auc_roc: 0.7338
# Epoch 40/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6027 - accuracy: 0.7028 - auc_roc: 0.7518
# Epoch 41/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6032 - accuracy: 0.7054 - auc_roc: 0.7556
# Epoch 42/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6097 - accuracy: 0.6854 - auc_roc: 0.7421
# Epoch 43/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6097 - accuracy: 0.6923 - auc_roc: 0.7467
# Epoch 44/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6003 - accuracy: 0.7079 - auc_roc: 0.7631
# Epoch 45/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5999 - accuracy: 0.6931 - auc_roc: 0.7553
# Epoch 46/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6139 - accuracy: 0.6885 - auc_roc: 0.7323
# Epoch 47/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5929 - accuracy: 0.7002 - auc_roc: 0.7598
# Epoch 48/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6036 - accuracy: 0.6973 - auc_roc: 0.7472
# Epoch 49/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6036 - accuracy: 0.6985 - auc_roc: 0.7503
# Epoch 50/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6064 - accuracy: 0.6894 - auc_roc: 0.7447
# Epoch 51/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6076 - accuracy: 0.6864 - auc_roc: 0.7341
# Epoch 52/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5933 - accuracy: 0.7059 - auc_roc: 0.7608
# Epoch 53/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5989 - accuracy: 0.6852 - auc_roc: 0.7489
# Epoch 54/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6009 - accuracy: 0.6924 - auc_roc: 0.7519
# Epoch 55/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5938 - accuracy: 0.7006 - auc_roc: 0.7608
# Epoch 56/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5950 - accuracy: 0.7062 - auc_roc: 0.7479
# Epoch 57/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5933 - accuracy: 0.6944 - auc_roc: 0.7585
# Epoch 58/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5841 - accuracy: 0.7039 - auc_roc: 0.7678
# Epoch 59/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5814 - accuracy: 0.7154 - auc_roc: 0.7708
# Epoch 60/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5903 - accuracy: 0.6951 - auc_roc: 0.7628
# Epoch 61/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6013 - accuracy: 0.6943 - auc_roc: 0.7527
# Epoch 62/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5970 - accuracy: 0.7070 - auc_roc: 0.7595
# Epoch 63/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5992 - accuracy: 0.6940 - auc_roc: 0.7539
# Epoch 64/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5961 - accuracy: 0.7021 - auc_roc: 0.7588
# Epoch 65/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5881 - accuracy: 0.7172 - auc_roc: 0.7652
# Epoch 66/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5946 - accuracy: 0.7001 - auc_roc: 0.7561
# Epoch 67/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6078 - accuracy: 0.6891 - auc_roc: 0.7422
# Epoch 68/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5882 - accuracy: 0.7052 - auc_roc: 0.7589
# Epoch 69/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5829 - accuracy: 0.7174 - auc_roc: 0.7708
# Epoch 70/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5709 - accuracy: 0.7303 - auc_roc: 0.7808
# Epoch 71/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5966 - accuracy: 0.7004 - auc_roc: 0.7508
# Epoch 72/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6001 - accuracy: 0.7093 - auc_roc: 0.7483
# Epoch 73/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5909 - accuracy: 0.7016 - auc_roc: 0.7618
# Epoch 74/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5987 - accuracy: 0.6912 - auc_roc: 0.7529
# Epoch 75/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5793 - accuracy: 0.7215 - auc_roc: 0.7799
# Epoch 76/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5755 - accuracy: 0.7171 - auc_roc: 0.7774
# Epoch 77/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5772 - accuracy: 0.7228 - auc_roc: 0.7800
# Epoch 78/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5931 - accuracy: 0.6968 - auc_roc: 0.7562
# Epoch 79/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5908 - accuracy: 0.7039 - auc_roc: 0.7630
# Epoch 80/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5953 - accuracy: 0.7048 - auc_roc: 0.7604
# Epoch 81/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5794 - accuracy: 0.7202 - auc_roc: 0.7765
# Epoch 82/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5961 - accuracy: 0.6950 - auc_roc: 0.7569
# Epoch 83/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5808 - accuracy: 0.7138 - auc_roc: 0.7652
# Epoch 84/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5990 - accuracy: 0.6950 - auc_roc: 0.7525
# Epoch 85/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5959 - accuracy: 0.6950 - auc_roc: 0.7535
# Epoch 86/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5735 - accuracy: 0.7202 - auc_roc: 0.7793
# Epoch 87/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5762 - accuracy: 0.7066 - auc_roc: 0.7742
# Epoch 88/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5829 - accuracy: 0.7071 - auc_roc: 0.7651
# Epoch 89/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5719 - accuracy: 0.7232 - auc_roc: 0.7756
# Epoch 90/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5912 - accuracy: 0.6973 - auc_roc: 0.7653
# Epoch 91/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5826 - accuracy: 0.7171 - auc_roc: 0.7688
# Epoch 92/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5829 - accuracy: 0.7086 - auc_roc: 0.7680
# Epoch 93/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5742 - accuracy: 0.7262 - auc_roc: 0.7798
# Epoch 94/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5744 - accuracy: 0.7224 - auc_roc: 0.7779
# Epoch 95/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5899 - accuracy: 0.7028 - auc_roc: 0.7640
# Epoch 96/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5864 - accuracy: 0.7084 - auc_roc: 0.7643
# Epoch 97/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6000 - accuracy: 0.6941 - auc_roc: 0.7480
# Epoch 98/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5946 - accuracy: 0.7050 - auc_roc: 0.7589
# Epoch 99/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5821 - accuracy: 0.7066 - auc_roc: 0.7698
# Epoch 100/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5722 - accuracy: 0.7034 - auc_roc: 0.7783
# 7/7 [==============================] - 0s 525us/step
# 7/7 [==============================] - 0s 582us/step
# 0003
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Epoch 1/100
# 14/14 [==============================] - 1s 14ms/step - loss: 0.6999 - accuracy: 0.5046 - auc_roc: 0.7191
# Epoch 2/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6947 - accuracy: 0.5914 - auc_roc: 0.6244
# Epoch 3/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6908 - accuracy: 0.6270 - auc_roc: 0.6553
# Epoch 4/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6833 - accuracy: 0.6512 - auc_roc: 0.6940
# Epoch 5/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6791 - accuracy: 0.6567 - auc_roc: 0.7140
# Epoch 6/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6748 - accuracy: 0.6830 - auc_roc: 0.7307
# Epoch 7/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6731 - accuracy: 0.6818 - auc_roc: 0.7210
# Epoch 8/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6639 - accuracy: 0.6952 - auc_roc: 0.7417
# Epoch 9/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6631 - accuracy: 0.7060 - auc_roc: 0.7348
# Epoch 10/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6536 - accuracy: 0.7016 - auc_roc: 0.7501
# Epoch 11/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6619 - accuracy: 0.6890 - auc_roc: 0.7090
# Epoch 12/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6564 - accuracy: 0.6713 - auc_roc: 0.7207
# Epoch 13/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6440 - accuracy: 0.7015 - auc_roc: 0.7462
# Epoch 14/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6475 - accuracy: 0.6899 - auc_roc: 0.7222
# Epoch 15/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6312 - accuracy: 0.7092 - auc_roc: 0.7525
# Epoch 16/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.6332 - accuracy: 0.6979 - auc_roc: 0.7349
# Epoch 17/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.6311 - accuracy: 0.7110 - auc_roc: 0.7438
# Epoch 18/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6185 - accuracy: 0.7063 - auc_roc: 0.7460
# Epoch 19/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6206 - accuracy: 0.7094 - auc_roc: 0.7478
# Epoch 20/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6226 - accuracy: 0.7084 - auc_roc: 0.7376
# Epoch 21/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6264 - accuracy: 0.6953 - auc_roc: 0.7342
# Epoch 22/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6273 - accuracy: 0.6979 - auc_roc: 0.7311
# Epoch 23/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6207 - accuracy: 0.6975 - auc_roc: 0.7392
# Epoch 24/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6306 - accuracy: 0.7024 - auc_roc: 0.7308
# Epoch 25/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6133 - accuracy: 0.7069 - auc_roc: 0.7489
# Epoch 26/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6221 - accuracy: 0.7112 - auc_roc: 0.7447
# Epoch 27/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6056 - accuracy: 0.7117 - auc_roc: 0.7565
# Epoch 28/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6080 - accuracy: 0.7084 - auc_roc: 0.7512
# Epoch 29/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6066 - accuracy: 0.7238 - auc_roc: 0.7584
# Epoch 30/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6270 - accuracy: 0.7080 - auc_roc: 0.7397
# Epoch 31/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6201 - accuracy: 0.6888 - auc_roc: 0.7318
# Epoch 32/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6081 - accuracy: 0.7073 - auc_roc: 0.7487
# Epoch 33/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6130 - accuracy: 0.7138 - auc_roc: 0.7464
# Epoch 34/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6057 - accuracy: 0.7074 - auc_roc: 0.7564
# Epoch 35/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6067 - accuracy: 0.7104 - auc_roc: 0.7504
# Epoch 36/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5949 - accuracy: 0.7222 - auc_roc: 0.7663
# Epoch 37/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6151 - accuracy: 0.7123 - auc_roc: 0.7452
# Epoch 38/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.6134 - accuracy: 0.6895 - auc_roc: 0.7398
# Epoch 39/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6102 - accuracy: 0.7006 - auc_roc: 0.7486
# Epoch 40/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6203 - accuracy: 0.6911 - auc_roc: 0.7333
# Epoch 41/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5964 - accuracy: 0.7055 - auc_roc: 0.7660
# Epoch 42/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6052 - accuracy: 0.7090 - auc_roc: 0.7518
# Epoch 43/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6031 - accuracy: 0.7216 - auc_roc: 0.7577
# Epoch 44/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6118 - accuracy: 0.7122 - auc_roc: 0.7446
# Epoch 45/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5948 - accuracy: 0.7269 - auc_roc: 0.7675
# Epoch 46/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6130 - accuracy: 0.6954 - auc_roc: 0.7423
# Epoch 47/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.5988 - accuracy: 0.7160 - auc_roc: 0.7631
# Epoch 48/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6072 - accuracy: 0.7124 - auc_roc: 0.7519
# Epoch 49/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6206 - accuracy: 0.7009 - auc_roc: 0.7357
# Epoch 50/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6081 - accuracy: 0.7031 - auc_roc: 0.7441
# Epoch 51/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.5856 - accuracy: 0.7261 - auc_roc: 0.7741
# Epoch 52/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5970 - accuracy: 0.7218 - auc_roc: 0.7609
# Epoch 53/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5931 - accuracy: 0.7253 - auc_roc: 0.7687
# Epoch 54/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5885 - accuracy: 0.7202 - auc_roc: 0.7680
# Epoch 55/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5945 - accuracy: 0.7281 - auc_roc: 0.7600
# Epoch 56/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6011 - accuracy: 0.7050 - auc_roc: 0.7529
# Epoch 57/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6006 - accuracy: 0.7085 - auc_roc: 0.7531
# Epoch 58/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5997 - accuracy: 0.7221 - auc_roc: 0.7550
# Epoch 59/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5887 - accuracy: 0.7229 - auc_roc: 0.7661
# Epoch 60/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6064 - accuracy: 0.7115 - auc_roc: 0.7505
# Epoch 61/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6008 - accuracy: 0.7206 - auc_roc: 0.7582
# Epoch 62/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.5950 - accuracy: 0.7228 - auc_roc: 0.7611
# Epoch 63/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6022 - accuracy: 0.7105 - auc_roc: 0.7565
# Epoch 64/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6010 - accuracy: 0.6990 - auc_roc: 0.7526
# Epoch 65/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5985 - accuracy: 0.7205 - auc_roc: 0.7640
# Epoch 66/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6018 - accuracy: 0.7092 - auc_roc: 0.7539
# Epoch 67/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.5873 - accuracy: 0.7224 - auc_roc: 0.7680
# Epoch 68/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5894 - accuracy: 0.7171 - auc_roc: 0.7676
# Epoch 69/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5924 - accuracy: 0.7196 - auc_roc: 0.7645
# Epoch 70/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5891 - accuracy: 0.7149 - auc_roc: 0.7687
# Epoch 71/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6233 - accuracy: 0.6998 - auc_roc: 0.7337
# Epoch 72/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6011 - accuracy: 0.7022 - auc_roc: 0.7545
# Epoch 73/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6063 - accuracy: 0.7115 - auc_roc: 0.7522
# Epoch 74/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5898 - accuracy: 0.7128 - auc_roc: 0.7663
# Epoch 75/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5835 - accuracy: 0.7334 - auc_roc: 0.7745
# Epoch 76/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6008 - accuracy: 0.7063 - auc_roc: 0.7509
# Epoch 77/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5997 - accuracy: 0.7090 - auc_roc: 0.7549
# Epoch 78/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5796 - accuracy: 0.7166 - auc_roc: 0.7745
# Epoch 79/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5978 - accuracy: 0.7097 - auc_roc: 0.7504
# Epoch 80/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6015 - accuracy: 0.7012 - auc_roc: 0.7523
# Epoch 81/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5825 - accuracy: 0.7254 - auc_roc: 0.7694
# Epoch 82/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5959 - accuracy: 0.7120 - auc_roc: 0.7579
# Epoch 83/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6030 - accuracy: 0.7129 - auc_roc: 0.7516
# Epoch 84/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5883 - accuracy: 0.7280 - auc_roc: 0.7690
# Epoch 85/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5909 - accuracy: 0.7208 - auc_roc: 0.7642
# Epoch 86/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5910 - accuracy: 0.7275 - auc_roc: 0.7643
# Epoch 87/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5920 - accuracy: 0.7120 - auc_roc: 0.7627
# Epoch 88/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5867 - accuracy: 0.7144 - auc_roc: 0.7692
# Epoch 89/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5909 - accuracy: 0.7127 - auc_roc: 0.7639
# Epoch 90/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5770 - accuracy: 0.7238 - auc_roc: 0.7777
# Epoch 91/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5886 - accuracy: 0.7157 - auc_roc: 0.7627
# Epoch 92/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5952 - accuracy: 0.7068 - auc_roc: 0.7605
# Epoch 93/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6138 - accuracy: 0.6964 - auc_roc: 0.7418
# Epoch 94/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5925 - accuracy: 0.6962 - auc_roc: 0.7574
# Epoch 95/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6007 - accuracy: 0.7166 - auc_roc: 0.7557
# Epoch 96/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5856 - accuracy: 0.7321 - auc_roc: 0.7678
# Epoch 97/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5781 - accuracy: 0.7305 - auc_roc: 0.7751
# Epoch 98/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5770 - accuracy: 0.7193 - auc_roc: 0.7771
# Epoch 99/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5942 - accuracy: 0.7151 - auc_roc: 0.7593
# Epoch 100/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.5893 - accuracy: 0.7061 - auc_roc: 0.7628
# 7/7 [==============================] - 0s 666us/step
# 7/7 [==============================] - 0s 841us/step
# 0004
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Epoch 1/100
# 14/14 [==============================] - 1s 14ms/step - loss: 0.7167 - accuracy: 0.3534 - auc_roc: 0.6840
# Epoch 2/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.7090 - accuracy: 0.4015 - auc_roc: 0.3955
# Epoch 3/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.7021 - accuracy: 0.4742 - auc_roc: 0.4953
# Epoch 4/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6969 - accuracy: 0.5366 - auc_roc: 0.5815
# Epoch 5/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6918 - accuracy: 0.5923 - auc_roc: 0.6327
# Epoch 6/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6867 - accuracy: 0.6148 - auc_roc: 0.6747
# Epoch 7/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6785 - accuracy: 0.6700 - auc_roc: 0.7213
# Epoch 8/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6716 - accuracy: 0.6713 - auc_roc: 0.7361
# Epoch 9/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6708 - accuracy: 0.6790 - auc_roc: 0.7229
# Epoch 10/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6648 - accuracy: 0.6802 - auc_roc: 0.7353
# Epoch 11/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6610 - accuracy: 0.6894 - auc_roc: 0.7352
# Epoch 12/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6578 - accuracy: 0.6901 - auc_roc: 0.7347
# Epoch 13/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6505 - accuracy: 0.6929 - auc_roc: 0.7442
# Epoch 14/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6481 - accuracy: 0.6936 - auc_roc: 0.7333
# Epoch 15/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6477 - accuracy: 0.6791 - auc_roc: 0.7185
# Epoch 16/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6367 - accuracy: 0.6992 - auc_roc: 0.7354
# Epoch 17/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6398 - accuracy: 0.6881 - auc_roc: 0.7279
# Epoch 18/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6255 - accuracy: 0.7103 - auc_roc: 0.7504
# Epoch 19/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6159 - accuracy: 0.7109 - auc_roc: 0.7631
# Epoch 20/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6127 - accuracy: 0.7086 - auc_roc: 0.7559
# Epoch 21/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6140 - accuracy: 0.7149 - auc_roc: 0.7543
# Epoch 22/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6259 - accuracy: 0.6932 - auc_roc: 0.7301
# Epoch 23/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6121 - accuracy: 0.7124 - auc_roc: 0.7486
# Epoch 24/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6254 - accuracy: 0.6929 - auc_roc: 0.7355
# Epoch 25/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6158 - accuracy: 0.7074 - auc_roc: 0.7481
# Epoch 26/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6109 - accuracy: 0.7097 - auc_roc: 0.7479
# Epoch 27/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6042 - accuracy: 0.7127 - auc_roc: 0.7561
# Epoch 28/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5986 - accuracy: 0.7185 - auc_roc: 0.7634
# Epoch 29/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6024 - accuracy: 0.7242 - auc_roc: 0.7611
# Epoch 30/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5988 - accuracy: 0.7104 - auc_roc: 0.7591
# Epoch 31/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6174 - accuracy: 0.7059 - auc_roc: 0.7434
# Epoch 32/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6100 - accuracy: 0.7076 - auc_roc: 0.7493
# Epoch 33/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6091 - accuracy: 0.7040 - auc_roc: 0.7492
# Epoch 34/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6221 - accuracy: 0.7072 - auc_roc: 0.7486
# Epoch 35/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5960 - accuracy: 0.7103 - auc_roc: 0.7570
# Epoch 36/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6001 - accuracy: 0.7227 - auc_roc: 0.7588
# Epoch 37/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6005 - accuracy: 0.7136 - auc_roc: 0.7572
# Epoch 38/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5964 - accuracy: 0.7088 - auc_roc: 0.7573
# Epoch 39/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6045 - accuracy: 0.7018 - auc_roc: 0.7463
# Epoch 40/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6055 - accuracy: 0.7082 - auc_roc: 0.7532
# Epoch 41/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6096 - accuracy: 0.6974 - auc_roc: 0.7509
# Epoch 42/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6101 - accuracy: 0.7004 - auc_roc: 0.7451
# Epoch 43/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6050 - accuracy: 0.7167 - auc_roc: 0.7568
# Epoch 44/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6007 - accuracy: 0.7022 - auc_roc: 0.7558
# Epoch 45/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5917 - accuracy: 0.7155 - auc_roc: 0.7692
# Epoch 46/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5988 - accuracy: 0.7153 - auc_roc: 0.7607
# Epoch 47/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5895 - accuracy: 0.7261 - auc_roc: 0.7692
# Epoch 48/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5980 - accuracy: 0.7156 - auc_roc: 0.7588
# Epoch 49/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5934 - accuracy: 0.7169 - auc_roc: 0.7668
# Epoch 50/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6029 - accuracy: 0.7175 - auc_roc: 0.7536
# Epoch 51/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5864 - accuracy: 0.7248 - auc_roc: 0.7768
# Epoch 52/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.6023 - accuracy: 0.7080 - auc_roc: 0.7555
# Epoch 53/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5950 - accuracy: 0.7113 - auc_roc: 0.7613
# Epoch 54/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5947 - accuracy: 0.7197 - auc_roc: 0.7617
# Epoch 55/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5952 - accuracy: 0.7202 - auc_roc: 0.7643
# Epoch 56/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5789 - accuracy: 0.7381 - auc_roc: 0.7810
# Epoch 57/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5942 - accuracy: 0.7127 - auc_roc: 0.7575
# Epoch 58/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5906 - accuracy: 0.7265 - auc_roc: 0.7675
# Epoch 59/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5907 - accuracy: 0.7189 - auc_roc: 0.7639
# Epoch 60/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5909 - accuracy: 0.7253 - auc_roc: 0.7653
# Epoch 61/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5863 - accuracy: 0.7292 - auc_roc: 0.7707
# Epoch 62/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5912 - accuracy: 0.7239 - auc_roc: 0.7634
# Epoch 63/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5871 - accuracy: 0.7232 - auc_roc: 0.7634
# Epoch 64/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5958 - accuracy: 0.7134 - auc_roc: 0.7574
# Epoch 65/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5938 - accuracy: 0.7111 - auc_roc: 0.7610
# Epoch 66/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.5886 - accuracy: 0.7219 - auc_roc: 0.7707
# Epoch 67/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5981 - accuracy: 0.7305 - auc_roc: 0.7577
# Epoch 68/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5840 - accuracy: 0.7223 - auc_roc: 0.7745
# Epoch 69/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5947 - accuracy: 0.7062 - auc_roc: 0.7587
# Epoch 70/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5910 - accuracy: 0.7167 - auc_roc: 0.7614
# Epoch 71/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5883 - accuracy: 0.7267 - auc_roc: 0.7648
# Epoch 72/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5969 - accuracy: 0.7143 - auc_roc: 0.7587
# Epoch 73/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5836 - accuracy: 0.7081 - auc_roc: 0.7706
# Epoch 74/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5898 - accuracy: 0.7174 - auc_roc: 0.7671
# Epoch 75/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5954 - accuracy: 0.7066 - auc_roc: 0.7590
# Epoch 76/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.5832 - accuracy: 0.7304 - auc_roc: 0.7735
# Epoch 77/100
# ...
# Epoch 75/100
# 21/21 [==============================] - 0s 14ms/step - loss: 0.5179 - accuracy: 0.7598 - auc_roc: 0.7721
# Epoch 76/100
# 21/21 [==============================] - 0s 14ms/step - loss: 0.4940 - accuracy: 0.7836 - auc_roc: 0.7900
# Epoch 77/100
# 21/21 [==============================] - 0s 14ms/step - loss: 0.5127 - accuracy: 0.7639 - auc_roc: 0.7800
# Epoch 78/100
# 21/21 [==============================] - 0s 14ms/step - loss: 0.5181 - accuracy: 0.7567 - auc_roc: 0.7790
# Epoch 79/100
# 21/21 [==============================] - 0s 14ms/step - loss: 0.5138 - accuracy: 0.7589 - auc_roc: 0.7710
# Epoch 80/100
# 21/21 [==============================] - 0s 14ms/step - loss: 0.4976 - accuracy: 0.7688 - auc_roc: 0.7877
# Epoch 81/100
# 21/21 [==============================] - 0s 14ms/step - loss: 0.5212 - accuracy: 0.7577 - auc_roc: 0.7760
# Epoch 82/100
# 21/21 [==============================] - 0s 14ms/step - loss: 0.5003 - accuracy: 0.7684 - auc_roc: 0.7865
# Epoch 83/100
# 21/21 [==============================] - 0s 14ms/step - loss: 0.5224 - accuracy: 0.7537 - auc_roc: 0.7679
# Epoch 84/100
# 21/21 [==============================] - 0s 14ms/step - loss: 0.5094 - accuracy: 0.7638 - auc_roc: 0.7688
# Epoch 85/100
# 21/21 [==============================] - 0s 14ms/step - loss: 0.5170 - accuracy: 0.7529 - auc_roc: 0.7760
# Epoch 86/100
# 21/21 [==============================] - 0s 14ms/step - loss: 0.5144 - accuracy: 0.7606 - auc_roc: 0.7760
# Epoch 87/100
# 21/21 [==============================] - 0s 14ms/step - loss: 0.4988 - accuracy: 0.7712 - auc_roc: 0.7890
# Epoch 88/100
# 21/21 [==============================] - 0s 14ms/step - loss: 0.4995 - accuracy: 0.7660 - auc_roc: 0.7843
# Epoch 89/100
# 21/21 [==============================] - 0s 14ms/step - loss: 0.5014 - accuracy: 0.7691 - auc_roc: 0.7866
# Epoch 90/100
# 21/21 [==============================] - 0s 14ms/step - loss: 0.5126 - accuracy: 0.7605 - auc_roc: 0.7759
# Epoch 91/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.5146 - accuracy: 0.7728 - auc_roc: 0.7745
# Epoch 92/100
# 21/21 [==============================] - 0s 14ms/step - loss: 0.5143 - accuracy: 0.7578 - auc_roc: 0.7746
# Epoch 93/100
# 21/21 [==============================] - 0s 14ms/step - loss: 0.5018 - accuracy: 0.7612 - auc_roc: 0.7941
# Epoch 94/100
# 21/21 [==============================] - 0s 14ms/step - loss: 0.4992 - accuracy: 0.7707 - auc_roc: 0.7876
# Epoch 95/100
# 21/21 [==============================] - 0s 14ms/step - loss: 0.5043 - accuracy: 0.7694 - auc_roc: 0.7770
# Epoch 96/100
# 21/21 [==============================] - 0s 14ms/step - loss: 0.4990 - accuracy: 0.7705 - auc_roc: 0.7925
# Epoch 97/100
# 21/21 [==============================] - 0s 14ms/step - loss: 0.4973 - accuracy: 0.7668 - auc_roc: 0.7954
# Epoch 98/100
# 21/21 [==============================] - 0s 14ms/step - loss: 0.4881 - accuracy: 0.7719 - auc_roc: 0.8017
# Epoch 99/100
# 21/21 [==============================] - 0s 14ms/step - loss: 0.5108 - accuracy: 0.7565 - auc_roc: 0.7811
# Epoch 100/100
# 21/21 [==============================] - 0s 14ms/step - loss: 0.5101 - accuracy: 0.7623 - auc_roc: 0.7804
# 7/7 [==============================] - 0s 617us/step
# 7/7 [==============================] - 0s 603us/step
# 0121
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Epoch 1/100
# 26/26 [==============================] - 1s 14ms/step - loss: 0.6926 - accuracy: 0.5903 - auc_roc: 0.7234
# Epoch 2/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.6820 - accuracy: 0.6661 - auc_roc: 0.6987
# Epoch 3/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.6727 - accuracy: 0.6661 - auc_roc: 0.7153
# Epoch 4/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.6646 - accuracy: 0.6889 - auc_roc: 0.7222
# Epoch 5/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.6503 - accuracy: 0.6963 - auc_roc: 0.7456
# Epoch 6/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.6445 - accuracy: 0.6838 - auc_roc: 0.7286
# Epoch 7/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.6351 - accuracy: 0.6863 - auc_roc: 0.7273
# Epoch 8/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.6284 - accuracy: 0.6889 - auc_roc: 0.7337
# Epoch 9/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.6181 - accuracy: 0.6842 - auc_roc: 0.7287
# Epoch 10/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.6148 - accuracy: 0.6852 - auc_roc: 0.7272
# Epoch 11/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.6008 - accuracy: 0.6954 - auc_roc: 0.7377
# Epoch 12/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5943 - accuracy: 0.6993 - auc_roc: 0.7431
# Epoch 13/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5908 - accuracy: 0.7063 - auc_roc: 0.7464
# Epoch 14/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5780 - accuracy: 0.7039 - auc_roc: 0.7629
# Epoch 15/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5801 - accuracy: 0.7144 - auc_roc: 0.7569
# Epoch 16/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.6025 - accuracy: 0.6987 - auc_roc: 0.7272
# Epoch 17/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5822 - accuracy: 0.7051 - auc_roc: 0.7510
# Epoch 18/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5760 - accuracy: 0.7211 - auc_roc: 0.7624
# Epoch 19/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5981 - accuracy: 0.7009 - auc_roc: 0.7407
# Epoch 20/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5762 - accuracy: 0.7043 - auc_roc: 0.7574
# Epoch 21/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5742 - accuracy: 0.7193 - auc_roc: 0.7622
# Epoch 22/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5893 - accuracy: 0.7048 - auc_roc: 0.7447
# Epoch 23/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5618 - accuracy: 0.7292 - auc_roc: 0.7674
# Epoch 24/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5670 - accuracy: 0.7147 - auc_roc: 0.7617
# Epoch 25/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5763 - accuracy: 0.7100 - auc_roc: 0.7565
# Epoch 26/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5855 - accuracy: 0.7050 - auc_roc: 0.7554
# Epoch 27/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5708 - accuracy: 0.7188 - auc_roc: 0.7596
# Epoch 28/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5810 - accuracy: 0.7120 - auc_roc: 0.7544
# Epoch 29/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5658 - accuracy: 0.7149 - auc_roc: 0.7638
# Epoch 30/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5609 - accuracy: 0.7221 - auc_roc: 0.7747
# Epoch 31/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5647 - accuracy: 0.7160 - auc_roc: 0.7663
# Epoch 32/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5742 - accuracy: 0.7270 - auc_roc: 0.7568
# Epoch 33/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5662 - accuracy: 0.7206 - auc_roc: 0.7637
# Epoch 34/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5814 - accuracy: 0.7116 - auc_roc: 0.7563
# Epoch 35/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5669 - accuracy: 0.7226 - auc_roc: 0.7624
# Epoch 36/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5669 - accuracy: 0.7219 - auc_roc: 0.7620
# Epoch 37/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5709 - accuracy: 0.7141 - auc_roc: 0.7579
# Epoch 38/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5671 - accuracy: 0.7230 - auc_roc: 0.7577
# Epoch 39/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5762 - accuracy: 0.7164 - auc_roc: 0.7589
# Epoch 40/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5684 - accuracy: 0.7211 - auc_roc: 0.7612
# Epoch 41/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5603 - accuracy: 0.7243 - auc_roc: 0.7700
# Epoch 42/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5710 - accuracy: 0.7248 - auc_roc: 0.7629
# Epoch 43/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5720 - accuracy: 0.7140 - auc_roc: 0.7568
# Epoch 44/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5609 - accuracy: 0.7319 - auc_roc: 0.7723
# Epoch 45/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5661 - accuracy: 0.7205 - auc_roc: 0.7657
# Epoch 46/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5782 - accuracy: 0.7146 - auc_roc: 0.7512
# Epoch 47/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5696 - accuracy: 0.7228 - auc_roc: 0.7656
# Epoch 48/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5640 - accuracy: 0.7158 - auc_roc: 0.7681
# Epoch 49/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5663 - accuracy: 0.7197 - auc_roc: 0.7663
# Epoch 50/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5735 - accuracy: 0.7263 - auc_roc: 0.7666
# Epoch 51/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5689 - accuracy: 0.7227 - auc_roc: 0.7574
# Epoch 52/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5623 - accuracy: 0.7215 - auc_roc: 0.7722
# Epoch 53/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5578 - accuracy: 0.7331 - auc_roc: 0.7770
# Epoch 54/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5659 - accuracy: 0.7207 - auc_roc: 0.7591
# Epoch 55/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5708 - accuracy: 0.7152 - auc_roc: 0.7532
# Epoch 56/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5504 - accuracy: 0.7340 - auc_roc: 0.7770
# Epoch 57/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5581 - accuracy: 0.7256 - auc_roc: 0.7766
# Epoch 58/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5506 - accuracy: 0.7332 - auc_roc: 0.7778
# Epoch 59/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5475 - accuracy: 0.7387 - auc_roc: 0.7769
# Epoch 60/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5611 - accuracy: 0.7199 - auc_roc: 0.7681
# Epoch 61/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5644 - accuracy: 0.7254 - auc_roc: 0.7686
# Epoch 62/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5591 - accuracy: 0.7320 - auc_roc: 0.7762
# Epoch 63/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5576 - accuracy: 0.7219 - auc_roc: 0.7736
# Epoch 64/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5631 - accuracy: 0.7282 - auc_roc: 0.7618
# Epoch 65/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5531 - accuracy: 0.7402 - auc_roc: 0.7766
# Epoch 66/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5525 - accuracy: 0.7305 - auc_roc: 0.7784
# Epoch 67/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5456 - accuracy: 0.7339 - auc_roc: 0.7844
# Epoch 68/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5657 - accuracy: 0.7175 - auc_roc: 0.7631
# Epoch 69/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5493 - accuracy: 0.7393 - auc_roc: 0.7749
# Epoch 70/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5473 - accuracy: 0.7369 - auc_roc: 0.7840
# Epoch 71/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5548 - accuracy: 0.7341 - auc_roc: 0.7729
# Epoch 72/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5617 - accuracy: 0.7261 - auc_roc: 0.7702
# Epoch 73/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5573 - accuracy: 0.7314 - auc_roc: 0.7718
# Epoch 74/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5801 - accuracy: 0.7107 - auc_roc: 0.7559
# Epoch 75/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5570 - accuracy: 0.7259 - auc_roc: 0.7689
# Epoch 76/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5560 - accuracy: 0.7284 - auc_roc: 0.7799
# Epoch 77/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5524 - accuracy: 0.7298 - auc_roc: 0.7751
# Epoch 78/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5565 - accuracy: 0.7355 - auc_roc: 0.7667
# Epoch 79/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5547 - accuracy: 0.7311 - auc_roc: 0.7746
# Epoch 80/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5603 - accuracy: 0.7170 - auc_roc: 0.7771
# Epoch 81/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5477 - accuracy: 0.7259 - auc_roc: 0.7831
# Epoch 82/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5539 - accuracy: 0.7317 - auc_roc: 0.7752
# Epoch 83/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5535 - accuracy: 0.7283 - auc_roc: 0.7807
# Epoch 84/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5546 - accuracy: 0.7316 - auc_roc: 0.7711
# Epoch 85/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5567 - accuracy: 0.7326 - auc_roc: 0.7754
# Epoch 86/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5516 - accuracy: 0.7361 - auc_roc: 0.7837
# Epoch 87/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5576 - accuracy: 0.7296 - auc_roc: 0.7730
# Epoch 88/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5604 - accuracy: 0.7276 - auc_roc: 0.7675
# Epoch 89/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5596 - accuracy: 0.7248 - auc_roc: 0.7715
# Epoch 90/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5489 - accuracy: 0.7367 - auc_roc: 0.7785
# Epoch 91/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5538 - accuracy: 0.7323 - auc_roc: 0.7729
# Epoch 92/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5644 - accuracy: 0.7293 - auc_roc: 0.7697
# Epoch 93/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5518 - accuracy: 0.7360 - auc_roc: 0.7790
# Epoch 94/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5559 - accuracy: 0.7270 - auc_roc: 0.7836
# Epoch 95/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5499 - accuracy: 0.7449 - auc_roc: 0.7876
# Epoch 96/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5616 - accuracy: 0.7190 - auc_roc: 0.7719
# Epoch 97/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5524 - accuracy: 0.7372 - auc_roc: 0.7790
# Epoch 98/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5465 - accuracy: 0.7383 - auc_roc: 0.7807
# Epoch 99/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5366 - accuracy: 0.7466 - auc_roc: 0.7923
# Epoch 100/100
# 26/26 [==============================] - 0s 14ms/step - loss: 0.5579 - accuracy: 0.7249 - auc_roc: 0.7708

# %%
# top 20 performers by the test_roc_auc score
#,'param_model__max_features'
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
#res_cols = ['mean_test_roc_auc', 'mean_test_accuracy', 'param_balance__balancer_type', 'param_features__k', 
#            'param_features__score_func', 'param_model__C', 'param_model__solver', 
#            'param_outlier__outlier_threshold', 'param__vif_score_threshold']
#res_cols = ['mean_test_roc_auc','mean_test_accuracy', 'param_balance__balancer_type','param_features__k', 'param_model__batch_size','param_model__epochs',
            #'param_outlier__outlier_threshold']
res_cols = ['mean_test_roc_auc','mean_test_accuracy', 'param_balance__balancer_type','param_features__k',
            'param_outlier__outlier_threshold']
#res_cols = ['mean_test_roc_auc','mean_test_accuracy', 'param_balance__balancer_type','param_model__optimizer',
            #'param_outlier__outlier_threshold']
df_sorted = df_result[res_cols].reset_index(drop=True).sort_values('mean_test_roc_auc', axis=0, ascending=False)
df_sorted.index = pd.RangeIndex(1, len(df_sorted.index)+1)
df_sorted
# Out:
#     mean_test_roc_auc  mean_test_accuracy param_balance__balancer_type  \
# 1            0.646217            0.472295                    smote-enn
# 2            0.642381            0.466157                    smote-enn
# 3            0.642141            0.467390                    smote-enn
# 4            0.641516            0.579249                       allknn
# 5            0.641161            0.448482                    smote-enn
# 6            0.641029            0.583661                       allknn
# 7            0.640324            0.579250                       allknn
# 8            0.639958            0.441861                    smote-enn
# 9            0.639031            0.581703                       allknn
# 10           0.638975            0.440386                    smote-enn
# 11           0.638842            0.581456                       allknn
# 12           0.638772            0.461990                    smote-enn
# 13           0.638172            0.587102                       allknn
# 14           0.637999            0.581698                       allknn
# 15           0.637939            0.577525                       allknn
# 16           0.636779            0.429109                    smote-enn
# 17           0.635998            0.445543                    smote-enn
# 18           0.635650            0.578028                       allknn
# 19           0.635021            0.586853                       allknn
# 20           0.633154            0.438192                    smote-enn
# 21           0.631379            0.579494                       allknn
# 22           0.630810            0.588078                       allknn
# 23           0.629748            0.410201                    smote-enn
# 24           0.628090            0.418805                    smote-enn
#
#    param_features__k param_outlier__outlier_threshold
# 1                 12                                3
# 2                 12                                0
# 3                 15                                0
# 4                 15                                3
# 5                 18                                3
# 6                 18                                0
# 7                 18                                3
# 8                 24                                0
# 9                 12                                0
# 10                24                                3
# 11                12                                3
# 12                15                                3
# 13                24                                0
# 14                15                                0
# 15                21                                0
# 16                21                                0
# 17                18                                0
# 18                21                                3
# 19                24                                3
# 20                21                                3
# 21                31                                3
# 22                31                                0
# 23                31                                3
# 24                31                                0

# %%
# the average roc-auc and accuracy scores of just completed search.
# these are the averages of each model over the convolution folds.
#print(df_result['mean_test_roc_auc'])
#print(df_result['mean_test_accuracy'])
print(best_params)
# Out:
# {'balance__balancer_type': 'smote-enn', 'features__k': 12, 'outlier__outlier_threshold': 3.0, 'scaling__type_of_scaling': 'standard'}

# %%
# display results for the best estimator we found
predictions = best_estimator.predict(df_features)
probabilities = best_estimator.predict_proba(df_features)[:,1]
mindwandering.evaluate.evaluate_model_results(mind_wandered_label, predictions, probabilities)
# Out:
# 32/32 [==============================] - 0s 411us/step
# 32/32 [==============================] - 0s 410us/step
# Accuracy score:         0.5049067713444554
# Recall (TPR) score:     0.8194070080862533
# Precision score:        0.33418834737999265
# AUC-ROC score:          0.6030885867295932
#
# True positives:   912
# True negatives:   1146
# False positives:  1817
# False negatives:  201
# True Positive Rate (recall):  0.8194070080862533
# False Positive Rate:          0.6132298346270671
# Specificity:                  0.38677016537293285
#
# [[1146 1817]
#  [ 201  912]]
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '

# %%
# save the results and preliminary figures in the following cells

# create base save file name for this file, use datetime to keep a unique file name
"""now = datetime.now()
date_time = now.strftime('%Y%m%d-%H%M')
result_file_basename = 'replication-07-Neural-Network-using-Adam' + date_time
print(result_file_basename)"""
# Out:
# "now = datetime.now()\ndate_time = now.strftime('%Y%m%d-%H%M')\nresult_file_basename = 'replication-07-Neural-Network-using-Adam' + date_time\nprint(result_file_basename)"

# %%
# A quick histogram of this search auc-roc scores.  Basically the figure 1 from the paper.
plt.figure(figsize=(12,8))

#bins = np.linspace(0.605, 0.612, 8)
plt.hist(df_result.mean_test_roc_auc, 
         bins=20,
         color='lightblue',
         rwidth=0.9);
#plt.xlabel('Area under the receiver operating characteristic (AUC-ROC)');
plt.xlabel('Area under the receiver operating characteristic (AUC-ROC)');
plt.ylabel('Number of models');
plt.title('Neural Network Replication using Adam: ' + result_file_basename);

"""result_dir = '../figures'
result_file_name = result_file_basename + '.eps'
result_file_path = os.path.join(result_dir, result_file_name)
plt.savefig(result_file_path)"""
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-3e71222807f5> in <module>
#      10 plt.xlabel('Area under the receiver operating characteristic (AUC-ROC)');
#      11 plt.ylabel('Number of models');
# ---> 12 plt.title('Neural Network Replication using Adam: ' + result_file_basename);
#      13
#      14 """result_dir = '../figures'
#
# NameError: name 'result_file_basename' is not defined
