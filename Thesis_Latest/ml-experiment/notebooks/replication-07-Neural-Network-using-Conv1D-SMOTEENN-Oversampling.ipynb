# %% [markdown]
# - mean_test_auc_roc using Logistic Regression:
# - mean_test_auc_roc using KNN:0.631033
# - mean_test_auc_roc using SVM:0.658805
# - mean_test_auc_roc using Random Forest:0.657398
# - mean_test_auc_roc using Decision Tree:0.640888
# - mean_test_auc_roc using **Naive Bayes:0.659468**
# - mean_test_auc_roc using Neural Network(Adam):0.634302
# - mean_test_auc_roc using Neural Network(SGD):0.630862
# - mean_test_auc_roc using Neural Network(RMSprop):0.629448

# %%
# globally useful imports of standard libraries needed in this notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os.path
from datetime import datetime

# specific libraries or classes needed for the work in this notebook
#from sklearn.linear_model import LogisticRegression
#from sklearn.linear_model import LogisticRegressionCV
#from sklearn.svm import SVC
#from sklearn.naive_bayes import GaussianNB
#from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GroupKFold
from sklearn.model_selection import LeaveOneGroupOut
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import SelectKBest, f_classif, chi2, SelectFpr, f_regression, mutual_info_classif
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import RFE
from sklearn.feature_selection import VarianceThreshold
from sklearn.ensemble import ExtraTreesClassifier
#from sklearn.pipeline import Pipeline
# need to use Pipeline from imblearn to add in a downsample or upsample
# to cross validation training
from imblearn.pipeline import Pipeline

# import project specific modules used in this notebook
import sys
sys.path.append('../src')
import mindwandering.data
import mindwandering.features
import mindwandering.evaluate
from mindwandering.data import FeatureScalerTransformer
from mindwandering.data import WinsorizationOutlierTransformer
from mindwandering.data import VIFThresholdTransformer
from mindwandering.data import FeatureSelectionTransformer
from mindwandering.data import ClassImbalanceTransformer
from mindwandering.data import GridSearchProgressHack


from sklearn.preprocessing import StandardScaler

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.layers import Input, Dense, Activation, Dropout, BatchNormalization,Flatten
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import SGD,Adam,RMSprop
from tensorflow.keras.layers import Conv1D,GRU,TimeDistributed,MaxPooling1D
from tensorflow.keras.models import Model
from tensorflow.keras.layers import AveragePooling1D,ZeroPadding1D

# %%
# Load Data and Features
df_features = mindwandering.data.get_df_features()
mind_wandered_label = mindwandering.data.get_mind_wandered_label()
participant_ids = mindwandering.data.get_participant_ids()

# %% [markdown]
# # Standard Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_features=scaler.fit_transform(df_features)

# %% [markdown]
# # Select k-best features

# %%
from sklearn.feature_selection import SelectKBest
df_features = SelectKBest(k=12).fit_transform(df_features,mind_wandered_label)

# %%
participant_ids=participant_ids[:3300]

# %% [markdown]
# # Allknn undersampling

# %%
"""from imblearn.under_sampling import AllKNN
#df_features=df_features.values.reshape(-1, 1)
allknn = AllKNN()
df_features, mind_wandered_label = allknn.fit_resample(df_features, mind_wandered_label)"""
# Out:
# 'from imblearn.under_sampling import AllKNN\n#df_features=df_features.values.reshape(-1, 1)\nallknn = AllKNN()\ndf_features, mind_wandered_label = allknn.fit_resample(df_features, mind_wandered_label)'

# %% [markdown]
# # SMOTEENN Oversampling

# %%
from imblearn.combine import SMOTEENN
sme = SMOTEENN(random_state=42)
df_features, mind_wandered_label = sme.fit_resample(df_features, mind_wandered_label)

# %%
mind_wandered_label.shape
# Out:
# (3300,)

# %% [markdown]
# # Data Reshape for conv1d

# %%
#df_features = df_features.to_numpy()
df_features=df_features.reshape((df_features.shape[0], df_features.shape[1], 1))
df_features.shape
# Out:
# (3300, 12, 1)

# %% [markdown]
# # AUROC

# %%
import tensorflow
auc_roc = tensorflow.keras.metrics.AUC(name='auc_roc',num_thresholds=20000,curve='ROC')

# %% [markdown]
# # Conv1d Model

# %%
def create_model(filters=64,kernel_size=5):
    model = Sequential([
    Conv1D(filters=filters, kernel_size=kernel_size,strides=8, activation='tanh',padding='same', input_shape=(df_features.shape[1], 1)),
    ZeroPadding1D(padding=1),
    Flatten(),
    Dense(32, activation='relu'),
    Dense(1, activation='swish'),
    Activation('sigmoid')])
    optimizer=SGD(lr=0.001)
    model.compile(loss='binary_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy', auc_roc])
    return model

# %%
# Wrap Keras model so it can be used by scikit-learn
#kears_estimator = KerasClassifier(build_fn=create_model,epochs=100, batch_size=32, verbose=1)
kears_estimator = KerasClassifier(build_fn=create_model,epochs=50, batch_size=32, verbose=1)
#kears_estimator = KerasClassifier(build_fn=create_model, verbose=1)

# %%
# Empty dataframe to gather grid search results into 1 place
best_estimator = None
best_score = 0.0
best_params = {}
best_index = 0
df_result = None


parameters = {
        #'scaling__type_of_scaling': ['standard'],
        #'outlier__outlier_threshold': [0.0, 3.0],
        #'features__k': [12],
        #'balance__balancer_type': ['random-undersampler', 'allknn', 'nearmiss', 'instance-hardness-threshold'],
        #'balance__balancer_type': ['allknn', 'condensed-nn', 'neighbourhood-cleaning', 'one-sided-selection'],
        #'balance__balancer_type': ['allknn', 'one-sided-selection'],
        #'balance__balancer_type': ['allknn', 'smote-enn'],
        #'model__var_smoothing': [1e-6,1e-7,1e-8,1e-9,1e-10,1e-11,1e-12],
        'model__batch_size': [32, 48],#usually multiple of 8
        'model__epochs':[50,60],
        'model__filters':[8,16,32,64],
        'model__kernel_size':[3,5,7],
        #'model__batch_size': [60],
        #'model__epochs':[10],
        #'model__optimizer' : ['RMSprop', 'Adagrad', 'Adadelta','Adam']
    }

# Estimator Pipeline
pipeline = Pipeline(
      [
        #('progress', GridSearchProgressHack(verbose=False)),
        #('scaling',  FeatureScalerTransformer()),
        #('outlier',  WinsorizationOutlierTransformer()),
        #('features', SelectKBest()),
        #('features', SelectFromModel(estimator=LogisticRegression(solver='liblinear', penalty='l1', C=0.1), threshold=-np.inf)),
        #('balance',  ClassImbalanceTransformer()),
        ('model',    kears_estimator)
      ]
    )
    
# Cross Validation Splitter
cv_group_splitter = GroupKFold(n_splits=5)
    #cv_group_splitter = LeaveOneGroupOut()

    # perform the grid search for this vif selection
    # set up the search
search = GridSearchCV(
        estimator = pipeline,
        param_grid = parameters,
        scoring = ['roc_auc','accuracy'],
        cv = cv_group_splitter,
        #cv = 5,
        refit = 'roc_auc',
        verbose = 1)

search.fit(df_features, mind_wandered_label, groups=participant_ids)
#search.fit(df_features, mind_wandered_label)

df = pd.DataFrame(data=search.cv_results_)
    
    
if best_estimator is None:
    df_result = df
    best_estimator = search.best_estimator_
    best_score = search.best_score_
    best_params = search.best_params_
    best_index = search.best_index_
else:
    df_result = df_result.append(df, ignore_index=True)
    if search.best_score_ > best_score:
        best_estimator = search.best_estimator_
        best_score = search.best_score_
        best_params = search.best_params_
        best_index = search.best_index_  # todo this is only the index of this search
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# Epoch 1/50
# 83/83 [==============================] - 1s 3ms/step - loss: 0.7124 - accuracy: 0.3534 - auc_roc: 0.3572
# Epoch 2/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7122 - accuracy: 0.3561 - auc_roc: 0.3454
# Epoch 3/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7121 - accuracy: 0.3409 - auc_roc: 0.3580
# Epoch 4/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7097 - accuracy: 0.3643 - auc_roc: 0.3458
# Epoch 5/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.7094 - accuracy: 0.3535 - auc_roc: 0.3668
# Epoch 6/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.7099 - accuracy: 0.3419 - auc_roc: 0.3620
# Epoch 7/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7079 - accuracy: 0.3413 - auc_roc: 0.3830
# Epoch 8/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7077 - accuracy: 0.3418 - auc_roc: 0.3916
# Epoch 9/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7064 - accuracy: 0.3506 - auc_roc: 0.3996
# Epoch 10/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7055 - accuracy: 0.3695 - auc_roc: 0.3923
# Epoch 11/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7047 - accuracy: 0.3682 - auc_roc: 0.3954
# Epoch 12/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.7031 - accuracy: 0.3883 - auc_roc: 0.4097
# Epoch 13/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.7023 - accuracy: 0.3949 - auc_roc: 0.4176
# Epoch 14/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7015 - accuracy: 0.4097 - auc_roc: 0.4188
# Epoch 15/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.7003 - accuracy: 0.4175 - auc_roc: 0.4331
# Epoch 16/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6997 - accuracy: 0.4257 - auc_roc: 0.4347
# Epoch 17/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6979 - accuracy: 0.4553 - auc_roc: 0.4554
# Epoch 18/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6968 - accuracy: 0.4694 - auc_roc: 0.4609
# Epoch 19/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6961 - accuracy: 0.4619 - auc_roc: 0.4562
# Epoch 20/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6953 - accuracy: 0.4681 - auc_roc: 0.4539
# Epoch 21/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6945 - accuracy: 0.4853 - auc_roc: 0.4658
# Epoch 22/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6930 - accuracy: 0.5014 - auc_roc: 0.4783
# Epoch 23/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6922 - accuracy: 0.5070 - auc_roc: 0.4782
# Epoch 24/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6913 - accuracy: 0.5011 - auc_roc: 0.4732
# Epoch 25/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6902 - accuracy: 0.5232 - auc_roc: 0.4795
# Epoch 26/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6898 - accuracy: 0.5230 - auc_roc: 0.4669
# Epoch 27/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6884 - accuracy: 0.5487 - auc_roc: 0.4975
# Epoch 28/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6865 - accuracy: 0.5673 - auc_roc: 0.5058
# Epoch 29/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6861 - accuracy: 0.5634 - auc_roc: 0.4962
# Epoch 30/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6850 - accuracy: 0.5798 - auc_roc: 0.5131
# Epoch 31/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6842 - accuracy: 0.5866 - auc_roc: 0.5139
# Epoch 32/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6826 - accuracy: 0.5939 - auc_roc: 0.5293
# Epoch 33/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6817 - accuracy: 0.6121 - auc_roc: 0.5445
# Epoch 34/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6801 - accuracy: 0.6318 - auc_roc: 0.5253
# Epoch 35/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6805 - accuracy: 0.6184 - auc_roc: 0.5375
# Epoch 36/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6802 - accuracy: 0.6205 - auc_roc: 0.5438
# Epoch 37/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6773 - accuracy: 0.6286 - auc_roc: 0.5694
# Epoch 38/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6767 - accuracy: 0.6410 - auc_roc: 0.5398
# Epoch 39/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6745 - accuracy: 0.6439 - auc_roc: 0.5700
# Epoch 40/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6728 - accuracy: 0.6558 - auc_roc: 0.5749
# Epoch 41/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6727 - accuracy: 0.6514 - auc_roc: 0.5663
# Epoch 42/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6714 - accuracy: 0.6499 - auc_roc: 0.5685
# Epoch 43/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6714 - accuracy: 0.6387 - auc_roc: 0.5929
# Epoch 44/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6708 - accuracy: 0.6348 - auc_roc: 0.5950
# Epoch 45/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6676 - accuracy: 0.6567 - auc_roc: 0.5792
# Epoch 46/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6676 - accuracy: 0.6516 - auc_roc: 0.5885
# Epoch 47/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6661 - accuracy: 0.6526 - auc_roc: 0.6187
# Epoch 48/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6659 - accuracy: 0.6521 - auc_roc: 0.5943
# Epoch 49/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6627 - accuracy: 0.6620 - auc_roc: 0.6103
# Epoch 50/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6636 - accuracy: 0.6489 - auc_roc: 0.6126
# 21/21 [==============================] - 0s 483us/step
# 21/21 [==============================] - 0s 496us/step
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Epoch 1/50
# 83/83 [==============================] - 1s 3ms/step - loss: 0.7040 - accuracy: 0.4110 - auc_roc: 0.5394
# Epoch 2/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.7028 - accuracy: 0.4264 - auc_roc: 0.3993
# Epoch 3/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.7013 - accuracy: 0.4328 - auc_roc: 0.4116
# Epoch 4/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.7023 - accuracy: 0.4342 - auc_roc: 0.3944
# Epoch 5/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.7006 - accuracy: 0.4551 - auc_roc: 0.4013
# Epoch 6/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6993 - accuracy: 0.4548 - auc_roc: 0.4040
# Epoch 7/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6977 - accuracy: 0.4674 - auc_roc: 0.4220
# Epoch 8/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6989 - accuracy: 0.4718 - auc_roc: 0.3989
# Epoch 9/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6960 - accuracy: 0.4909 - auc_roc: 0.4117
# Epoch 10/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6954 - accuracy: 0.5022 - auc_roc: 0.4223
# Epoch 11/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6945 - accuracy: 0.5074 - auc_roc: 0.4269
# Epoch 12/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6920 - accuracy: 0.5212 - auc_roc: 0.4486
# Epoch 13/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6929 - accuracy: 0.5225 - auc_roc: 0.4383
# Epoch 14/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6887 - accuracy: 0.5667 - auc_roc: 0.4653
# Epoch 15/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6899 - accuracy: 0.5455 - auc_roc: 0.4684
# Epoch 16/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6862 - accuracy: 0.5698 - auc_roc: 0.4881
# Epoch 17/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6890 - accuracy: 0.5493 - auc_roc: 0.4671
# Epoch 18/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6871 - accuracy: 0.5551 - auc_roc: 0.4767
# Epoch 19/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6856 - accuracy: 0.5686 - auc_roc: 0.5021
# Epoch 20/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6823 - accuracy: 0.5818 - auc_roc: 0.5072
# Epoch 21/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6827 - accuracy: 0.5738 - auc_roc: 0.4948
# Epoch 22/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6807 - accuracy: 0.6012 - auc_roc: 0.5017
# Epoch 23/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6812 - accuracy: 0.5858 - auc_roc: 0.5021
# Epoch 24/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6806 - accuracy: 0.5932 - auc_roc: 0.5008
# Epoch 25/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6766 - accuracy: 0.6049 - auc_roc: 0.5243
# Epoch 26/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6767 - accuracy: 0.6058 - auc_roc: 0.5257
# Epoch 27/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6754 - accuracy: 0.5942 - auc_roc: 0.5277
# Epoch 28/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6752 - accuracy: 0.5967 - auc_roc: 0.5217
# Epoch 29/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6728 - accuracy: 0.5973 - auc_roc: 0.5400
# Epoch 30/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6709 - accuracy: 0.6070 - auc_roc: 0.5451
# Epoch 31/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6689 - accuracy: 0.6164 - auc_roc: 0.5470
# Epoch 32/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6695 - accuracy: 0.6064 - auc_roc: 0.5487
# Epoch 33/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6629 - accuracy: 0.6354 - auc_roc: 0.5751
# Epoch 34/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6690 - accuracy: 0.6015 - auc_roc: 0.5465
# Epoch 35/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6675 - accuracy: 0.5969 - auc_roc: 0.5608
# Epoch 36/50
# 83/83 [==============================] - 0s 5ms/step - loss: 0.6643 - accuracy: 0.6168 - auc_roc: 0.5684
# Epoch 37/50
# 83/83 [==============================] - 0s 5ms/step - loss: 0.6670 - accuracy: 0.5981 - auc_roc: 0.5625
# Epoch 38/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6609 - accuracy: 0.6192 - auc_roc: 0.5819
# Epoch 39/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6584 - accuracy: 0.6248 - auc_roc: 0.5904
# Epoch 40/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6568 - accuracy: 0.6153 - auc_roc: 0.6018
# Epoch 41/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6549 - accuracy: 0.6261 - auc_roc: 0.6052
# Epoch 42/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6583 - accuracy: 0.6112 - auc_roc: 0.5967
# Epoch 43/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6489 - accuracy: 0.6438 - auc_roc: 0.6209
# Epoch 44/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6523 - accuracy: 0.6246 - auc_roc: 0.6236
# Epoch 45/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6497 - accuracy: 0.6255 - auc_roc: 0.6437
# Epoch 46/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6514 - accuracy: 0.6235 - auc_roc: 0.6059
# Epoch 47/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6504 - accuracy: 0.6209 - auc_roc: 0.6217
# Epoch 48/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6431 - accuracy: 0.6478 - auc_roc: 0.6280
# Epoch 49/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6438 - accuracy: 0.6402 - auc_roc: 0.6227
# Epoch 50/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6377 - accuracy: 0.6435 - auc_roc: 0.6473
# 21/21 [==============================] - 0s 503us/step
# 21/21 [==============================] - 0s 482us/step
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Epoch 1/50
# 83/83 [==============================] - 1s 3ms/step - loss: 0.6891 - accuracy: 0.5120 - auc_roc: 0.5992
# Epoch 2/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6868 - accuracy: 0.5295 - auc_roc: 0.5534
# Epoch 3/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6876 - accuracy: 0.5292 - auc_roc: 0.5438
# Epoch 4/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6851 - accuracy: 0.5365 - auc_roc: 0.5509
# Epoch 5/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6821 - accuracy: 0.5419 - auc_roc: 0.5667
# Epoch 6/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6799 - accuracy: 0.5655 - auc_roc: 0.5800
# Epoch 7/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6831 - accuracy: 0.5438 - auc_roc: 0.5545
# Epoch 8/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6828 - accuracy: 0.5469 - auc_roc: 0.5506
# Epoch 9/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6801 - accuracy: 0.5622 - auc_roc: 0.5708
# Epoch 10/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6784 - accuracy: 0.5658 - auc_roc: 0.5713
# Epoch 11/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6786 - accuracy: 0.5663 - auc_roc: 0.5683
# Epoch 12/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6733 - accuracy: 0.5766 - auc_roc: 0.5942
# Epoch 13/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6740 - accuracy: 0.5823 - auc_roc: 0.5860
# Epoch 14/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6753 - accuracy: 0.5856 - auc_roc: 0.5834
# Epoch 15/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6755 - accuracy: 0.5796 - auc_roc: 0.5789
# Epoch 16/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6725 - accuracy: 0.5947 - auc_roc: 0.5958
# Epoch 17/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6745 - accuracy: 0.5712 - auc_roc: 0.5787
# Epoch 18/50
# 83/83 [==============================] - 0s 2ms/step - loss: 0.6675 - accuracy: 0.6063 - auc_roc: 0.6123
# Epoch 19/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6644 - accuracy: 0.6000 - auc_roc: 0.6201
# Epoch 20/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6658 - accuracy: 0.5949 - auc_roc: 0.6068
# Epoch 21/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6650 - accuracy: 0.6006 - auc_roc: 0.6071
# Epoch 22/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6678 - accuracy: 0.5848 - auc_roc: 0.5916
# Epoch 23/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6662 - accuracy: 0.5979 - auc_roc: 0.6117
# Epoch 24/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6632 - accuracy: 0.6092 - auc_roc: 0.6195
# Epoch 25/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6646 - accuracy: 0.5916 - auc_roc: 0.6045
# Epoch 26/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6596 - accuracy: 0.6235 - auc_roc: 0.6329
# Epoch 27/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6597 - accuracy: 0.6029 - auc_roc: 0.6254
# Epoch 28/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6640 - accuracy: 0.5979 - auc_roc: 0.6058
# Epoch 29/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6557 - accuracy: 0.6115 - auc_roc: 0.6462
# Epoch 30/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6621 - accuracy: 0.5933 - auc_roc: 0.6184
# Epoch 31/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6603 - accuracy: 0.6005 - auc_roc: 0.6240
# Epoch 32/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6556 - accuracy: 0.6065 - auc_roc: 0.6353
# Epoch 33/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6566 - accuracy: 0.6128 - auc_roc: 0.6157
# Epoch 34/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6511 - accuracy: 0.6266 - auc_roc: 0.6423
# Epoch 35/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6550 - accuracy: 0.6139 - auc_roc: 0.6233
# Epoch 36/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6485 - accuracy: 0.6129 - auc_roc: 0.6492
# Epoch 37/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6473 - accuracy: 0.6291 - auc_roc: 0.6596
# Epoch 38/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6480 - accuracy: 0.6277 - auc_roc: 0.6548
# Epoch 39/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6413 - accuracy: 0.6362 - auc_roc: 0.6735
# Epoch 40/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6473 - accuracy: 0.6312 - auc_roc: 0.6512
# Epoch 41/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6431 - accuracy: 0.6163 - auc_roc: 0.6540
# Epoch 42/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6426 - accuracy: 0.6102 - auc_roc: 0.6671
# Epoch 43/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6418 - accuracy: 0.6356 - auc_roc: 0.6683
# Epoch 44/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6461 - accuracy: 0.6125 - auc_roc: 0.6503
# Epoch 45/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6468 - accuracy: 0.6248 - auc_roc: 0.6540
# Epoch 46/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6411 - accuracy: 0.6255 - auc_roc: 0.6781
# Epoch 47/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6389 - accuracy: 0.6207 - auc_roc: 0.6668
# Epoch 48/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6437 - accuracy: 0.6192 - auc_roc: 0.6676
# Epoch 49/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6412 - accuracy: 0.6142 - auc_roc: 0.6652
# Epoch 50/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6453 - accuracy: 0.6099 - auc_roc: 0.6570
# 21/21 [==============================] - 0s 428us/step
# 21/21 [==============================] - 0s 464us/step
# Epoch 1/50
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# 83/83 [==============================] - 1s 3ms/step - loss: 0.7003 - accuracy: 0.4355 - auc_roc: 0.5799
# Epoch 2/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6992 - accuracy: 0.4410 - auc_roc: 0.3499
# Epoch 3/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6970 - accuracy: 0.4749 - auc_roc: 0.3765
# Epoch 4/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6971 - accuracy: 0.4789 - auc_roc: 0.3546
# Epoch 5/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6968 - accuracy: 0.4905 - auc_roc: 0.3581
# Epoch 6/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6950 - accuracy: 0.5034 - auc_roc: 0.3696
# Epoch 7/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6919 - accuracy: 0.5346 - auc_roc: 0.3916
# Epoch 8/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6927 - accuracy: 0.5282 - auc_roc: 0.3756
# Epoch 9/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6918 - accuracy: 0.5459 - auc_roc: 0.3874
# Epoch 10/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6911 - accuracy: 0.5679 - auc_roc: 0.3805
# Epoch 11/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6884 - accuracy: 0.5972 - auc_roc: 0.3936
# Epoch 12/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6879 - accuracy: 0.6009 - auc_roc: 0.3945
# Epoch 13/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6861 - accuracy: 0.6156 - auc_roc: 0.4152
# Epoch 14/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6837 - accuracy: 0.6237 - auc_roc: 0.4160
# Epoch 15/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6836 - accuracy: 0.6284 - auc_roc: 0.4152
# Epoch 16/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6804 - accuracy: 0.6441 - auc_roc: 0.4250
# Epoch 17/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6810 - accuracy: 0.6299 - auc_roc: 0.4415
# Epoch 18/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6807 - accuracy: 0.6303 - auc_roc: 0.4487
# Epoch 19/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6788 - accuracy: 0.6303 - auc_roc: 0.4679
# Epoch 20/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6789 - accuracy: 0.6290 - auc_roc: 0.4594
# Epoch 21/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6793 - accuracy: 0.6186 - auc_roc: 0.4750
# Epoch 22/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6785 - accuracy: 0.6201 - auc_roc: 0.4785
# Epoch 23/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6740 - accuracy: 0.6358 - auc_roc: 0.4955
# Epoch 24/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6736 - accuracy: 0.6336 - auc_roc: 0.5034
# Epoch 25/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6706 - accuracy: 0.6376 - auc_roc: 0.5269
# Epoch 26/50
# 83/83 [==============================] - 0s 2ms/step - loss: 0.6705 - accuracy: 0.6336 - auc_roc: 0.5293
# Epoch 27/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6712 - accuracy: 0.6275 - auc_roc: 0.5317
# Epoch 28/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6693 - accuracy: 0.6263 - auc_roc: 0.5532
# Epoch 29/50
# 83/83 [==============================] - 0s 2ms/step - loss: 0.6661 - accuracy: 0.6368 - auc_roc: 0.5626
# Epoch 30/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6619 - accuracy: 0.6491 - auc_roc: 0.5757
# Epoch 31/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6665 - accuracy: 0.6220 - auc_roc: 0.5868
# Epoch 32/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6592 - accuracy: 0.6458 - auc_roc: 0.6045
# Epoch 33/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6589 - accuracy: 0.6408 - auc_roc: 0.6153
# Epoch 34/50
# 83/83 [==============================] - 0s 2ms/step - loss: 0.6559 - accuracy: 0.6438 - auc_roc: 0.6264
# Epoch 35/50
# 83/83 [==============================] - 0s 2ms/step - loss: 0.6576 - accuracy: 0.6358 - auc_roc: 0.6218
# Epoch 36/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6520 - accuracy: 0.6501 - auc_roc: 0.6371
# Epoch 37/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6521 - accuracy: 0.6399 - auc_roc: 0.6540
# Epoch 38/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6508 - accuracy: 0.6449 - auc_roc: 0.6535
# Epoch 39/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6517 - accuracy: 0.6412 - auc_roc: 0.6395
# Epoch 40/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6460 - accuracy: 0.6505 - auc_roc: 0.6584
# Epoch 41/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6484 - accuracy: 0.6432 - auc_roc: 0.6453
# Epoch 42/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6512 - accuracy: 0.6290 - auc_roc: 0.6504
# Epoch 43/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6514 - accuracy: 0.6243 - auc_roc: 0.6557
# Epoch 44/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6477 - accuracy: 0.6265 - auc_roc: 0.6759
# Epoch 45/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6402 - accuracy: 0.6455 - auc_roc: 0.6802
# Epoch 46/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6402 - accuracy: 0.6456 - auc_roc: 0.6675
# Epoch 47/50
# 83/83 [==============================] - 0s 2ms/step - loss: 0.6368 - accuracy: 0.6427 - auc_roc: 0.6978
# Epoch 48/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6305 - accuracy: 0.6652 - auc_roc: 0.6769
# Epoch 49/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6358 - accuracy: 0.6430 - auc_roc: 0.6820
# Epoch 50/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6472 - accuracy: 0.6194 - auc_roc: 0.6558
# 21/21 [==============================] - 0s 429us/step
# 21/21 [==============================] - 0s 446us/step
# Epoch 1/50
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# 83/83 [==============================] - 1s 3ms/step - loss: 0.7008 - accuracy: 0.3801 - auc_roc: 0.5800
# Epoch 2/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6998 - accuracy: 0.3948 - auc_roc: 0.5387
# Epoch 3/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6984 - accuracy: 0.4131 - auc_roc: 0.5439
# Epoch 4/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6973 - accuracy: 0.4261 - auc_roc: 0.5532
# Epoch 5/50
# 83/83 [==============================] - 0s 2ms/step - loss: 0.6958 - accuracy: 0.4375 - auc_roc: 0.5384
# Epoch 6/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6937 - accuracy: 0.4530 - auc_roc: 0.5619
# Epoch 7/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6930 - accuracy: 0.4763 - auc_roc: 0.5590
# Epoch 8/50
# 83/83 [==============================] - 0s 2ms/step - loss: 0.6912 - accuracy: 0.4973 - auc_roc: 0.5596
# Epoch 9/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6891 - accuracy: 0.5203 - auc_roc: 0.5781
# Epoch 10/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6898 - accuracy: 0.5203 - auc_roc: 0.5492
# Epoch 11/50
# 83/83 [==============================] - 0s 2ms/step - loss: 0.6849 - accuracy: 0.5679 - auc_roc: 0.5884
# Epoch 12/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6854 - accuracy: 0.5620 - auc_roc: 0.5642
# Epoch 13/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6820 - accuracy: 0.5983 - auc_roc: 0.5908
# Epoch 14/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6799 - accuracy: 0.6039 - auc_roc: 0.5992
# Epoch 15/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6786 - accuracy: 0.6241 - auc_roc: 0.5816
# Epoch 16/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6785 - accuracy: 0.6315 - auc_roc: 0.5982
# Epoch 17/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6759 - accuracy: 0.6520 - auc_roc: 0.5966
# Epoch 18/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6739 - accuracy: 0.6576 - auc_roc: 0.5951
# Epoch 19/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6712 - accuracy: 0.6682 - auc_roc: 0.5935
# Epoch 20/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6704 - accuracy: 0.6920 - auc_roc: 0.5934
# Epoch 21/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6696 - accuracy: 0.6729 - auc_roc: 0.5971
# Epoch 22/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6668 - accuracy: 0.6887 - auc_roc: 0.6098
# Epoch 23/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6648 - accuracy: 0.7032 - auc_roc: 0.6052
# Epoch 24/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6626 - accuracy: 0.6950 - auc_roc: 0.6130
# Epoch 25/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6619 - accuracy: 0.7001 - auc_roc: 0.6183
# Epoch 26/50
# 83/83 [==============================] - 0s 2ms/step - loss: 0.6604 - accuracy: 0.6918 - auc_roc: 0.6020
# Epoch 27/50
# 83/83 [==============================] - 0s 2ms/step - loss: 0.6585 - accuracy: 0.6902 - auc_roc: 0.6240
# Epoch 28/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6568 - accuracy: 0.6872 - auc_roc: 0.6210
# Epoch 29/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6530 - accuracy: 0.6972 - auc_roc: 0.6265
# Epoch 30/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6508 - accuracy: 0.6894 - auc_roc: 0.6410
# Epoch 31/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6465 - accuracy: 0.7084 - auc_roc: 0.6278
# Epoch 32/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6489 - accuracy: 0.6871 - auc_roc: 0.6255
# Epoch 33/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6468 - accuracy: 0.6799 - auc_roc: 0.6413
# Epoch 34/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6418 - accuracy: 0.7041 - auc_roc: 0.6316
# Epoch 35/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6468 - accuracy: 0.6734 - auc_roc: 0.6318
# Epoch 36/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6397 - accuracy: 0.6878 - auc_roc: 0.6429
# Epoch 37/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6391 - accuracy: 0.6818 - auc_roc: 0.6453
# Epoch 38/50
# 83/83 [==============================] - 0s 2ms/step - loss: 0.6345 - accuracy: 0.6976 - auc_roc: 0.6339
# Epoch 39/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6336 - accuracy: 0.6893 - auc_roc: 0.6462
# Epoch 40/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6287 - accuracy: 0.7008 - auc_roc: 0.6534
# Epoch 41/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6313 - accuracy: 0.6796 - auc_roc: 0.6596
# Epoch 42/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6329 - accuracy: 0.6691 - auc_roc: 0.6602
# Epoch 43/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6265 - accuracy: 0.6906 - auc_roc: 0.6482
# Epoch 44/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6269 - accuracy: 0.6807 - auc_roc: 0.6523
# Epoch 45/50
# 83/83 [==============================] - 0s 2ms/step - loss: 0.6208 - accuracy: 0.7008 - auc_roc: 0.6436
# Epoch 46/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6259 - accuracy: 0.6814 - auc_roc: 0.6380
# Epoch 47/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6200 - accuracy: 0.6840 - auc_roc: 0.6711
# Epoch 48/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6219 - accuracy: 0.6835 - auc_roc: 0.6541
# Epoch 49/50
# 83/83 [==============================] - 0s 2ms/step - loss: 0.6235 - accuracy: 0.6669 - auc_roc: 0.6604
# Epoch 50/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6145 - accuracy: 0.6879 - auc_roc: 0.6616
# 21/21 [==============================] - 0s 429us/step
# 21/21 [==============================] - 0s 418us/step
# Epoch 1/50
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# 83/83 [==============================] - 1s 3ms/step - loss: 0.6886 - accuracy: 0.5685 - auc_roc: 0.6099
# Epoch 2/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6873 - accuracy: 0.5649 - auc_roc: 0.5584
# Epoch 3/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6839 - accuracy: 0.6030 - auc_roc: 0.5824
# Epoch 4/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6833 - accuracy: 0.5989 - auc_roc: 0.5849
# Epoch 5/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6817 - accuracy: 0.5926 - auc_roc: 0.5858
# Epoch 6/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6792 - accuracy: 0.6220 - auc_roc: 0.6053
# Epoch 7/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6768 - accuracy: 0.6168 - auc_roc: 0.6133
# Epoch 8/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6774 - accuracy: 0.6211 - auc_roc: 0.6047
# Epoch 9/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6751 - accuracy: 0.6290 - auc_roc: 0.6091
# Epoch 10/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6724 - accuracy: 0.6286 - auc_roc: 0.6283
# Epoch 11/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6726 - accuracy: 0.6213 - auc_roc: 0.6130
# Epoch 12/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6692 - accuracy: 0.6268 - auc_roc: 0.6413
# Epoch 13/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6688 - accuracy: 0.6201 - auc_roc: 0.6407
# Epoch 14/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6650 - accuracy: 0.6468 - auc_roc: 0.6468
# Epoch 15/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6665 - accuracy: 0.6360 - auc_roc: 0.6422
# Epoch 16/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6606 - accuracy: 0.6459 - auc_roc: 0.6527
# Epoch 17/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6598 - accuracy: 0.6516 - auc_roc: 0.6465
# Epoch 18/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6601 - accuracy: 0.6389 - auc_roc: 0.6424
# Epoch 19/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6585 - accuracy: 0.6508 - auc_roc: 0.6600
# Epoch 20/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6539 - accuracy: 0.6504 - auc_roc: 0.6779
# Epoch 21/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6526 - accuracy: 0.6410 - auc_roc: 0.6869
# Epoch 22/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6526 - accuracy: 0.6506 - auc_roc: 0.6728
# Epoch 23/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6517 - accuracy: 0.6558 - auc_roc: 0.6652
# Epoch 24/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6494 - accuracy: 0.6569 - auc_roc: 0.6742
# Epoch 25/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6437 - accuracy: 0.6629 - auc_roc: 0.6846
# Epoch 26/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6464 - accuracy: 0.6489 - auc_roc: 0.6830
# Epoch 27/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6464 - accuracy: 0.6404 - auc_roc: 0.6805
# Epoch 28/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6461 - accuracy: 0.6353 - auc_roc: 0.6852
# Epoch 29/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6360 - accuracy: 0.6620 - auc_roc: 0.7024
# Epoch 30/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6372 - accuracy: 0.6584 - auc_roc: 0.7083
# Epoch 31/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6340 - accuracy: 0.6606 - auc_roc: 0.7065
# Epoch 32/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6362 - accuracy: 0.6550 - auc_roc: 0.6899
# Epoch 33/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6342 - accuracy: 0.6512 - auc_roc: 0.7151
# Epoch 34/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6295 - accuracy: 0.6620 - auc_roc: 0.6925
# Epoch 35/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6351 - accuracy: 0.6399 - auc_roc: 0.7093
# Epoch 36/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6244 - accuracy: 0.6591 - auc_roc: 0.7256
# Epoch 37/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6231 - accuracy: 0.6612 - auc_roc: 0.7258
# Epoch 38/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6222 - accuracy: 0.6544 - auc_roc: 0.7243
# Epoch 39/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6206 - accuracy: 0.6567 - auc_roc: 0.7207
# Epoch 40/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6252 - accuracy: 0.6373 - auc_roc: 0.7249
# Epoch 41/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6190 - accuracy: 0.6566 - auc_roc: 0.7178
# Epoch 42/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6197 - accuracy: 0.6537 - auc_roc: 0.7097
# Epoch 43/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6173 - accuracy: 0.6505 - auc_roc: 0.7347
# Epoch 44/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6198 - accuracy: 0.6455 - auc_roc: 0.7270
# Epoch 45/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6075 - accuracy: 0.6702 - auc_roc: 0.7310
# Epoch 46/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6090 - accuracy: 0.6562 - auc_roc: 0.7385
# Epoch 47/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6070 - accuracy: 0.6577 - auc_roc: 0.7403
# Epoch 48/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6078 - accuracy: 0.6500 - auc_roc: 0.7409
# Epoch 49/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6048 - accuracy: 0.6608 - auc_roc: 0.7357
# Epoch 50/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6081 - accuracy: 0.6514 - auc_roc: 0.7311
# 21/21 [==============================] - 0s 441us/step
# 21/21 [==============================] - 0s 443us/step
# Epoch 1/50
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# 83/83 [==============================] - 1s 3ms/step - loss: 0.6901 - accuracy: 0.4973 - auc_roc: 0.6272
# Epoch 2/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6889 - accuracy: 0.5136 - auc_roc: 0.5257
# Epoch 3/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6882 - accuracy: 0.5092 - auc_roc: 0.5235
# Epoch 4/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6867 - accuracy: 0.5287 - auc_roc: 0.5272
# Epoch 5/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6849 - accuracy: 0.5346 - auc_roc: 0.5348
# Epoch 6/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6825 - accuracy: 0.5563 - auc_roc: 0.5459
# Epoch 7/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6838 - accuracy: 0.5448 - auc_roc: 0.5323
# Epoch 8/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6802 - accuracy: 0.5748 - auc_roc: 0.5503
# Epoch 9/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6786 - accuracy: 0.5702 - auc_roc: 0.5724
# Epoch 10/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6791 - accuracy: 0.5690 - auc_roc: 0.5608
# Epoch 11/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6775 - accuracy: 0.5683 - auc_roc: 0.5682
# Epoch 12/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6763 - accuracy: 0.5880 - auc_roc: 0.5677
# Epoch 13/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6734 - accuracy: 0.6105 - auc_roc: 0.5820
# Epoch 14/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6739 - accuracy: 0.6077 - auc_roc: 0.5747
# Epoch 15/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6706 - accuracy: 0.6210 - auc_roc: 0.5979
# Epoch 16/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6698 - accuracy: 0.6228 - auc_roc: 0.5824
# Epoch 17/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6718 - accuracy: 0.6114 - auc_roc: 0.5824
# Epoch 18/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6701 - accuracy: 0.6174 - auc_roc: 0.5710
# Epoch 19/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6662 - accuracy: 0.6189 - auc_roc: 0.5997
# Epoch 20/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6644 - accuracy: 0.6276 - auc_roc: 0.5858
# Epoch 21/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6632 - accuracy: 0.6366 - auc_roc: 0.5903
# Epoch 22/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6603 - accuracy: 0.6503 - auc_roc: 0.6130
# Epoch 23/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6609 - accuracy: 0.6460 - auc_roc: 0.6010
# Epoch 24/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6600 - accuracy: 0.6333 - auc_roc: 0.6183
# Epoch 25/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6571 - accuracy: 0.6575 - auc_roc: 0.6226
# Epoch 26/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6582 - accuracy: 0.6448 - auc_roc: 0.6043
# Epoch 27/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6550 - accuracy: 0.6481 - auc_roc: 0.6058
# Epoch 28/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6513 - accuracy: 0.6543 - auc_roc: 0.6284
# Epoch 29/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6520 - accuracy: 0.6453 - auc_roc: 0.6374
# Epoch 30/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6566 - accuracy: 0.6399 - auc_roc: 0.6096
# Epoch 31/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6501 - accuracy: 0.6395 - auc_roc: 0.6292
# Epoch 32/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6475 - accuracy: 0.6483 - auc_roc: 0.6376
# Epoch 33/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6434 - accuracy: 0.6604 - auc_roc: 0.6500
# Epoch 34/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6434 - accuracy: 0.6493 - auc_roc: 0.6455
# Epoch 35/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6412 - accuracy: 0.6656 - auc_roc: 0.6445
# Epoch 36/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6400 - accuracy: 0.6510 - auc_roc: 0.6546
# Epoch 37/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6385 - accuracy: 0.6494 - auc_roc: 0.6662
# Epoch 38/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6395 - accuracy: 0.6464 - auc_roc: 0.6676
# Epoch 39/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6347 - accuracy: 0.6537 - auc_roc: 0.6703
# Epoch 40/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6357 - accuracy: 0.6544 - auc_roc: 0.6507
# Epoch 41/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6339 - accuracy: 0.6525 - auc_roc: 0.6667
# Epoch 42/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6355 - accuracy: 0.6491 - auc_roc: 0.6549
# Epoch 43/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6370 - accuracy: 0.6214 - auc_roc: 0.6777
# Epoch 44/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6304 - accuracy: 0.6616 - auc_roc: 0.6656
# Epoch 45/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6328 - accuracy: 0.6446 - auc_roc: 0.6692
# Epoch 46/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6295 - accuracy: 0.6464 - auc_roc: 0.6803
# Epoch 47/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6280 - accuracy: 0.6476 - auc_roc: 0.6733
# Epoch 48/50
# 83/83 [==============================] - 0s 4ms/step - loss: 0.6188 - accuracy: 0.6657 - auc_roc: 0.6866
# Epoch 49/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6250 - accuracy: 0.6469 - auc_roc: 0.6958
# Epoch 50/50
# 83/83 [==============================] - 0s 3ms/step - loss: 0.6260 - accuracy: 0.6405 - auc_roc: 0.6815
# 21/21 [==============================] - 0s 483us/step
# 21/21 [==============================] - 0s 482us/step
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Epoch 1/50
# 83/83 [==============================] - 1s 3ms/step - loss: 0.6823 - accuracy: 0.5138 - auc_roc: 0.6267
# Epoch 2/50
# ...
# Epoch 51/60
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6109 - accuracy: 0.6798 - auc_roc: 0.7363
# Epoch 52/60
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6050 - accuracy: 0.6870 - auc_roc: 0.7485
# Epoch 53/60
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6073 - accuracy: 0.6632 - auc_roc: 0.7587
# Epoch 54/60
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6066 - accuracy: 0.6756 - auc_roc: 0.7440
# Epoch 55/60
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6083 - accuracy: 0.6618 - auc_roc: 0.7490
# Epoch 56/60
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6095 - accuracy: 0.6795 - auc_roc: 0.7510
# Epoch 57/60
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6018 - accuracy: 0.6740 - auc_roc: 0.7606
# Epoch 58/60
# 55/55 [==============================] - 0s 4ms/step - loss: 0.5917 - accuracy: 0.6789 - auc_roc: 0.7720
# Epoch 59/60
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6025 - accuracy: 0.6605 - auc_roc: 0.7535
# Epoch 60/60
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6024 - accuracy: 0.6804 - auc_roc: 0.7476
# 14/14 [==============================] - 0s 515us/step
# 14/14 [==============================] - 0s 466us/step
# Epoch 1/60
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# 56/56 [==============================] - 1s 5ms/step - loss: 0.7017 - accuracy: 0.4007 - auc_roc: 0.6385
# Epoch 2/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.7012 - accuracy: 0.4170 - auc_roc: 0.5679
# Epoch 3/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6994 - accuracy: 0.4469 - auc_roc: 0.5825
# Epoch 4/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6986 - accuracy: 0.4758 - auc_roc: 0.5746
# Epoch 5/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6962 - accuracy: 0.5129 - auc_roc: 0.5907
# Epoch 6/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6962 - accuracy: 0.5255 - auc_roc: 0.5926
# Epoch 7/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6944 - accuracy: 0.5643 - auc_roc: 0.6031
# Epoch 8/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6926 - accuracy: 0.5852 - auc_roc: 0.6425
# Epoch 9/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6922 - accuracy: 0.5736 - auc_roc: 0.6108
# Epoch 10/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6903 - accuracy: 0.5903 - auc_roc: 0.6321
# Epoch 11/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6890 - accuracy: 0.6100 - auc_roc: 0.6499
# Epoch 12/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6877 - accuracy: 0.6089 - auc_roc: 0.6486
# Epoch 13/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6863 - accuracy: 0.6299 - auc_roc: 0.6596
# Epoch 14/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6850 - accuracy: 0.6341 - auc_roc: 0.6630
# Epoch 15/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6826 - accuracy: 0.6661 - auc_roc: 0.6977
# Epoch 16/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6819 - accuracy: 0.6718 - auc_roc: 0.6965
# Epoch 17/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6803 - accuracy: 0.6746 - auc_roc: 0.7030
# Epoch 18/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6782 - accuracy: 0.6894 - auc_roc: 0.7275
# Epoch 19/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6774 - accuracy: 0.6860 - auc_roc: 0.7116
# Epoch 20/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6761 - accuracy: 0.6796 - auc_roc: 0.7169
# Epoch 21/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6748 - accuracy: 0.6871 - auc_roc: 0.7135
# Epoch 22/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6716 - accuracy: 0.7081 - auc_roc: 0.7483
# Epoch 23/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6708 - accuracy: 0.6882 - auc_roc: 0.7339
# Epoch 24/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6678 - accuracy: 0.7107 - auc_roc: 0.7485
# Epoch 25/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6670 - accuracy: 0.6931 - auc_roc: 0.7460
# Epoch 26/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6655 - accuracy: 0.6948 - auc_roc: 0.7406
# Epoch 27/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6641 - accuracy: 0.6968 - auc_roc: 0.7322
# Epoch 28/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6639 - accuracy: 0.6865 - auc_roc: 0.7303
# Epoch 29/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6616 - accuracy: 0.6994 - auc_roc: 0.7561
# Epoch 30/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6591 - accuracy: 0.6947 - auc_roc: 0.7599
# Epoch 31/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6561 - accuracy: 0.7008 - auc_roc: 0.7521
# Epoch 32/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6559 - accuracy: 0.7048 - auc_roc: 0.7369
# Epoch 33/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6536 - accuracy: 0.6986 - auc_roc: 0.7429
# Epoch 34/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6503 - accuracy: 0.7084 - auc_roc: 0.7552
# Epoch 35/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6500 - accuracy: 0.6930 - auc_roc: 0.7441
# Epoch 36/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6459 - accuracy: 0.7036 - auc_roc: 0.7477
# Epoch 37/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6461 - accuracy: 0.6975 - auc_roc: 0.7515
# Epoch 38/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6451 - accuracy: 0.6937 - auc_roc: 0.7488
# Epoch 39/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6460 - accuracy: 0.6735 - auc_roc: 0.7432
# Epoch 40/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6426 - accuracy: 0.6910 - auc_roc: 0.7293
# Epoch 41/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6394 - accuracy: 0.6933 - auc_roc: 0.7474
# Epoch 42/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6372 - accuracy: 0.6873 - auc_roc: 0.7581
# Epoch 43/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6368 - accuracy: 0.6983 - auc_roc: 0.7356
# Epoch 44/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6338 - accuracy: 0.6899 - auc_roc: 0.7477
# Epoch 45/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6308 - accuracy: 0.6945 - auc_roc: 0.7438
# Epoch 46/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6286 - accuracy: 0.6995 - auc_roc: 0.7433
# Epoch 47/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6315 - accuracy: 0.6932 - auc_roc: 0.7273
# Epoch 48/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6277 - accuracy: 0.6996 - auc_roc: 0.7389
# Epoch 49/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6238 - accuracy: 0.7014 - auc_roc: 0.7533
# Epoch 50/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6217 - accuracy: 0.7018 - auc_roc: 0.7327
# Epoch 51/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6193 - accuracy: 0.7016 - auc_roc: 0.7455
# Epoch 52/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6193 - accuracy: 0.6974 - auc_roc: 0.7377
# Epoch 53/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6231 - accuracy: 0.6881 - auc_roc: 0.7372
# Epoch 54/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6141 - accuracy: 0.6971 - auc_roc: 0.7539
# Epoch 55/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6134 - accuracy: 0.6998 - auc_roc: 0.7413
# Epoch 56/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6067 - accuracy: 0.7120 - auc_roc: 0.7557
# Epoch 57/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6041 - accuracy: 0.7121 - auc_roc: 0.7594
# Epoch 58/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6021 - accuracy: 0.7187 - auc_roc: 0.7559
# Epoch 59/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6052 - accuracy: 0.7033 - auc_roc: 0.7425
# Epoch 60/60
# 56/56 [==============================] - 0s 5ms/step - loss: 0.6002 - accuracy: 0.7123 - auc_roc: 0.7468
# 14/14 [==============================] - 0s 504us/step
# 14/14 [==============================] - 0s 495us/step
# Epoch 1/50
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# 69/69 [==============================] - 1s 5ms/step - loss: 0.6976 - accuracy: 0.4384 - auc_roc: 0.6234
# Epoch 2/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6967 - accuracy: 0.4457 - auc_roc: 0.4161
# Epoch 3/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6949 - accuracy: 0.4661 - auc_roc: 0.4421
# Epoch 4/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6941 - accuracy: 0.4531 - auc_roc: 0.4376
# Epoch 5/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6915 - accuracy: 0.4989 - auc_roc: 0.4830
# Epoch 6/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6903 - accuracy: 0.4968 - auc_roc: 0.4851
# Epoch 7/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6895 - accuracy: 0.4860 - auc_roc: 0.4845
# Epoch 8/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6872 - accuracy: 0.5175 - auc_roc: 0.5203
# Epoch 9/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6856 - accuracy: 0.5411 - auc_roc: 0.5488
# Epoch 10/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6839 - accuracy: 0.5657 - auc_roc: 0.5503
# Epoch 11/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6820 - accuracy: 0.5960 - auc_roc: 0.5777
# Epoch 12/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6806 - accuracy: 0.6191 - auc_roc: 0.5936
# Epoch 13/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6792 - accuracy: 0.6299 - auc_roc: 0.6084
# Epoch 14/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6773 - accuracy: 0.6430 - auc_roc: 0.6342
# Epoch 15/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6753 - accuracy: 0.6505 - auc_roc: 0.6627
# Epoch 16/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6732 - accuracy: 0.6489 - auc_roc: 0.6773
# Epoch 17/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6704 - accuracy: 0.6567 - auc_roc: 0.6865
# Epoch 18/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6688 - accuracy: 0.6579 - auc_roc: 0.6935
# Epoch 19/50
# 69/69 [==============================] - 0s 6ms/step - loss: 0.6680 - accuracy: 0.6486 - auc_roc: 0.6986
# Epoch 20/50
# 69/69 [==============================] - 0s 6ms/step - loss: 0.6662 - accuracy: 0.6568 - auc_roc: 0.6988
# Epoch 21/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6649 - accuracy: 0.6581 - auc_roc: 0.6965
# Epoch 22/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6648 - accuracy: 0.6491 - auc_roc: 0.6905
# Epoch 23/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6608 - accuracy: 0.6434 - auc_roc: 0.7209
# Epoch 24/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6581 - accuracy: 0.6482 - auc_roc: 0.7263
# Epoch 25/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6554 - accuracy: 0.6704 - auc_roc: 0.7210
# Epoch 26/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6577 - accuracy: 0.6504 - auc_roc: 0.7234
# Epoch 27/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6534 - accuracy: 0.6574 - auc_roc: 0.7297
# Epoch 28/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6529 - accuracy: 0.6433 - auc_roc: 0.7256
# Epoch 29/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6511 - accuracy: 0.6403 - auc_roc: 0.7311
# Epoch 30/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6466 - accuracy: 0.6524 - auc_roc: 0.7433
# Epoch 31/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6441 - accuracy: 0.6554 - auc_roc: 0.7388
# Epoch 32/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6462 - accuracy: 0.6465 - auc_roc: 0.7274
# Epoch 33/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6404 - accuracy: 0.6628 - auc_roc: 0.7288
# Epoch 34/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6400 - accuracy: 0.6486 - auc_roc: 0.7427
# Epoch 35/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6368 - accuracy: 0.6553 - auc_roc: 0.7354
# Epoch 36/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6406 - accuracy: 0.6380 - auc_roc: 0.7387
# Epoch 37/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6396 - accuracy: 0.6332 - auc_roc: 0.7273
# Epoch 38/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6334 - accuracy: 0.6436 - auc_roc: 0.7412
# Epoch 39/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6292 - accuracy: 0.6509 - auc_roc: 0.7433
# Epoch 40/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6262 - accuracy: 0.6533 - auc_roc: 0.7420
# Epoch 41/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6259 - accuracy: 0.6447 - auc_roc: 0.7575
# Epoch 42/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6198 - accuracy: 0.6646 - auc_roc: 0.7503
# Epoch 43/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6215 - accuracy: 0.6591 - auc_roc: 0.7377
# Epoch 44/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6235 - accuracy: 0.6425 - auc_roc: 0.7410
# Epoch 45/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6224 - accuracy: 0.6448 - auc_roc: 0.7456
# Epoch 46/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6189 - accuracy: 0.6454 - auc_roc: 0.7465
# Epoch 47/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6110 - accuracy: 0.6598 - auc_roc: 0.7512
# Epoch 48/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6133 - accuracy: 0.6397 - auc_roc: 0.7477
# Epoch 49/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6135 - accuracy: 0.6485 - auc_roc: 0.7322
# Epoch 50/50
# 69/69 [==============================] - 0s 5ms/step - loss: 0.6149 - accuracy: 0.6494 - auc_roc: 0.7371

# %%
# top 20 performers by the test_roc_auc score
#,'param_model__max_features'
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
#res_cols = ['mean_test_roc_auc', 'mean_test_accuracy', 'param_balance__balancer_type', 'param_features__k', 
#            'param_features__score_func', 'param_model__C', 'param_model__solver', 
#            'param_outlier__outlier_threshold', 'param__vif_score_threshold']
#res_cols = ['mean_test_roc_auc','mean_test_accuracy', 'param_balance__balancer_type', 'param_model__batch_size','param_model__epochs',
            #'param_outlier__outlier_threshold']
#res_cols = ['mean_test_roc_auc','mean_test_accuracy','model__batch_size','param_model__epochs','model__filters','model__kernel_size']
res_cols = ['mean_test_roc_auc','mean_test_accuracy','param_model__batch_size','param_model__epochs','param_model__filters','param_model__kernel_size']
#res_cols = ['mean_test_roc_auc','mean_test_accuracy', 'param_balance__balancer_type','param_model__optimizer',
            #'param_outlier__outlier_threshold']
df_sorted = df_result[res_cols].reset_index(drop=True).sort_values('mean_test_roc_auc', axis=0, ascending=False)
df_sorted.index = pd.RangeIndex(1, len(df_sorted.index)+1)
df_sorted
# Out:
#     mean_test_roc_auc  mean_test_accuracy param_model__batch_size  \
# 1            0.749476            0.637821                      48
# 2            0.748395            0.653878                      32
# 3            0.744035            0.662072                      32
# 4            0.742968            0.659952                      32
# 5            0.742287            0.667533                      32
# 6            0.741728            0.655404                      32
# 7            0.741438            0.654794                      48
# 8            0.737122            0.661461                      48
# 9            0.736438            0.647821                      48
# 10           0.731787            0.649030                      32
# 11           0.731503            0.652378                      32
# 12           0.728569            0.657818                      32
# 13           0.728557            0.644185                      48
# 14           0.728237            0.645698                      32
# 15           0.728078            0.652977                      32
# 16           0.727613            0.646305                      32
# 17           0.726137            0.641455                      32
# 18           0.725972            0.646911                      32
# 19           0.725918            0.652972                      48
# 20           0.724794            0.648434                      48
# 21           0.724339            0.649030                      48
# 22           0.719873            0.643295                      48
# 23           0.718833            0.645091                      32
# 24           0.718625            0.648728                      48
# 25           0.718173            0.654788                      32
# 26           0.716978            0.650847                      32
# 27           0.716255            0.648725                      48
# 28           0.713310            0.642669                      32
# 29           0.711231            0.648731                      48
# 30           0.708395            0.641763                      48
# 31           0.707789            0.646911                      32
# 32           0.706867            0.646608                      32
# 33           0.705262            0.641761                      48
# 34           0.705229            0.640851                      32
# 35           0.701995            0.644790                      48
# 36           0.700286            0.643576                      32
# 37           0.699947            0.653572                      48
# 38           0.697072            0.649937                      48
# 39           0.696648            0.649640                      48
# 40           0.696009            0.655410                      32
# 41           0.685720            0.638132                      48
# 42           0.680592            0.644487                      32
# 43           0.680546            0.657531                      48
# 44           0.679941            0.651455                      48
# 45           0.658699            0.654200                      48
# 46           0.650180            0.633282                      32
# 47           0.635284            0.634485                      48
# 48           0.539808            0.613291                      48
#
#    param_model__epochs param_model__filters param_model__kernel_size
# 1                   50                   64                        7
# 2                   60                   64                        7
# 3                   60                   16                        7
# 4                   60                   32                        7
# 5                   50                   64                        7
# 6                   50                   32                        7
# 7                   60                   32                        7
# 8                   60                   64                        7
# 9                   60                   64                        5
# 10                  50                   64                        5
# 11                  60                    8                        7
# 12                  60                   32                        3
# 13                  60                   64                        3
# 14                  50                   16                        7
# 15                  60                   64                        3
# 16                  60                   32                        5
# 17                  50                    8                        7
# 18                  50                   64                        3
# 19                  60                   32                        3
# 20                  60                   16                        7
# 21                  60                   32                        5
# 22                  50                   16                        7
# 23                  50                   16                        5
# 24                  50                   64                        3
# 25                  60                   64                        5
# 26                  60                   16                        3
# 27                  50                   32                        5
# 28                  60                   16                        5
# 29                  50                   32                        7
# 30                  60                    8                        7
# 31                  50                    8                        5
# 32                  50                   32                        3
# 33                  50                   32                        3
# 34                  50                   32                        5
# 35                  60                   16                        5
# 36                  60                    8                        5
# 37                  50                   16                        5
# 38                  50                    8                        7
# 39                  50                   64                        5
# 40                  50                   16                        3
# 41                  60                   16                        3
# 42                  60                    8                        3
# 43                  50                   16                        3
# 44                  60                    8                        5
# 45                  60                    8                        3
# 46                  50                    8                        3
# 47                  50                    8                        5
# 48                  50                    8                        3

# %%
# the average roc-auc and accuracy scores of just completed search.
# these are the averages of each model over the convolution folds.
#print(df_result['mean_test_roc_auc'])
#print(df_result['mean_test_accuracy'])
print(best_params)
# Out:
# {'model__batch_size': 48, 'model__epochs': 50, 'model__filters': 64, 'model__kernel_size': 7}

# %%
# display results for the best estimator we found
predictions = best_estimator.predict(df_features)
probabilities = best_estimator.predict_proba(df_features)[:,1]
mindwandering.evaluate.evaluate_model_results(mind_wandered_label, predictions, probabilities)
# Out:
# 69/69 [==============================] - 0s 382us/step
# 69/69 [==============================] - 0s 361us/step
# Accuracy score:         0.6493939393939394
# Recall (TPR) score:     0.9948162111215834
# Precision score:        0.6481424623887012
# AUC-ROC score:          0.5109904485149513
#
# True positives:   2111
# True negatives:   32
# False positives:  1146
# False negatives:  11
# True Positive Rate (recall):  0.9948162111215834
# False Positive Rate:          0.9728353140916808
# Specificity:                  0.027164685908319185
#
# [[  32 1146]
#  [  11 2111]]
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '

# %%
# save the results and preliminary figures in the following cells

# create base save file name for this file, use datetime to keep a unique file name
now = datetime.now()
date_time = now.strftime('%Y%m%d-%H%M')
result_file_basename = 'replication-07-Neural-Network-using-Conv1D-SMOTEENN-Oversampling' + date_time
print(result_file_basename)
# Out:
# replication-07-Neural-Network-using-Conv1D-SMOTEENN-Oversampling20210602-2137

# %%
# A quick histogram of this search auc-roc scores.  Basically the figure 1 from the paper.
plt.figure(figsize=(12,8))

#bins = np.linspace(0.605, 0.612, 8)
plt.hist(df_result.mean_test_roc_auc, 
         bins=20,
         color='lightblue',
         rwidth=0.9);
#plt.xlabel('Area under the receiver operating characteristic (AUC-ROC)');
plt.xlabel('Area under the receiver operating characteristic (AUC-ROC)');
plt.ylabel('Number of models');
plt.title('Neural Network Replication using Conv1d for Oversampling Dataset: ' + result_file_basename);

result_dir = '../figures'
result_file_name = result_file_basename + '.eps'
result_file_path = os.path.join(result_dir, result_file_name)
plt.savefig(result_file_path)

# %%
# save the search results dataframe to a file so can retrieve for later data analysis or
# to combine with other grid search results for summaries
result_dir = '../DeepLearningResults'
result_file_name = result_file_basename + '.pkl'
result_file_path = os.path.join(result_dir, result_file_name)
df_result.to_pickle(result_file_path)
