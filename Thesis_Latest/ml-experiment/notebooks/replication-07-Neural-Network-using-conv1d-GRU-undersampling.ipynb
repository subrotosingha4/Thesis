# %% [markdown]
# - mean_test_auc_roc using Logistic Regression:
# - mean_test_auc_roc using KNN:0.631033
# - mean_test_auc_roc using SVM:0.658805
# - mean_test_auc_roc using Random Forest:0.657398
# - mean_test_auc_roc using Decision Tree:0.640888
# - mean_test_auc_roc using **Naive Bayes:0.659468**
# - mean_test_auc_roc using Neural Network(Adam):0.634302
# - mean_test_auc_roc using Neural Network(SGD):0.630862
# - mean_test_auc_roc using Neural Network(RMSprop):0.629448

# %%
# globally useful imports of standard libraries needed in this notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os.path
from datetime import datetime

# specific libraries or classes needed for the work in this notebook
#from sklearn.linear_model import LogisticRegression
#from sklearn.linear_model import LogisticRegressionCV
#from sklearn.svm import SVC
#from sklearn.naive_bayes import GaussianNB
#from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GroupKFold
from sklearn.model_selection import LeaveOneGroupOut
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import SelectKBest, f_classif, chi2, SelectFpr, f_regression, mutual_info_classif
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import RFE
from sklearn.feature_selection import VarianceThreshold
from sklearn.ensemble import ExtraTreesClassifier
#from sklearn.pipeline import Pipeline
# need to use Pipeline from imblearn to add in a downsample or upsample
# to cross validation training
from imblearn.pipeline import Pipeline

# import project specific modules used in this notebook
import sys
sys.path.append('../src')
import mindwandering.data
import mindwandering.features
import mindwandering.evaluate
from mindwandering.data import FeatureScalerTransformer
from mindwandering.data import WinsorizationOutlierTransformer
from mindwandering.data import VIFThresholdTransformer
from mindwandering.data import FeatureSelectionTransformer
from mindwandering.data import ClassImbalanceTransformer
from mindwandering.data import GridSearchProgressHack


from sklearn.preprocessing import StandardScaler

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.layers import Input, Dense, Activation, Dropout, BatchNormalization,Flatten
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import SGD,Adam,RMSprop
from tensorflow.keras.layers import Conv1D,GRU,TimeDistributed,MaxPooling1D,LSTM
from tensorflow.keras.models import Model
from tensorflow.keras.layers import AveragePooling1D,ZeroPadding1D

# %%
# Load Data and Features
df_features = mindwandering.data.get_df_features()
mind_wandered_label = mindwandering.data.get_mind_wandered_label()
participant_ids = mindwandering.data.get_participant_ids()

# %% [markdown]
# # Standard Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_features=scaler.fit_transform(df_features)

# %% [markdown]
# # Select k-best features

# %%
#from sklearn.feature_selection import SelectKBest,f_classif
#k=[12,15,18,21,24,31]
df_features = SelectKBest(f_classif,k=12).fit_transform(df_features,mind_wandered_label)

# %%
#participant_ids=participant_ids[:2193]

# %%
#participant_ids=participant_ids[:3300]

# %% [markdown]
# # Allknn undersampling

# %%
from imblearn.under_sampling import AllKNN
allknn = AllKNN()
df_features, mind_wandered_label = allknn.fit_resample(df_features, mind_wandered_label)

# %% [markdown]
# # SMOTEENN Oversampling

# %%
"""from imblearn.combine import SMOTEENN
sme = SMOTEENN(random_state=42)
df_features, mind_wandered_label = sme.fit_resample(df_features, mind_wandered_label)"""
# Out:
# 'from imblearn.combine import SMOTEENN\nsme = SMOTEENN(random_state=42)\ndf_features, mind_wandered_label = sme.fit_resample(df_features, mind_wandered_label)'

# %%
mind_wandered_label.shape
# Out:
# (2193,)

# %% [markdown]
# # Data Reshape for conv1d

# %%
#df_features = df_features.to_numpy()
df_features=df_features.reshape((df_features.shape[0], df_features.shape[1], 1))
df_features.shape
# Out:
# (2193, 12, 1)

# %%
"""from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df_features, mind_wandered_label, test_size=0.33, random_state=42)"""

# %%
import tensorflow
auc_roc = tensorflow.keras.metrics.AUC(name='auc_roc',num_thresholds=20000,curve='ROC')

# %%
"""model = Sequential([
    Conv1D(filters=64, kernel_size=5,strides=8, activation='tanh',padding='same', input_shape=(df_features.shape[1], 1)),
    #ZeroPadding1D(padding=1),
    GRU(20, return_sequences=True),
    Flatten(),
    Dense(32, activation='relu'),
    Dense(1, activation='swish'),
    Activation('sigmoid')])
optimizer=SGD(lr=0.001)
model.compile(loss='binary_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy', auc_roc])"""

# %%
"""model.fit(X_train, y_train, epochs=1,verbose=1, validation_data=(X_test, y_test))"""
# Out:
# 46/46 [==============================] - 2s 15ms/step - loss: 0.6932 - accuracy: 0.4807 - auc_roc: 0.4997 - val_loss: 0.6929 - val_accuracy: 0.4945 - val_auc_roc: 0.5265

# %%
"""model.summary()"""
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 2, 64)             384
# _________________________________________________________________
# gru_1 (GRU)                  (None, 2, 20)             5160
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 40)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                1312
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 6,889
# Trainable params: 6,889
# Non-trainable params: 0
# _________________________________________________________________

# %%
"""from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model_conv_GRU_plot.png', show_shapes=True, show_layer_names=True)"""

# %% [markdown]
# # AUROC

# %%
import tensorflow
auc_roc = tensorflow.keras.metrics.AUC(name='auc_roc',num_thresholds=20000,curve='ROC')

# %% [markdown]
# # Conv1d Model

# %%
def create_model(filters=64,kernel_size=5):
    model = Sequential([
    Conv1D(filters=filters, kernel_size=kernel_size,strides=8, activation='tanh',padding='same', input_shape=(df_features.shape[1], 1)),
    ZeroPadding1D(padding=1),
    GRU(20, return_sequences=True),
    Flatten(),
    Dense(32, activation='relu'),
    Dense(1, activation='swish'),
    Activation('sigmoid')])
    optimizer=SGD(lr=0.001)
    model.compile(loss='binary_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy', auc_roc])
    return model

# %%
# Wrap Keras model so it can be used by scikit-learn
#kears_estimator = KerasClassifier(build_fn=create_model,epochs=100, batch_size=32, verbose=1)
kears_estimator = KerasClassifier(build_fn=create_model,epochs=50, batch_size=32, verbose=1)
#kears_estimator = KerasClassifier(build_fn=create_model, verbose=1)

# %%
# Empty dataframe to gather grid search results into 1 place
best_estimator = None
best_score = 0.0
best_params = {}
best_index = 0
df_result = None


parameters = {
        #'scaling__type_of_scaling': ['standard'],
        #'outlier__outlier_threshold': [0.0, 3.0],
        #'features__k': [12,15],
        #'balance__balancer_type': ['random-undersampler', 'allknn', 'nearmiss', 'instance-hardness-threshold'],
        #'balance__balancer_type': ['allknn', 'condensed-nn', 'neighbourhood-cleaning', 'one-sided-selection'],
        #'balance__balancer_type': ['allknn', 'one-sided-selection'],
        #'balance__balancer_type': ['allknn', 'smote-enn'],
        #'model__var_smoothing': [1e-6,1e-7,1e-8,1e-9,1e-10,1e-11,1e-12],
        'model__batch_size': [32, 48],#usually multiple of 8
        'model__epochs':[50,60],
        'model__filters':[8,16,32,64],
        'model__kernel_size':[3,5,7],
        #'model__batch_size': [60],
        #'model__epochs':[10],
        #'model__optimizer' : ['RMSprop', 'Adagrad', 'Adadelta','Adam']
    }

# Estimator Pipeline
pipeline = Pipeline(
      [
        #('progress', GridSearchProgressHack(verbose=False)),
        #('scaling',  FeatureScalerTransformer()),
        #('outlier',  WinsorizationOutlierTransformer()),
        #('features', SelectKBest()),
        #('features', SelectFromModel(estimator=LogisticRegression(solver='liblinear', penalty='l1', C=0.1), threshold=-np.inf)),
        #('balance',  ClassImbalanceTransformer()),
        ('model',    kears_estimator)
      ]
    )
    
# Cross Validation Splitter
cv_group_splitter = GroupKFold(n_splits=5)
    #cv_group_splitter = LeaveOneGroupOut()

    # perform the grid search for this vif selection
    # set up the search
search = GridSearchCV(
        estimator = pipeline,
        param_grid = parameters,
        scoring = ['roc_auc','accuracy'],
        cv = cv_group_splitter,
        #cv = 5,
        refit = 'roc_auc',
        verbose = 1)

search.fit(df_features, mind_wandered_label, groups=participant_ids)
#search.fit(df_features, mind_wandered_label)

df = pd.DataFrame(data=search.cv_results_)
    
    
if best_estimator is None:
    df_result = df
    best_estimator = search.best_estimator_
    best_score = search.best_score_
    best_params = search.best_params_
    best_index = search.best_index_
else:
    df_result = df_result.append(df, ignore_index=True)
    if search.best_score_ > best_score:
        best_estimator = search.best_estimator_
        best_score = search.best_score_
        best_params = search.best_params_
        best_index = search.best_index_  # todo this is only the index of this search
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# Epoch 1/50
# 55/55 [==============================] - 2s 5ms/step - loss: 0.6888 - accuracy: 0.5950 - auc_roc: 0.6587
# Epoch 2/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6879 - accuracy: 0.5801 - auc_roc: 0.6819
# Epoch 3/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6883 - accuracy: 0.5655 - auc_roc: 0.6942
# Epoch 4/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6892 - accuracy: 0.5497 - auc_roc: 0.6720
# Epoch 5/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6878 - accuracy: 0.5745 - auc_roc: 0.7046
# Epoch 6/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6887 - accuracy: 0.5415 - auc_roc: 0.6735
# Epoch 7/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6882 - accuracy: 0.5507 - auc_roc: 0.6815
# Epoch 8/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6877 - accuracy: 0.5765 - auc_roc: 0.6976
# Epoch 9/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6878 - accuracy: 0.5499 - auc_roc: 0.6927
# Epoch 10/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6872 - accuracy: 0.5623 - auc_roc: 0.7196
# Epoch 11/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6869 - accuracy: 0.5758 - auc_roc: 0.6809
# Epoch 12/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6868 - accuracy: 0.5669 - auc_roc: 0.6938
# Epoch 13/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6863 - accuracy: 0.5571 - auc_roc: 0.7167
# Epoch 14/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6867 - accuracy: 0.5458 - auc_roc: 0.7126
# Epoch 15/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6869 - accuracy: 0.5529 - auc_roc: 0.6850
# Epoch 16/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6869 - accuracy: 0.5599 - auc_roc: 0.6883
# Epoch 17/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6863 - accuracy: 0.5539 - auc_roc: 0.6968
# Epoch 18/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6861 - accuracy: 0.5467 - auc_roc: 0.7094
# Epoch 19/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6857 - accuracy: 0.5532 - auc_roc: 0.7171
# Epoch 20/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6858 - accuracy: 0.5468 - auc_roc: 0.7124
# Epoch 21/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6856 - accuracy: 0.5450 - auc_roc: 0.7005
# Epoch 22/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6850 - accuracy: 0.5667 - auc_roc: 0.7125
# Epoch 23/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6866 - accuracy: 0.5407 - auc_roc: 0.6990
# Epoch 24/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6851 - accuracy: 0.5462 - auc_roc: 0.7025
# Epoch 25/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6860 - accuracy: 0.5404 - auc_roc: 0.7124
# Epoch 26/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6850 - accuracy: 0.5443 - auc_roc: 0.7206
# Epoch 27/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6850 - accuracy: 0.5473 - auc_roc: 0.7134
# Epoch 28/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6850 - accuracy: 0.5261 - auc_roc: 0.7144
# Epoch 29/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6853 - accuracy: 0.5540 - auc_roc: 0.7126
# Epoch 30/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6838 - accuracy: 0.5543 - auc_roc: 0.7133
# Epoch 31/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6853 - accuracy: 0.5337 - auc_roc: 0.7074
# Epoch 32/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6839 - accuracy: 0.5520 - auc_roc: 0.7235
# Epoch 33/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6824 - accuracy: 0.5707 - auc_roc: 0.7368
# Epoch 34/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6850 - accuracy: 0.5277 - auc_roc: 0.7140
# Epoch 35/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6856 - accuracy: 0.5208 - auc_roc: 0.7079
# Epoch 36/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6836 - accuracy: 0.5471 - auc_roc: 0.6965
# Epoch 37/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6834 - accuracy: 0.5586 - auc_roc: 0.7053
# Epoch 38/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6842 - accuracy: 0.5297 - auc_roc: 0.7092
# Epoch 39/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6831 - accuracy: 0.5392 - auc_roc: 0.7183
# Epoch 40/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6845 - accuracy: 0.5404 - auc_roc: 0.7045
# Epoch 41/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6831 - accuracy: 0.5374 - auc_roc: 0.7200
# Epoch 42/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6848 - accuracy: 0.5271 - auc_roc: 0.7096
# Epoch 43/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6823 - accuracy: 0.5304 - auc_roc: 0.7399
# Epoch 44/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6819 - accuracy: 0.5432 - auc_roc: 0.7000
# Epoch 45/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6825 - accuracy: 0.5490 - auc_roc: 0.7000
# Epoch 46/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6808 - accuracy: 0.5518 - auc_roc: 0.7353
# Epoch 47/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6842 - accuracy: 0.5254 - auc_roc: 0.7061
# Epoch 48/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6827 - accuracy: 0.5376 - auc_roc: 0.7110
# Epoch 49/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6818 - accuracy: 0.5383 - auc_roc: 0.7236
# Epoch 50/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6837 - accuracy: 0.5186 - auc_roc: 0.7134
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# 14/14 [==============================] - 0s 866us/step
# 14/14 [==============================] - 0s 845us/step
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Epoch 1/50
# 55/55 [==============================] - 2s 4ms/step - loss: 0.6905 - accuracy: 0.5807 - auc_roc: 0.6501
# Epoch 2/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6897 - accuracy: 0.6106 - auc_roc: 0.6430
# Epoch 3/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6899 - accuracy: 0.6042 - auc_roc: 0.6325
# Epoch 4/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6895 - accuracy: 0.6131 - auc_roc: 0.6419
# Epoch 5/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6901 - accuracy: 0.6108 - auc_roc: 0.6320
# Epoch 6/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6889 - accuracy: 0.6343 - auc_roc: 0.6551
# Epoch 7/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6894 - accuracy: 0.6197 - auc_roc: 0.6401
# Epoch 8/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6894 - accuracy: 0.6129 - auc_roc: 0.6322
# Epoch 9/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6891 - accuracy: 0.6147 - auc_roc: 0.6408
# Epoch 10/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6892 - accuracy: 0.6155 - auc_roc: 0.6430
# Epoch 11/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6892 - accuracy: 0.6144 - auc_roc: 0.6437
# Epoch 12/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6889 - accuracy: 0.6080 - auc_roc: 0.6423
# Epoch 13/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6888 - accuracy: 0.6101 - auc_roc: 0.6398
# Epoch 14/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6886 - accuracy: 0.6134 - auc_roc: 0.6597
# Epoch 15/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6881 - accuracy: 0.6149 - auc_roc: 0.6516
# Epoch 16/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6880 - accuracy: 0.6334 - auc_roc: 0.6684
# Epoch 17/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6867 - accuracy: 0.6483 - auc_roc: 0.6861
# Epoch 18/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6880 - accuracy: 0.6270 - auc_roc: 0.6572
# Epoch 19/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6876 - accuracy: 0.6284 - auc_roc: 0.6640
# Epoch 20/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6871 - accuracy: 0.6436 - auc_roc: 0.6846
# Epoch 21/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6868 - accuracy: 0.6309 - auc_roc: 0.6747
# Epoch 22/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6870 - accuracy: 0.6291 - auc_roc: 0.6796
# Epoch 23/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6867 - accuracy: 0.6279 - auc_roc: 0.6829
# Epoch 24/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6865 - accuracy: 0.6275 - auc_roc: 0.6805
# Epoch 25/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6873 - accuracy: 0.6198 - auc_roc: 0.6548
# Epoch 26/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6860 - accuracy: 0.6425 - auc_roc: 0.6850
# Epoch 27/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6862 - accuracy: 0.6299 - auc_roc: 0.6813
# Epoch 28/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6848 - accuracy: 0.6559 - auc_roc: 0.7086
# Epoch 29/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6859 - accuracy: 0.6460 - auc_roc: 0.6845
# Epoch 30/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6858 - accuracy: 0.6301 - auc_roc: 0.6869
# Epoch 31/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6864 - accuracy: 0.6195 - auc_roc: 0.6724
# Epoch 32/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6853 - accuracy: 0.6362 - auc_roc: 0.6805
# Epoch 33/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6858 - accuracy: 0.6377 - auc_roc: 0.6753
# Epoch 34/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6850 - accuracy: 0.6358 - auc_roc: 0.6901
# Epoch 35/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6854 - accuracy: 0.6334 - auc_roc: 0.6863
# Epoch 36/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6859 - accuracy: 0.6291 - auc_roc: 0.6763
# Epoch 37/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6846 - accuracy: 0.6586 - auc_roc: 0.6884
# Epoch 38/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6847 - accuracy: 0.6336 - auc_roc: 0.6852
# Epoch 39/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6839 - accuracy: 0.6506 - auc_roc: 0.7116
# Epoch 40/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6848 - accuracy: 0.6316 - auc_roc: 0.6831
# Epoch 41/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6846 - accuracy: 0.6426 - auc_roc: 0.6840
# Epoch 42/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6843 - accuracy: 0.6457 - auc_roc: 0.6972
# Epoch 43/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6840 - accuracy: 0.6419 - auc_roc: 0.6980
# Epoch 44/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6851 - accuracy: 0.6329 - auc_roc: 0.6730
# Epoch 45/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6845 - accuracy: 0.6295 - auc_roc: 0.6909
# Epoch 46/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6838 - accuracy: 0.6347 - auc_roc: 0.6852
# Epoch 47/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6839 - accuracy: 0.6454 - auc_roc: 0.6881
# Epoch 48/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6837 - accuracy: 0.6489 - auc_roc: 0.6842
# Epoch 49/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6833 - accuracy: 0.6420 - auc_roc: 0.6899
# Epoch 50/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6838 - accuracy: 0.6239 - auc_roc: 0.6803
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# 14/14 [==============================] - 0s 857us/step
# 14/14 [==============================] - 0s 802us/step
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Epoch 1/50
# 55/55 [==============================] - 2s 4ms/step - loss: 0.6890 - accuracy: 0.5347 - auc_roc: 0.6596
# Epoch 2/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6866 - accuracy: 0.5760 - auc_roc: 0.6451
# Epoch 3/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6878 - accuracy: 0.5582 - auc_roc: 0.6380
# Epoch 4/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6884 - accuracy: 0.5484 - auc_roc: 0.6372
# Epoch 5/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6892 - accuracy: 0.5149 - auc_roc: 0.6318
# Epoch 6/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6867 - accuracy: 0.5586 - auc_roc: 0.6367
# Epoch 7/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6882 - accuracy: 0.5255 - auc_roc: 0.6328
# Epoch 8/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6864 - accuracy: 0.5571 - auc_roc: 0.6371
# Epoch 9/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6864 - accuracy: 0.5392 - auc_roc: 0.6673
# Epoch 10/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6855 - accuracy: 0.5593 - auc_roc: 0.6491
# Epoch 11/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6855 - accuracy: 0.5512 - auc_roc: 0.6531
# Epoch 12/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6860 - accuracy: 0.5378 - auc_roc: 0.6540
# Epoch 13/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6853 - accuracy: 0.5587 - auc_roc: 0.6435
# Epoch 14/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6863 - accuracy: 0.5426 - auc_roc: 0.6512
# Epoch 15/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6861 - accuracy: 0.5491 - auc_roc: 0.6310
# Epoch 16/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6840 - accuracy: 0.5658 - auc_roc: 0.6578
# Epoch 17/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6857 - accuracy: 0.5355 - auc_roc: 0.6519
# Epoch 18/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6858 - accuracy: 0.5229 - auc_roc: 0.6707
# Epoch 19/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6844 - accuracy: 0.5442 - auc_roc: 0.6649
# Epoch 20/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6843 - accuracy: 0.5497 - auc_roc: 0.6655
# Epoch 21/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6847 - accuracy: 0.5313 - auc_roc: 0.6754
# Epoch 22/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6846 - accuracy: 0.5338 - auc_roc: 0.6749
# Epoch 23/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6851 - accuracy: 0.5415 - auc_roc: 0.6454
# Epoch 24/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6834 - accuracy: 0.5367 - auc_roc: 0.6876
# Epoch 25/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6842 - accuracy: 0.5313 - auc_roc: 0.6841
# Epoch 26/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6835 - accuracy: 0.5383 - auc_roc: 0.6921
# Epoch 27/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6839 - accuracy: 0.5333 - auc_roc: 0.6799
# Epoch 28/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6834 - accuracy: 0.5225 - auc_roc: 0.7006
# Epoch 29/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6838 - accuracy: 0.5223 - auc_roc: 0.6914
# Epoch 30/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6809 - accuracy: 0.5634 - auc_roc: 0.6883
# Epoch 31/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6835 - accuracy: 0.5430 - auc_roc: 0.6633
# Epoch 32/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6835 - accuracy: 0.5381 - auc_roc: 0.6662
# Epoch 33/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.6834 - accuracy: 0.5370 - auc_roc: 0.6736
# Epoch 34/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6836 - accuracy: 0.5280 - auc_roc: 0.6864
# Epoch 35/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6809 - accuracy: 0.5494 - auc_roc: 0.6991
# Epoch 36/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6819 - accuracy: 0.5385 - auc_roc: 0.6876
# Epoch 37/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6818 - accuracy: 0.5405 - auc_roc: 0.6808
# Epoch 38/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6805 - accuracy: 0.5533 - auc_roc: 0.6918
# Epoch 39/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6806 - accuracy: 0.5519 - auc_roc: 0.6762
# Epoch 40/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6837 - accuracy: 0.5235 - auc_roc: 0.6770
# Epoch 41/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6782 - accuracy: 0.5593 - auc_roc: 0.7116
# Epoch 42/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6820 - accuracy: 0.5403 - auc_roc: 0.6698
# Epoch 43/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6832 - accuracy: 0.5211 - auc_roc: 0.6812
# Epoch 44/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6809 - accuracy: 0.5402 - auc_roc: 0.6842
# Epoch 45/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6796 - accuracy: 0.5468 - auc_roc: 0.7004
# Epoch 46/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6794 - accuracy: 0.5513 - auc_roc: 0.6921
# Epoch 47/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6797 - accuracy: 0.5484 - auc_roc: 0.6871
# Epoch 48/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6802 - accuracy: 0.5455 - auc_roc: 0.6886
# Epoch 49/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6794 - accuracy: 0.5446 - auc_roc: 0.6898
# Epoch 50/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6789 - accuracy: 0.5401 - auc_roc: 0.7068
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# 14/14 [==============================] - 0s 996us/step
# 14/14 [==============================] - 0s 816us/step
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Epoch 1/50
# 55/55 [==============================] - 2s 5ms/step - loss: 0.6958 - accuracy: 0.4434 - auc_roc: 0.6215
# Epoch 2/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6955 - accuracy: 0.4572 - auc_roc: 0.4504
# Epoch 3/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6950 - accuracy: 0.4546 - auc_roc: 0.4553
# Epoch 4/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6956 - accuracy: 0.4450 - auc_roc: 0.4359
# Epoch 5/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6945 - accuracy: 0.4757 - auc_roc: 0.4720
# Epoch 6/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6952 - accuracy: 0.4622 - auc_roc: 0.4478
# Epoch 7/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6943 - accuracy: 0.4895 - auc_roc: 0.4778
# Epoch 8/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6939 - accuracy: 0.4728 - auc_roc: 0.4775
# Epoch 9/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6941 - accuracy: 0.4751 - auc_roc: 0.4757
# Epoch 10/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6942 - accuracy: 0.4795 - auc_roc: 0.4738
# Epoch 11/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6940 - accuracy: 0.4646 - auc_roc: 0.4699
# Epoch 12/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6933 - accuracy: 0.4961 - auc_roc: 0.5000
# Epoch 13/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6937 - accuracy: 0.4762 - auc_roc: 0.4826
# Epoch 14/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6933 - accuracy: 0.5012 - auc_roc: 0.4930
# Epoch 15/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6933 - accuracy: 0.4951 - auc_roc: 0.4908
# Epoch 16/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6934 - accuracy: 0.4988 - auc_roc: 0.4933
# Epoch 17/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6926 - accuracy: 0.5188 - auc_roc: 0.5124
# Epoch 18/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6922 - accuracy: 0.5198 - auc_roc: 0.5142
# Epoch 19/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6929 - accuracy: 0.5166 - auc_roc: 0.5011
# Epoch 20/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6916 - accuracy: 0.5414 - auc_roc: 0.5401
# Epoch 21/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6917 - accuracy: 0.5263 - auc_roc: 0.5299
# Epoch 22/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6925 - accuracy: 0.5138 - auc_roc: 0.5151
# Epoch 23/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6918 - accuracy: 0.5397 - auc_roc: 0.5332
# Epoch 24/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6919 - accuracy: 0.5305 - auc_roc: 0.5278
# Epoch 25/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6914 - accuracy: 0.5413 - auc_roc: 0.5432
# Epoch 26/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6922 - accuracy: 0.5252 - auc_roc: 0.5205
# Epoch 27/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6914 - accuracy: 0.5422 - auc_roc: 0.5414
# Epoch 28/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6903 - accuracy: 0.5647 - auc_roc: 0.5706
# Epoch 29/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6912 - accuracy: 0.5373 - auc_roc: 0.5407
# Epoch 30/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6907 - accuracy: 0.5587 - auc_roc: 0.5616
# Epoch 31/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6909 - accuracy: 0.5410 - auc_roc: 0.5484
# Epoch 32/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6913 - accuracy: 0.5227 - auc_roc: 0.5308
# Epoch 33/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6902 - accuracy: 0.5539 - auc_roc: 0.5700
# Epoch 34/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6898 - accuracy: 0.5663 - auc_roc: 0.5746
# Epoch 35/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6892 - accuracy: 0.5789 - auc_roc: 0.6005
# Epoch 36/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6889 - accuracy: 0.5764 - auc_roc: 0.5973
# Epoch 37/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6885 - accuracy: 0.5858 - auc_roc: 0.6031
# Epoch 38/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6896 - accuracy: 0.5693 - auc_roc: 0.5819
# Epoch 39/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6884 - accuracy: 0.5760 - auc_roc: 0.6017
# Epoch 40/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6880 - accuracy: 0.5763 - auc_roc: 0.6067
# Epoch 41/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6880 - accuracy: 0.5981 - auc_roc: 0.6186
# Epoch 42/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6886 - accuracy: 0.5828 - auc_roc: 0.6005
# Epoch 43/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6878 - accuracy: 0.5997 - auc_roc: 0.6237
# Epoch 44/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6873 - accuracy: 0.6177 - auc_roc: 0.6333
# Epoch 45/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6880 - accuracy: 0.5816 - auc_roc: 0.6130
# Epoch 46/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6872 - accuracy: 0.5981 - auc_roc: 0.6299
# Epoch 47/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6876 - accuracy: 0.5871 - auc_roc: 0.6172
# Epoch 48/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6873 - accuracy: 0.6041 - auc_roc: 0.6347
# Epoch 49/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6868 - accuracy: 0.6017 - auc_roc: 0.6364
# Epoch 50/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6861 - accuracy: 0.6180 - auc_roc: 0.6504
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# 14/14 [==============================] - 0s 4ms/step
# 14/14 [==============================] - 0s 2ms/step
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Epoch 1/50
# 55/55 [==============================] - 3s 5ms/step - loss: 0.6888 - accuracy: 0.6179 - auc_roc: 0.6387
# Epoch 2/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6889 - accuracy: 0.6065 - auc_roc: 0.6485
# Epoch 3/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6880 - accuracy: 0.6274 - auc_roc: 0.6757
# Epoch 4/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6874 - accuracy: 0.6321 - auc_roc: 0.6863
# Epoch 5/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6874 - accuracy: 0.6436 - auc_roc: 0.6868
# Epoch 6/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6883 - accuracy: 0.6264 - auc_roc: 0.6508
# Epoch 7/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6886 - accuracy: 0.6097 - auc_roc: 0.6435
# Epoch 8/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6869 - accuracy: 0.6488 - auc_roc: 0.6822
# Epoch 9/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6868 - accuracy: 0.6422 - auc_roc: 0.6718
# Epoch 10/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6869 - accuracy: 0.6370 - auc_roc: 0.6745
# Epoch 11/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6862 - accuracy: 0.6350 - auc_roc: 0.6843
# Epoch 12/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6859 - accuracy: 0.6444 - auc_roc: 0.6915
# Epoch 13/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6859 - accuracy: 0.6407 - auc_roc: 0.6911
# Epoch 14/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6851 - accuracy: 0.6436 - auc_roc: 0.6880
# Epoch 15/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6865 - accuracy: 0.6120 - auc_roc: 0.6681
# Epoch 16/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6864 - accuracy: 0.6238 - auc_roc: 0.6687
# Epoch 17/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6845 - accuracy: 0.6444 - auc_roc: 0.7018
# Epoch 18/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6851 - accuracy: 0.6327 - auc_roc: 0.6850
# Epoch 19/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6844 - accuracy: 0.6472 - auc_roc: 0.7028
# Epoch 20/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6838 - accuracy: 0.6530 - auc_roc: 0.6971
# Epoch 21/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6842 - accuracy: 0.6482 - auc_roc: 0.6987
# Epoch 22/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6842 - accuracy: 0.6327 - auc_roc: 0.6926
# Epoch 23/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6838 - accuracy: 0.6382 - auc_roc: 0.6963
# Epoch 24/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6826 - accuracy: 0.6553 - auc_roc: 0.7071
# Epoch 25/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6823 - accuracy: 0.6420 - auc_roc: 0.7028
# Epoch 26/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6830 - accuracy: 0.6244 - auc_roc: 0.6878
# Epoch 27/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6823 - accuracy: 0.6230 - auc_roc: 0.6985
# Epoch 28/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6834 - accuracy: 0.6256 - auc_roc: 0.6957
# Epoch 29/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6829 - accuracy: 0.6310 - auc_roc: 0.6838
# Epoch 30/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6823 - accuracy: 0.6402 - auc_roc: 0.7088
# Epoch 31/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6818 - accuracy: 0.6378 - auc_roc: 0.7017
# Epoch 32/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6816 - accuracy: 0.6384 - auc_roc: 0.7027
# Epoch 33/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6830 - accuracy: 0.6225 - auc_roc: 0.6929
# Epoch 34/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6825 - accuracy: 0.5952 - auc_roc: 0.6930
# Epoch 35/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6821 - accuracy: 0.6127 - auc_roc: 0.6935
# Epoch 36/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6810 - accuracy: 0.6047 - auc_roc: 0.6922
# Epoch 37/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6813 - accuracy: 0.6102 - auc_roc: 0.7043
# Epoch 38/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6801 - accuracy: 0.6095 - auc_roc: 0.7036
# Epoch 39/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6805 - accuracy: 0.6148 - auc_roc: 0.7101
# Epoch 40/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6805 - accuracy: 0.5915 - auc_roc: 0.6901
# Epoch 41/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6801 - accuracy: 0.6056 - auc_roc: 0.6941
# Epoch 42/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6791 - accuracy: 0.6231 - auc_roc: 0.7206
# Epoch 43/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6797 - accuracy: 0.6136 - auc_roc: 0.7086
# Epoch 44/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6807 - accuracy: 0.5949 - auc_roc: 0.7015
# Epoch 45/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6785 - accuracy: 0.6293 - auc_roc: 0.7083
# Epoch 46/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6770 - accuracy: 0.6114 - auc_roc: 0.7164
# Epoch 47/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6768 - accuracy: 0.6299 - auc_roc: 0.7163
# Epoch 48/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6791 - accuracy: 0.6049 - auc_roc: 0.7174
# Epoch 49/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6775 - accuracy: 0.6057 - auc_roc: 0.7097
# Epoch 50/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6769 - accuracy: 0.6018 - auc_roc: 0.7255
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# 14/14 [==============================] - 0s 995us/step
# 14/14 [==============================] - 0s 872us/step
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Epoch 1/50
# 55/55 [==============================] - 2s 6ms/step - loss: 0.6989 - accuracy: 0.3809 - auc_roc: 0.6025
# Epoch 2/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6986 - accuracy: 0.3720 - auc_roc: 0.3308
# Epoch 3/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6985 - accuracy: 0.3541 - auc_roc: 0.3224
# Epoch 4/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6985 - accuracy: 0.3716 - auc_roc: 0.3210
# Epoch 5/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6986 - accuracy: 0.3749 - auc_roc: 0.3237
# Epoch 6/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6979 - accuracy: 0.3761 - auc_roc: 0.3324
# Epoch 7/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6978 - accuracy: 0.3878 - auc_roc: 0.3417
# Epoch 8/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6978 - accuracy: 0.3661 - auc_roc: 0.3268
# Epoch 9/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6978 - accuracy: 0.3889 - auc_roc: 0.3328
# Epoch 10/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6976 - accuracy: 0.3607 - auc_roc: 0.3280
# Epoch 11/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6977 - accuracy: 0.3681 - auc_roc: 0.3338
# Epoch 12/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6979 - accuracy: 0.3564 - auc_roc: 0.3110
# Epoch 13/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6970 - accuracy: 0.3863 - auc_roc: 0.3502
# Epoch 14/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6968 - accuracy: 0.3855 - auc_roc: 0.3508
# Epoch 15/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6971 - accuracy: 0.3840 - auc_roc: 0.3472
# Epoch 16/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6966 - accuracy: 0.4025 - auc_roc: 0.3594
# Epoch 17/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6967 - accuracy: 0.4075 - auc_roc: 0.3629
# Epoch 18/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6963 - accuracy: 0.4196 - auc_roc: 0.3772
# Epoch 19/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6963 - accuracy: 0.4011 - auc_roc: 0.3628
# Epoch 20/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6960 - accuracy: 0.4257 - auc_roc: 0.3849
# Epoch 21/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6961 - accuracy: 0.3973 - auc_roc: 0.3681
# Epoch 22/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6957 - accuracy: 0.4365 - auc_roc: 0.3987
# Epoch 23/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6956 - accuracy: 0.4254 - auc_roc: 0.3855
# Epoch 24/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6954 - accuracy: 0.4248 - auc_roc: 0.3907
# Epoch 25/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6956 - accuracy: 0.4251 - auc_roc: 0.3872
# Epoch 26/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6949 - accuracy: 0.4542 - auc_roc: 0.4248
# Epoch 27/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6954 - accuracy: 0.4455 - auc_roc: 0.3950
# Epoch 28/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6950 - accuracy: 0.4377 - auc_roc: 0.4086
# Epoch 29/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6949 - accuracy: 0.4422 - auc_roc: 0.4156
# Epoch 30/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6949 - accuracy: 0.4579 - auc_roc: 0.4123
# Epoch 31/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6948 - accuracy: 0.4516 - auc_roc: 0.4223
# Epoch 32/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6949 - accuracy: 0.4434 - auc_roc: 0.4148
# Epoch 33/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6944 - accuracy: 0.4574 - auc_roc: 0.4311
# Epoch 34/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6944 - accuracy: 0.4724 - auc_roc: 0.4352
# Epoch 35/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6942 - accuracy: 0.4614 - auc_roc: 0.4464
# Epoch 36/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6947 - accuracy: 0.4417 - auc_roc: 0.4212
# Epoch 37/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6943 - accuracy: 0.4550 - auc_roc: 0.4469
# Epoch 38/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6942 - accuracy: 0.4570 - auc_roc: 0.4451
# Epoch 39/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6942 - accuracy: 0.4505 - auc_roc: 0.4461
# Epoch 40/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6940 - accuracy: 0.4392 - auc_roc: 0.4448
# Epoch 41/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6936 - accuracy: 0.4915 - auc_roc: 0.4809
# Epoch 42/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6938 - accuracy: 0.4765 - auc_roc: 0.4682
# Epoch 43/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6931 - accuracy: 0.5050 - auc_roc: 0.5095
# Epoch 44/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6935 - accuracy: 0.4745 - auc_roc: 0.4853
# Epoch 45/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6931 - accuracy: 0.5060 - auc_roc: 0.5117
# Epoch 46/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6936 - accuracy: 0.4639 - auc_roc: 0.4715
# Epoch 47/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6934 - accuracy: 0.4816 - auc_roc: 0.4682
# Epoch 48/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6932 - accuracy: 0.4915 - auc_roc: 0.4991
# Epoch 49/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6932 - accuracy: 0.4958 - auc_roc: 0.4988
# Epoch 50/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6929 - accuracy: 0.5024 - auc_roc: 0.5218
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# 14/14 [==============================] - 0s 2ms/step
# 14/14 [==============================] - 0s 2ms/step
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Epoch 1/50
# 55/55 [==============================] - 2s 6ms/step - loss: 0.6944 - accuracy: 0.5183 - auc_roc: 0.5035
# Epoch 2/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6936 - accuracy: 0.5572 - auc_roc: 0.4423
# Epoch 3/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6937 - accuracy: 0.5618 - auc_roc: 0.4489
# Epoch 4/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6936 - accuracy: 0.5525 - auc_roc: 0.4373
# Epoch 5/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6933 - accuracy: 0.5422 - auc_roc: 0.4497
# Epoch 6/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6933 - accuracy: 0.5302 - auc_roc: 0.4949
# Epoch 7/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6930 - accuracy: 0.5475 - auc_roc: 0.4777
# Epoch 8/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6930 - accuracy: 0.5410 - auc_roc: 0.4671
# Epoch 9/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6926 - accuracy: 0.5414 - auc_roc: 0.4914
# Epoch 10/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6933 - accuracy: 0.5202 - auc_roc: 0.4798
# Epoch 11/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6925 - accuracy: 0.5357 - auc_roc: 0.5075
# Epoch 12/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6920 - accuracy: 0.5383 - auc_roc: 0.5325
# Epoch 13/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6917 - accuracy: 0.5421 - auc_roc: 0.5219
# Epoch 14/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6925 - accuracy: 0.5178 - auc_roc: 0.5307
# Epoch 15/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6914 - accuracy: 0.5453 - auc_roc: 0.5300
# Epoch 16/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6914 - accuracy: 0.5395 - auc_roc: 0.5543
# Epoch 17/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6921 - accuracy: 0.5184 - auc_roc: 0.5540
# Epoch 18/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6909 - accuracy: 0.5448 - auc_roc: 0.5734
# Epoch 19/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6914 - accuracy: 0.5330 - auc_roc: 0.5548
# Epoch 20/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6918 - accuracy: 0.5104 - auc_roc: 0.6074
# Epoch 21/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6915 - accuracy: 0.5135 - auc_roc: 0.6066
# Epoch 22/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6904 - accuracy: 0.5342 - auc_roc: 0.6194
# Epoch 23/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6895 - accuracy: 0.5471 - auc_roc: 0.6412
# Epoch 24/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6902 - accuracy: 0.5342 - auc_roc: 0.6317
# Epoch 25/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6900 - accuracy: 0.5330 - auc_roc: 0.6455
# Epoch 26/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6893 - accuracy: 0.5413 - auc_roc: 0.6586
# Epoch 27/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6904 - accuracy: 0.5241 - auc_roc: 0.6510
# Epoch 28/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6895 - accuracy: 0.5362 - auc_roc: 0.6601
# Epoch 29/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6905 - accuracy: 0.5134 - auc_roc: 0.6648
# Epoch 30/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6897 - accuracy: 0.5227 - auc_roc: 0.6894
# Epoch 31/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6891 - accuracy: 0.5388 - auc_roc: 0.6531
# Epoch 32/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6900 - accuracy: 0.5144 - auc_roc: 0.6910
# Epoch 33/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6892 - accuracy: 0.5269 - auc_roc: 0.6805
# Epoch 34/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6891 - accuracy: 0.5275 - auc_roc: 0.6910
# Epoch 35/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6894 - accuracy: 0.5186 - auc_roc: 0.6942
# Epoch 36/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6893 - accuracy: 0.5260 - auc_roc: 0.6771
# Epoch 37/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6880 - accuracy: 0.5393 - auc_roc: 0.6968
# Epoch 38/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6878 - accuracy: 0.5442 - auc_roc: 0.6953
# Epoch 39/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6886 - accuracy: 0.5243 - auc_roc: 0.7091
# Epoch 40/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6882 - accuracy: 0.5292 - auc_roc: 0.7148
# Epoch 41/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6886 - accuracy: 0.5278 - auc_roc: 0.6896
# Epoch 42/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6884 - accuracy: 0.5223 - auc_roc: 0.7186
# Epoch 43/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6890 - accuracy: 0.5170 - auc_roc: 0.6901
# Epoch 44/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.6888 - accuracy: 0.5215 - auc_roc: 0.6967
# Epoch 45/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6870 - accuracy: 0.5409 - auc_roc: 0.7045
# Epoch 46/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6879 - accuracy: 0.5286 - auc_roc: 0.6945
# Epoch 47/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6859 - accuracy: 0.5472 - auc_roc: 0.7327
# Epoch 48/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6880 - accuracy: 0.5254 - auc_roc: 0.7010
# Epoch 49/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6881 - accuracy: 0.5168 - auc_roc: 0.7161
# Epoch 50/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.6854 - accuracy: 0.5525 - auc_roc: 0.7276
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# 14/14 [==============================] - 0s 1ms/step
# 14/14 [==============================] - 0s 869us/step
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Epoch 1/50
# 55/55 [==============================] - 2s 5ms/step - loss: 0.6969 - accuracy: 0.4605 - auc_roc: 0.6122
# Epoch 2/50
# ...
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# 10/10 [==============================] - 1s 1ms/step
# 10/10 [==============================] - 0s 942us/step
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Epoch 1/60
# 37/37 [==============================] - 2s 7ms/step - loss: 0.6962 - accuracy: 0.4474 - auc_roc: 0.6907
# Epoch 2/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6958 - accuracy: 0.4620 - auc_roc: 0.4179
# Epoch 3/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6959 - accuracy: 0.4620 - auc_roc: 0.4283
# Epoch 4/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6956 - accuracy: 0.4599 - auc_roc: 0.4274
# Epoch 5/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6957 - accuracy: 0.4475 - auc_roc: 0.4248
# Epoch 6/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6958 - accuracy: 0.4605 - auc_roc: 0.4248
# Epoch 7/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6947 - accuracy: 0.4747 - auc_roc: 0.4528
# Epoch 8/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6942 - accuracy: 0.4889 - auc_roc: 0.4674
# Epoch 9/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6945 - accuracy: 0.4754 - auc_roc: 0.4600
# Epoch 10/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6933 - accuracy: 0.5034 - auc_roc: 0.5051
# Epoch 11/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6942 - accuracy: 0.4816 - auc_roc: 0.4837
# Epoch 12/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6944 - accuracy: 0.4833 - auc_roc: 0.4714
# Epoch 13/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6936 - accuracy: 0.4881 - auc_roc: 0.4892
# Epoch 14/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6934 - accuracy: 0.5053 - auc_roc: 0.5022
# Epoch 15/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6932 - accuracy: 0.4950 - auc_roc: 0.5174
# Epoch 16/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6933 - accuracy: 0.4927 - auc_roc: 0.5187
# Epoch 17/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6929 - accuracy: 0.5046 - auc_roc: 0.5374
# Epoch 18/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6927 - accuracy: 0.5109 - auc_roc: 0.5281
# Epoch 19/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6921 - accuracy: 0.5349 - auc_roc: 0.5555
# Epoch 20/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6918 - accuracy: 0.5433 - auc_roc: 0.5713
# Epoch 21/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6917 - accuracy: 0.5318 - auc_roc: 0.5785
# Epoch 22/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6919 - accuracy: 0.5361 - auc_roc: 0.5678
# Epoch 23/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6916 - accuracy: 0.5496 - auc_roc: 0.5757
# Epoch 24/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6908 - accuracy: 0.5672 - auc_roc: 0.6112
# Epoch 25/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6903 - accuracy: 0.5580 - auc_roc: 0.6239
# Epoch 26/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6908 - accuracy: 0.5727 - auc_roc: 0.6086
# Epoch 27/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6900 - accuracy: 0.5877 - auc_roc: 0.6371
# Epoch 28/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6900 - accuracy: 0.5898 - auc_roc: 0.6364
# Epoch 29/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6901 - accuracy: 0.5755 - auc_roc: 0.6253
# Epoch 30/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6891 - accuracy: 0.6084 - auc_roc: 0.6656
# Epoch 31/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6894 - accuracy: 0.6125 - auc_roc: 0.6502
# Epoch 32/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6887 - accuracy: 0.6222 - auc_roc: 0.6773
# Epoch 33/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6892 - accuracy: 0.6153 - auc_roc: 0.6529
# Epoch 34/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6889 - accuracy: 0.6243 - auc_roc: 0.6650
# Epoch 35/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6886 - accuracy: 0.6101 - auc_roc: 0.6660
# Epoch 36/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6881 - accuracy: 0.6318 - auc_roc: 0.6798
# Epoch 37/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6879 - accuracy: 0.6351 - auc_roc: 0.6856
# Epoch 38/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6876 - accuracy: 0.6342 - auc_roc: 0.6839
# Epoch 39/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6884 - accuracy: 0.6214 - auc_roc: 0.6647
# Epoch 40/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6878 - accuracy: 0.6280 - auc_roc: 0.6818
# Epoch 41/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6870 - accuracy: 0.6557 - auc_roc: 0.6954
# Epoch 42/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6872 - accuracy: 0.6305 - auc_roc: 0.6893
# Epoch 43/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6861 - accuracy: 0.6645 - auc_roc: 0.7201
# Epoch 44/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6860 - accuracy: 0.6554 - auc_roc: 0.7178
# Epoch 45/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6861 - accuracy: 0.6455 - auc_roc: 0.7078
# Epoch 46/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6861 - accuracy: 0.6564 - auc_roc: 0.7028
# Epoch 47/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6858 - accuracy: 0.6643 - auc_roc: 0.7039
# Epoch 48/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6866 - accuracy: 0.6329 - auc_roc: 0.6814
# Epoch 49/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6853 - accuracy: 0.6660 - auc_roc: 0.7199
# Epoch 50/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6845 - accuracy: 0.6694 - auc_roc: 0.7322
# Epoch 51/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6846 - accuracy: 0.6687 - auc_roc: 0.7260
# Epoch 52/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6842 - accuracy: 0.6675 - auc_roc: 0.7273
# Epoch 53/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6847 - accuracy: 0.6638 - auc_roc: 0.7067
# Epoch 54/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6837 - accuracy: 0.6675 - auc_roc: 0.7359
# Epoch 55/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6837 - accuracy: 0.6585 - auc_roc: 0.7153
# Epoch 56/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6834 - accuracy: 0.6716 - auc_roc: 0.7330
# Epoch 57/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6825 - accuracy: 0.6786 - auc_roc: 0.7389
# Epoch 58/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6831 - accuracy: 0.6650 - auc_roc: 0.7261
# Epoch 59/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6814 - accuracy: 0.6774 - auc_roc: 0.7533
# Epoch 60/60
# 37/37 [==============================] - 0s 6ms/step - loss: 0.6822 - accuracy: 0.6735 - auc_roc: 0.7394
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# 10/10 [==============================] - 0s 1ms/step
# 10/10 [==============================] - 0s 921us/step
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Epoch 1/60
# 69/69 [==============================] - 2s 5ms/step - loss: 0.6953 - accuracy: 0.5080 - auc_roc: 0.6219
# Epoch 2/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6940 - accuracy: 0.5235 - auc_roc: 0.4609
# Epoch 3/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6951 - accuracy: 0.5114 - auc_roc: 0.4519
# Epoch 4/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6946 - accuracy: 0.5141 - auc_roc: 0.4519
# Epoch 5/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6942 - accuracy: 0.5206 - auc_roc: 0.4743
# Epoch 6/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6939 - accuracy: 0.5176 - auc_roc: 0.4842
# Epoch 7/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6939 - accuracy: 0.5185 - auc_roc: 0.5002
# Epoch 8/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6929 - accuracy: 0.5207 - auc_roc: 0.5311
# Epoch 9/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6934 - accuracy: 0.5259 - auc_roc: 0.5164
# Epoch 10/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6922 - accuracy: 0.5377 - auc_roc: 0.5470
# Epoch 11/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6924 - accuracy: 0.5273 - auc_roc: 0.5451
# Epoch 12/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6914 - accuracy: 0.5361 - auc_roc: 0.5792
# Epoch 13/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6924 - accuracy: 0.5337 - auc_roc: 0.5467
# Epoch 14/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6925 - accuracy: 0.5312 - auc_roc: 0.5581
# Epoch 15/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6916 - accuracy: 0.5400 - auc_roc: 0.5774
# Epoch 16/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6903 - accuracy: 0.5572 - auc_roc: 0.6040
# Epoch 17/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6910 - accuracy: 0.5471 - auc_roc: 0.5884
# Epoch 18/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6901 - accuracy: 0.5569 - auc_roc: 0.6186
# Epoch 19/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6900 - accuracy: 0.5609 - auc_roc: 0.6209
# Epoch 20/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6906 - accuracy: 0.5552 - auc_roc: 0.6120
# Epoch 21/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6896 - accuracy: 0.5826 - auc_roc: 0.6367
# Epoch 22/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6901 - accuracy: 0.5470 - auc_roc: 0.6342
# Epoch 23/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6888 - accuracy: 0.5843 - auc_roc: 0.6647
# Epoch 24/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6882 - accuracy: 0.5816 - auc_roc: 0.6730
# Epoch 25/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6894 - accuracy: 0.5660 - auc_roc: 0.6428
# Epoch 26/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6882 - accuracy: 0.5939 - auc_roc: 0.6795
# Epoch 27/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6875 - accuracy: 0.5981 - auc_roc: 0.6741
# Epoch 28/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6879 - accuracy: 0.5943 - auc_roc: 0.6682
# Epoch 29/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6863 - accuracy: 0.6197 - auc_roc: 0.6881
# Epoch 30/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6869 - accuracy: 0.6228 - auc_roc: 0.6923
# Epoch 31/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6880 - accuracy: 0.5900 - auc_roc: 0.6601
# Epoch 32/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6861 - accuracy: 0.6197 - auc_roc: 0.6963
# Epoch 33/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6849 - accuracy: 0.6320 - auc_roc: 0.7147
# Epoch 34/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6844 - accuracy: 0.6460 - auc_roc: 0.7189
# Epoch 35/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6853 - accuracy: 0.6214 - auc_roc: 0.7132
# Epoch 36/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6849 - accuracy: 0.6435 - auc_roc: 0.7059
# Epoch 37/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6842 - accuracy: 0.6378 - auc_roc: 0.7096
# Epoch 38/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6846 - accuracy: 0.6397 - auc_roc: 0.7000
# Epoch 39/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6842 - accuracy: 0.6390 - auc_roc: 0.7098
# Epoch 40/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6842 - accuracy: 0.6475 - auc_roc: 0.6998
# Epoch 41/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6833 - accuracy: 0.6527 - auc_roc: 0.7267
# Epoch 42/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6833 - accuracy: 0.6454 - auc_roc: 0.7065
# Epoch 43/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6816 - accuracy: 0.6642 - auc_roc: 0.7421
# Epoch 44/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6823 - accuracy: 0.6657 - auc_roc: 0.7217
# Epoch 45/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6804 - accuracy: 0.6907 - auc_roc: 0.7488
# Epoch 46/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6817 - accuracy: 0.6618 - auc_roc: 0.7256
# Epoch 47/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6805 - accuracy: 0.6883 - auc_roc: 0.7421
# Epoch 48/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6811 - accuracy: 0.6670 - auc_roc: 0.7234
# Epoch 49/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6806 - accuracy: 0.6678 - auc_roc: 0.7284
# Epoch 50/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6798 - accuracy: 0.6795 - auc_roc: 0.7329
# Epoch 51/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6800 - accuracy: 0.6709 - auc_roc: 0.7265
# Epoch 52/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6789 - accuracy: 0.6790 - auc_roc: 0.7401
# Epoch 53/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6792 - accuracy: 0.6848 - auc_roc: 0.7306
# Epoch 54/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6775 - accuracy: 0.6957 - auc_roc: 0.7456
# Epoch 55/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6784 - accuracy: 0.6767 - auc_roc: 0.7331
# Epoch 56/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6774 - accuracy: 0.6944 - auc_roc: 0.7424
# Epoch 57/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6772 - accuracy: 0.6911 - auc_roc: 0.7406
# Epoch 58/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6773 - accuracy: 0.6866 - auc_roc: 0.7315
# Epoch 59/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6762 - accuracy: 0.6936 - auc_roc: 0.7459
# Epoch 60/60
# 69/69 [==============================] - 0s 4ms/step - loss: 0.6761 - accuracy: 0.6970 - auc_roc: 0.7378

# %%
# top 20 performers by the test_roc_auc score
#,'param_model__max_features'
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
#res_cols = ['mean_test_roc_auc', 'mean_test_accuracy', 'param_balance__balancer_type', 'param_features__k', 
#            'param_features__score_func', 'param_model__C', 'param_model__solver', 
#            'param_outlier__outlier_threshold', 'param__vif_score_threshold']
#res_cols = ['mean_test_roc_auc','mean_test_accuracy', 'param_balance__balancer_type', 'param_model__batch_size','param_model__epochs',
            #'param_outlier__outlier_threshold']
#res_cols = ['mean_test_roc_auc','mean_test_accuracy','model__batch_size','param_model__epochs','model__filters','model__kernel_size']
res_cols = ['mean_test_roc_auc','mean_test_accuracy','param_model__epochs']
#res_cols = ['mean_test_roc_auc','mean_test_accuracy', 'param_balance__balancer_type','param_model__optimizer',
            #'param_outlier__outlier_threshold']
df_sorted = df_result[res_cols].reset_index(drop=True).sort_values('mean_test_roc_auc', axis=0, ascending=False)
df_sorted.index = pd.RangeIndex(1, len(df_sorted.index)+1)
df_sorted
# Out:
#     mean_test_roc_auc  mean_test_accuracy param_model__epochs
# 1            0.740484            0.582672                  60
# 2            0.736459            0.584578                  50
# 3            0.735355            0.614685                  50
# 4            0.734807            0.621509                  50
# 5            0.731382            0.631936                  60
# 6            0.730745            0.636989                  50
# 7            0.728063            0.619253                  60
# 8            0.726485            0.628364                  60
# 9            0.725590            0.589987                  50
# 10           0.725501            0.517527                  60
# 11           0.722739            0.585952                  60
# 12           0.719521            0.554926                  60
# 13           0.715413            0.583603                  50
# 14           0.715411            0.534893                  60
# 15           0.715284            0.584088                  60
# 16           0.712353            0.554983                  50
# 17           0.710846            0.570470                  50
# 18           0.710634            0.565380                  60
# 19           0.709807            0.565381                  60
# 20           0.707934            0.592315                  50
# 21           0.707675            0.580459                  60
# 22           0.704989            0.527058                  60
# 23           0.704162            0.577742                  60
# 24           0.703905            0.640220                  50
# 25           0.701596            0.528434                  60
# 26           0.700034            0.544878                  50
# 27           0.697122            0.607375                  60
# 28           0.689009            0.565820                  60
# 29           0.688695            0.550791                  60
# 30           0.687152            0.584159                  50
# 31           0.686239            0.557671                  60
# 32           0.684400            0.548531                  60
# 33           0.679806            0.553141                  50
# 34           0.679254            0.543155                  50
# 35           0.677068            0.548014                  50
# 36           0.675126            0.573591                  60
# 37           0.674466            0.539811                  60
# 38           0.672841            0.495158                  50
# 39           0.671924            0.547554                  50
# 40           0.671393            0.575898                  50
# 41           0.660955            0.544004                  50
# 42           0.647950            0.504288                  50
# 43           0.642484            0.535860                  50
# 44           0.635860            0.578645                  50
# 45           0.635139            0.514304                  60
# 46           0.635138            0.497463                  60
# 47           0.619485            0.533514                  50
# 48           0.617611            0.496649                  50

# %%
# the average roc-auc and accuracy scores of just completed search.
# these are the averages of each model over the convolution folds.
#print(df_result['mean_test_roc_auc'])
#print(df_result['mean_test_accuracy'])
print(best_params)
# Out:
# {'model__batch_size': 32, 'model__epochs': 60, 'model__filters': 32, 'model__kernel_size': 7}

# %%
# display results for the best estimator we found
predictions = best_estimator.predict(df_features)
probabilities = best_estimator.predict_proba(df_features)[:,1]
mindwandering.evaluate.evaluate_model_results(mind_wandered_label, predictions, probabilities)
# Out:
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# 69/69 [==============================] - 0s 725us/step
# 69/69 [==============================] - 0s 719us/step
# Accuracy score:         0.7031463748290013
# Recall (TPR) score:     0.6082659478885895
# Precision score:        0.7589686098654709
# AUC-ROC score:          0.7045959369072577
#
# True positives:   677
# True negatives:   865
# False positives:  215
# False negatives:  436
# True Positive Rate (recall):  0.6082659478885895
# False Positive Rate:          0.19907407407407407
# Specificity:                  0.8009259259259259
#
# [[865 215]
#  [436 677]]
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '

# %%
# save the results and preliminary figures in the following cells

# create base save file name for this file, use datetime to keep a unique file name
now = datetime.now()
date_time = now.strftime('%Y%m%d-%H%M')
result_file_basename = 'replication-07-Neural-Network-using-conv1d-GRU-undersampling' + date_time
print(result_file_basename)
# Out:
# replication-07-Neural-Network-using-conv1d-GRU-undersampling20210527-0116

# %%
# A quick histogram of this search auc-roc scores.  Basically the figure 1 from the paper.
plt.figure(figsize=(12,8))

#bins = np.linspace(0.605, 0.612, 8)
plt.hist(df_result.mean_test_roc_auc, 
         bins=20,
         color='lightblue',
         rwidth=0.9);
#plt.xlabel('Area under the receiver operating characteristic (AUC-ROC)');
plt.xlabel('Area under the receiver operating characteristic (AUC-ROC)');
plt.ylabel('Number of models');
plt.title('Neural Network Replication using conv1d and GRU for Undersampling Dataset: ' + result_file_basename);

result_dir = '../figures'
result_file_name = result_file_basename + '.eps'
result_file_path = os.path.join(result_dir, result_file_name)
plt.savefig(result_file_path)
