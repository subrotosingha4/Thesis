# %% [markdown]
# - mean_test_auc_roc using Logistic Regression:
# - mean_test_auc_roc using KNN:0.631033
# - mean_test_auc_roc using SVM:0.658805
# - mean_test_auc_roc using Random Forest:0.657398
# - mean_test_auc_roc using Decision Tree:0.640888
# - mean_test_auc_roc using **Naive Bayes:0.659468**
# - mean_test_auc_roc using Neural Network(Adam):0.634302
# - mean_test_auc_roc using Neural Network(SGD):0.630862
# - mean_test_auc_roc using Neural Network(RMSprop):0.629448

# %%
# globally useful imports of standard libraries needed in this notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os.path
from datetime import datetime

# specific libraries or classes needed for the work in this notebook
#from sklearn.linear_model import LogisticRegression
#from sklearn.linear_model import LogisticRegressionCV
#from sklearn.svm import SVC
#from sklearn.naive_bayes import GaussianNB
#from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GroupKFold
from sklearn.model_selection import LeaveOneGroupOut
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import SelectKBest, f_classif, chi2, SelectFpr, f_regression, mutual_info_classif
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import RFE
from sklearn.feature_selection import VarianceThreshold
from sklearn.ensemble import ExtraTreesClassifier
#from sklearn.pipeline import Pipeline
# need to use Pipeline from imblearn to add in a downsample or upsample
# to cross validation training
from imblearn.pipeline import Pipeline

# import project specific modules used in this notebook
import sys
sys.path.append('../src')
import mindwandering.data
import mindwandering.features
import mindwandering.evaluate
from mindwandering.data import FeatureScalerTransformer
from mindwandering.data import WinsorizationOutlierTransformer
from mindwandering.data import VIFThresholdTransformer
from mindwandering.data import FeatureSelectionTransformer
from mindwandering.data import ClassImbalanceTransformer
from mindwandering.data import GridSearchProgressHack

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.layers import Input, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import SGD,Adam,RMSprop,Adamax,Adagrad

# %%
# Load Data and Features
df_features = mindwandering.data.get_df_features()
mind_wandered_label = mindwandering.data.get_mind_wandered_label()
participant_ids = mindwandering.data.get_participant_ids()

# %%
import tensorflow
auc_roc = tensorflow.keras.metrics.AUC(name='auc_roc',num_thresholds=20000,curve='ROC')

# %%
#First Model
def create_model():
    model = Sequential()
    model.add(Dense(
        32, 
        activation='swish', 
        kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4),
        bias_regularizer=regularizers.l2(1e-4),
        activity_regularizer=regularizers.l2(1e-5)))
    #model.add(Dense(32, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(64,activation='swish'))
    model.add(Dropout(0.2))
    #model.add(Dense(128,activation='relu'))
    #model.add(Dropout(0.3))
    model.add(Dense(1, activation='sigmoid'))
    optimizer=Adamax(learning_rate=0.01)
    model.compile(loss='binary_crossentropy', optimizer=optimizer,metrics=['accuracy',auc_roc])
    return model

# %%
# Wrap Keras model so it can be used by scikit-learn
#kears_estimator = KerasClassifier(build_fn=create_model,epochs=100, batch_size=32, verbose=1)
kears_estimator = KerasClassifier(build_fn=create_model,epochs=200, batch_size=512, verbose=1)
#kears_estimator = KerasClassifier(build_fn=create_model, verbose=1)

# %%
# vif thresholds to apply to data and labels before grid search pipeline
#vif_thresholds = [0, 5]
vif_thresholds = [0]

# we want to actually select a certain percentage of features of whatever remains
# after vif thresholding.  So we will calculate these in the loop based on the number
# of features in data, and add to the parameters dictionary before the grid search
#features__k_ratios = np.array([0.25, 0.5, 0.75, 1.0])
features__k_ratios = np.array([0.2, 0.25, 0.3, 0.35, 0.4, 0.5])

# Empty dataframe to gather grid search results into 1 place
best_estimator = None
best_score = 0.0
best_params = {}
best_index = 0
df_result = None

# search over vif threshold meta parameters, create separate df from vif_threshold
# for otherwise identical grid searches
for vif_threshold in vif_thresholds:
    # display progress
    print('')
    print('=' * 50)
    print('Starting vif meta-parameter condition: vif_threshold: ', vif_threshold)
    
    # pipeline to apply vif threshold selection
    vif_pipeline = Pipeline(
      [
        ('vif',      VIFThresholdTransformer(score_threshold=vif_threshold)),
      ]
    )
 
    df_vif_features = vif_pipeline.transform(df_features)
    num_trials, num_features = df_vif_features.shape
    print('   Number of trials: ', num_trials, ' Number of Features: ', num_features)
    
    parameters = {
        'scaling__type_of_scaling': ['standard'],
        'outlier__outlier_threshold': [0.0, 3.0],
        'features__k': [12],
        #'balance__balancer_type': ['random-undersampler', 'allknn', 'nearmiss', 'instance-hardness-threshold'],
        #'balance__balancer_type': ['allknn', 'condensed-nn', 'neighbourhood-cleaning', 'one-sided-selection'],
        #'balance__balancer_type': ['allknn', 'one-sided-selection'],
        'balance__balancer_type': ['allknn', 'smote-enn'],
        #'model__var_smoothing': [1e-6,1e-7,1e-8,1e-9,1e-10,1e-11,1e-12],
        #'model__batch_size': [8, 16, 24, 32, 40, 48],#usually multiple of 8
        #'model__epochs':[100,150,200],
        #'model__batch_size': [60],
        #'model__epochs':[10],
        #'model__optimizer' : ['RMSprop', 'Adagrad', 'Adadelta','Adam']
    }

    # set feature selection k correctly
    features__k = features__k_ratios * num_features
    features__k = features__k.astype(int) 
    parameters['features__k'] = features__k.tolist()

    # Estimator Pipeline
    pipeline = Pipeline(
      [
        ('progress', GridSearchProgressHack(verbose=False)),
        ('scaling',  FeatureScalerTransformer()),
        ('outlier',  WinsorizationOutlierTransformer()),
        ('features', SelectKBest()),
        #('features', SelectFromModel(estimator=LogisticRegression(solver='liblinear', penalty='l1', C=0.1), threshold=-np.inf)),
        ('balance',  ClassImbalanceTransformer()),
        ('model',    kears_estimator)
      ]
    )
    
    # Cross Validation Splitter
    cv_group_splitter = GroupKFold(n_splits=5)
    #cv_group_splitter = LeaveOneGroupOut()

    # perform the grid search for this vif selection
    # set up the search
    search = GridSearchCV(
        estimator = pipeline,
        param_grid = parameters,
        scoring = ['roc_auc','accuracy'],
        cv = cv_group_splitter,
        refit = 'roc_auc',
        verbose = 1
    )
    search.fit(df_vif_features, mind_wandered_label, groups=participant_ids)
    
    # append results onto the dataframe collecting the results.  Need to add
    # a feature column to this dataframe for the vif vit condition here
    df = pd.DataFrame(data=search.cv_results_)
    df['param__vif_score_threshold'] = vif_threshold
    
    if best_estimator is None:
        df_result = df
        best_estimator = search.best_estimator_
        best_score = search.best_score_
        best_params = search.best_params_
        best_index = search.best_index_
    else:
        df_result = df_result.append(df, ignore_index=True)
        if search.best_score_ > best_score:
            best_estimator = search.best_estimator_
            best_score = search.best_score_
            best_params = search.best_params_
            best_index = search.best_index_  # todo this is only the index of this search
# Out:
# ==================================================
# Starting vif meta-parameter condition: vif_threshold:  0
#    Number of trials:  4076  Number of Features:  62
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# 0001 Epoch 1/200
# 4/4 [==============================] - 12s 159ms/step - loss: 0.6966 - accuracy: 0.5946 - auc_roc: 0.6349
# Epoch 2/200
# 4/4 [==============================] - 1s 182ms/step - loss: 0.5851 - accuracy: 0.7089 - auc_roc: 0.7659
# Epoch 3/200
# 4/4 [==============================] - 1s 177ms/step - loss: 0.5603 - accuracy: 0.7286 - auc_roc: 0.7902
# Epoch 4/200
# 4/4 [==============================] - 1s 177ms/step - loss: 0.5573 - accuracy: 0.7158 - auc_roc: 0.7861
# Epoch 5/200
# 4/4 [==============================] - 1s 178ms/step - loss: 0.5463 - accuracy: 0.7215 - auc_roc: 0.7931
# Epoch 6/200
# 4/4 [==============================] - 1s 167ms/step - loss: 0.5639 - accuracy: 0.7131 - auc_roc: 0.7840
# Epoch 7/200
# 4/4 [==============================] - 1s 183ms/step - loss: 0.5595 - accuracy: 0.7232 - auc_roc: 0.7876
# Epoch 8/200
# 4/4 [==============================] - 1s 187ms/step - loss: 0.5544 - accuracy: 0.7202 - auc_roc: 0.7907
# Epoch 9/200
# 4/4 [==============================] - 1s 174ms/step - loss: 0.5354 - accuracy: 0.7266 - auc_roc: 0.8005
# Epoch 10/200
# 4/4 [==============================] - 1s 177ms/step - loss: 0.5359 - accuracy: 0.7284 - auc_roc: 0.8025
# Epoch 11/200
# 4/4 [==============================] - 1s 163ms/step - loss: 0.5254 - accuracy: 0.7402 - auc_roc: 0.8131
# Epoch 12/200
# 4/4 [==============================] - 1s 156ms/step - loss: 0.5398 - accuracy: 0.7251 - auc_roc: 0.7983
# Epoch 13/200
# 4/4 [==============================] - 1s 180ms/step - loss: 0.5283 - accuracy: 0.7407 - auc_roc: 0.8146
# Epoch 14/200
# 4/4 [==============================] - 1s 169ms/step - loss: 0.5220 - accuracy: 0.7453 - auc_roc: 0.8157
# Epoch 15/200
# 4/4 [==============================] - 1s 173ms/step - loss: 0.5261 - accuracy: 0.7347 - auc_roc: 0.8119
# Epoch 16/200
# 4/4 [==============================] - 1s 162ms/step - loss: 0.5281 - accuracy: 0.7326 - auc_roc: 0.8057
# Epoch 17/200
# 4/4 [==============================] - 1s 129ms/step - loss: 0.5149 - accuracy: 0.7418 - auc_roc: 0.8199
# Epoch 18/200
# 4/4 [==============================] - 1s 123ms/step - loss: 0.5183 - accuracy: 0.7495 - auc_roc: 0.8163
# Epoch 19/200
# 4/4 [==============================] - 1s 127ms/step - loss: 0.5311 - accuracy: 0.7388 - auc_roc: 0.8045
# Epoch 20/200
# 4/4 [==============================] - 1s 197ms/step - loss: 0.5320 - accuracy: 0.7362 - auc_roc: 0.8081
# Epoch 21/200
# 4/4 [==============================] - 1s 206ms/step - loss: 0.5204 - accuracy: 0.7418 - auc_roc: 0.8136
# Epoch 22/200
# 4/4 [==============================] - 1s 176ms/step - loss: 0.5238 - accuracy: 0.7517 - auc_roc: 0.8150
# Epoch 23/200
# 4/4 [==============================] - 1s 166ms/step - loss: 0.5210 - accuracy: 0.7401 - auc_roc: 0.8154
# Epoch 24/200
# 4/4 [==============================] - 1s 143ms/step - loss: 0.5062 - accuracy: 0.7569 - auc_roc: 0.8262
# Epoch 25/200
# 4/4 [==============================] - 1s 175ms/step - loss: 0.5181 - accuracy: 0.7385 - auc_roc: 0.8148
# Epoch 26/200
# 4/4 [==============================] - 1s 167ms/step - loss: 0.5220 - accuracy: 0.7320 - auc_roc: 0.8152
# Epoch 27/200
# 4/4 [==============================] - 1s 141ms/step - loss: 0.5175 - accuracy: 0.7410 - auc_roc: 0.8193
# Epoch 28/200
# 4/4 [==============================] - 1s 152ms/step - loss: 0.5177 - accuracy: 0.7535 - auc_roc: 0.8191
# Epoch 29/200
# 4/4 [==============================] - 1s 187ms/step - loss: 0.5143 - accuracy: 0.7463 - auc_roc: 0.8202
# Epoch 30/200
# 4/4 [==============================] - 1s 181ms/step - loss: 0.5018 - accuracy: 0.7419 - auc_roc: 0.8238
# Epoch 31/200
# 4/4 [==============================] - 1s 168ms/step - loss: 0.5129 - accuracy: 0.7466 - auc_roc: 0.8170
# Epoch 32/200
# 4/4 [==============================] - 1s 166ms/step - loss: 0.5221 - accuracy: 0.7390 - auc_roc: 0.8123
# Epoch 33/200
# 4/4 [==============================] - 1s 155ms/step - loss: 0.5117 - accuracy: 0.7437 - auc_roc: 0.8216
# Epoch 34/200
# 4/4 [==============================] - 1s 190ms/step - loss: 0.5212 - accuracy: 0.7366 - auc_roc: 0.8142
# Epoch 35/200
# 4/4 [==============================] - 1s 257ms/step - loss: 0.5072 - accuracy: 0.7494 - auc_roc: 0.8256
# Epoch 36/200
# 4/4 [==============================] - 1s 214ms/step - loss: 0.5132 - accuracy: 0.7439 - auc_roc: 0.8228
# Epoch 37/200
# 4/4 [==============================] - 1s 179ms/step - loss: 0.5106 - accuracy: 0.7608 - auc_roc: 0.8281
# Epoch 38/200
# 4/4 [==============================] - 1s 251ms/step - loss: 0.5030 - accuracy: 0.7653 - auc_roc: 0.8299
# Epoch 39/200
# 4/4 [==============================] - 1s 271ms/step - loss: 0.5002 - accuracy: 0.7435 - auc_roc: 0.8264
# Epoch 40/200
# 4/4 [==============================] - 1s 232ms/step - loss: 0.5167 - accuracy: 0.7444 - auc_roc: 0.8234
# Epoch 41/200
# 4/4 [==============================] - 1s 226ms/step - loss: 0.5159 - accuracy: 0.7422 - auc_roc: 0.8214
# Epoch 42/200
# 4/4 [==============================] - 1s 240ms/step - loss: 0.4875 - accuracy: 0.7638 - auc_roc: 0.8407
# Epoch 43/200
# 4/4 [==============================] - 1s 220ms/step - loss: 0.5059 - accuracy: 0.7478 - auc_roc: 0.8260
# Epoch 44/200
# 4/4 [==============================] - 1s 275ms/step - loss: 0.5167 - accuracy: 0.7415 - auc_roc: 0.8186
# Epoch 45/200
# 4/4 [==============================] - 1s 191ms/step - loss: 0.5040 - accuracy: 0.7626 - auc_roc: 0.8295
# Epoch 46/200
# 4/4 [==============================] - 1s 227ms/step - loss: 0.4920 - accuracy: 0.7588 - auc_roc: 0.8347
# Epoch 47/200
# 4/4 [==============================] - 1s 255ms/step - loss: 0.5054 - accuracy: 0.7682 - auc_roc: 0.8275
# Epoch 48/200
# 4/4 [==============================] - 1s 221ms/step - loss: 0.4972 - accuracy: 0.7543 - auc_roc: 0.8315
# Epoch 49/200
# 4/4 [==============================] - 1s 238ms/step - loss: 0.5001 - accuracy: 0.7509 - auc_roc: 0.8301
# Epoch 50/200
# 4/4 [==============================] - 1s 230ms/step - loss: 0.4924 - accuracy: 0.7564 - auc_roc: 0.8383
# Epoch 51/200
# 4/4 [==============================] - 1s 293ms/step - loss: 0.5039 - accuracy: 0.7561 - auc_roc: 0.8289
# Epoch 52/200
# 4/4 [==============================] - 1s 260ms/step - loss: 0.4960 - accuracy: 0.7582 - auc_roc: 0.8343
# Epoch 53/200
# 4/4 [==============================] - 1s 292ms/step - loss: 0.4886 - accuracy: 0.7613 - auc_roc: 0.8376
# Epoch 54/200
# 4/4 [==============================] - 1s 251ms/step - loss: 0.5046 - accuracy: 0.7565 - auc_roc: 0.8264
# Epoch 55/200
# 4/4 [==============================] - 1s 257ms/step - loss: 0.5053 - accuracy: 0.7504 - auc_roc: 0.8268
# Epoch 56/200
# 4/4 [==============================] - 1s 273ms/step - loss: 0.5145 - accuracy: 0.7332 - auc_roc: 0.8183
# Epoch 57/200
# 4/4 [==============================] - 1s 244ms/step - loss: 0.4938 - accuracy: 0.7629 - auc_roc: 0.8341
# Epoch 58/200
# 4/4 [==============================] - 1s 262ms/step - loss: 0.4983 - accuracy: 0.7582 - auc_roc: 0.8335
# Epoch 59/200
# 4/4 [==============================] - 1s 321ms/step - loss: 0.5152 - accuracy: 0.7467 - auc_roc: 0.8190
# Epoch 60/200
# 4/4 [==============================] - 1s 261ms/step - loss: 0.4937 - accuracy: 0.7652 - auc_roc: 0.8335
# Epoch 61/200
# 4/4 [==============================] - 1s 321ms/step - loss: 0.4925 - accuracy: 0.7571 - auc_roc: 0.8338
# Epoch 62/200
# 4/4 [==============================] - 1s 221ms/step - loss: 0.5001 - accuracy: 0.7602 - auc_roc: 0.8279
# Epoch 63/200
# 4/4 [==============================] - 1s 290ms/step - loss: 0.4993 - accuracy: 0.7519 - auc_roc: 0.8281
# Epoch 64/200
# 4/4 [==============================] - 1s 315ms/step - loss: 0.4891 - accuracy: 0.7725 - auc_roc: 0.8368
# Epoch 65/200
# 4/4 [==============================] - 1s 220ms/step - loss: 0.4996 - accuracy: 0.7587 - auc_roc: 0.8321
# Epoch 66/200
# 4/4 [==============================] - 1s 239ms/step - loss: 0.4849 - accuracy: 0.7690 - auc_roc: 0.8436
# Epoch 67/200
# 4/4 [==============================] - 1s 238ms/step - loss: 0.5079 - accuracy: 0.7472 - auc_roc: 0.8210
# Epoch 68/200
# 4/4 [==============================] - 1s 225ms/step - loss: 0.4835 - accuracy: 0.7731 - auc_roc: 0.8459
# Epoch 69/200
# 4/4 [==============================] - 1s 248ms/step - loss: 0.4894 - accuracy: 0.7614 - auc_roc: 0.8365
# Epoch 70/200
# 4/4 [==============================] - 1s 262ms/step - loss: 0.4721 - accuracy: 0.7743 - auc_roc: 0.8550
# Epoch 71/200
# 4/4 [==============================] - 1s 239ms/step - loss: 0.4909 - accuracy: 0.7639 - auc_roc: 0.8394
# Epoch 72/200
# 4/4 [==============================] - 1s 223ms/step - loss: 0.4969 - accuracy: 0.7615 - auc_roc: 0.8333
# Epoch 73/200
# 4/4 [==============================] - 1s 237ms/step - loss: 0.4920 - accuracy: 0.7680 - auc_roc: 0.8363
# Epoch 74/200
# 4/4 [==============================] - 1s 215ms/step - loss: 0.4848 - accuracy: 0.7717 - auc_roc: 0.8415
# Epoch 75/200
# 4/4 [==============================] - 1s 196ms/step - loss: 0.4905 - accuracy: 0.7661 - auc_roc: 0.8394
# Epoch 76/200
# 4/4 [==============================] - 1s 231ms/step - loss: 0.4793 - accuracy: 0.7693 - auc_roc: 0.8477
# Epoch 77/200
# 4/4 [==============================] - 1s 197ms/step - loss: 0.4869 - accuracy: 0.7628 - auc_roc: 0.8410
# Epoch 78/200
# 4/4 [==============================] - 1s 269ms/step - loss: 0.4847 - accuracy: 0.7592 - auc_roc: 0.8430
# Epoch 79/200
# 4/4 [==============================] - 1s 242ms/step - loss: 0.4869 - accuracy: 0.7707 - auc_roc: 0.8432
# Epoch 80/200
# 4/4 [==============================] - 1s 219ms/step - loss: 0.4841 - accuracy: 0.7664 - auc_roc: 0.8442
# Epoch 81/200
# 4/4 [==============================] - 1s 216ms/step - loss: 0.4822 - accuracy: 0.7652 - auc_roc: 0.8441
# Epoch 82/200
# 4/4 [==============================] - 1s 215ms/step - loss: 0.4699 - accuracy: 0.7748 - auc_roc: 0.8527
# Epoch 83/200
# 4/4 [==============================] - 1s 194ms/step - loss: 0.4677 - accuracy: 0.7772 - auc_roc: 0.8546
# Epoch 84/200
# 4/4 [==============================] - 1s 264ms/step - loss: 0.4768 - accuracy: 0.7714 - auc_roc: 0.8513
# Epoch 85/200
# 4/4 [==============================] - 1s 264ms/step - loss: 0.4781 - accuracy: 0.7766 - auc_roc: 0.8456
# Epoch 86/200
# 4/4 [==============================] - 1s 209ms/step - loss: 0.4855 - accuracy: 0.7670 - auc_roc: 0.8455
# Epoch 87/200
# 4/4 [==============================] - 1s 209ms/step - loss: 0.4919 - accuracy: 0.7631 - auc_roc: 0.8342
# Epoch 88/200
# 4/4 [==============================] - 1s 245ms/step - loss: 0.4915 - accuracy: 0.7606 - auc_roc: 0.8382
# Epoch 89/200
# 4/4 [==============================] - 1s 202ms/step - loss: 0.4695 - accuracy: 0.7842 - auc_roc: 0.8531
# Epoch 90/200
# 4/4 [==============================] - 1s 256ms/step - loss: 0.4768 - accuracy: 0.7713 - auc_roc: 0.8465
# Epoch 91/200
# 4/4 [==============================] - 1s 225ms/step - loss: 0.4944 - accuracy: 0.7495 - auc_roc: 0.8338
# Epoch 92/200
# 4/4 [==============================] - 1s 198ms/step - loss: 0.4851 - accuracy: 0.7725 - auc_roc: 0.8443
# Epoch 93/200
# 4/4 [==============================] - 1s 234ms/step - loss: 0.4823 - accuracy: 0.7651 - auc_roc: 0.8434
# Epoch 94/200
# 4/4 [==============================] - 1s 246ms/step - loss: 0.4843 - accuracy: 0.7627 - auc_roc: 0.8398
# Epoch 95/200
# 4/4 [==============================] - 1s 243ms/step - loss: 0.4790 - accuracy: 0.7721 - auc_roc: 0.8461
# Epoch 96/200
# 4/4 [==============================] - 1s 240ms/step - loss: 0.4755 - accuracy: 0.7673 - auc_roc: 0.8497
# Epoch 97/200
# 4/4 [==============================] - 1s 212ms/step - loss: 0.4930 - accuracy: 0.7683 - auc_roc: 0.8380
# Epoch 98/200
# 4/4 [==============================] - 1s 281ms/step - loss: 0.4750 - accuracy: 0.7750 - auc_roc: 0.8503
# Epoch 99/200
# 4/4 [==============================] - 1s 216ms/step - loss: 0.4795 - accuracy: 0.7682 - auc_roc: 0.8477
# Epoch 100/200
# 4/4 [==============================] - 1s 297ms/step - loss: 0.4742 - accuracy: 0.7742 - auc_roc: 0.8514
# Epoch 101/200
# 4/4 [==============================] - 1s 275ms/step - loss: 0.4829 - accuracy: 0.7694 - auc_roc: 0.8431
# Epoch 102/200
# 4/4 [==============================] - 1s 230ms/step - loss: 0.4813 - accuracy: 0.7641 - auc_roc: 0.8446
# Epoch 103/200
# 4/4 [==============================] - 1s 273ms/step - loss: 0.4707 - accuracy: 0.7752 - auc_roc: 0.8514
# Epoch 104/200
# 4/4 [==============================] - 1s 290ms/step - loss: 0.4696 - accuracy: 0.7745 - auc_roc: 0.8514
# Epoch 105/200
# 4/4 [==============================] - 1s 282ms/step - loss: 0.4926 - accuracy: 0.7629 - auc_roc: 0.8365
# Epoch 106/200
# 4/4 [==============================] - 1s 264ms/step - loss: 0.4732 - accuracy: 0.7807 - auc_roc: 0.8499
# Epoch 107/200
# 4/4 [==============================] - 1s 266ms/step - loss: 0.4742 - accuracy: 0.7615 - auc_roc: 0.8465
# Epoch 108/200
# 4/4 [==============================] - 1s 254ms/step - loss: 0.4834 - accuracy: 0.7745 - auc_roc: 0.8421
# Epoch 109/200
# 4/4 [==============================] - 1s 281ms/step - loss: 0.4824 - accuracy: 0.7690 - auc_roc: 0.8461
# Epoch 110/200
# 4/4 [==============================] - 1s 280ms/step - loss: 0.4752 - accuracy: 0.7707 - auc_roc: 0.8508
# Epoch 111/200
# 4/4 [==============================] - 1s 238ms/step - loss: 0.4814 - accuracy: 0.7634 - auc_roc: 0.8437
# Epoch 112/200
# 4/4 [==============================] - 1s 289ms/step - loss: 0.4705 - accuracy: 0.7762 - auc_roc: 0.8489
# Epoch 113/200
# 4/4 [==============================] - 1s 267ms/step - loss: 0.4677 - accuracy: 0.7750 - auc_roc: 0.8545
# Epoch 114/200
# 4/4 [==============================] - 1s 259ms/step - loss: 0.4858 - accuracy: 0.7667 - auc_roc: 0.8413
# Epoch 115/200
# 4/4 [==============================] - 1s 251ms/step - loss: 0.4762 - accuracy: 0.7730 - auc_roc: 0.8471
# Epoch 116/200
# 4/4 [==============================] - 1s 225ms/step - loss: 0.4726 - accuracy: 0.7706 - auc_roc: 0.8513
# Epoch 117/200
# 4/4 [==============================] - 1s 229ms/step - loss: 0.4716 - accuracy: 0.7688 - auc_roc: 0.8475
# Epoch 118/200
# 4/4 [==============================] - 1s 228ms/step - loss: 0.4704 - accuracy: 0.7690 - auc_roc: 0.8524
# Epoch 119/200
# 4/4 [==============================] - 1s 253ms/step - loss: 0.4829 - accuracy: 0.7666 - auc_roc: 0.8438
# Epoch 120/200
# 4/4 [==============================] - 1s 201ms/step - loss: 0.4813 - accuracy: 0.7800 - auc_roc: 0.8470
# Epoch 121/200
# 4/4 [==============================] - 1s 202ms/step - loss: 0.4711 - accuracy: 0.7847 - auc_roc: 0.8495
# Epoch 122/200
# 4/4 [==============================] - 1s 194ms/step - loss: 0.4662 - accuracy: 0.7859 - auc_roc: 0.8566
# Epoch 123/200
# 4/4 [==============================] - 1s 202ms/step - loss: 0.4597 - accuracy: 0.7850 - auc_roc: 0.8593
# Epoch 124/200
# 4/4 [==============================] - 1s 220ms/step - loss: 0.4661 - accuracy: 0.7789 - auc_roc: 0.8561
# Epoch 125/200
# 4/4 [==============================] - 1s 293ms/step - loss: 0.4592 - accuracy: 0.7771 - auc_roc: 0.8602
# Epoch 126/200
# 4/4 [==============================] - 1s 222ms/step - loss: 0.4776 - accuracy: 0.7674 - auc_roc: 0.8452
# Epoch 127/200
# 4/4 [==============================] - 1s 240ms/step - loss: 0.4800 - accuracy: 0.7628 - auc_roc: 0.8462
# Epoch 128/200
# 4/4 [==============================] - 1s 228ms/step - loss: 0.4828 - accuracy: 0.7632 - auc_roc: 0.8415
# Epoch 129/200
# 4/4 [==============================] - 1s 213ms/step - loss: 0.4746 - accuracy: 0.7716 - auc_roc: 0.8480
# Epoch 130/200
# 4/4 [==============================] - 1s 197ms/step - loss: 0.4811 - accuracy: 0.7803 - auc_roc: 0.8452
# Epoch 131/200
# 4/4 [==============================] - 1s 225ms/step - loss: 0.4664 - accuracy: 0.7919 - auc_roc: 0.8547
# Epoch 132/200
# 4/4 [==============================] - 1s 227ms/step - loss: 0.4804 - accuracy: 0.7757 - auc_roc: 0.8505
# Epoch 133/200
# 4/4 [==============================] - 1s 239ms/step - loss: 0.4668 - accuracy: 0.7792 - auc_roc: 0.8534
# Epoch 134/200
# 4/4 [==============================] - 1s 189ms/step - loss: 0.4742 - accuracy: 0.7745 - auc_roc: 0.8523
# Epoch 135/200
# 4/4 [==============================] - 1s 269ms/step - loss: 0.4691 - accuracy: 0.7797 - auc_roc: 0.8555
# Epoch 136/200
# 4/4 [==============================] - 1s 216ms/step - loss: 0.4620 - accuracy: 0.7892 - auc_roc: 0.8597
# Epoch 137/200
# 4/4 [==============================] - 1s 253ms/step - loss: 0.4749 - accuracy: 0.7788 - auc_roc: 0.8460
# Epoch 138/200
# 4/4 [==============================] - 1s 239ms/step - loss: 0.4592 - accuracy: 0.7807 - auc_roc: 0.8583
# Epoch 139/200
# 4/4 [==============================] - 1s 247ms/step - loss: 0.4696 - accuracy: 0.7736 - auc_roc: 0.8512
# Epoch 140/200
# 4/4 [==============================] - 1s 235ms/step - loss: 0.4701 - accuracy: 0.7694 - auc_roc: 0.8543
# Epoch 141/200
# 4/4 [==============================] - 1s 246ms/step - loss: 0.4707 - accuracy: 0.7784 - auc_roc: 0.8492
# Epoch 142/200
# 4/4 [==============================] - 1s 228ms/step - loss: 0.4686 - accuracy: 0.7764 - auc_roc: 0.8535
# Epoch 143/200
# 4/4 [==============================] - 1s 258ms/step - loss: 0.4602 - accuracy: 0.7800 - auc_roc: 0.8594
# Epoch 144/200
# 4/4 [==============================] - 1s 223ms/step - loss: 0.4691 - accuracy: 0.7778 - auc_roc: 0.8537
# Epoch 145/200
# 4/4 [==============================] - 1s 253ms/step - loss: 0.4452 - accuracy: 0.7909 - auc_roc: 0.8694
# Epoch 146/200
# 4/4 [==============================] - 1s 250ms/step - loss: 0.4628 - accuracy: 0.7732 - auc_roc: 0.8577
# Epoch 147/200
# 4/4 [==============================] - 1s 292ms/step - loss: 0.4748 - accuracy: 0.7673 - auc_roc: 0.8455
# Epoch 148/200
# 4/4 [==============================] - 1s 268ms/step - loss: 0.4679 - accuracy: 0.7786 - auc_roc: 0.8522
# Epoch 149/200
# 4/4 [==============================] - 1s 229ms/step - loss: 0.4534 - accuracy: 0.7890 - auc_roc: 0.8667
# Epoch 150/200
# 4/4 [==============================] - 1s 293ms/step - loss: 0.4644 - accuracy: 0.7694 - auc_roc: 0.8578
# Epoch 151/200
# 4/4 [==============================] - 1s 306ms/step - loss: 0.4728 - accuracy: 0.7784 - auc_roc: 0.8526
# Epoch 152/200
# 4/4 [==============================] - 1s 249ms/step - loss: 0.4679 - accuracy: 0.7804 - auc_roc: 0.8542
# Epoch 153/200
# 4/4 [==============================] - 1s 248ms/step - loss: 0.4623 - accuracy: 0.7766 - auc_roc: 0.8593
# Epoch 154/200
# 4/4 [==============================] - 1s 287ms/step - loss: 0.4695 - accuracy: 0.7715 - auc_roc: 0.8523
# Epoch 155/200
# 4/4 [==============================] - 1s 237ms/step - loss: 0.4613 - accuracy: 0.7745 - auc_roc: 0.8608
# Epoch 156/200
# 4/4 [==============================] - 1s 274ms/step - loss: 0.4396 - accuracy: 0.7952 - auc_roc: 0.8745
# Epoch 157/200
# 4/4 [==============================] - 1s 315ms/step - loss: 0.4514 - accuracy: 0.7770 - auc_roc: 0.8646
# Epoch 158/200
# 4/4 [==============================] - 1s 250ms/step - loss: 0.4632 - accuracy: 0.7706 - auc_roc: 0.8523
# Epoch 159/200
# 4/4 [==============================] - 1s 305ms/step - loss: 0.4718 - accuracy: 0.7789 - auc_roc: 0.8537
# Epoch 160/200
# 4/4 [==============================] - 1s 295ms/step - loss: 0.4602 - accuracy: 0.7839 - auc_roc: 0.8627
# Epoch 161/200
# 4/4 [==============================] - 1s 303ms/step - loss: 0.4537 - accuracy: 0.7850 - auc_roc: 0.8642
# Epoch 162/200
# 4/4 [==============================] - 1s 267ms/step - loss: 0.4570 - accuracy: 0.7884 - auc_roc: 0.8626
# Epoch 163/200
# 4/4 [==============================] - 1s 279ms/step - loss: 0.4573 - accuracy: 0.7881 - auc_roc: 0.8599
# Epoch 164/200
# 4/4 [==============================] - 1s 277ms/step - loss: 0.4755 - accuracy: 0.7705 - auc_roc: 0.8479
# Epoch 165/200
# 4/4 [==============================] - 1s 263ms/step - loss: 0.4570 - accuracy: 0.7834 - auc_roc: 0.8627
# Epoch 166/200
# 4/4 [==============================] - 1s 235ms/step - loss: 0.4604 - accuracy: 0.7812 - auc_roc: 0.8547
# Epoch 167/200
# 4/4 [==============================] - 1s 266ms/step - loss: 0.4631 - accuracy: 0.7794 - auc_roc: 0.8575
# Epoch 168/200
# 4/4 [==============================] - 1s 232ms/step - loss: 0.4611 - accuracy: 0.7833 - auc_roc: 0.8616
# Epoch 169/200
# 4/4 [==============================] - 1s 259ms/step - loss: 0.4496 - accuracy: 0.7868 - auc_roc: 0.8667
# Epoch 170/200
# 4/4 [==============================] - 1s 234ms/step - loss: 0.4596 - accuracy: 0.7900 - auc_roc: 0.8614
# Epoch 171/200
# 4/4 [==============================] - 1s 225ms/step - loss: 0.4630 - accuracy: 0.7929 - auc_roc: 0.8589
# Epoch 172/200
# 4/4 [==============================] - 1s 235ms/step - loss: 0.4584 - accuracy: 0.7776 - auc_roc: 0.8600
# Epoch 173/200
# 4/4 [==============================] - 1s 243ms/step - loss: 0.4548 - accuracy: 0.7793 - auc_roc: 0.8664
# Epoch 174/200
# 4/4 [==============================] - 1s 219ms/step - loss: 0.4466 - accuracy: 0.7940 - auc_roc: 0.8661
# Epoch 175/200
# 4/4 [==============================] - 1s 205ms/step - loss: 0.4374 - accuracy: 0.8009 - auc_roc: 0.8746
# Epoch 176/200
# 4/4 [==============================] - 1s 220ms/step - loss: 0.4652 - accuracy: 0.7722 - auc_roc: 0.8521
# Epoch 177/200
# 4/4 [==============================] - 1s 228ms/step - loss: 0.4607 - accuracy: 0.7810 - auc_roc: 0.8571
# Epoch 178/200
# 4/4 [==============================] - 1s 232ms/step - loss: 0.4497 - accuracy: 0.7954 - auc_roc: 0.8679
# Epoch 179/200
# 4/4 [==============================] - 1s 223ms/step - loss: 0.4639 - accuracy: 0.7773 - auc_roc: 0.8566
# Epoch 180/200
# 4/4 [==============================] - 1s 223ms/step - loss: 0.4656 - accuracy: 0.7675 - auc_roc: 0.8552
# Epoch 181/200
# 4/4 [==============================] - 1s 239ms/step - loss: 0.4474 - accuracy: 0.7814 - auc_roc: 0.8663
# Epoch 182/200
# 4/4 [==============================] - 1s 248ms/step - loss: 0.4516 - accuracy: 0.7935 - auc_roc: 0.8656
# Epoch 183/200
# 4/4 [==============================] - 1s 251ms/step - loss: 0.4505 - accuracy: 0.7862 - auc_roc: 0.8706
# Epoch 184/200
# 4/4 [==============================] - 1s 262ms/step - loss: 0.4606 - accuracy: 0.7842 - auc_roc: 0.8609
# Epoch 185/200
# 4/4 [==============================] - 1s 225ms/step - loss: 0.4762 - accuracy: 0.7714 - auc_roc: 0.8477
# Epoch 186/200
# 4/4 [==============================] - 1s 244ms/step - loss: 0.4666 - accuracy: 0.7690 - auc_roc: 0.8558
# Epoch 187/200
# 4/4 [==============================] - 1s 261ms/step - loss: 0.4490 - accuracy: 0.7901 - auc_roc: 0.8663
# Epoch 188/200
# 4/4 [==============================] - 1s 228ms/step - loss: 0.4605 - accuracy: 0.7846 - auc_roc: 0.8586
# Epoch 189/200
# 4/4 [==============================] - 1s 249ms/step - loss: 0.4544 - accuracy: 0.7791 - auc_roc: 0.8656
# Epoch 190/200
# 4/4 [==============================] - 1s 219ms/step - loss: 0.4542 - accuracy: 0.7871 - auc_roc: 0.8628
# Epoch 191/200
# 4/4 [==============================] - 1s 268ms/step - loss: 0.4692 - accuracy: 0.7735 - auc_roc: 0.8498
# Epoch 192/200
# 4/4 [==============================] - 1s 232ms/step - loss: 0.4456 - accuracy: 0.7926 - auc_roc: 0.8668
# Epoch 193/200
# 4/4 [==============================] - 1s 272ms/step - loss: 0.4573 - accuracy: 0.7785 - auc_roc: 0.8646
# Epoch 194/200
# 4/4 [==============================] - 1s 260ms/step - loss: 0.4521 - accuracy: 0.7794 - auc_roc: 0.8639
# Epoch 195/200
# 4/4 [==============================] - 1s 292ms/step - loss: 0.4354 - accuracy: 0.7936 - auc_roc: 0.8771
# Epoch 196/200
# 4/4 [==============================] - 1s 270ms/step - loss: 0.4556 - accuracy: 0.7974 - auc_roc: 0.8645
# Epoch 197/200
# 4/4 [==============================] - 1s 262ms/step - loss: 0.4526 - accuracy: 0.7916 - auc_roc: 0.8627
# Epoch 198/200
# 4/4 [==============================] - 1s 271ms/step - loss: 0.4566 - accuracy: 0.7894 - auc_roc: 0.8609
# Epoch 199/200
# 4/4 [==============================] - 1s 273ms/step - loss: 0.4589 - accuracy: 0.7748 - auc_roc: 0.8591
# Epoch 200/200
# 4/4 [==============================] - 1s 288ms/step - loss: 0.4594 - accuracy: 0.7847 - auc_roc: 0.8609
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# 2/2 [==============================] - 2s 6ms/step
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# 2/2 [==============================] - 0s 17ms/step
# 0002 Epoch 1/200
# 4/4 [==============================] - 18s 150ms/step - loss: 0.7854 - accuracy: 0.5355 - auc_roc: 0.7567
# Epoch 2/200
# 4/4 [==============================] - 1s 157ms/step - loss: 0.6210 - accuracy: 0.6985 - auc_roc: 0.7405
# Epoch 3/200
# 4/4 [==============================] - 1s 174ms/step - loss: 0.5937 - accuracy: 0.7045 - auc_roc: 0.7541
# Epoch 4/200
# 4/4 [==============================] - 1s 157ms/step - loss: 0.5693 - accuracy: 0.7205 - auc_roc: 0.7795
# Epoch 5/200
# 4/4 [==============================] - 1s 171ms/step - loss: 0.5604 - accuracy: 0.7119 - auc_roc: 0.7856
# Epoch 6/200
# 4/4 [==============================] - 1s 174ms/step - loss: 0.5591 - accuracy: 0.7130 - auc_roc: 0.7826
# Epoch 7/200
# 4/4 [==============================] - 1s 184ms/step - loss: 0.5559 - accuracy: 0.7193 - auc_roc: 0.7852
# Epoch 8/200
# 4/4 [==============================] - 1s 161ms/step - loss: 0.5662 - accuracy: 0.7076 - auc_roc: 0.7855
# Epoch 9/200
# 4/4 [==============================] - 1s 165ms/step - loss: 0.5589 - accuracy: 0.7153 - auc_roc: 0.7797
# Epoch 10/200
# 4/4 [==============================] - 1s 175ms/step - loss: 0.5540 - accuracy: 0.7223 - auc_roc: 0.7857
# Epoch 11/200
# 4/4 [==============================] - 1s 159ms/step - loss: 0.5564 - accuracy: 0.7207 - auc_roc: 0.7856
# Epoch 12/200
# 4/4 [==============================] - 1s 191ms/step - loss: 0.5605 - accuracy: 0.7211 - auc_roc: 0.78140s - loss: 0.5635 - accuracy: 0.7214 - auc_roc: 0.
# Epoch 13/200
# 4/4 [==============================] - 1s 149ms/step - loss: 0.5452 - accuracy: 0.7281 - auc_roc: 0.8001
# Epoch 14/200
# 4/4 [==============================] - 1s 181ms/step - loss: 0.5470 - accuracy: 0.7187 - auc_roc: 0.7968
# Epoch 15/200
# 4/4 [==============================] - 1s 168ms/step - loss: 0.5284 - accuracy: 0.7452 - auc_roc: 0.8096
# Epoch 16/200
# 4/4 [==============================] - 1s 187ms/step - loss: 0.5432 - accuracy: 0.7303 - auc_roc: 0.7927
# Epoch 17/200
# 4/4 [==============================] - 1s 169ms/step - loss: 0.5268 - accuracy: 0.7344 - auc_roc: 0.8126
# Epoch 18/200
# 4/4 [==============================] - 1s 182ms/step - loss: 0.5359 - accuracy: 0.7372 - auc_roc: 0.8020
# Epoch 19/200
# 4/4 [==============================] - 1s 252ms/step - loss: 0.5278 - accuracy: 0.7476 - auc_roc: 0.8123
# Epoch 20/200
# 4/4 [==============================] - 1s 240ms/step - loss: 0.5502 - accuracy: 0.7255 - auc_roc: 0.7922
# Epoch 21/200
# 4/4 [==============================] - 1s 248ms/step - loss: 0.5367 - accuracy: 0.7283 - auc_roc: 0.8011
# Epoch 22/200
# 4/4 [==============================] - 1s 226ms/step - loss: 0.5443 - accuracy: 0.7261 - auc_roc: 0.7969
# Epoch 23/200
# 4/4 [==============================] - 1s 287ms/step - loss: 0.5301 - accuracy: 0.7302 - auc_roc: 0.8053
# Epoch 24/200
# 4/4 [==============================] - 1s 264ms/step - loss: 0.5363 - accuracy: 0.7323 - auc_roc: 0.8038
# Epoch 25/200
# 4/4 [==============================] - 1s 279ms/step - loss: 0.5318 - accuracy: 0.7318 - auc_roc: 0.8056
# Epoch 26/200
# 4/4 [==============================] - 1s 229ms/step - loss: 0.5312 - accuracy: 0.7475 - auc_roc: 0.8084
# Epoch 27/200
# 4/4 [==============================] - 1s 226ms/step - loss: 0.5207 - accuracy: 0.7510 - auc_roc: 0.8147
# Epoch 28/200
# 4/4 [==============================] - 1s 273ms/step - loss: 0.5261 - accuracy: 0.7526 - auc_roc: 0.8149
# Epoch 29/200
# 4/4 [==============================] - 1s 237ms/step - loss: 0.5287 - accuracy: 0.7489 - auc_roc: 0.8123
# Epoch 30/200
# 4/4 [==============================] - 1s 262ms/step - loss: 0.5272 - accuracy: 0.7470 - auc_roc: 0.8150
# Epoch 31/200
# 4/4 [==============================] - 1s 228ms/step - loss: 0.5253 - accuracy: 0.7420 - auc_roc: 0.8117
# Epoch 32/200
# 4/4 [==============================] - 1s 246ms/step - loss: 0.5297 - accuracy: 0.7400 - auc_roc: 0.8093
# Epoch 33/200
# 4/4 [==============================] - 1s 230ms/step - loss: 0.5217 - accuracy: 0.7431 - auc_roc: 0.8182
# Epoch 34/200
# 4/4 [==============================] - 1s 272ms/step - loss: 0.5379 - accuracy: 0.7448 - auc_roc: 0.8063
# Epoch 35/200
# 4/4 [==============================] - 1s 242ms/step - loss: 0.5315 - accuracy: 0.7428 - auc_roc: 0.8115
# Epoch 36/200
# 4/4 [==============================] - 1s 260ms/step - loss: 0.5147 - accuracy: 0.7547 - auc_roc: 0.8247
# Epoch 37/200
# 4/4 [==============================] - 1s 289ms/step - loss: 0.5159 - accuracy: 0.7552 - auc_roc: 0.8242
# Epoch 38/200
# 4/4 [==============================] - 1s 257ms/step - loss: 0.5286 - accuracy: 0.7371 - auc_roc: 0.8092
# Epoch 39/200
# 4/4 [==============================] - 1s 207ms/step - loss: 0.5118 - accuracy: 0.7551 - auc_roc: 0.8258
# Epoch 40/200
# 4/4 [==============================] - 1s 260ms/step - loss: 0.5249 - accuracy: 0.7484 - auc_roc: 0.8119
# Epoch 41/200
# 4/4 [==============================] - 1s 260ms/step - loss: 0.5346 - accuracy: 0.7415 - auc_roc: 0.8075
# Epoch 42/200
# 4/4 [==============================] - 1s 237ms/step - loss: 0.5220 - accuracy: 0.7389 - auc_roc: 0.8131
# Epoch 43/200
# 4/4 [==============================] - 1s 241ms/step - loss: 0.5078 - accuracy: 0.7639 - auc_roc: 0.8265
# Epoch 44/200
# 4/4 [==============================] - 1s 253ms/step - loss: 0.5243 - accuracy: 0.7441 - auc_roc: 0.8148
# Epoch 45/200
# 4/4 [==============================] - 1s 253ms/step - loss: 0.5054 - accuracy: 0.7589 - auc_roc: 0.8312
# Epoch 46/200
# 4/4 [==============================] - 1s 280ms/step - loss: 0.5185 - accuracy: 0.7419 - auc_roc: 0.8190
# Epoch 47/200
# 4/4 [==============================] - 1s 213ms/step - loss: 0.5225 - accuracy: 0.7521 - auc_roc: 0.8172
# Epoch 48/200
# 4/4 [==============================] - 1s 212ms/step - loss: 0.5126 - accuracy: 0.7533 - auc_roc: 0.8214
# Epoch 49/200
# 4/4 [==============================] - 1s 274ms/step - loss: 0.5234 - accuracy: 0.7461 - auc_roc: 0.8162
# Epoch 50/200
# 4/4 [==============================] - 1s 229ms/step - loss: 0.5234 - accuracy: 0.7539 - auc_roc: 0.8202
# Epoch 51/200
# 4/4 [==============================] - 1s 286ms/step - loss: 0.5287 - accuracy: 0.7540 - auc_roc: 0.8150
# Epoch 52/200
# 4/4 [==============================] - 1s 251ms/step - loss: 0.5125 - accuracy: 0.7499 - auc_roc: 0.8246
# Epoch 53/200
# 4/4 [==============================] - 1s 242ms/step - loss: 0.5138 - accuracy: 0.7634 - auc_roc: 0.8254
# Epoch 54/200
# 4/4 [==============================] - 1s 238ms/step - loss: 0.5054 - accuracy: 0.7613 - auc_roc: 0.8273
# Epoch 55/200
# 4/4 [==============================] - 1s 255ms/step - loss: 0.5013 - accuracy: 0.7569 - auc_roc: 0.8330
# Epoch 56/200
# 4/4 [==============================] - 1s 271ms/step - loss: 0.5096 - accuracy: 0.7534 - auc_roc: 0.8206
# Epoch 57/200
# 4/4 [==============================] - 1s 221ms/step - loss: 0.5196 - accuracy: 0.7454 - auc_roc: 0.8143
# Epoch 58/200
# 4/4 [==============================] - 1s 229ms/step - loss: 0.5233 - accuracy: 0.7459 - auc_roc: 0.8129
# Epoch 59/200
# 4/4 [==============================] - 1s 219ms/step - loss: 0.5108 - accuracy: 0.7542 - auc_roc: 0.8240
# Epoch 60/200
# 4/4 [==============================] - 1s 222ms/step - loss: 0.5146 - accuracy: 0.7463 - auc_roc: 0.8233
# Epoch 61/200
# 4/4 [==============================] - 1s 258ms/step - loss: 0.5038 - accuracy: 0.7559 - auc_roc: 0.8291
# Epoch 62/200
# 4/4 [==============================] - 1s 220ms/step - loss: 0.5072 - accuracy: 0.7606 - auc_roc: 0.8274
# Epoch 63/200
# 4/4 [==============================] - 1s 219ms/step - loss: 0.5131 - accuracy: 0.7537 - auc_roc: 0.8240
# Epoch 64/200
# 4/4 [==============================] - 1s 217ms/step - loss: 0.5136 - accuracy: 0.7536 - auc_roc: 0.8232
# Epoch 65/200
# 4/4 [==============================] - 1s 253ms/step - loss: 0.5018 - accuracy: 0.7499 - auc_roc: 0.8292
# Epoch 66/200
# 4/4 [==============================] - 1s 294ms/step - loss: 0.5063 - accuracy: 0.7641 - auc_roc: 0.8298
# Epoch 67/200
# 4/4 [==============================] - 1s 262ms/step - loss: 0.5159 - accuracy: 0.7479 - auc_roc: 0.8209
# Epoch 68/200
# 4/4 [==============================] - 1s 264ms/step - loss: 0.5119 - accuracy: 0.7567 - auc_roc: 0.8258
# Epoch 69/200
# 4/4 [==============================] - 1s 321ms/step - loss: 0.5022 - accuracy: 0.7582 - auc_roc: 0.8289
# Epoch 70/200
# 4/4 [==============================] - 1s 282ms/step - loss: 0.5077 - accuracy: 0.7509 - auc_roc: 0.8249
# Epoch 71/200
# 4/4 [==============================] - 1s 277ms/step - loss: 0.4979 - accuracy: 0.7621 - auc_roc: 0.8329
# Epoch 72/200
# 4/4 [==============================] - 1s 315ms/step - loss: 0.5078 - accuracy: 0.7530 - auc_roc: 0.8258
# Epoch 73/200
# 4/4 [==============================] - 1s 322ms/step - loss: 0.4984 - accuracy: 0.7580 - auc_roc: 0.8371
# Epoch 74/200
# 4/4 [==============================] - 1s 294ms/step - loss: 0.5034 - accuracy: 0.7591 - auc_roc: 0.8302
# Epoch 75/200
# 4/4 [==============================] - 1s 297ms/step - loss: 0.4968 - accuracy: 0.7642 - auc_roc: 0.8355
# Epoch 76/200
# 4/4 [==============================] - 1s 285ms/step - loss: 0.5107 - accuracy: 0.7537 - auc_roc: 0.8258
# Epoch 77/200
# 4/4 [==============================] - 1s 313ms/step - loss: 0.5013 - accuracy: 0.7646 - auc_roc: 0.8344
# Epoch 78/200
# 4/4 [==============================] - 1s 295ms/step - loss: 0.5038 - accuracy: 0.7628 - auc_roc: 0.8286
# Epoch 79/200
# 4/4 [==============================] - 1s 266ms/step - loss: 0.4984 - accuracy: 0.7678 - auc_roc: 0.8389
# Epoch 80/200
# 4/4 [==============================] - 1s 272ms/step - loss: 0.5092 - accuracy: 0.7555 - auc_roc: 0.8268
# Epoch 81/200
# 4/4 [==============================] - 1s 272ms/step - loss: 0.5016 - accuracy: 0.7649 - auc_roc: 0.8289
# Epoch 82/200
# 4/4 [==============================] - 1s 315ms/step - loss: 0.5120 - accuracy: 0.7579 - auc_roc: 0.8214
# Epoch 83/200
# 4/4 [==============================] - 1s 283ms/step - loss: 0.5234 - accuracy: 0.7596 - auc_roc: 0.8173
# Epoch 84/200
# 4/4 [==============================] - 1s 304ms/step - loss: 0.4934 - accuracy: 0.7744 - auc_roc: 0.8378
# Epoch 85/200
# 4/4 [==============================] - 1s 291ms/step - loss: 0.5096 - accuracy: 0.7466 - auc_roc: 0.8220
# Epoch 86/200
# 4/4 [==============================] - 1s 306ms/step - loss: 0.5104 - accuracy: 0.7564 - auc_roc: 0.8209
# Epoch 87/200
# 4/4 [==============================] - 1s 276ms/step - loss: 0.5173 - accuracy: 0.7549 - auc_roc: 0.8240
# Epoch 88/200
# 4/4 [==============================] - 1s 283ms/step - loss: 0.4850 - accuracy: 0.7809 - auc_roc: 0.8438
# Epoch 89/200
# 4/4 [==============================] - 1s 292ms/step - loss: 0.4917 - accuracy: 0.7699 - auc_roc: 0.8402
# Epoch 90/200
# 4/4 [==============================] - 1s 252ms/step - loss: 0.5043 - accuracy: 0.7648 - auc_roc: 0.8320
# Epoch 91/200
# 4/4 [==============================] - 1s 276ms/step - loss: 0.5133 - accuracy: 0.7578 - auc_roc: 0.8245
# Epoch 92/200
# 4/4 [==============================] - 1s 232ms/step - loss: 0.5039 - accuracy: 0.7630 - auc_roc: 0.8312
# Epoch 93/200
# 4/4 [==============================] - 2s 371ms/step - loss: 0.4864 - accuracy: 0.7708 - auc_roc: 0.8433
# Epoch 94/200
# 4/4 [==============================] - 1s 277ms/step - loss: 0.4949 - accuracy: 0.7573 - auc_roc: 0.8391
# Epoch 95/200
# 4/4 [==============================] - 1s 284ms/step - loss: 0.4919 - accuracy: 0.7696 - auc_roc: 0.8365
# Epoch 96/200
# 4/4 [==============================] - 1s 299ms/step - loss: 0.4956 - accuracy: 0.7643 - auc_roc: 0.8310
# Epoch 97/200
# 4/4 [==============================] - 1s 321ms/step - loss: 0.4973 - accuracy: 0.7509 - auc_roc: 0.8337
# Epoch 98/200
# 4/4 [==============================] - 1s 293ms/step - loss: 0.5097 - accuracy: 0.7484 - auc_roc: 0.8251
# Epoch 99/200
# 4/4 [==============================] - 1s 272ms/step - loss: 0.5043 - accuracy: 0.7576 - auc_roc: 0.8292
# Epoch 100/200
# 4/4 [==============================] - 1s 266ms/step - loss: 0.4957 - accuracy: 0.7678 - auc_roc: 0.8348
# Epoch 101/200
# 4/4 [==============================] - 1s 238ms/step - loss: 0.4908 - accuracy: 0.7675 - auc_roc: 0.8396
# Epoch 102/200
# 4/4 [==============================] - 1s 229ms/step - loss: 0.4949 - accuracy: 0.7667 - auc_roc: 0.8386
# Epoch 103/200
# 4/4 [==============================] - 1s 242ms/step - loss: 0.4954 - accuracy: 0.7674 - auc_roc: 0.8378
# Epoch 104/200
# 4/4 [==============================] - 1s 288ms/step - loss: 0.4968 - accuracy: 0.7684 - auc_roc: 0.8364
# Epoch 105/200
# 4/4 [==============================] - 1s 240ms/step - loss: 0.4808 - accuracy: 0.7738 - auc_roc: 0.8467
# Epoch 106/200
# 4/4 [==============================] - 1s 230ms/step - loss: 0.4992 - accuracy: 0.7514 - auc_roc: 0.8319
# Epoch 107/200
# 4/4 [==============================] - 1s 237ms/step - loss: 0.4984 - accuracy: 0.7657 - auc_roc: 0.8340
# Epoch 108/200
# 4/4 [==============================] - 1s 270ms/step - loss: 0.4903 - accuracy: 0.7731 - auc_roc: 0.8417
# Epoch 109/200
# 4/4 [==============================] - 1s 277ms/step - loss: 0.4869 - accuracy: 0.7589 - auc_roc: 0.8425
# Epoch 110/200
# 4/4 [==============================] - 1s 249ms/step - loss: 0.4804 - accuracy: 0.7713 - auc_roc: 0.8476
# Epoch 111/200
# 4/4 [==============================] - 1s 231ms/step - loss: 0.4890 - accuracy: 0.7703 - auc_roc: 0.8400
# Epoch 112/200
# 4/4 [==============================] - 1s 265ms/step - loss: 0.5116 - accuracy: 0.7550 - auc_roc: 0.8270
# Epoch 113/200
# 4/4 [==============================] - 1s 222ms/step - loss: 0.5035 - accuracy: 0.7605 - auc_roc: 0.8320
# Epoch 114/200
# 4/4 [==============================] - 1s 232ms/step - loss: 0.5059 - accuracy: 0.7507 - auc_roc: 0.8260
# Epoch 115/200
# 4/4 [==============================] - 1s 281ms/step - loss: 0.5065 - accuracy: 0.7495 - auc_roc: 0.8270
# Epoch 116/200
# 4/4 [==============================] - 1s 251ms/step - loss: 0.5012 - accuracy: 0.7578 - auc_roc: 0.8294
# Epoch 117/200
# 4/4 [==============================] - 1s 246ms/step - loss: 0.4911 - accuracy: 0.7705 - auc_roc: 0.8382
# Epoch 118/200
# 4/4 [==============================] - 1s 261ms/step - loss: 0.4852 - accuracy: 0.7639 - auc_roc: 0.8449
# Epoch 119/200
# 4/4 [==============================] - 1s 289ms/step - loss: 0.4910 - accuracy: 0.7655 - auc_roc: 0.8388
# Epoch 120/200
# 4/4 [==============================] - 1s 226ms/step - loss: 0.4875 - accuracy: 0.7620 - auc_roc: 0.8414
# Epoch 121/200
# 4/4 [==============================] - 1s 219ms/step - loss: 0.4889 - accuracy: 0.7679 - auc_roc: 0.8392
# Epoch 122/200
# 4/4 [==============================] - 1s 213ms/step - loss: 0.4929 - accuracy: 0.7679 - auc_roc: 0.8393
# Epoch 123/200
# 4/4 [==============================] - 1s 258ms/step - loss: 0.4938 - accuracy: 0.7638 - auc_roc: 0.8359
# Epoch 124/200
# 4/4 [==============================] - 1s 261ms/step - loss: 0.4972 - accuracy: 0.7588 - auc_roc: 0.8320
# Epoch 125/200
# 4/4 [==============================] - 1s 252ms/step - loss: 0.4792 - accuracy: 0.7776 - auc_roc: 0.8471
# Epoch 126/200
# 4/4 [==============================] - 1s 232ms/step - loss: 0.4831 - accuracy: 0.7676 - auc_roc: 0.8496
# Epoch 127/200
# 4/4 [==============================] - 1s 304ms/step - loss: 0.4852 - accuracy: 0.7586 - auc_roc: 0.8423
# Epoch 128/200
# 4/4 [==============================] - 1s 280ms/step - loss: 0.4862 - accuracy: 0.7684 - auc_roc: 0.8415
# Epoch 129/200
# 4/4 [==============================] - 1s 264ms/step - loss: 0.4902 - accuracy: 0.7670 - auc_roc: 0.8390
# Epoch 130/200
# 4/4 [==============================] - 1s 284ms/step - loss: 0.4946 - accuracy: 0.7554 - auc_roc: 0.8339
# Epoch 131/200
# 4/4 [==============================] - 1s 294ms/step - loss: 0.4849 - accuracy: 0.7684 - auc_roc: 0.8412
# Epoch 132/200
# 4/4 [==============================] - 1s 263ms/step - loss: 0.4811 - accuracy: 0.7719 - auc_roc: 0.8425
# Epoch 133/200
# 4/4 [==============================] - 1s 296ms/step - loss: 0.5016 - accuracy: 0.7630 - auc_roc: 0.8332
# Epoch 134/200
# 4/4 [==============================] - 1s 363ms/step - loss: 0.4815 - accuracy: 0.7806 - auc_roc: 0.8466
# Epoch 135/200
# 4/4 [==============================] - 1s 347ms/step - loss: 0.4874 - accuracy: 0.7674 - auc_roc: 0.8423
# Epoch 136/200
# 4/4 [==============================] - 1s 271ms/step - loss: 0.4836 - accuracy: 0.7778 - auc_roc: 0.8448
# Epoch 137/200
# 4/4 [==============================] - 1s 265ms/step - loss: 0.4838 - accuracy: 0.7750 - auc_roc: 0.8435
# Epoch 138/200
# 4/4 [==============================] - 1s 294ms/step - loss: 0.4686 - accuracy: 0.7825 - auc_roc: 0.8531
# Epoch 139/200
# 4/4 [==============================] - 1s 267ms/step - loss: 0.4873 - accuracy: 0.7599 - auc_roc: 0.8421
# Epoch 140/200
# 4/4 [==============================] - 1s 269ms/step - loss: 0.4805 - accuracy: 0.7712 - auc_roc: 0.8521
# Epoch 141/200
# 4/4 [==============================] - 1s 245ms/step - loss: 0.4870 - accuracy: 0.7606 - auc_roc: 0.8411
# Epoch 142/200
# 4/4 [==============================] - 1s 286ms/step - loss: 0.4670 - accuracy: 0.7777 - auc_roc: 0.8567
# Epoch 143/200
# 4/4 [==============================] - 1s 255ms/step - loss: 0.4873 - accuracy: 0.7640 - auc_roc: 0.8455
# Epoch 144/200
# 4/4 [==============================] - 1s 257ms/step - loss: 0.4831 - accuracy: 0.7786 - auc_roc: 0.8452
# Epoch 145/200
# 4/4 [==============================] - 1s 256ms/step - loss: 0.4842 - accuracy: 0.7726 - auc_roc: 0.8453
# Epoch 146/200
# 4/4 [==============================] - 1s 241ms/step - loss: 0.4663 - accuracy: 0.7750 - auc_roc: 0.8581
# Epoch 147/200
# 4/4 [==============================] - 1s 239ms/step - loss: 0.4913 - accuracy: 0.7630 - auc_roc: 0.8385
# Epoch 148/200
# 4/4 [==============================] - 1s 261ms/step - loss: 0.4894 - accuracy: 0.7711 - auc_roc: 0.8413
# Epoch 149/200
# 4/4 [==============================] - 1s 249ms/step - loss: 0.4800 - accuracy: 0.7593 - auc_roc: 0.8439
# Epoch 150/200
# 4/4 [==============================] - 1s 231ms/step - loss: 0.4810 - accuracy: 0.7786 - auc_roc: 0.8485
# Epoch 151/200
# 4/4 [==============================] - 1s 220ms/step - loss: 0.4720 - accuracy: 0.7722 - auc_roc: 0.8527
# Epoch 152/200
# 4/4 [==============================] - 1s 248ms/step - loss: 0.4849 - accuracy: 0.7703 - auc_roc: 0.8390
# Epoch 153/200
# 4/4 [==============================] - 1s 251ms/step - loss: 0.4796 - accuracy: 0.7701 - auc_roc: 0.8475
# Epoch 154/200
# 4/4 [==============================] - 1s 227ms/step - loss: 0.4828 - accuracy: 0.7680 - auc_roc: 0.8441
# Epoch 155/200
# 4/4 [==============================] - 1s 276ms/step - loss: 0.4832 - accuracy: 0.7632 - auc_roc: 0.8437
# Epoch 156/200
# 4/4 [==============================] - 1s 260ms/step - loss: 0.4856 - accuracy: 0.7696 - auc_roc: 0.8427
# Epoch 157/200
# 4/4 [==============================] - 1s 256ms/step - loss: 0.4757 - accuracy: 0.7736 - auc_roc: 0.8536
# Epoch 158/200
# 4/4 [==============================] - 1s 272ms/step - loss: 0.4821 - accuracy: 0.7764 - auc_roc: 0.8457
# Epoch 159/200
# 4/4 [==============================] - 1s 238ms/step - loss: 0.4852 - accuracy: 0.7732 - auc_roc: 0.8452
# Epoch 160/200
# 4/4 [==============================] - 1s 235ms/step - loss: 0.4810 - accuracy: 0.7644 - auc_roc: 0.8484
# Epoch 161/200
# 4/4 [==============================] - 1s 257ms/step - loss: 0.4816 - accuracy: 0.7735 - auc_roc: 0.8474
# Epoch 162/200
# 4/4 [==============================] - 1s 239ms/step - loss: 0.4851 - accuracy: 0.7637 - auc_roc: 0.8408
# Epoch 163/200
# 4/4 [==============================] - 1s 251ms/step - loss: 0.4712 - accuracy: 0.7765 - auc_roc: 0.8514
# Epoch 164/200
# 4/4 [==============================] - 1s 247ms/step - loss: 0.4707 - accuracy: 0.7749 - auc_roc: 0.8520
# Epoch 165/200
# 4/4 [==============================] - 1s 253ms/step - loss: 0.4882 - accuracy: 0.7736 - auc_roc: 0.8408
# Epoch 166/200
# 4/4 [==============================] - 1s 225ms/step - loss: 0.4853 - accuracy: 0.7652 - auc_roc: 0.8399
# Epoch 167/200
# 4/4 [==============================] - 1s 233ms/step - loss: 0.4807 - accuracy: 0.7656 - auc_roc: 0.8472
# Epoch 168/200
# 4/4 [==============================] - 1s 275ms/step - loss: 0.4691 - accuracy: 0.7808 - auc_roc: 0.8500
# Epoch 169/200
# 4/4 [==============================] - 1s 292ms/step - loss: 0.4797 - accuracy: 0.7789 - auc_roc: 0.8444
# Epoch 170/200
# 4/4 [==============================] - 1s 272ms/step - loss: 0.4713 - accuracy: 0.7743 - auc_roc: 0.8529
# Epoch 171/200
# 4/4 [==============================] - 1s 242ms/step - loss: 0.4742 - accuracy: 0.7749 - auc_roc: 0.8478
# Epoch 172/200
# 4/4 [==============================] - 1s 322ms/step - loss: 0.4736 - accuracy: 0.7807 - auc_roc: 0.8491
# Epoch 173/200
# 4/4 [==============================] - 1s 276ms/step - loss: 0.4820 - accuracy: 0.7695 - auc_roc: 0.8440
# Epoch 174/200
# 4/4 [==============================] - 1s 277ms/step - loss: 0.4920 - accuracy: 0.7622 - auc_roc: 0.8388
# Epoch 175/200
# 4/4 [==============================] - 1s 239ms/step - loss: 0.4784 - accuracy: 0.7832 - auc_roc: 0.8519
# Epoch 176/200
# 4/4 [==============================] - 1s 289ms/step - loss: 0.4860 - accuracy: 0.7735 - auc_roc: 0.8404
# Epoch 177/200
# 4/4 [==============================] - 1s 253ms/step - loss: 0.4670 - accuracy: 0.7798 - auc_roc: 0.8576
# Epoch 178/200
# 4/4 [==============================] - 1s 257ms/step - loss: 0.4824 - accuracy: 0.7726 - auc_roc: 0.8488
# Epoch 179/200
# 4/4 [==============================] - 1s 253ms/step - loss: 0.4719 - accuracy: 0.7755 - auc_roc: 0.8533
# Epoch 180/200
# 4/4 [==============================] - 1s 266ms/step - loss: 0.4621 - accuracy: 0.7845 - auc_roc: 0.8565
# Epoch 181/200
# 4/4 [==============================] - 1s 282ms/step - loss: 0.4871 - accuracy: 0.7673 - auc_roc: 0.8425
# Epoch 182/200
# 4/4 [==============================] - 1s 282ms/step - loss: 0.4757 - accuracy: 0.7735 - auc_roc: 0.8477
# Epoch 183/200
# 4/4 [==============================] - 1s 263ms/step - loss: 0.4704 - accuracy: 0.7743 - auc_roc: 0.8545
# Epoch 184/200
# 4/4 [==============================] - 1s 302ms/step - loss: 0.4680 - accuracy: 0.7652 - auc_roc: 0.8557
# Epoch 185/200
# 4/4 [==============================] - 1s 261ms/step - loss: 0.4661 - accuracy: 0.7775 - auc_roc: 0.8546
# Epoch 186/200
# 4/4 [==============================] - 1s 308ms/step - loss: 0.4725 - accuracy: 0.7653 - auc_roc: 0.8498
# Epoch 187/200
# 4/4 [==============================] - 1s 290ms/step - loss: 0.4675 - accuracy: 0.7903 - auc_roc: 0.8577
# Epoch 188/200
# 4/4 [==============================] - 1s 281ms/step - loss: 0.4723 - accuracy: 0.7775 - auc_roc: 0.8504
# Epoch 189/200
# 4/4 [==============================] - 1s 283ms/step - loss: 0.4611 - accuracy: 0.7848 - auc_roc: 0.8616
# Epoch 190/200
# 4/4 [==============================] - 1s 279ms/step - loss: 0.4660 - accuracy: 0.7866 - auc_roc: 0.8563
# Epoch 191/200
# 4/4 [==============================] - 1s 256ms/step - loss: 0.4638 - accuracy: 0.7950 - auc_roc: 0.8582
# Epoch 192/200
# 4/4 [==============================] - 1s 315ms/step - loss: 0.4671 - accuracy: 0.7830 - auc_roc: 0.8563
# Epoch 193/200
# 4/4 [==============================] - 1s 220ms/step - loss: 0.4802 - accuracy: 0.7702 - auc_roc: 0.8435
# Epoch 194/200
# 4/4 [==============================] - 1s 248ms/step - loss: 0.4712 - accuracy: 0.7829 - auc_roc: 0.8530
# Epoch 195/200
# ...
# Epoch 67/200
# 5/5 [==============================] - 1s 125ms/step - loss: 0.4858 - accuracy: 0.7575 - auc_roc: 0.8380
# Epoch 68/200
# 5/5 [==============================] - 1s 130ms/step - loss: 0.4931 - accuracy: 0.7604 - auc_roc: 0.8328
# Epoch 69/200
# 5/5 [==============================] - 1s 132ms/step - loss: 0.4954 - accuracy: 0.7551 - auc_roc: 0.8354
# Epoch 70/200
# 5/5 [==============================] - 1s 135ms/step - loss: 0.4905 - accuracy: 0.7677 - auc_roc: 0.8385
# Epoch 71/200
# 5/5 [==============================] - 1s 122ms/step - loss: 0.4906 - accuracy: 0.7633 - auc_roc: 0.8375
# Epoch 72/200
# 5/5 [==============================] - 1s 139ms/step - loss: 0.4877 - accuracy: 0.7611 - auc_roc: 0.8397
# Epoch 73/200
# 5/5 [==============================] - 1s 142ms/step - loss: 0.4902 - accuracy: 0.7676 - auc_roc: 0.8375
# Epoch 74/200
# 5/5 [==============================] - 1s 131ms/step - loss: 0.4910 - accuracy: 0.7604 - auc_roc: 0.8361
# Epoch 75/200
# 5/5 [==============================] - 1s 96ms/step - loss: 0.4858 - accuracy: 0.7558 - auc_roc: 0.8380
# Epoch 76/200
# 5/5 [==============================] - 0s 91ms/step - loss: 0.4877 - accuracy: 0.7671 - auc_roc: 0.8402
# Epoch 77/200
# 5/5 [==============================] - 0s 86ms/step - loss: 0.4923 - accuracy: 0.7599 - auc_roc: 0.8372
# Epoch 78/200
# 5/5 [==============================] - 0s 96ms/step - loss: 0.4842 - accuracy: 0.7729 - auc_roc: 0.8396
# Epoch 79/200
# 5/5 [==============================] - 0s 93ms/step - loss: 0.4740 - accuracy: 0.7708 - auc_roc: 0.8504
# Epoch 80/200
# 5/5 [==============================] - 0s 91ms/step - loss: 0.4969 - accuracy: 0.7514 - auc_roc: 0.8328
# Epoch 81/200
# 5/5 [==============================] - 0s 85ms/step - loss: 0.4730 - accuracy: 0.7740 - auc_roc: 0.8513
# Epoch 82/200
# 5/5 [==============================] - 0s 89ms/step - loss: 0.4849 - accuracy: 0.7632 - auc_roc: 0.8420
# Epoch 83/200
# 5/5 [==============================] - 0s 88ms/step - loss: 0.4870 - accuracy: 0.7532 - auc_roc: 0.8389
# Epoch 84/200
# 5/5 [==============================] - 0s 86ms/step - loss: 0.4916 - accuracy: 0.7587 - auc_roc: 0.8397
# Epoch 85/200
# 5/5 [==============================] - 0s 89ms/step - loss: 0.4691 - accuracy: 0.7697 - auc_roc: 0.8528
# Epoch 86/200
# 5/5 [==============================] - 0s 87ms/step - loss: 0.4820 - accuracy: 0.7612 - auc_roc: 0.8438
# Epoch 87/200
# 5/5 [==============================] - 0s 89ms/step - loss: 0.4891 - accuracy: 0.7605 - auc_roc: 0.8354
# Epoch 88/200
# 5/5 [==============================] - 0s 86ms/step - loss: 0.4968 - accuracy: 0.7570 - auc_roc: 0.8338
# Epoch 89/200
# 5/5 [==============================] - 0s 87ms/step - loss: 0.4810 - accuracy: 0.7684 - auc_roc: 0.8456
# Epoch 90/200
# 5/5 [==============================] - 0s 86ms/step - loss: 0.4743 - accuracy: 0.7760 - auc_roc: 0.8495
# Epoch 91/200
# 5/5 [==============================] - 0s 84ms/step - loss: 0.4863 - accuracy: 0.7705 - auc_roc: 0.8437
# Epoch 92/200
# 5/5 [==============================] - 1s 141ms/step - loss: 0.4825 - accuracy: 0.7653 - auc_roc: 0.8425
# Epoch 93/200
# 5/5 [==============================] - 1s 126ms/step - loss: 0.4813 - accuracy: 0.7681 - auc_roc: 0.8463
# Epoch 94/200
# 5/5 [==============================] - 1s 126ms/step - loss: 0.4877 - accuracy: 0.7566 - auc_roc: 0.8413
# Epoch 95/200
# 5/5 [==============================] - 1s 113ms/step - loss: 0.4795 - accuracy: 0.7729 - auc_roc: 0.8443
# Epoch 96/200
# 5/5 [==============================] - 1s 126ms/step - loss: 0.4920 - accuracy: 0.7535 - auc_roc: 0.8325
# Epoch 97/200
# 5/5 [==============================] - 1s 136ms/step - loss: 0.4683 - accuracy: 0.7649 - auc_roc: 0.8531
# Epoch 98/200
# 5/5 [==============================] - 1s 133ms/step - loss: 0.4701 - accuracy: 0.7864 - auc_roc: 0.8538
# Epoch 99/200
# 5/5 [==============================] - 1s 134ms/step - loss: 0.4672 - accuracy: 0.7729 - auc_roc: 0.8535
# Epoch 100/200
# 5/5 [==============================] - 1s 143ms/step - loss: 0.4825 - accuracy: 0.7743 - auc_roc: 0.8420
# Epoch 101/200
# 5/5 [==============================] - 1s 127ms/step - loss: 0.4814 - accuracy: 0.7661 - auc_roc: 0.8435
# Epoch 102/200
# 5/5 [==============================] - 1s 137ms/step - loss: 0.4707 - accuracy: 0.7743 - auc_roc: 0.8525
# Epoch 103/200
# 5/5 [==============================] - 1s 127ms/step - loss: 0.4870 - accuracy: 0.7588 - auc_roc: 0.8391
# Epoch 104/200
# 5/5 [==============================] - 1s 130ms/step - loss: 0.4818 - accuracy: 0.7611 - auc_roc: 0.8430
# Epoch 105/200
# 5/5 [==============================] - 1s 132ms/step - loss: 0.4682 - accuracy: 0.7762 - auc_roc: 0.8517
# Epoch 106/200
# 5/5 [==============================] - 1s 133ms/step - loss: 0.4683 - accuracy: 0.7743 - auc_roc: 0.8535
# Epoch 107/200
# 5/5 [==============================] - 1s 131ms/step - loss: 0.4726 - accuracy: 0.7690 - auc_roc: 0.8496
# Epoch 108/200
# 5/5 [==============================] - 1s 133ms/step - loss: 0.4668 - accuracy: 0.7705 - auc_roc: 0.8548
# Epoch 109/200
# 5/5 [==============================] - 1s 130ms/step - loss: 0.4789 - accuracy: 0.7743 - auc_roc: 0.8467
# Epoch 110/200
# 5/5 [==============================] - 1s 134ms/step - loss: 0.4729 - accuracy: 0.7765 - auc_roc: 0.8487
# Epoch 111/200
# 5/5 [==============================] - 1s 123ms/step - loss: 0.4827 - accuracy: 0.7580 - auc_roc: 0.8427
# Epoch 112/200
# 5/5 [==============================] - 1s 127ms/step - loss: 0.4629 - accuracy: 0.7761 - auc_roc: 0.8581
# Epoch 113/200
# 5/5 [==============================] - 1s 133ms/step - loss: 0.4613 - accuracy: 0.7792 - auc_roc: 0.8583
# Epoch 114/200
# 5/5 [==============================] - 1s 123ms/step - loss: 0.4704 - accuracy: 0.7853 - auc_roc: 0.8542
# Epoch 115/200
# 5/5 [==============================] - 1s 131ms/step - loss: 0.4824 - accuracy: 0.7629 - auc_roc: 0.8426
# Epoch 116/200
# 5/5 [==============================] - 1s 121ms/step - loss: 0.4792 - accuracy: 0.7690 - auc_roc: 0.8436
# Epoch 117/200
# 5/5 [==============================] - 1s 130ms/step - loss: 0.4727 - accuracy: 0.7744 - auc_roc: 0.8504
# Epoch 118/200
# 5/5 [==============================] - 1s 118ms/step - loss: 0.4746 - accuracy: 0.7703 - auc_roc: 0.8488
# Epoch 119/200
# 5/5 [==============================] - 1s 137ms/step - loss: 0.4854 - accuracy: 0.7688 - auc_roc: 0.8399
# Epoch 120/200
# 5/5 [==============================] - 1s 129ms/step - loss: 0.4789 - accuracy: 0.7735 - auc_roc: 0.8445
# Epoch 121/200
# 5/5 [==============================] - 1s 126ms/step - loss: 0.4778 - accuracy: 0.7647 - auc_roc: 0.8461
# Epoch 122/200
# 5/5 [==============================] - 1s 128ms/step - loss: 0.4796 - accuracy: 0.7762 - auc_roc: 0.8470
# Epoch 123/200
# 5/5 [==============================] - 1s 135ms/step - loss: 0.4690 - accuracy: 0.7715 - auc_roc: 0.8504
# Epoch 124/200
# 5/5 [==============================] - 1s 142ms/step - loss: 0.4612 - accuracy: 0.7794 - auc_roc: 0.8581
# Epoch 125/200
# 5/5 [==============================] - 1s 128ms/step - loss: 0.4606 - accuracy: 0.7898 - auc_roc: 0.8585
# Epoch 126/200
# 5/5 [==============================] - 1s 131ms/step - loss: 0.4767 - accuracy: 0.7701 - auc_roc: 0.8463
# Epoch 127/200
# 5/5 [==============================] - 1s 124ms/step - loss: 0.4676 - accuracy: 0.7786 - auc_roc: 0.8525
# Epoch 128/200
# 5/5 [==============================] - 1s 117ms/step - loss: 0.4725 - accuracy: 0.7705 - auc_roc: 0.8493
# Epoch 129/200
# 5/5 [==============================] - 1s 127ms/step - loss: 0.4656 - accuracy: 0.7745 - auc_roc: 0.8545
# Epoch 130/200
# 5/5 [==============================] - 1s 134ms/step - loss: 0.4688 - accuracy: 0.7815 - auc_roc: 0.8544
# Epoch 131/200
# 5/5 [==============================] - 1s 121ms/step - loss: 0.4569 - accuracy: 0.7840 - auc_roc: 0.8648
# Epoch 132/200
# 5/5 [==============================] - 1s 118ms/step - loss: 0.4725 - accuracy: 0.7843 - auc_roc: 0.8484
# Epoch 133/200
# 5/5 [==============================] - 1s 137ms/step - loss: 0.4649 - accuracy: 0.7877 - auc_roc: 0.8582
# Epoch 134/200
# 5/5 [==============================] - 1s 133ms/step - loss: 0.4581 - accuracy: 0.7980 - auc_roc: 0.8578
# Epoch 135/200
# 5/5 [==============================] - 1s 130ms/step - loss: 0.4629 - accuracy: 0.7844 - auc_roc: 0.8568
# Epoch 136/200
# 5/5 [==============================] - 1s 115ms/step - loss: 0.4659 - accuracy: 0.7794 - auc_roc: 0.8537
# Epoch 137/200
# 5/5 [==============================] - 1s 119ms/step - loss: 0.4714 - accuracy: 0.7699 - auc_roc: 0.8518
# Epoch 138/200
# 5/5 [==============================] - 1s 144ms/step - loss: 0.4613 - accuracy: 0.7727 - auc_roc: 0.8562
# Epoch 139/200
# 5/5 [==============================] - 1s 114ms/step - loss: 0.4584 - accuracy: 0.7773 - auc_roc: 0.8595
# Epoch 140/200
# 5/5 [==============================] - 1s 130ms/step - loss: 0.4690 - accuracy: 0.7649 - auc_roc: 0.8503
# Epoch 141/200
# 5/5 [==============================] - 1s 128ms/step - loss: 0.4555 - accuracy: 0.7853 - auc_roc: 0.8595
# Epoch 142/200
# 5/5 [==============================] - 1s 127ms/step - loss: 0.4687 - accuracy: 0.7762 - auc_roc: 0.8530
# Epoch 143/200
# 5/5 [==============================] - 1s 132ms/step - loss: 0.4410 - accuracy: 0.7980 - auc_roc: 0.8729
# Epoch 144/200
# 5/5 [==============================] - 1s 134ms/step - loss: 0.4654 - accuracy: 0.7874 - auc_roc: 0.8566
# Epoch 145/200
# 5/5 [==============================] - 1s 124ms/step - loss: 0.4719 - accuracy: 0.7738 - auc_roc: 0.8532
# Epoch 146/200
# 5/5 [==============================] - 1s 126ms/step - loss: 0.4811 - accuracy: 0.7722 - auc_roc: 0.8432
# Epoch 147/200
# 5/5 [==============================] - 1s 133ms/step - loss: 0.4651 - accuracy: 0.7868 - auc_roc: 0.8544
# Epoch 148/200
# 5/5 [==============================] - 1s 128ms/step - loss: 0.4587 - accuracy: 0.7848 - auc_roc: 0.8589
# Epoch 149/200
# 5/5 [==============================] - 1s 130ms/step - loss: 0.4538 - accuracy: 0.7913 - auc_roc: 0.8630
# Epoch 150/200
# 5/5 [==============================] - 1s 128ms/step - loss: 0.4621 - accuracy: 0.7865 - auc_roc: 0.8590
# Epoch 151/200
# 5/5 [==============================] - 1s 135ms/step - loss: 0.4584 - accuracy: 0.7738 - auc_roc: 0.8601
# Epoch 152/200
# 5/5 [==============================] - 1s 131ms/step - loss: 0.4730 - accuracy: 0.7794 - auc_roc: 0.8503
# Epoch 153/200
# 5/5 [==============================] - 1s 130ms/step - loss: 0.4548 - accuracy: 0.7916 - auc_roc: 0.8640
# Epoch 154/200
# 5/5 [==============================] - 1s 139ms/step - loss: 0.4715 - accuracy: 0.7760 - auc_roc: 0.8521
# Epoch 155/200
# 5/5 [==============================] - 1s 135ms/step - loss: 0.4557 - accuracy: 0.7853 - auc_roc: 0.8629
# Epoch 156/200
# 5/5 [==============================] - 1s 127ms/step - loss: 0.4555 - accuracy: 0.7848 - auc_roc: 0.8609
# Epoch 157/200
# 5/5 [==============================] - 1s 133ms/step - loss: 0.4596 - accuracy: 0.7832 - auc_roc: 0.8598
# Epoch 158/200
# 5/5 [==============================] - 1s 130ms/step - loss: 0.4687 - accuracy: 0.7824 - auc_roc: 0.8527
# Epoch 159/200
# 5/5 [==============================] - 1s 130ms/step - loss: 0.4654 - accuracy: 0.7820 - auc_roc: 0.8541
# Epoch 160/200
# 5/5 [==============================] - 1s 135ms/step - loss: 0.4592 - accuracy: 0.7898 - auc_roc: 0.8561
# Epoch 161/200
# 5/5 [==============================] - 1s 140ms/step - loss: 0.4575 - accuracy: 0.7826 - auc_roc: 0.8609
# Epoch 162/200
# 5/5 [==============================] - 1s 140ms/step - loss: 0.4635 - accuracy: 0.7800 - auc_roc: 0.8571
# Epoch 163/200
# 5/5 [==============================] - 1s 127ms/step - loss: 0.4562 - accuracy: 0.7752 - auc_roc: 0.8619
# Epoch 164/200
# 5/5 [==============================] - 1s 128ms/step - loss: 0.4454 - accuracy: 0.7969 - auc_roc: 0.8713
# Epoch 165/200
# 5/5 [==============================] - 1s 128ms/step - loss: 0.4558 - accuracy: 0.7922 - auc_roc: 0.8604
# Epoch 166/200
# 5/5 [==============================] - 1s 120ms/step - loss: 0.4568 - accuracy: 0.7878 - auc_roc: 0.8625
# Epoch 167/200
# 5/5 [==============================] - 1s 132ms/step - loss: 0.4474 - accuracy: 0.7896 - auc_roc: 0.8695
# Epoch 168/200
# 5/5 [==============================] - 1s 126ms/step - loss: 0.4660 - accuracy: 0.7710 - auc_roc: 0.8521
# Epoch 169/200
# 5/5 [==============================] - 1s 128ms/step - loss: 0.4623 - accuracy: 0.7711 - auc_roc: 0.8584
# Epoch 170/200
# 5/5 [==============================] - 1s 121ms/step - loss: 0.4541 - accuracy: 0.7838 - auc_roc: 0.8625
# Epoch 171/200
# 5/5 [==============================] - 1s 128ms/step - loss: 0.4512 - accuracy: 0.7890 - auc_roc: 0.8647
# Epoch 172/200
# 5/5 [==============================] - 1s 135ms/step - loss: 0.4573 - accuracy: 0.7815 - auc_roc: 0.8589
# Epoch 173/200
# 5/5 [==============================] - 1s 123ms/step - loss: 0.4442 - accuracy: 0.7899 - auc_roc: 0.8715
# Epoch 174/200
# 5/5 [==============================] - 1s 135ms/step - loss: 0.4559 - accuracy: 0.7854 - auc_roc: 0.8639
# Epoch 175/200
# 5/5 [==============================] - 1s 129ms/step - loss: 0.4601 - accuracy: 0.7769 - auc_roc: 0.8580
# Epoch 176/200
# 5/5 [==============================] - 1s 140ms/step - loss: 0.4485 - accuracy: 0.7857 - auc_roc: 0.8702
# Epoch 177/200
# 5/5 [==============================] - 1s 130ms/step - loss: 0.4531 - accuracy: 0.7813 - auc_roc: 0.8695
# Epoch 178/200
# 5/5 [==============================] - 1s 131ms/step - loss: 0.4641 - accuracy: 0.7799 - auc_roc: 0.8523
# Epoch 179/200
# 5/5 [==============================] - 1s 132ms/step - loss: 0.4509 - accuracy: 0.7884 - auc_roc: 0.8681
# Epoch 180/200
# 5/5 [==============================] - 1s 134ms/step - loss: 0.4559 - accuracy: 0.7886 - auc_roc: 0.8621
# Epoch 181/200
# 5/5 [==============================] - 1s 130ms/step - loss: 0.4337 - accuracy: 0.7927 - auc_roc: 0.8761
# Epoch 182/200
# 5/5 [==============================] - 1s 124ms/step - loss: 0.4640 - accuracy: 0.7796 - auc_roc: 0.8567
# Epoch 183/200
# 5/5 [==============================] - 1s 141ms/step - loss: 0.4658 - accuracy: 0.7875 - auc_roc: 0.8590
# Epoch 184/200
# 5/5 [==============================] - 1s 130ms/step - loss: 0.4425 - accuracy: 0.7922 - auc_roc: 0.8718
# Epoch 185/200
# 5/5 [==============================] - 1s 137ms/step - loss: 0.4618 - accuracy: 0.7759 - auc_roc: 0.8588
# Epoch 186/200
# 5/5 [==============================] - 1s 127ms/step - loss: 0.4557 - accuracy: 0.7916 - auc_roc: 0.8637
# Epoch 187/200
# 5/5 [==============================] - 1s 126ms/step - loss: 0.4459 - accuracy: 0.7868 - auc_roc: 0.8678
# Epoch 188/200
# 5/5 [==============================] - 1s 125ms/step - loss: 0.4504 - accuracy: 0.7961 - auc_roc: 0.8657
# Epoch 189/200
# 5/5 [==============================] - 1s 134ms/step - loss: 0.4616 - accuracy: 0.7786 - auc_roc: 0.8580
# Epoch 190/200
# 5/5 [==============================] - 1s 119ms/step - loss: 0.4560 - accuracy: 0.7747 - auc_roc: 0.8623
# Epoch 191/200
# 5/5 [==============================] - 1s 129ms/step - loss: 0.4472 - accuracy: 0.7912 - auc_roc: 0.8672
# Epoch 192/200
# 5/5 [==============================] - 1s 131ms/step - loss: 0.4521 - accuracy: 0.7930 - auc_roc: 0.8634
# Epoch 193/200
# 5/5 [==============================] - 1s 122ms/step - loss: 0.4350 - accuracy: 0.8001 - auc_roc: 0.8749
# Epoch 194/200
# 5/5 [==============================] - 1s 124ms/step - loss: 0.4596 - accuracy: 0.7913 - auc_roc: 0.8626
# Epoch 195/200
# 5/5 [==============================] - 1s 124ms/step - loss: 0.4499 - accuracy: 0.7913 - auc_roc: 0.8689
# Epoch 196/200
# 5/5 [==============================] - 1s 127ms/step - loss: 0.4382 - accuracy: 0.7958 - auc_roc: 0.8738
# Epoch 197/200
# 5/5 [==============================] - 1s 135ms/step - loss: 0.4429 - accuracy: 0.7907 - auc_roc: 0.8710
# Epoch 198/200
# 5/5 [==============================] - 1s 129ms/step - loss: 0.4392 - accuracy: 0.7967 - auc_roc: 0.8715
# Epoch 199/200
# 5/5 [==============================] - 1s 144ms/step - loss: 0.4610 - accuracy: 0.7847 - auc_roc: 0.8620
# Epoch 200/200
# 5/5 [==============================] - 1s 124ms/step - loss: 0.4617 - accuracy: 0.7812 - auc_roc: 0.8578

# %%
# top 20 performers by the test_roc_auc score
#,'param_model__max_features'
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
#res_cols = ['mean_test_roc_auc', 'mean_test_accuracy', 'param_balance__balancer_type', 'param_features__k', 
#            'param_features__score_func', 'param_model__C', 'param_model__solver', 
#            'param_outlier__outlier_threshold', 'param__vif_score_threshold']
#res_cols = ['mean_test_roc_auc','mean_test_accuracy', 'param_balance__balancer_type', 'param_model__batch_size','param_model__epochs',
            #'param_outlier__outlier_threshold']
res_cols = ['mean_test_roc_auc','mean_test_accuracy', 'param_balance__balancer_type','param_features__k',
            'param_outlier__outlier_threshold']
#res_cols = ['mean_test_roc_auc','mean_test_accuracy', 'param_balance__balancer_type','param_model__optimizer',
            #'param_outlier__outlier_threshold']
df_sorted = df_result[res_cols].reset_index(drop=True).sort_values('mean_test_roc_auc', axis=0, ascending=False)
df_sorted.index = pd.RangeIndex(1, len(df_sorted.index)+1)
df_sorted
# Out:
#     mean_test_roc_auc  mean_test_accuracy param_balance__balancer_type  \
# 1            0.650983            0.606718                       allknn
# 2            0.645601            0.590042                       allknn
# 3            0.644856            0.603298                       allknn
# 4            0.642956            0.596667                       allknn
# 5            0.640826            0.600350                       allknn
# 6            0.639521            0.591511                       allknn
# 7            0.635324            0.594457                       allknn
# 8            0.634818            0.603050                       allknn
# 9            0.632639            0.598382                       allknn
# 10           0.628628            0.506124                    smote-enn
# 11           0.626541            0.527481                    smote-enn
# 12           0.625686            0.592257                       allknn
# 13           0.625068            0.507351                    smote-enn
# 14           0.620294            0.583173                       allknn
# 15           0.617768            0.583923                       allknn
# 16           0.615087            0.502444                    smote-enn
# 17           0.612850            0.501967                    smote-enn
# 18           0.608223            0.519617                    smote-enn
# 19           0.605567            0.498052                    smote-enn
# 20           0.603299            0.485754                    smote-enn
# 21           0.602606            0.517170                    smote-enn
# 22           0.590559            0.501959                    smote-enn
# 23           0.582876            0.512750                    smote-enn
# 24           0.576416            0.494119                    smote-enn
#
#    param_features__k param_outlier__outlier_threshold
# 1                 18                                0
# 2                 12                                0
# 3                 12                                3
# 4                 15                                0
# 5                 18                                3
# 6                 21                                0
# 7                 15                                3
# 8                 21                                3
# 9                 24                                0
# 10                12                                0
# 11                12                                3
# 12                24                                3
# 13                18                                0
# 14                31                                0
# 15                31                                3
# 16                18                                3
# 17                15                                0
# 18                21                                3
# 19                15                                3
# 20                21                                0
# 21                24                                0
# 22                24                                3
# 23                31                                3
# 24                31                                0

# %%
# the average roc-auc and accuracy scores of just completed search.
# these are the averages of each model over the convolution folds.
#print(df_result['mean_test_roc_auc'])
#print(df_result['mean_test_accuracy'])
print(best_params)
# Out:
# {'balance__balancer_type': 'allknn', 'features__k': 18, 'outlier__outlier_threshold': 0.0, 'scaling__type_of_scaling': 'standard'}

# %%
# display results for the best estimator we found
predictions = best_estimator.predict(df_features)
probabilities = best_estimator.predict_proba(df_features)[:,1]
mindwandering.evaluate.evaluate_model_results(mind_wandered_label, predictions, probabilities)
# Out:
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# 8/8 [==============================] - 0s 8ms/step
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# 8/8 [==============================] - 0s 6ms/step
# Accuracy score:         0.6457311089303238
# Recall (TPR) score:     0.7169811320754716
# Precision score:        0.41411520498183707
# AUC-ROC score:          0.6679741974923425
#
# True positives:   798
# True negatives:   1834
# False positives:  1129
# False negatives:  315
# True Positive Rate (recall):  0.7169811320754716
# False Positive Rate:          0.3810327370907864
# Specificity:                  0.6189672629092137
#
# [[1834 1129]
#  [ 315  798]]

# %%
# save the results and preliminary figures in the following cells

# create base save file name for this file, use datetime to keep a unique file name
now = datetime.now()
date_time = now.strftime('%Y%m%d-%H%M')
result_file_basename = 'replication-07-Neural-Network-using-Adamax' + date_time
print(result_file_basename)
# Out:
# replication-07-Neural-Network-using-Adamax20210603-0954

# %%
# A quick histogram of this search auc-roc scores.  Basically the figure 1 from the paper.
plt.figure(figsize=(12,8))

#bins = np.linspace(0.605, 0.612, 8)
plt.hist(df_result.mean_test_roc_auc, 
         bins=20,
         color='lightblue',
         rwidth=0.9);
#plt.xlabel('Area under the receiver operating characteristic (AUC-ROC)');
plt.xlabel('Area under the receiver operating characteristic (AUC-ROC)');
plt.ylabel('Number of models');
plt.title('Neural Network Replication using Adamax: ' + result_file_basename);

result_dir = '../figures'
result_file_name = result_file_basename + '.eps'
result_file_path = os.path.join(result_dir, result_file_name)
plt.savefig(result_file_path)

# %%
# save the search results dataframe to a file so can retrieve for later data analysis or
# to combine with other grid search results for summaries
result_dir = '../NeuralNetworkResults'
result_file_name = result_file_basename + '.pkl'
result_file_path = os.path.join(result_dir, result_file_name)
df_result.to_pickle(result_file_path)
