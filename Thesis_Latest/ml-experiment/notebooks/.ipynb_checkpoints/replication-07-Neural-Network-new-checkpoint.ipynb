# %%
# globally useful imports of standard libraries needed in this notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os.path
from datetime import datetime

# specific libraries or classes needed for the work in this notebook
#from sklearn.linear_model import LogisticRegression
#from sklearn.linear_model import LogisticRegressionCV
#from sklearn.svm import SVC
#from sklearn.naive_bayes import GaussianNB
#from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GroupKFold
from sklearn.model_selection import LeaveOneGroupOut
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import SelectKBest, f_classif, chi2, SelectFpr, f_regression, mutual_info_classif
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import RFE
from sklearn.feature_selection import VarianceThreshold
from sklearn.ensemble import ExtraTreesClassifier
#from sklearn.pipeline import Pipeline
# need to use Pipeline from imblearn to add in a downsample or upsample
# to cross validation training
from imblearn.pipeline import Pipeline

# import project specific modules used in this notebook
import sys
sys.path.append('../src')
import mindwandering.data
import mindwandering.features
import mindwandering.evaluate
from mindwandering.data import FeatureScalerTransformer
from mindwandering.data import WinsorizationOutlierTransformer
from mindwandering.data import VIFThresholdTransformer
from mindwandering.data import FeatureSelectionTransformer
from mindwandering.data import ClassImbalanceTransformer
from mindwandering.data import GridSearchProgressHack

# %%
# Load Data and Features
df_features = mindwandering.data.get_df_features()
mind_wandered_label = mindwandering.data.get_mind_wandered_label()

# %%
# Load libraries
from sklearn import preprocessing
# Create scaler
scaler = preprocessing.StandardScaler()

# Transform the feature
df_features = scaler.fit_transform(df_features)

# Show feature
df_features
# Out:
# array([[-0.42306825, -0.42825678, -0.12050103, ...,  0.45775364,
#         -0.67987977, -1.06569582],
#        [-0.79372281, -0.649674  , -0.0165653 , ...,  0.45775364,
#         -0.58254442, -1.01427231],
#        [-1.14257417, -1.03179097, -0.13712342, ...,  0.45775364,
#          1.05825152, -1.12957165],
#        ...,
#        [-0.42306825, -0.08961158,  0.52865675, ..., -0.54560646,
#         -0.86064543,  0.44956807],
#        [-0.59749393, -0.90290689, -0.88501832, ..., -0.35747644,
#          1.44759293,  0.00612682],
#        [-0.42306825, -0.83181874, -0.623994  , ...,  0.45775364,
#         -1.44465754,  0.45740843]])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.layers import Input, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras import regularizers
#from tensorflow.keras.optimizers import SGD,Adam

# %%
"""from sklearn.metrics import roc_auc_score
import tensorflow

def auroc(y_true, y_pred):
    return tensorflow.py_function(roc_auc_score, (y_true, y_pred), tensorflow.double)"""

# %%
from sklearn.metrics import roc_auc_score
import tensorflow

def auroc(y_true, y_pred):
    try:
        tensorflow.py_function(roc_auc_score, (y_true, y_pred), tensorflow.double)
    except ValueError:
        pass

# %%
inputs_shape=df_features.shape[1]

# %%
def create_model():
    #learn_rate=0.01
    #momentum=0.001
    dropout_rate=0.3
    activation='relu'
    model = Sequential()
    model.add(Dense(512, activation=activation,kernel_regularizer=regularizers.l2(0.01), input_shape=(inputs_shape,)))
    model.add(Dropout(dropout_rate))
    model.add(Dense(256,activation=activation))
    model.add(Dropout(dropout_rate))
    model.add(Dense(128,activation=activation))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1, activation='sigmoid'))
    #optimizer=Adam(lr=learn_rate, momentum=momentum)
    model.compile(loss='binary_crossentropy', optimizer='Adam',metrics=['accuracy',auroc])
    return model

# %%
# Wrap Keras model so it can be used by scikit-learn
kears_estimator = KerasClassifier(build_fn=create_model, verbose=1)

# %%
participant_ids = mindwandering.data.get_participant_ids()

#Parameters for GridSearching
param_grid = {
    #'scaling__type_of_scaling': ['standard'],
        #'outlier__outlier_threshold': [0.0, 3.0],
        #'features__score_func': [f_classif],
        #'balance__balancer_type': ['random-undersampler', 'allknn', 'nearmiss', 'instance-hardness-threshold'],
        #'balance__balancer_type': ['allknn', 'condensed-nn', 'neighbourhood-cleaning', 'one-sided-selection'],
        #'balance__balancer_type': ['allknn', 'one-sided-selection'],
        #'balance__balancer_type': ['allknn', 'smote-enn'],
        'model__batch_size': [10, 20, 40, 60, 80, 100],
        'model__epochs':[10, 50, 100],
        #'model__optimizer':['SGD', 'RMSprop', 'Adagrad', 'Adadelta', 'Adam', 'Adamax', 'Nadam'],
        #'model__optimizer':['SGD', 'RMSprop','Adam'],
        #'model__dropout_rate':[0.5, 0.4, 0.3, 0.2, 0.1, 0],
        #'model__learn_rate' : [0.001, 0.01, 0.1, 0.2, 0.3],
        #'model__momentum' : [0.0, 0.2, 0.4, 0.6, 0.8, 0.9],
        #'model__activation' : ['softmax', 'softplus', 'softsign', 'relu', 'tanh', 'sigmoid', 'hard_sigmoid', 'linear'],
        #'model__l2':[0.01,0.02,0.03,0.1,0.2,0.3],
        #'model__l1':[0.01,0.02,0.03,0.1,0.2,0.3]
}

# Estimator Pipeline
pipeline = Pipeline(
      [
        #('progress', GridSearchProgressHack(verbose=False)),
        #('scaling',  FeatureScalerTransformer()),
        #('outlier',  WinsorizationOutlierTransformer()),
        #('features', SelectKBest()),
        #('features', SelectFromModel(estimator=LogisticRegression(solver='liblinear', penalty='l1', C=0.1), threshold=-np.inf)),
        #('balance',  ClassImbalanceTransformer()),
        ('model',    kears_estimator),
      ]
    )

# Cross Validation Splitter
cv_group_splitter = GroupKFold(n_splits=5)


#Perform GridSearch
search = GridSearchCV(
    estimator=pipeline, 
    param_grid=param_grid,
    scoring = ['roc_auc', 'accuracy'],
    refit = 'roc_auc', 
    cv=cv_group_splitter,
    verbose = 1
    )


grid_result = search.fit(df_features, mind_wandered_label,groups=participant_ids)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# Epoch 1/10
#  23/326 [=>............................] - ETA: 0s - loss: 1.6915 - accuracy: 0.7148 - auroc: 0.5900  Epoch 1/10
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/imblearn/pipeline.py", line 266, in fit
#     self._final_estimator.fit(Xt, yt, **fit_params_last_step)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 166, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py", line 1100, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 855, in _call
#     return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 2942, in __call__
#     return graph_function._call_flat(
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 1918, in _call_flat
#     return self._build_call_outputs(self._inference_function.call(
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 555, in call
#     outputs = execute.execute(
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/execute.py", line 59, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InvalidArgumentError:  ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.
# Traceback (most recent call last):
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/script_ops.py", line 247, in __call__
#     return func(device, token, args)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/script_ops.py", line 135, in __call__
#     ret = self._func(*args)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py", line 620, in wrapper
#     return func(*args, **kwargs)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py", line 542, in roc_auc_score
#     return _average_binary_score(partial(_binary_roc_auc_score,
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_base.py", line 77, in _average_binary_score
#     return binary_metric(y_true, y_score, sample_weight=sample_weight)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py", line 327, in _binary_roc_auc_score
#     raise ValueError("Only one class present in y_true. ROC AUC score "
#
# ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.
#
#
# 	 [[node EagerPyFunc (defined at <ipython-input-5-806e9f5faa5c>:5) ]] [Op:__inference_train_function_884]
#
# Errors may have originated from an input operation.
# Input Source operations connected to node EagerPyFunc:
#  sequential/dense_3/Sigmoid (defined at /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/imblearn/pipeline.py:266)
#
# Function call stack:
# train_function
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#   1/327 [..............................] - ETA: 2:06 - loss: 2.1333 - accuracy: 0.3000 - auroc: 0.5000Epoch 1/10
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/imblearn/pipeline.py", line 266, in fit
#     self._final_estimator.fit(Xt, yt, **fit_params_last_step)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 166, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py", line 1100, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 855, in _call
#     return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 2942, in __call__
#     return graph_function._call_flat(
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 1918, in _call_flat
#     return self._build_call_outputs(self._inference_function.call(
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 555, in call
#     outputs = execute.execute(
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/execute.py", line 59, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InvalidArgumentError:  ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.
# Traceback (most recent call last):
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/script_ops.py", line 247, in __call__
#     return func(device, token, args)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/script_ops.py", line 135, in __call__
#     ret = self._func(*args)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py", line 620, in wrapper
#     return func(*args, **kwargs)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py", line 542, in roc_auc_score
#     return _average_binary_score(partial(_binary_roc_auc_score,
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_base.py", line 77, in _average_binary_score
#     return binary_metric(y_true, y_score, sample_weight=sample_weight)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py", line 327, in _binary_roc_auc_score
#     raise ValueError("Only one class present in y_true. ROC AUC score "
#
# ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.
#
#
# 	 [[node EagerPyFunc (defined at <ipython-input-5-806e9f5faa5c>:5) ]] [Op:__inference_train_function_2022]
#
# Errors may have originated from an input operation.
# Input Source operations connected to node EagerPyFunc:
#  Cast_6 (defined at /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/imblearn/pipeline.py:266)
#
# Function call stack:
# train_function
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#   1/326 [..............................] - ETA: 1:50 - loss: 1.6120 - accuracy: 0.9000 - auroc: 0.8125Epoch 1/10
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/imblearn/pipeline.py", line 266, in fit
#     self._final_estimator.fit(Xt, yt, **fit_params_last_step)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 166, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py", line 1100, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 855, in _call
#     return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 2942, in __call__
#     return graph_function._call_flat(
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 1918, in _call_flat
#     return self._build_call_outputs(self._inference_function.call(
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 555, in call
#     outputs = execute.execute(
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/execute.py", line 59, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InvalidArgumentError:  ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.
# Traceback (most recent call last):
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/script_ops.py", line 247, in __call__
#     return func(device, token, args)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/script_ops.py", line 135, in __call__
#     ret = self._func(*args)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py", line 620, in wrapper
#     return func(*args, **kwargs)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py", line 542, in roc_auc_score
#     return _average_binary_score(partial(_binary_roc_auc_score,
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_base.py", line 77, in _average_binary_score
#     return binary_metric(y_true, y_score, sample_weight=sample_weight)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py", line 327, in _binary_roc_auc_score
#     raise ValueError("Only one class present in y_true. ROC AUC score "
#
# ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.
#
#
# 	 [[node EagerPyFunc (defined at <ipython-input-5-806e9f5faa5c>:5) ]] [Op:__inference_train_function_2979]
#
# Errors may have originated from an input operation.
# Input Source operations connected to node EagerPyFunc:
#  Cast_6 (defined at /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/imblearn/pipeline.py:266)
#
# Function call stack:
# train_function
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#   1/327 [..............................] - ETA: 2:09 - loss: 1.9354 - accuracy: 0.3000 - auroc: 0.3333Epoch 1/10
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/imblearn/pipeline.py", line 266, in fit
#     self._final_estimator.fit(Xt, yt, **fit_params_last_step)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 166, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py", line 1100, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 855, in _call
#     return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 2942, in __call__
#     return graph_function._call_flat(
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 1918, in _call_flat
#     return self._build_call_outputs(self._inference_function.call(
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 555, in call
#     outputs = execute.execute(
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/execute.py", line 59, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InvalidArgumentError:  ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.
# Traceback (most recent call last):
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/script_ops.py", line 247, in __call__
#     return func(device, token, args)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/script_ops.py", line 135, in __call__
#     ret = self._func(*args)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py", line 620, in wrapper
#     return func(*args, **kwargs)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py", line 542, in roc_auc_score
#     return _average_binary_score(partial(_binary_roc_auc_score,
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_base.py", line 77, in _average_binary_score
#     return binary_metric(y_true, y_score, sample_weight=sample_weight)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py", line 327, in _binary_roc_auc_score
#     raise ValueError("Only one class present in y_true. ROC AUC score "
#
# ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.
#
#
# 	 [[node EagerPyFunc (defined at <ipython-input-5-806e9f5faa5c>:5) ]] [Op:__inference_train_function_4075]
#
# Errors may have originated from an input operation.
# Input Source operations connected to node EagerPyFunc:
#  Cast_6 (defined at /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/imblearn/pipeline.py:266)
#
# Function call stack:
# train_function
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#   1/327 [..............................] - ETA: 2:16 - loss: 1.8405 - accuracy: 0.5000 - auroc: 0.3750Epoch 1/50
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/imblearn/pipeline.py", line 266, in fit
#     self._final_estimator.fit(Xt, yt, **fit_params_last_step)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 166, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py", line 1100, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 855, in _call
#     return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 2942, in __call__
#     return graph_function._call_flat(
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 1918, in _call_flat
#     return self._build_call_outputs(self._inference_function.call(
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 555, in call
#     outputs = execute.execute(
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/execute.py", line 59, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InvalidArgumentError:  ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.
# Traceback (most recent call last):
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/script_ops.py", line 247, in __call__
#     return func(device, token, args)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/script_ops.py", line 135, in __call__
#     ret = self._func(*args)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py", line 620, in wrapper
#     return func(*args, **kwargs)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py", line 542, in roc_auc_score
#     return _average_binary_score(partial(_binary_roc_auc_score,
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_base.py", line 77, in _average_binary_score
#     return binary_metric(y_true, y_score, sample_weight=sample_weight)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py", line 327, in _binary_roc_auc_score
#     raise ValueError("Only one class present in y_true. ROC AUC score "
#
# ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.
#
#
# 	 [[node EagerPyFunc (defined at <ipython-input-5-806e9f5faa5c>:5) ]] [Op:__inference_train_function_5081]
#
# Errors may have originated from an input operation.
# Input Source operations connected to node EagerPyFunc:
#  Cast_6 (defined at /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/imblearn/pipeline.py:266)
#
# Function call stack:
# train_function
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# 104/326 [========>.....................] - ETA: 0s - loss: 1.5992 - accuracy: 0.7122 - auroc: 0.4637Epoch 1/50
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/imblearn/pipeline.py", line 266, in fit
#     self._final_estimator.fit(Xt, yt, **fit_params_last_step)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 166, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py", line 1100, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 855, in _call
#     return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 2942, in __call__
#     return graph_function._call_flat(
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 1918, in _call_flat
#     return self._build_call_outputs(self._inference_function.call(
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 555, in call
#     outputs = execute.execute(
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/execute.py", line 59, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InvalidArgumentError:  ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.
# Traceback (most recent call last):
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/script_ops.py", line 247, in __call__
#     return func(device, token, args)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/script_ops.py", line 135, in __call__
#     ret = self._func(*args)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py", line 620, in wrapper
#     return func(*args, **kwargs)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py", line 542, in roc_auc_score
#     return _average_binary_score(partial(_binary_roc_auc_score,
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_base.py", line 77, in _average_binary_score
#     return binary_metric(y_true, y_score, sample_weight=sample_weight)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py", line 327, in _binary_roc_auc_score
#     raise ValueError("Only one class present in y_true. ROC AUC score "
#
# ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.
#
#
# 	 [[node EagerPyFunc (defined at <ipython-input-5-806e9f5faa5c>:5) ]] [Op:__inference_train_function_6020]
#
# Errors may have originated from an input operation.
# Input Source operations connected to node EagerPyFunc:
#  sequential_5/dense_23/Sigmoid (defined at /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/imblearn/pipeline.py:266)
#
# Function call stack:
# train_function
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#  24/327 [=>............................] - ETA: 0s - loss: 1.7885 - accuracy: 0.5427 - auroc: 0.4793  Epoch 1/50
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/imblearn/pipeline.py", line 266, in fit
#     self._final_estimator.fit(Xt, yt, **fit_params_last_step)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 166, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py", line 1100, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 855, in _call
#     return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 2942, in __call__
#     return graph_function._call_flat(
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 1918, in _call_flat
#     return self._build_call_outputs(self._inference_function.call(
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 555, in call
#     outputs = execute.execute(
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/execute.py", line 59, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InvalidArgumentError:  ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.
# Traceback (most recent call last):
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/script_ops.py", line 247, in __call__
#     return func(device, token, args)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/script_ops.py", line 135, in __call__
#     ret = self._func(*args)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py", line 620, in wrapper
#     return func(*args, **kwargs)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py", line 542, in roc_auc_score
#     return _average_binary_score(partial(_binary_roc_auc_score,
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_base.py", line 77, in _average_binary_score
#     return binary_metric(y_true, y_score, sample_weight=sample_weight)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py", line 327, in _binary_roc_auc_score
#     raise ValueError("Only one class present in y_true. ROC AUC score "
#
# ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.
#
#
# 	 [[node EagerPyFunc (defined at <ipython-input-5-806e9f5faa5c>:5) ]] [Op:__inference_train_function_7698]
#
# Errors may have originated from an input operation.
# Input Source operations connected to node EagerPyFunc:
#  Cast_6 (defined at /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/imblearn/pipeline.py:266)
#
# Function call stack:
# train_function
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#   1/326 [..............................] - ETA: 1:43 - loss: 1.9181 - accuracy: 0.5000 - auroc: 0.3200Epoch 1/50
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/imblearn/pipeline.py", line 266, in fit
#     self._final_estimator.fit(Xt, yt, **fit_params_last_step)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 166, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py", line 1100, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 855, in _call
#     return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 2942, in __call__
#     return graph_function._call_flat(
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 1918, in _call_flat
#     return self._build_call_outputs(self._inference_function.call(
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 555, in call
#     outputs = execute.execute(
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/execute.py", line 59, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InvalidArgumentError:  ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.
# Traceback (most recent call last):
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/script_ops.py", line 247, in __call__
#     return func(device, token, args)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/script_ops.py", line 135, in __call__
#     ret = self._func(*args)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py", line 620, in wrapper
#     return func(*args, **kwargs)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py", line 542, in roc_auc_score
#     return _average_binary_score(partial(_binary_roc_auc_score,
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_base.py", line 77, in _average_binary_score
#     return binary_metric(y_true, y_score, sample_weight=sample_weight)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py", line 327, in _binary_roc_auc_score
#     raise ValueError("Only one class present in y_true. ROC AUC score "
#
# ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.
#
#
# 	 [[node EagerPyFunc (defined at <ipython-input-5-806e9f5faa5c>:5) ]] [Op:__inference_train_function_8793]
#
# Errors may have originated from an input operation.
# Input Source operations connected to node EagerPyFunc:
#  Cast_6 (defined at /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/imblearn/pipeline.py:266)
#
# Function call stack:
# train_function
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#   1/327 [..............................] - ETA: 3:24 - loss: 1.9114 - accuracy: 0.1000 - auroc: 0.0000e+00Epoch 1/50
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/imblearn/pipeline.py", line 266, in fit
#     self._final_estimator.fit(Xt, yt, **fit_params_last_step)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 166, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py", line 1100, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 855, in _call
#     return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 2942, in __call__
#     return graph_function._call_flat(
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 1918, in _call_flat
#     return self._build_call_outputs(self._inference_function.call(
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 555, in call
#     outputs = execute.execute(
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/execute.py", line 59, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InvalidArgumentError:  ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.
# Traceback (most recent call last):
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/script_ops.py", line 247, in __call__
#     return func(device, token, args)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/script_ops.py", line 135, in __call__
#     ret = self._func(*args)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py", line 620, in wrapper
#     return func(*args, **kwargs)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py", line 542, in roc_auc_score
#     return _average_binary_score(partial(_binary_roc_auc_score,
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_base.py", line 77, in _average_binary_score
#     return binary_metric(y_true, y_score, sample_weight=sample_weight)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py", line 327, in _binary_roc_auc_score
#     raise ValueError("Only one class present in y_true. ROC AUC score "
#
# ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.
#
#
# 	 [[node EagerPyFunc (defined at <ipython-input-5-806e9f5faa5c>:5) ]] [Op:__inference_train_function_9919]
#
# Errors may have originated from an input operation.
# Input Source operations connected to node EagerPyFunc:
#  sequential_8/dense_35/Sigmoid (defined at /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/imblearn/pipeline.py:266)
#
# Function call stack:
# train_function
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#  26/327 [=>............................] - ETA: 0s - loss: 1.7339 - accuracy: 0.6770 - auroc: 0.5116  Epoch 1/100
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/imblearn/pipeline.py", line 266, in fit
#     self._final_estimator.fit(Xt, yt, **fit_params_last_step)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 166, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py", line 1100, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 855, in _call
#     return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 2942, in __call__
#     return graph_function._call_flat(
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 1918, in _call_flat
#     return self._build_call_outputs(self._inference_function.call(
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 555, in call
#     outputs = execute.execute(
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/execute.py", line 59, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InvalidArgumentError:  ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.
# Traceback (most recent call last):
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/script_ops.py", line 247, in __call__
#     return func(device, token, args)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/script_ops.py", line 135, in __call__
#     ret = self._func(*args)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py", line 620, in wrapper
#     return func(*args, **kwargs)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py", line 542, in roc_auc_score
#     return _average_binary_score(partial(_binary_roc_auc_score,
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_base.py", line 77, in _average_binary_score
#     return binary_metric(y_true, y_score, sample_weight=sample_weight)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py", line 327, in _binary_roc_auc_score
#     raise ValueError("Only one class present in y_true. ROC AUC score "
#
# ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.
#
#
# 	 [[node EagerPyFunc (defined at <ipython-input-5-806e9f5faa5c>:5) ]] [Op:__inference_train_function_10985]
#
# Errors may have originated from an input operation.
# Input Source operations connected to node EagerPyFunc:
#  Cast_6 (defined at /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/imblearn/pipeline.py:266)
#
# Function call stack:
# train_function
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#   1/326 [..............................] - ETA: 1:53 - loss: 1.9363 - accuracy: 0.0000e+00 - auroc: 0.0000e+00Epoch 1/100
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/imblearn/pipeline.py", line 266, in fit
#     self._final_estimator.fit(Xt, yt, **fit_params_last_step)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 166, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py", line 1100, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 855, in _call
#     return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 2942, in __call__
#     return graph_function._call_flat(
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 1918, in _call_flat
#     return self._build_call_outputs(self._inference_function.call(
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 555, in call
#     outputs = execute.execute(
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/execute.py", line 59, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InvalidArgumentError:  ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.
# Traceback (most recent call last):
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/script_ops.py", line 247, in __call__
#     return func(device, token, args)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/script_ops.py", line 135, in __call__
#     ret = self._func(*args)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py", line 620, in wrapper
#     return func(*args, **kwargs)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py", line 542, in roc_auc_score
#     return _average_binary_score(partial(_binary_roc_auc_score,
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_base.py", line 77, in _average_binary_score
#     return binary_metric(y_true, y_score, sample_weight=sample_weight)
#
#   File "/Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py", line 327, in _binary_roc_auc_score
# ...
# Epoch 97/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3173 - accuracy: 0.9308 - auroc: 0.9750
# Epoch 98/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2936 - accuracy: 0.9383 - auroc: 0.9814
# Epoch 99/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3009 - accuracy: 0.9291 - auroc: 0.9794
# Epoch 100/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3020 - accuracy: 0.9358 - auroc: 0.9812
# 9/9 [==============================] - 0s 1ms/step
# 9/9 [==============================] - 0s 1ms/step
# Epoch 1/100
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# 33/33 [==============================] - 0s 3ms/step - loss: 1.6260 - accuracy: 0.6774 - auroc: 0.4893
# Epoch 2/100
# 33/33 [==============================] - 0s 3ms/step - loss: 1.1293 - accuracy: 0.7269 - auroc: 0.6483
# Epoch 3/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.8669 - accuracy: 0.7322 - auroc: 0.6843
# Epoch 4/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.7157 - accuracy: 0.7569 - auroc: 0.6949
# Epoch 5/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.6321 - accuracy: 0.7639 - auroc: 0.7193
# Epoch 6/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.6221 - accuracy: 0.7558 - auroc: 0.6851
# Epoch 7/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.5892 - accuracy: 0.7537 - auroc: 0.7105
# Epoch 8/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.5751 - accuracy: 0.7575 - auroc: 0.7254
# Epoch 9/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.5736 - accuracy: 0.7526 - auroc: 0.7101
# Epoch 10/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.5553 - accuracy: 0.7627 - auroc: 0.7288
# Epoch 11/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.5504 - accuracy: 0.7644 - auroc: 0.7450
# Epoch 12/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.5526 - accuracy: 0.7606 - auroc: 0.7181
# Epoch 13/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.5408 - accuracy: 0.7643 - auroc: 0.7421
# Epoch 14/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.5527 - accuracy: 0.7641 - auroc: 0.7460
# Epoch 15/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.5303 - accuracy: 0.7793 - auroc: 0.7716
# Epoch 16/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.5208 - accuracy: 0.7818 - auroc: 0.7763
# Epoch 17/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.5282 - accuracy: 0.7738 - auroc: 0.7715
# Epoch 18/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.5370 - accuracy: 0.7736 - auroc: 0.7592
# Epoch 19/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.5281 - accuracy: 0.7810 - auroc: 0.7773
# Epoch 20/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.5282 - accuracy: 0.7869 - auroc: 0.7879
# Epoch 21/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.5248 - accuracy: 0.7798 - auroc: 0.7802
# Epoch 22/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.5277 - accuracy: 0.7805 - auroc: 0.7826
# Epoch 23/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.5147 - accuracy: 0.7797 - auroc: 0.7949
# Epoch 24/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.5236 - accuracy: 0.7942 - auroc: 0.7871
# Epoch 25/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.5258 - accuracy: 0.7922 - auroc: 0.7806
# Epoch 26/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.5227 - accuracy: 0.7825 - auroc: 0.8059
# Epoch 27/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4989 - accuracy: 0.7952 - auroc: 0.8230
# Epoch 28/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.5104 - accuracy: 0.7961 - auroc: 0.8173
# Epoch 29/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4920 - accuracy: 0.8029 - auroc: 0.8352
# Epoch 30/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.5017 - accuracy: 0.8019 - auroc: 0.8231
# Epoch 31/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4775 - accuracy: 0.8182 - auroc: 0.8320
# Epoch 32/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4691 - accuracy: 0.8287 - auroc: 0.8508
# Epoch 33/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4961 - accuracy: 0.8025 - auroc: 0.8416
# Epoch 34/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4628 - accuracy: 0.8256 - auroc: 0.8657
# Epoch 35/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4755 - accuracy: 0.8258 - auroc: 0.8598
# Epoch 36/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4821 - accuracy: 0.8222 - auroc: 0.8567
# Epoch 37/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4673 - accuracy: 0.8333 - auroc: 0.8735
# Epoch 38/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4529 - accuracy: 0.8377 - auroc: 0.8806
# Epoch 39/100
# 33/33 [==============================] - 0s 2ms/step - loss: 0.4667 - accuracy: 0.8266 - auroc: 0.8709
# Epoch 40/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4589 - accuracy: 0.8322 - auroc: 0.8814
# Epoch 41/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4564 - accuracy: 0.8355 - auroc: 0.8850
# Epoch 42/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4456 - accuracy: 0.8448 - auroc: 0.8904
# Epoch 43/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4520 - accuracy: 0.8383 - auroc: 0.8891
# Epoch 44/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4336 - accuracy: 0.8635 - auroc: 0.8953
# Epoch 45/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4470 - accuracy: 0.8402 - auroc: 0.8983
# Epoch 46/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4337 - accuracy: 0.8602 - auroc: 0.9085
# Epoch 47/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4399 - accuracy: 0.8502 - auroc: 0.8978
# Epoch 48/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4270 - accuracy: 0.8602 - auroc: 0.9103
# Epoch 49/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4324 - accuracy: 0.8509 - auroc: 0.9114
# Epoch 50/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4125 - accuracy: 0.8649 - auroc: 0.9243
# Epoch 51/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4066 - accuracy: 0.8684 - auroc: 0.9267
# Epoch 52/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4014 - accuracy: 0.8685 - auroc: 0.9278
# Epoch 53/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4191 - accuracy: 0.8631 - auroc: 0.9199
# Epoch 54/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3822 - accuracy: 0.8866 - auroc: 0.9393
# Epoch 55/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4228 - accuracy: 0.8738 - auroc: 0.9170
# Epoch 56/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3988 - accuracy: 0.8793 - auroc: 0.9335
# Epoch 57/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3965 - accuracy: 0.8698 - auroc: 0.9373
# Epoch 58/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3800 - accuracy: 0.8904 - auroc: 0.9382
# Epoch 59/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4112 - accuracy: 0.8730 - auroc: 0.9311
# Epoch 60/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3714 - accuracy: 0.8923 - auroc: 0.9528
# Epoch 61/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3774 - accuracy: 0.8851 - auroc: 0.9452
# Epoch 62/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3977 - accuracy: 0.8853 - auroc: 0.9418
# Epoch 63/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3755 - accuracy: 0.8905 - auroc: 0.9521
# Epoch 64/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3740 - accuracy: 0.8867 - auroc: 0.9516
# Epoch 65/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3469 - accuracy: 0.9115 - auroc: 0.9571
# Epoch 66/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3556 - accuracy: 0.8930 - auroc: 0.9558
# Epoch 67/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3477 - accuracy: 0.9115 - auroc: 0.9587
# Epoch 68/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3733 - accuracy: 0.8961 - auroc: 0.9471
# Epoch 69/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3446 - accuracy: 0.9135 - auroc: 0.9636
# Epoch 70/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3450 - accuracy: 0.9085 - auroc: 0.9656
# Epoch 71/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3618 - accuracy: 0.8992 - auroc: 0.9572
# Epoch 72/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3611 - accuracy: 0.9011 - auroc: 0.9592
# Epoch 73/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3733 - accuracy: 0.8957 - auroc: 0.9559
# Epoch 74/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3333 - accuracy: 0.9151 - auroc: 0.9684
# Epoch 75/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3471 - accuracy: 0.9065 - auroc: 0.9616
# Epoch 76/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3208 - accuracy: 0.9248 - auroc: 0.9725
# Epoch 77/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3283 - accuracy: 0.9186 - auroc: 0.9672
# Epoch 78/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3196 - accuracy: 0.9293 - auroc: 0.9716
# Epoch 79/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3664 - accuracy: 0.9062 - auroc: 0.9549
# Epoch 80/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3332 - accuracy: 0.9134 - auroc: 0.9705
# Epoch 81/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3291 - accuracy: 0.9217 - auroc: 0.9717
# Epoch 82/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3057 - accuracy: 0.9327 - auroc: 0.9765
# Epoch 83/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3076 - accuracy: 0.9194 - auroc: 0.9768
# Epoch 84/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3161 - accuracy: 0.9262 - auroc: 0.9766
# Epoch 85/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3220 - accuracy: 0.9281 - auroc: 0.9719
# Epoch 86/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3110 - accuracy: 0.9308 - auroc: 0.9757
# Epoch 87/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3029 - accuracy: 0.9286 - auroc: 0.9782
# Epoch 88/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3075 - accuracy: 0.9327 - auroc: 0.9746
# Epoch 89/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2895 - accuracy: 0.9380 - auroc: 0.9819
# Epoch 90/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3146 - accuracy: 0.9274 - auroc: 0.9726
# Epoch 91/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3108 - accuracy: 0.9299 - auroc: 0.9759
# Epoch 92/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3311 - accuracy: 0.9300 - auroc: 0.9699
# Epoch 93/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2996 - accuracy: 0.9402 - auroc: 0.9782
# Epoch 94/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2983 - accuracy: 0.9353 - auroc: 0.9814
# Epoch 95/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3072 - accuracy: 0.9339 - auroc: 0.9761
# Epoch 96/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3092 - accuracy: 0.9299 - auroc: 0.9754
# Epoch 97/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2886 - accuracy: 0.9406 - auroc: 0.9798
# Epoch 98/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2894 - accuracy: 0.9434 - auroc: 0.9821
# Epoch 99/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2912 - accuracy: 0.9340 - auroc: 0.9829
# Epoch 100/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2953 - accuracy: 0.9374 - auroc: 0.9795
# 9/9 [==============================] - 0s 1ms/step
# 9/9 [==============================] - 0s 1ms/step
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:918: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#  0.6197195  0.58691585 0.55679669 0.61897765        nan 0.57603171
#  0.6255739  0.57172329 0.56375652 0.6253441  0.582601   0.57542022]
#   warnings.warn(
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:918: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#  0.72620398 0.68965639 0.64819631 0.72670351        nan 0.65775634
#  0.72988286 0.66144544 0.64500371 0.71762525 0.66929099 0.65309043]
#   warnings.warn(
# Epoch 1/10
# 51/51 [==============================] - 1s 2ms/step - loss: 1.5537 - accuracy: 0.6972 - auroc: 0.5284
# Epoch 2/10
# 51/51 [==============================] - 0s 2ms/step - loss: 0.9723 - accuracy: 0.7305 - auroc: 0.6357
# Epoch 3/10
# 51/51 [==============================] - 0s 3ms/step - loss: 0.7354 - accuracy: 0.7379 - auroc: 0.6817
# Epoch 4/10
# 51/51 [==============================] - 0s 3ms/step - loss: 0.6388 - accuracy: 0.7496 - auroc: 0.6919
# Epoch 5/10
# 51/51 [==============================] - 0s 2ms/step - loss: 0.6083 - accuracy: 0.7332 - auroc: 0.6880
# Epoch 6/10
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5670 - accuracy: 0.7624 - auroc: 0.6943
# Epoch 7/10
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5755 - accuracy: 0.7441 - auroc: 0.6995
# Epoch 8/10
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5810 - accuracy: 0.7438 - auroc: 0.6901
# Epoch 9/10
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5877 - accuracy: 0.7309 - auroc: 0.6773
# Epoch 10/10
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5575 - accuracy: 0.7509 - auroc: 0.7159

# %%
# Empty dataframe to gather grid search results into 1 place
best_estimator = None
best_score = 0.0
best_params = {}
best_index = 0
df_result = None

df = pd.DataFrame(data=search.cv_results_)

if best_estimator is None:
        df_result = df
        best_estimator = search.best_estimator_
        best_score = search.best_score_
        best_params = search.best_params_
        best_index = search.best_index_
else:
    df_result = df_result.append(df, ignore_index=True)
    if search.best_score_ > best_score:
        best_estimator = search.best_estimator_
        best_score = search.best_score_
        best_params = search.best_params_
        best_index = search.best_index_  # todo this is only the index of this search

# %%
# top 20 performers by the test_roc_auc score
#,'param_model__max_features'
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
#res_cols = ['mean_test_roc_auc', 'mean_test_accuracy', 'param_balance__balancer_type', 'param_features__k', 
#            'param_features__score_func', 'param_model__C', 'param_model__solver', 
#            'param_outlier__outlier_threshold', 'param__vif_score_threshold']
res_cols = ['mean_test_roc_auc', 'mean_test_accuracy']
df_sorted = df_result[res_cols].reset_index(drop=True).sort_values('mean_test_roc_auc', axis=0, ascending=False)
df_sorted.index = pd.RangeIndex(1, len(df_sorted.index)+1)
df_sorted
# Out:
#     mean_test_roc_auc  mean_test_accuracy
# 1            0.625574            0.729883
# 2            0.625344            0.717625
# 3            0.619720            0.726204
# 4            0.618978            0.726704
# 5            0.586916            0.689656
# 6            0.582601            0.669291
# 7            0.576032            0.657756
# 8            0.575420            0.653090
# 9            0.571723            0.661445
# 10           0.563757            0.645004
# 11           0.556797            0.648196
# 12                NaN                 NaN
# 13                NaN                 NaN
# 14                NaN                 NaN
# 15                NaN                 NaN
# 16                NaN                 NaN
# 17                NaN                 NaN
# 18                NaN                 NaN

# %%
print(best_params)
# Out:
# {'model__batch_size': 80, 'model__epochs': 10}

# %%
# display results for the best estimator we found
predictions = best_estimator.predict(df_features)
probabilities = best_estimator.predict_proba(df_features)[:,1]
mindwandering.evaluate.evaluate_model_results(mind_wandered_label, predictions, probabilities)
# Out:
# 51/51 [==============================] - 0s 780us/step
# 51/51 [==============================] - 0s 860us/step
# Accuracy score:         0.7595682041216879
# Recall (TPR) score:     0.20125786163522014
# Precision score:        0.7111111111111111
# AUC-ROC score:          0.5852728727683356
#
# True positives:   224
# True negatives:   2872
# False positives:  91
# False negatives:  889
# True Positive Rate (recall):  0.20125786163522014
# False Positive Rate:          0.030712116098548767
# Specificity:                  0.9692878839014513
#
# [[2872   91]
#  [ 889  224]]
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /Users/subrotosingha/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '

# %%
# save the results and preliminary figures in the following cells

# create base save file name for this file, use datetime to keep a unique file name
now = datetime.now()
date_time = now.strftime('%Y%m%d-%H%M')
result_file_basename = 'replication-07-Neural-Network-new' + date_time
print(result_file_basename)
# Out:
# replication-07-Neural-Network-new20210421-0029

# %%
# A quick histogram of this search auc-roc scores.  Basically the figure 1 from the paper.
plt.figure(figsize=(12,8))

#bins = np.linspace(0.605, 0.612, 8)
plt.hist(df_result.mean_test_roc_auc, 
         bins=20,
         color='lightblue',
         rwidth=0.9);
plt.xlabel('Area under the receiver operating characteristic (AUC-ROC)');
plt.ylabel('Number of models');
plt.title('Neural Network new Experiment: ' + result_file_basename);

result_dir = '../figures'
result_file_name = result_file_basename + '.eps'
result_file_path = os.path.join(result_dir, result_file_name)
plt.savefig(result_file_path)

# %%
# save the search results dataframe to a file so can retrieve for later data analysis or
# to combine with other grid search results for summaries
result_dir = '../results'
result_file_name = result_file_basename + '.pkl'
result_file_path = os.path.join(result_dir, result_file_name)
df_result.to_pickle(result_file_path)

# %% [markdown]
# - wasn't able to use vif, scaling, and other params_grid for GridSearch
