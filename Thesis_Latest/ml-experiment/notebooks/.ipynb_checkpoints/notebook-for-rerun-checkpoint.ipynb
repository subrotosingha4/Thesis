# %%
# globally useful imports of standard libraries needed in this notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os.path
from datetime import datetime

# specific libraries or classes needed for the work in this notebook
#from sklearn.linear_model import LogisticRegression
#from sklearn.linear_model import LogisticRegressionCV
#from sklearn.svm import SVC
#from sklearn.naive_bayes import GaussianNB
#from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GroupKFold
from sklearn.model_selection import LeaveOneGroupOut
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import SelectKBest, f_classif, chi2, SelectFpr, f_regression, mutual_info_classif
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import RFE
from sklearn.feature_selection import VarianceThreshold
from sklearn.ensemble import ExtraTreesClassifier
#from sklearn.pipeline import Pipeline
# need to use Pipeline from imblearn to add in a downsample or upsample
# to cross validation training
from imblearn.pipeline import Pipeline

# import project specific modules used in this notebook
import sys
sys.path.append('../src')
import mindwandering.data
import mindwandering.features
import mindwandering.evaluate
from mindwandering.data import FeatureScalerTransformer
from mindwandering.data import WinsorizationOutlierTransformer
from mindwandering.data import VIFThresholdTransformer
from mindwandering.data import FeatureSelectionTransformer
from mindwandering.data import ClassImbalanceTransformer
from mindwandering.data import GridSearchProgressHack

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.layers import Input, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import SGD,Adam,RMSprop

# %%
# Load Data and Features
df_features = mindwandering.data.get_df_features()
mind_wandered_label = mindwandering.data.get_mind_wandered_label()
participant_ids = mindwandering.data.get_participant_ids()

# %%
inputs_shape=df_features.shape[1]

# %%
import tensorflow
auc_roc = tensorflow.keras.metrics.AUC(name='auc_roc',num_thresholds=20000,curve='ROC')
#auc_roc = tensorflow.keras.metrics.AUC(name='auc_roc',curve='ROC')

# %%
# Creates a model given an activation and learning rate
def create_model(learning_rate, activation):
    # Create an Adam optimizer with the given learning rate
    opt = Adam(lr = learning_rate)
  
    # Create your binary classification model  
    model = Sequential()
    model.add(Dense(128, input_shape=(inputs_shape,), activation = activation))
    model.add(Dense(256, activation = activation))
    model.add(Dense(1, activation = 'sigmoid'))
  
    # Compile your model with your optimizer, loss, and metrics
    model.compile(optimizer = opt, loss = 'binary_crossentropy', metrics = ['accuracy',auc_roc])
    return model

# %%
# Import KerasClassifier from keras scikit learn wrappers
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import KFold

# Create a KerasClassifier
model = KerasClassifier(build_fn = create_model)

# Define the parameters to try out
params = {'activation':['relu', 'tanh'], 'batch_size':[32, 128, 256], 
          'epochs':[50, 100, 200], 'learning_rate':[0.1, 0.01, 0.001]}

# Create a randomize search cv object passing in the parameters to try
random_search = RandomizedSearchCV(model, param_distributions = params, cv = 3)
random_search_results=random_search.fit(df_features,mind_wandered_label)
# Out:
# Epoch 1/100
# 85/85 [==============================] - 1s 3ms/step - loss: 697.4780 - accuracy: 0.6320 - auc_roc: 0.5119
# Epoch 2/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5838 - accuracy: 0.7347 - auc_roc: 0.5043
# Epoch 3/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6087 - accuracy: 0.7262 - auc_roc: 0.4987
# Epoch 4/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5958 - accuracy: 0.7242 - auc_roc: 0.4880
# Epoch 5/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6097 - accuracy: 0.7121 - auc_roc: 0.5183
# Epoch 6/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5994 - accuracy: 0.7180 - auc_roc: 0.5009
# Epoch 7/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5978 - accuracy: 0.7235 - auc_roc: 0.4775
# Epoch 8/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6220 - accuracy: 0.7115 - auc_roc: 0.4709
# Epoch 9/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6016 - accuracy: 0.7195 - auc_roc: 0.4813
# Epoch 10/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6044 - accuracy: 0.7166 - auc_roc: 0.4824
# Epoch 11/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5925 - accuracy: 0.7256 - auc_roc: 0.4907
# Epoch 12/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5928 - accuracy: 0.7224 - auc_roc: 0.4957
# Epoch 13/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5942 - accuracy: 0.7290 - auc_roc: 0.4964
# Epoch 14/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5888 - accuracy: 0.7347 - auc_roc: 0.4875
# Epoch 15/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5936 - accuracy: 0.7224 - auc_roc: 0.4969
# Epoch 16/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5897 - accuracy: 0.7280 - auc_roc: 0.4746
# Epoch 17/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5968 - accuracy: 0.7178 - auc_roc: 0.5122
# Epoch 18/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5936 - accuracy: 0.7301 - auc_roc: 0.4938
# Epoch 19/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5887 - accuracy: 0.7271 - auc_roc: 0.4887
# Epoch 20/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5979 - accuracy: 0.7166 - auc_roc: 0.4848
# Epoch 21/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5791 - accuracy: 0.7391 - auc_roc: 0.4770
# Epoch 22/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5742 - accuracy: 0.7406 - auc_roc: 0.4815
# Epoch 23/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5998 - accuracy: 0.7174 - auc_roc: 0.4946
# Epoch 24/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6007 - accuracy: 0.7178 - auc_roc: 0.4865
# Epoch 25/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5979 - accuracy: 0.7175 - auc_roc: 0.4998
# Epoch 26/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5926 - accuracy: 0.7243 - auc_roc: 0.4795
# Epoch 27/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5925 - accuracy: 0.7223 - auc_roc: 0.5022
# Epoch 28/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5972 - accuracy: 0.7183 - auc_roc: 0.4942
# Epoch 29/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6023 - accuracy: 0.7127 - auc_roc: 0.4950
# Epoch 30/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5921 - accuracy: 0.7235 - auc_roc: 0.4936
# Epoch 31/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5941 - accuracy: 0.7205 - auc_roc: 0.4806
# Epoch 32/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5835 - accuracy: 0.7327 - auc_roc: 0.5000
# Epoch 33/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5742 - accuracy: 0.7416 - auc_roc: 0.4624
# Epoch 34/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5929 - accuracy: 0.7213 - auc_roc: 0.4862
# Epoch 35/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5876 - accuracy: 0.7271 - auc_roc: 0.4777
# Epoch 36/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5864 - accuracy: 0.7286 - auc_roc: 0.5088
# Epoch 37/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5807 - accuracy: 0.7367 - auc_roc: 0.4847
# Epoch 38/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5897 - accuracy: 0.7263 - auc_roc: 0.4841
# Epoch 39/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5838 - accuracy: 0.7323 - auc_roc: 0.4848
# Epoch 40/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5916 - accuracy: 0.7228 - auc_roc: 0.4946
# Epoch 41/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5982 - accuracy: 0.7166 - auc_roc: 0.4838
# Epoch 42/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5927 - accuracy: 0.7222 - auc_roc: 0.4775
# Epoch 43/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5965 - accuracy: 0.7176 - auc_roc: 0.4851
# Epoch 44/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5922 - accuracy: 0.7233 - auc_roc: 0.4825
# Epoch 45/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6023 - accuracy: 0.7143 - auc_roc: 0.4802
# Epoch 46/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5793 - accuracy: 0.7360 - auc_roc: 0.4902
# Epoch 47/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5870 - accuracy: 0.7302 - auc_roc: 0.4764
# Epoch 48/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5762 - accuracy: 0.7370 - auc_roc: 0.5117
# Epoch 49/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5881 - accuracy: 0.7264 - auc_roc: 0.5002
# Epoch 50/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5760 - accuracy: 0.7387 - auc_roc: 0.4766
# Epoch 51/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6030 - accuracy: 0.7129 - auc_roc: 0.4824
# Epoch 52/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5904 - accuracy: 0.7241 - auc_roc: 0.4730
# Epoch 53/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5990 - accuracy: 0.7167 - auc_roc: 0.4583
# Epoch 54/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6009 - accuracy: 0.7131 - auc_roc: 0.4807
# Epoch 55/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6021 - accuracy: 0.7153 - auc_roc: 0.4749
# Epoch 56/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5951 - accuracy: 0.7234 - auc_roc: 0.4980
# Epoch 57/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5911 - accuracy: 0.7263 - auc_roc: 0.4890
# Epoch 58/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5776 - accuracy: 0.7387 - auc_roc: 0.4830
# Epoch 59/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5988 - accuracy: 0.7217 - auc_roc: 0.4853
# Epoch 60/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6030 - accuracy: 0.7142 - auc_roc: 0.4949
# Epoch 61/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5999 - accuracy: 0.7145 - auc_roc: 0.4710
# Epoch 62/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5816 - accuracy: 0.7337 - auc_roc: 0.4918
# Epoch 63/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5907 - accuracy: 0.7235 - auc_roc: 0.5062
# Epoch 64/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5994 - accuracy: 0.7130 - auc_roc: 0.5095
# Epoch 65/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5867 - accuracy: 0.7291 - auc_roc: 0.4896
# Epoch 66/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5915 - accuracy: 0.7226 - auc_roc: 0.4876
# Epoch 67/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5979 - accuracy: 0.7165 - auc_roc: 0.4726
# Epoch 68/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5979 - accuracy: 0.7197 - auc_roc: 0.4902
# Epoch 69/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5778 - accuracy: 0.7366 - auc_roc: 0.4880
# Epoch 70/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5918 - accuracy: 0.7267 - auc_roc: 0.4709
# Epoch 71/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6064 - accuracy: 0.7119 - auc_roc: 0.4761
# Epoch 72/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5914 - accuracy: 0.7229 - auc_roc: 0.4946
# Epoch 73/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5844 - accuracy: 0.7313 - auc_roc: 0.4878
# Epoch 74/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5905 - accuracy: 0.7233 - auc_roc: 0.5004
# Epoch 75/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5913 - accuracy: 0.7244 - auc_roc: 0.4900
# Epoch 76/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5754 - accuracy: 0.7382 - auc_roc: 0.4795
# Epoch 77/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5833 - accuracy: 0.7341 - auc_roc: 0.4814
# Epoch 78/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5831 - accuracy: 0.7316 - auc_roc: 0.4928
# Epoch 79/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5752 - accuracy: 0.7396 - auc_roc: 0.5040
# Epoch 80/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5835 - accuracy: 0.7346 - auc_roc: 0.4942
# Epoch 81/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5901 - accuracy: 0.7252 - auc_roc: 0.4853
# Epoch 82/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5951 - accuracy: 0.7201 - auc_roc: 0.4668
# Epoch 83/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.6024 - accuracy: 0.7126 - auc_roc: 0.4911
# Epoch 84/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5894 - accuracy: 0.7231 - auc_roc: 0.5264
# Epoch 85/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5993 - accuracy: 0.7134 - auc_roc: 0.5094
# Epoch 86/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5987 - accuracy: 0.7153 - auc_roc: 0.4835
# Epoch 87/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5873 - accuracy: 0.7279 - auc_roc: 0.4801
# Epoch 88/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5813 - accuracy: 0.7339 - auc_roc: 0.4715
# Epoch 89/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5956 - accuracy: 0.7184 - auc_roc: 0.4627
# Epoch 90/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5845 - accuracy: 0.7319 - auc_roc: 0.4871
# Epoch 91/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5988 - accuracy: 0.7159 - auc_roc: 0.4684
# Epoch 92/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5934 - accuracy: 0.7216 - auc_roc: 0.5074
# Epoch 93/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5803 - accuracy: 0.7345 - auc_roc: 0.5098
# Epoch 94/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5827 - accuracy: 0.7332 - auc_roc: 0.4766
# Epoch 95/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5917 - accuracy: 0.7222 - auc_roc: 0.4919
# Epoch 96/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5983 - accuracy: 0.7168 - auc_roc: 0.4744
# Epoch 97/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5968 - accuracy: 0.7182 - auc_roc: 0.4756
# Epoch 98/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5966 - accuracy: 0.7191 - auc_roc: 0.4816
# Epoch 99/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5787 - accuracy: 0.7351 - auc_roc: 0.4962
# Epoch 100/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5838 - accuracy: 0.7304 - auc_roc: 0.4738
# 43/43 [==============================] - 0s 3ms/step - loss: 0.5881 - accuracy: 0.7351 - auc_roc: 0.5014
# Epoch 1/100
# 85/85 [==============================] - 1s 3ms/step - loss: 1608.5241 - accuracy: 0.6390 - auc_roc: 0.4846
# Epoch 2/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5885 - accuracy: 0.7400 - auc_roc: 0.4700
# Epoch 3/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5947 - accuracy: 0.7331 - auc_roc: 0.5067
# Epoch 4/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5968 - accuracy: 0.7323 - auc_roc: 0.5197
# Epoch 5/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6132 - accuracy: 0.7455 - auc_roc: 0.4660
# Epoch 6/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5807 - accuracy: 0.7430 - auc_roc: 0.5023
# Epoch 7/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5759 - accuracy: 0.7434 - auc_roc: 0.4890
# Epoch 8/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5885 - accuracy: 0.7372 - auc_roc: 0.4993
# Epoch 9/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5779 - accuracy: 0.7429 - auc_roc: 0.4945
# Epoch 10/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5864 - accuracy: 0.7433 - auc_roc: 0.5062
# Epoch 11/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5675 - accuracy: 0.7533 - auc_roc: 0.4976
# Epoch 12/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5853 - accuracy: 0.7361 - auc_roc: 0.5010
# Epoch 13/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5846 - accuracy: 0.7330 - auc_roc: 0.4970
# Epoch 14/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5915 - accuracy: 0.7287 - auc_roc: 0.4690
# Epoch 15/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5883 - accuracy: 0.7421 - auc_roc: 0.4781
# Epoch 16/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5868 - accuracy: 0.7313 - auc_roc: 0.4852
# Epoch 17/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5789 - accuracy: 0.7423 - auc_roc: 0.5101
# Epoch 18/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5819 - accuracy: 0.7374 - auc_roc: 0.4839
# Epoch 19/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5910 - accuracy: 0.7235 - auc_roc: 0.5143
# Epoch 20/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5659 - accuracy: 0.7517 - auc_roc: 0.5034
# Epoch 21/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5781 - accuracy: 0.7378 - auc_roc: 0.4770
# Epoch 22/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5922 - accuracy: 0.7273 - auc_roc: 0.4994
# Epoch 23/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5864 - accuracy: 0.7349 - auc_roc: 0.4770
# Epoch 24/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5737 - accuracy: 0.7484 - auc_roc: 0.4728
# Epoch 25/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5802 - accuracy: 0.7393 - auc_roc: 0.4745
# Epoch 26/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.6045 - accuracy: 0.7194 - auc_roc: 0.4869
# Epoch 27/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5932 - accuracy: 0.7248 - auc_roc: 0.4948
# Epoch 28/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5900 - accuracy: 0.7286 - auc_roc: 0.4842
# Epoch 29/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5887 - accuracy: 0.7272 - auc_roc: 0.5048
# Epoch 30/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5751 - accuracy: 0.7427 - auc_roc: 0.5131
# Epoch 31/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5744 - accuracy: 0.7408 - auc_roc: 0.5081
# Epoch 32/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5798 - accuracy: 0.7367 - auc_roc: 0.4706
# Epoch 33/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5864 - accuracy: 0.7344 - auc_roc: 0.4858
# Epoch 34/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5801 - accuracy: 0.7363 - auc_roc: 0.4847
# Epoch 35/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5793 - accuracy: 0.7364 - auc_roc: 0.4858
# Epoch 36/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5852 - accuracy: 0.7304 - auc_roc: 0.4875
# Epoch 37/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5737 - accuracy: 0.7445 - auc_roc: 0.4944
# Epoch 38/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5775 - accuracy: 0.7421 - auc_roc: 0.4879
# Epoch 39/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5664 - accuracy: 0.7500 - auc_roc: 0.4597
# Epoch 40/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5797 - accuracy: 0.7345 - auc_roc: 0.5007
# Epoch 41/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5847 - accuracy: 0.7306 - auc_roc: 0.4998
# Epoch 42/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5691 - accuracy: 0.7490 - auc_roc: 0.5066
# Epoch 43/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5855 - accuracy: 0.7320 - auc_roc: 0.4848
# Epoch 44/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5878 - accuracy: 0.7298 - auc_roc: 0.4761
# Epoch 45/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5747 - accuracy: 0.7444 - auc_roc: 0.4585
# Epoch 46/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5832 - accuracy: 0.7345 - auc_roc: 0.4935
# Epoch 47/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5863 - accuracy: 0.7297 - auc_roc: 0.4875
# Epoch 48/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5854 - accuracy: 0.7331 - auc_roc: 0.4933
# Epoch 49/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5788 - accuracy: 0.7381 - auc_roc: 0.4781
# Epoch 50/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5718 - accuracy: 0.7419 - auc_roc: 0.5100
# Epoch 51/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5604 - accuracy: 0.7522 - auc_roc: 0.5064
# Epoch 52/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5875 - accuracy: 0.7306 - auc_roc: 0.5036
# Epoch 53/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5924 - accuracy: 0.7279 - auc_roc: 0.4989
# Epoch 54/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5843 - accuracy: 0.7417 - auc_roc: 0.4882
# Epoch 55/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5812 - accuracy: 0.7402 - auc_roc: 0.4782
# Epoch 56/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5735 - accuracy: 0.7432 - auc_roc: 0.4838
# Epoch 57/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5876 - accuracy: 0.7336 - auc_roc: 0.5050
# Epoch 58/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5914 - accuracy: 0.7250 - auc_roc: 0.4778
# Epoch 59/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5813 - accuracy: 0.7354 - auc_roc: 0.5001
# Epoch 60/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5826 - accuracy: 0.7343 - auc_roc: 0.4598
# Epoch 61/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5800 - accuracy: 0.7368 - auc_roc: 0.4912
# Epoch 62/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5917 - accuracy: 0.7259 - auc_roc: 0.4948
# Epoch 63/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5909 - accuracy: 0.7259 - auc_roc: 0.4805
# Epoch 64/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5735 - accuracy: 0.7426 - auc_roc: 0.4907
# Epoch 65/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5880 - accuracy: 0.7262 - auc_roc: 0.4992
# Epoch 66/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5919 - accuracy: 0.7299 - auc_roc: 0.4702
# Epoch 67/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5855 - accuracy: 0.7338 - auc_roc: 0.4945
# Epoch 68/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5663 - accuracy: 0.7481 - auc_roc: 0.4937
# Epoch 69/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5832 - accuracy: 0.7311 - auc_roc: 0.4962
# Epoch 70/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5851 - accuracy: 0.7319 - auc_roc: 0.4790
# Epoch 71/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5790 - accuracy: 0.7399 - auc_roc: 0.4841
# Epoch 72/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5803 - accuracy: 0.7342 - auc_roc: 0.5072
# Epoch 73/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5781 - accuracy: 0.7376 - auc_roc: 0.4925
# Epoch 74/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5903 - accuracy: 0.7256 - auc_roc: 0.4905
# Epoch 75/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5891 - accuracy: 0.7306 - auc_roc: 0.4786
# Epoch 76/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5795 - accuracy: 0.7341 - auc_roc: 0.5280
# Epoch 77/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5762 - accuracy: 0.7387 - auc_roc: 0.4836
# Epoch 78/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5823 - accuracy: 0.7339 - auc_roc: 0.4761
# Epoch 79/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5724 - accuracy: 0.7436 - auc_roc: 0.5118
# Epoch 80/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5888 - accuracy: 0.7252 - auc_roc: 0.4923
# Epoch 81/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5863 - accuracy: 0.7298 - auc_roc: 0.4475
# Epoch 82/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5841 - accuracy: 0.7306 - auc_roc: 0.4845
# Epoch 83/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5696 - accuracy: 0.7454 - auc_roc: 0.5074
# Epoch 84/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5734 - accuracy: 0.7406 - auc_roc: 0.4864
# Epoch 85/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5686 - accuracy: 0.7459 - auc_roc: 0.4706
# Epoch 86/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5946 - accuracy: 0.7218 - auc_roc: 0.4955
# Epoch 87/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5780 - accuracy: 0.7372 - auc_roc: 0.4833
# Epoch 88/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5880 - accuracy: 0.7291 - auc_roc: 0.4912
# Epoch 89/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5835 - accuracy: 0.7313 - auc_roc: 0.4841
# Epoch 90/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5597 - accuracy: 0.7535 - auc_roc: 0.4757
# Epoch 91/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5807 - accuracy: 0.7347 - auc_roc: 0.4576
# Epoch 92/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5741 - accuracy: 0.7400 - auc_roc: 0.5031
# Epoch 93/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5761 - accuracy: 0.7375 - auc_roc: 0.4981
# Epoch 94/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5648 - accuracy: 0.7493 - auc_roc: 0.5117
# Epoch 95/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5860 - accuracy: 0.7274 - auc_roc: 0.4920
# Epoch 96/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5667 - accuracy: 0.7465 - auc_roc: 0.4790
# Epoch 97/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5811 - accuracy: 0.7353 - auc_roc: 0.4793
# Epoch 98/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5809 - accuracy: 0.7353 - auc_roc: 0.4895
# Epoch 99/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5850 - accuracy: 0.7291 - auc_roc: 0.4656
# Epoch 100/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5684 - accuracy: 0.7457 - auc_roc: 0.4933
# 43/43 [==============================] - 0s 2ms/step - loss: 0.6052 - accuracy: 0.7071 - auc_roc: 0.4972
# Epoch 1/100
# 85/85 [==============================] - 1s 3ms/step - loss: 702.1430 - accuracy: 0.6410 - auc_roc: 0.5128
# Epoch 2/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5883 - accuracy: 0.7265 - auc_roc: 0.4997
# Epoch 3/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5894 - accuracy: 0.7247 - auc_roc: 0.4940
# Epoch 4/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5903 - accuracy: 0.7251 - auc_roc: 0.4803
# Epoch 5/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5986 - accuracy: 0.7171 - auc_roc: 0.4906
# Epoch 6/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5847 - accuracy: 0.7305 - auc_roc: 0.4770
# Epoch 7/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5996 - accuracy: 0.7133 - auc_roc: 0.4843
# Epoch 8/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5732 - accuracy: 0.7397 - auc_roc: 0.5002
# Epoch 9/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5829 - accuracy: 0.7322 - auc_roc: 0.4909
# Epoch 10/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5868 - accuracy: 0.7287 - auc_roc: 0.4684
# Epoch 11/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6035 - accuracy: 0.7111 - auc_roc: 0.4897
# Epoch 12/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5892 - accuracy: 0.7270 - auc_roc: 0.4679
# Epoch 13/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5944 - accuracy: 0.7194 - auc_roc: 0.4848
# Epoch 14/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5869 - accuracy: 0.7268 - auc_roc: 0.4768
# Epoch 15/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6008 - accuracy: 0.7117 - auc_roc: 0.4989
# Epoch 16/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6013 - accuracy: 0.7128 - auc_roc: 0.4651
# Epoch 17/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6000 - accuracy: 0.7147 - auc_roc: 0.4991
# Epoch 18/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5905 - accuracy: 0.7241 - auc_roc: 0.4863
# Epoch 19/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6000 - accuracy: 0.7159 - auc_roc: 0.4989
# Epoch 20/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6006 - accuracy: 0.7170 - auc_roc: 0.4992
# Epoch 21/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5906 - accuracy: 0.7232 - auc_roc: 0.4929
# Epoch 22/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6153 - accuracy: 0.7079 - auc_roc: 0.4808
# Epoch 23/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6034 - accuracy: 0.7131 - auc_roc: 0.4700
# Epoch 24/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5998 - accuracy: 0.7137 - auc_roc: 0.4944
# Epoch 25/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6071 - accuracy: 0.7111 - auc_roc: 0.4672
# Epoch 26/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.6000 - accuracy: 0.7135 - auc_roc: 0.4897
# Epoch 27/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5974 - accuracy: 0.7168 - auc_roc: 0.4817
# Epoch 28/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5901 - accuracy: 0.7236 - auc_roc: 0.4876
# Epoch 29/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5998 - accuracy: 0.7176 - auc_roc: 0.4788
# Epoch 30/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5956 - accuracy: 0.7185 - auc_roc: 0.4891
# Epoch 31/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5947 - accuracy: 0.7194 - auc_roc: 0.4849
# Epoch 32/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5906 - accuracy: 0.7261 - auc_roc: 0.4781
# Epoch 33/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5874 - accuracy: 0.7275 - auc_roc: 0.4829
# Epoch 34/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5944 - accuracy: 0.7195 - auc_roc: 0.4874
# Epoch 35/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5981 - accuracy: 0.7167 - auc_roc: 0.4915
# Epoch 36/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5927 - accuracy: 0.7219 - auc_roc: 0.4818
# Epoch 37/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5949 - accuracy: 0.7180 - auc_roc: 0.5067
# Epoch 38/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5926 - accuracy: 0.7227 - auc_roc: 0.4863
# Epoch 39/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5835 - accuracy: 0.7301 - auc_roc: 0.5116
# Epoch 40/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5997 - accuracy: 0.7181 - auc_roc: 0.4868
# Epoch 41/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5942 - accuracy: 0.7206 - auc_roc: 0.4922
# Epoch 42/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5876 - accuracy: 0.7262 - auc_roc: 0.4794
# Epoch 43/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6000 - accuracy: 0.7134 - auc_roc: 0.5190
# Epoch 44/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5960 - accuracy: 0.7188 - auc_roc: 0.4849
# Epoch 45/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5872 - accuracy: 0.7275 - auc_roc: 0.4819
# Epoch 46/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5748 - accuracy: 0.7391 - auc_roc: 0.4854
# Epoch 47/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5898 - accuracy: 0.7265 - auc_roc: 0.4944
# Epoch 48/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5974 - accuracy: 0.7151 - auc_roc: 0.5046
# Epoch 49/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5906 - accuracy: 0.7249 - auc_roc: 0.4634
# Epoch 50/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5899 - accuracy: 0.7257 - auc_roc: 0.4733
# Epoch 51/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5807 - accuracy: 0.7352 - auc_roc: 0.4746
# Epoch 52/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6004 - accuracy: 0.7147 - auc_roc: 0.4882
# Epoch 53/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6011 - accuracy: 0.7118 - auc_roc: 0.4830
# Epoch 54/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5949 - accuracy: 0.7196 - auc_roc: 0.4844
# Epoch 55/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5924 - accuracy: 0.7223 - auc_roc: 0.4801
# Epoch 56/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5973 - accuracy: 0.7167 - auc_roc: 0.4776
# Epoch 57/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5919 - accuracy: 0.7246 - auc_roc: 0.4826
# Epoch 58/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5889 - accuracy: 0.7246 - auc_roc: 0.4929
# Epoch 59/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5951 - accuracy: 0.7194 - auc_roc: 0.4958
# Epoch 60/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6038 - accuracy: 0.7097 - auc_roc: 0.4884
# Epoch 61/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5860 - accuracy: 0.7283 - auc_roc: 0.4837
# Epoch 62/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6054 - accuracy: 0.7081 - auc_roc: 0.4900
# Epoch 63/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6078 - accuracy: 0.7125 - auc_roc: 0.4747
# Epoch 64/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5962 - accuracy: 0.7182 - auc_roc: 0.4758
# Epoch 65/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5922 - accuracy: 0.7227 - auc_roc: 0.4653
# Epoch 66/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5933 - accuracy: 0.7218 - auc_roc: 0.4796
# Epoch 67/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5949 - accuracy: 0.7210 - auc_roc: 0.4966
# Epoch 68/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5805 - accuracy: 0.7337 - auc_roc: 0.4935
# Epoch 69/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6046 - accuracy: 0.7091 - auc_roc: 0.4988
# Epoch 70/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5886 - accuracy: 0.7257 - auc_roc: 0.4898
# Epoch 71/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5914 - accuracy: 0.7240 - auc_roc: 0.4777
# Epoch 72/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6013 - accuracy: 0.7124 - auc_roc: 0.5016
# Epoch 73/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6116 - accuracy: 0.7058 - auc_roc: 0.4737
# Epoch 74/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5831 - accuracy: 0.7300 - auc_roc: 0.5129
# Epoch 75/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5833 - accuracy: 0.7317 - auc_roc: 0.4677
# Epoch 76/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5932 - accuracy: 0.7207 - auc_roc: 0.4910
# Epoch 77/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5932 - accuracy: 0.7220 - auc_roc: 0.4831
# Epoch 78/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5940 - accuracy: 0.7216 - auc_roc: 0.4972
# Epoch 79/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5894 - accuracy: 0.7244 - auc_roc: 0.5059
# Epoch 80/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5897 - accuracy: 0.7265 - auc_roc: 0.4824
# Epoch 81/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5823 - accuracy: 0.7361 - auc_roc: 0.4534
# Epoch 82/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5868 - accuracy: 0.7289 - auc_roc: 0.4893
# Epoch 83/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5914 - accuracy: 0.7224 - auc_roc: 0.4986
# Epoch 84/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5829 - accuracy: 0.7318 - auc_roc: 0.4875
# Epoch 85/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5986 - accuracy: 0.7144 - auc_roc: 0.5000
# Epoch 86/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5909 - accuracy: 0.7264 - auc_roc: 0.4807
# Epoch 87/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5918 - accuracy: 0.7232 - auc_roc: 0.4938
# Epoch 88/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6014 - accuracy: 0.7137 - auc_roc: 0.4697
# Epoch 89/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5834 - accuracy: 0.7338 - auc_roc: 0.4840
# Epoch 90/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5800 - accuracy: 0.7336 - auc_roc: 0.4905
# Epoch 91/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5983 - accuracy: 0.7149 - auc_roc: 0.4871
# Epoch 92/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5736 - accuracy: 0.7395 - auc_roc: 0.4962
# Epoch 93/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.6035 - accuracy: 0.7122 - auc_roc: 0.4626
# Epoch 94/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5987 - accuracy: 0.7188 - auc_roc: 0.4799
# Epoch 95/100
# 85/85 [==============================] - 0s 4ms/step - loss: 0.5915 - accuracy: 0.7246 - auc_roc: 0.4988
# Epoch 96/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5844 - accuracy: 0.7306 - auc_roc: 0.4845
# Epoch 97/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5933 - accuracy: 0.7224 - auc_roc: 0.4739
# Epoch 98/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5965 - accuracy: 0.7187 - auc_roc: 0.5023
# Epoch 99/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5940 - accuracy: 0.7198 - auc_roc: 0.5086
# Epoch 100/100
# 85/85 [==============================] - 0s 3ms/step - loss: 0.5898 - accuracy: 0.7241 - auc_roc: 0.4821
# 43/43 [==============================] - 0s 3ms/step - loss: 0.6643 - accuracy: 0.7386 - auc_roc: 0.4990
# Epoch 1/50
# 22/22 [==============================] - 1s 14ms/step - loss: 23.8025 - accuracy: 0.6160 - auc_roc: 0.5033
# Epoch 2/50
# 22/22 [==============================] - 0s 16ms/step - loss: 5.2507 - accuracy: 0.6465 - auc_roc: 0.5225
# Epoch 3/50
# 22/22 [==============================] - 0s 16ms/step - loss: 2.5550 - accuracy: 0.6342 - auc_roc: 0.5358
# Epoch 4/50
# 22/22 [==============================] - 0s 15ms/step - loss: 2.5911 - accuracy: 0.6301 - auc_roc: 0.5264
# Epoch 5/50
# 22/22 [==============================] - 0s 14ms/step - loss: 1.7666 - accuracy: 0.6109 - auc_roc: 0.5840
# Epoch 6/50
# 22/22 [==============================] - 0s 13ms/step - loss: 2.2495 - accuracy: 0.6491 - auc_roc: 0.5638
# Epoch 7/50
# 22/22 [==============================] - 0s 13ms/step - loss: 1.8401 - accuracy: 0.6456 - auc_roc: 0.5795
# Epoch 8/50
# 22/22 [==============================] - 0s 13ms/step - loss: 1.3060 - accuracy: 0.6586 - auc_roc: 0.6158
# Epoch 9/50
# 22/22 [==============================] - 0s 13ms/step - loss: 2.3115 - accuracy: 0.6245 - auc_roc: 0.5648
# Epoch 10/50
# 22/22 [==============================] - 0s 13ms/step - loss: 1.8126 - accuracy: 0.6357 - auc_roc: 0.5750
# Epoch 11/50
# 22/22 [==============================] - 0s 13ms/step - loss: 1.2615 - accuracy: 0.6565 - auc_roc: 0.5719
# Epoch 12/50
# 22/22 [==============================] - 0s 13ms/step - loss: 1.3709 - accuracy: 0.6790 - auc_roc: 0.6092
# Epoch 13/50
# 22/22 [==============================] - 0s 13ms/step - loss: 1.8545 - accuracy: 0.6265 - auc_roc: 0.5693
# Epoch 14/50
# 22/22 [==============================] - 0s 13ms/step - loss: 1.1715 - accuracy: 0.6520 - auc_roc: 0.6145
# Epoch 15/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.9223 - accuracy: 0.6847 - auc_roc: 0.6430
# Epoch 16/50
# 22/22 [==============================] - 0s 13ms/step - loss: 1.4717 - accuracy: 0.6532 - auc_roc: 0.6055
# Epoch 17/50
# 22/22 [==============================] - 0s 14ms/step - loss: 1.0752 - accuracy: 0.6663 - auc_roc: 0.6216
# Epoch 18/50
# 22/22 [==============================] - 0s 14ms/step - loss: 1.4222 - accuracy: 0.6340 - auc_roc: 0.5957
# Epoch 19/50
# 22/22 [==============================] - 0s 15ms/step - loss: 0.9922 - accuracy: 0.6849 - auc_roc: 0.6509
# Epoch 20/50
# 22/22 [==============================] - 0s 16ms/step - loss: 1.2499 - accuracy: 0.6632 - auc_roc: 0.6265
# Epoch 21/50
# 22/22 [==============================] - 0s 15ms/step - loss: 1.0821 - accuracy: 0.6656 - auc_roc: 0.6350
# Epoch 22/50
# 22/22 [==============================] - 0s 16ms/step - loss: 1.1834 - accuracy: 0.6538 - auc_roc: 0.6481
# Epoch 23/50
# 22/22 [==============================] - 0s 15ms/step - loss: 1.4487 - accuracy: 0.6324 - auc_roc: 0.6338
# Epoch 24/50
# 22/22 [==============================] - 0s 16ms/step - loss: 0.7759 - accuracy: 0.7073 - auc_roc: 0.6770
# Epoch 25/50
# 22/22 [==============================] - 0s 15ms/step - loss: 1.0125 - accuracy: 0.6721 - auc_roc: 0.6619
# Epoch 26/50
# 22/22 [==============================] - 0s 15ms/step - loss: 1.0186 - accuracy: 0.6713 - auc_roc: 0.6405
# Epoch 27/50
# 22/22 [==============================] - 0s 15ms/step - loss: 0.6265 - accuracy: 0.7263 - auc_roc: 0.6997
# Epoch 28/50
# 22/22 [==============================] - 0s 14ms/step - loss: 0.8177 - accuracy: 0.6815 - auc_roc: 0.6718
# Epoch 29/50
# 22/22 [==============================] - 0s 15ms/step - loss: 0.7435 - accuracy: 0.7198 - auc_roc: 0.6928
# Epoch 30/50
# 22/22 [==============================] - 0s 15ms/step - loss: 0.9570 - accuracy: 0.6787 - auc_roc: 0.6512
# Epoch 31/50
# 22/22 [==============================] - 0s 14ms/step - loss: 0.8626 - accuracy: 0.6935 - auc_roc: 0.6722
# Epoch 32/50
# 22/22 [==============================] - 0s 14ms/step - loss: 1.3837 - accuracy: 0.6295 - auc_roc: 0.6268
# Epoch 33/50
# 22/22 [==============================] - 0s 14ms/step - loss: 0.9452 - accuracy: 0.6788 - auc_roc: 0.6787
# Epoch 34/50
# 22/22 [==============================] - 0s 14ms/step - loss: 1.1242 - accuracy: 0.6581 - auc_roc: 0.6672
# Epoch 35/50
# 22/22 [==============================] - 0s 14ms/step - loss: 0.6301 - accuracy: 0.7216 - auc_roc: 0.7074
# Epoch 36/50
# 22/22 [==============================] - 0s 14ms/step - loss: 0.8128 - accuracy: 0.7103 - auc_roc: 0.6739
# Epoch 37/50
# 22/22 [==============================] - 0s 15ms/step - loss: 1.0341 - accuracy: 0.6973 - auc_roc: 0.6598
# Epoch 38/50
# 22/22 [==============================] - 0s 15ms/step - loss: 2.3201 - accuracy: 0.6175 - auc_roc: 0.5839
# Epoch 39/50
# 22/22 [==============================] - 0s 14ms/step - loss: 1.2451 - accuracy: 0.6933 - auc_roc: 0.6492
# Epoch 40/50
# 22/22 [==============================] - 0s 14ms/step - loss: 0.8137 - accuracy: 0.6792 - auc_roc: 0.6804
# Epoch 41/50
# 22/22 [==============================] - 0s 15ms/step - loss: 0.9603 - accuracy: 0.6666 - auc_roc: 0.6594
# Epoch 42/50
# 22/22 [==============================] - 0s 15ms/step - loss: 0.6257 - accuracy: 0.7550 - auc_roc: 0.7460
# Epoch 43/50
# 22/22 [==============================] - 0s 14ms/step - loss: 0.6855 - accuracy: 0.7296 - auc_roc: 0.7152
# Epoch 44/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.7646 - accuracy: 0.7042 - auc_roc: 0.6919
# Epoch 45/50
# 22/22 [==============================] - 0s 14ms/step - loss: 0.5545 - accuracy: 0.7530 - auc_roc: 0.7550
# Epoch 46/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.5449 - accuracy: 0.7602 - auc_roc: 0.7496
# Epoch 47/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.5743 - accuracy: 0.7510 - auc_roc: 0.7362
# Epoch 48/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.4996 - accuracy: 0.7721 - auc_roc: 0.7854
# Epoch 49/50
# 22/22 [==============================] - 0s 14ms/step - loss: 0.8114 - accuracy: 0.6836 - auc_roc: 0.6887
# Epoch 50/50
# 22/22 [==============================] - 0s 14ms/step - loss: 0.6840 - accuracy: 0.7270 - auc_roc: 0.7183
# 11/11 [==============================] - 0s 13ms/step - loss: 1.2816 - accuracy: 0.7255 - auc_roc: 0.5172
# Epoch 1/50
# 22/22 [==============================] - 1s 13ms/step - loss: 22.1914 - accuracy: 0.6149 - auc_roc: 0.5200
# Epoch 2/50
# 22/22 [==============================] - 0s 13ms/step - loss: 3.4154 - accuracy: 0.6159 - auc_roc: 0.5416
# Epoch 3/50
# 22/22 [==============================] - 0s 13ms/step - loss: 2.3910 - accuracy: 0.6138 - auc_roc: 0.5523
# Epoch 4/50
# 22/22 [==============================] - 0s 13ms/step - loss: 1.3571 - accuracy: 0.6636 - auc_roc: 0.5813
# Epoch 5/50
# 22/22 [==============================] - 0s 13ms/step - loss: 1.4583 - accuracy: 0.6608 - auc_roc: 0.5716
# Epoch 6/50
# 22/22 [==============================] - 0s 13ms/step - loss: 2.4514 - accuracy: 0.6152 - auc_roc: 0.5851
# Epoch 7/50
# 22/22 [==============================] - 0s 13ms/step - loss: 1.1427 - accuracy: 0.6771 - auc_roc: 0.6294
# Epoch 8/50
# 22/22 [==============================] - 0s 13ms/step - loss: 2.2559 - accuracy: 0.6134 - auc_roc: 0.5438
# Epoch 9/50
# 22/22 [==============================] - 0s 13ms/step - loss: 1.7695 - accuracy: 0.6674 - auc_roc: 0.5957
# Epoch 10/50
# 22/22 [==============================] - 0s 13ms/step - loss: 1.1805 - accuracy: 0.6784 - auc_roc: 0.6065
# Epoch 11/50
# 22/22 [==============================] - 0s 13ms/step - loss: 1.1761 - accuracy: 0.6847 - auc_roc: 0.6242
# Epoch 12/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.9313 - accuracy: 0.6836 - auc_roc: 0.6201
# Epoch 13/50
# 22/22 [==============================] - 0s 13ms/step - loss: 1.7945 - accuracy: 0.6682 - auc_roc: 0.5935
# Epoch 14/50
# 22/22 [==============================] - 0s 14ms/step - loss: 1.3814 - accuracy: 0.6997 - auc_roc: 0.6099
# Epoch 15/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.8355 - accuracy: 0.7131 - auc_roc: 0.6548
# Epoch 16/50
# 22/22 [==============================] - 0s 13ms/step - loss: 1.3123 - accuracy: 0.6918 - auc_roc: 0.6292
# Epoch 17/50
# 22/22 [==============================] - 0s 13ms/step - loss: 1.8916 - accuracy: 0.6704 - auc_roc: 0.6043
# Epoch 18/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.7354 - accuracy: 0.7305 - auc_roc: 0.6784
# Epoch 19/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.8614 - accuracy: 0.6978 - auc_roc: 0.6436
# Epoch 20/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.9021 - accuracy: 0.7171 - auc_roc: 0.6672
# Epoch 21/50
# 22/22 [==============================] - 0s 13ms/step - loss: 1.4587 - accuracy: 0.6994 - auc_roc: 0.6489
# Epoch 22/50
# 22/22 [==============================] - 0s 14ms/step - loss: 2.5326 - accuracy: 0.6803 - auc_roc: 0.5800
# Epoch 23/50
# 22/22 [==============================] - 0s 14ms/step - loss: 1.0134 - accuracy: 0.6786 - auc_roc: 0.6440
# Epoch 24/50
# 22/22 [==============================] - 0s 14ms/step - loss: 1.2244 - accuracy: 0.6811 - auc_roc: 0.6428
# Epoch 25/50
# 22/22 [==============================] - 0s 14ms/step - loss: 0.6651 - accuracy: 0.7408 - auc_roc: 0.7006
# Epoch 26/50
# 22/22 [==============================] - 0s 14ms/step - loss: 0.6498 - accuracy: 0.7293 - auc_roc: 0.6881
# Epoch 27/50
# 22/22 [==============================] - 0s 14ms/step - loss: 1.6942 - accuracy: 0.6445 - auc_roc: 0.6257
# Epoch 28/50
# 22/22 [==============================] - 0s 14ms/step - loss: 0.8298 - accuracy: 0.7146 - auc_roc: 0.6694
# Epoch 29/50
# 22/22 [==============================] - 0s 13ms/step - loss: 1.0815 - accuracy: 0.6558 - auc_roc: 0.6646
# Epoch 30/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.8174 - accuracy: 0.7046 - auc_roc: 0.6924
# Epoch 31/50
# 22/22 [==============================] - 0s 14ms/step - loss: 0.5338 - accuracy: 0.7680 - auc_roc: 0.7428
# Epoch 32/50
# 22/22 [==============================] - 0s 14ms/step - loss: 0.7721 - accuracy: 0.7021 - auc_roc: 0.6824
# Epoch 33/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.8389 - accuracy: 0.7143 - auc_roc: 0.6617
# Epoch 34/50
# 22/22 [==============================] - 0s 14ms/step - loss: 0.7363 - accuracy: 0.7209 - auc_roc: 0.6951
# Epoch 35/50
# 22/22 [==============================] - 0s 14ms/step - loss: 0.7080 - accuracy: 0.7116 - auc_roc: 0.7033
# Epoch 36/50
# 22/22 [==============================] - 0s 16ms/step - loss: 1.1534 - accuracy: 0.6690 - auc_roc: 0.6489
# Epoch 37/50
# 22/22 [==============================] - 0s 15ms/step - loss: 0.5527 - accuracy: 0.7665 - auc_roc: 0.7476
# Epoch 38/50
# 22/22 [==============================] - 0s 15ms/step - loss: 1.0922 - accuracy: 0.7068 - auc_roc: 0.6801
# Epoch 39/50
# 22/22 [==============================] - 0s 15ms/step - loss: 1.2156 - accuracy: 0.6610 - auc_roc: 0.6473
# Epoch 40/50
# 22/22 [==============================] - 0s 15ms/step - loss: 0.8734 - accuracy: 0.7196 - auc_roc: 0.6804
# Epoch 41/50
# 22/22 [==============================] - 0s 15ms/step - loss: 0.6638 - accuracy: 0.7382 - auc_roc: 0.7157
# Epoch 42/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.5100 - accuracy: 0.7719 - auc_roc: 0.7640
# Epoch 43/50
# 22/22 [==============================] - 0s 14ms/step - loss: 0.7343 - accuracy: 0.7130 - auc_roc: 0.7152
# Epoch 44/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.8525 - accuracy: 0.6990 - auc_roc: 0.6819
# Epoch 45/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.5116 - accuracy: 0.7586 - auc_roc: 0.7675
# Epoch 46/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.9203 - accuracy: 0.6640 - auc_roc: 0.6738
# Epoch 47/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.4942 - accuracy: 0.7675 - auc_roc: 0.7845
# Epoch 48/50
# 22/22 [==============================] - 0s 13ms/step - loss: 0.4914 - accuracy: 0.7849 - auc_roc: 0.7829
# Epoch 49/50
# 22/22 [==============================] - 0s 14ms/step - loss: 0.6247 - accuracy: 0.7402 - auc_roc: 0.7291
# Epoch 50/50
# 22/22 [==============================] - 0s 14ms/step - loss: 0.6046 - accuracy: 0.7615 - auc_roc: 0.7549
# 11/11 [==============================] - 0s 13ms/step - loss: 1.1374 - accuracy: 0.6667 - auc_roc: 0.4992
# Epoch 1/50
# 22/22 [==============================] - 1s 14ms/step - loss: 20.0293 - accuracy: 0.6141 - auc_roc: 0.5201
# Epoch 2/50
# 22/22 [==============================] - 0s 14ms/step - loss: 5.5225 - accuracy: 0.5796 - auc_roc: 0.5177
# Epoch 3/50
# ...
# Epoch 68/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5800 - accuracy: 0.7343 - auc_roc: 0.4867
# Epoch 69/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5879 - accuracy: 0.7265 - auc_roc: 0.5001
# Epoch 70/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5900 - accuracy: 0.7249 - auc_roc: 0.4965
# Epoch 71/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5842 - accuracy: 0.7311 - auc_roc: 0.4863
# Epoch 72/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5841 - accuracy: 0.7297 - auc_roc: 0.5021
# Epoch 73/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.5885 - accuracy: 0.7264 - auc_roc: 0.4964
# Epoch 74/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.5857 - accuracy: 0.7284 - auc_roc: 0.4883
# Epoch 75/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5994 - accuracy: 0.7145 - auc_roc: 0.4765
# Epoch 76/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.5947 - accuracy: 0.7196 - auc_roc: 0.4859
# Epoch 77/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.5753 - accuracy: 0.7385 - auc_roc: 0.4921
# Epoch 78/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5852 - accuracy: 0.7288 - auc_roc: 0.4988
# Epoch 79/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.5828 - accuracy: 0.7316 - auc_roc: 0.4837
# Epoch 80/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.5851 - accuracy: 0.7299 - auc_roc: 0.4918
# Epoch 81/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.5796 - accuracy: 0.7346 - auc_roc: 0.5000
# Epoch 82/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5983 - accuracy: 0.7151 - auc_roc: 0.5039
# Epoch 83/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.5942 - accuracy: 0.7221 - auc_roc: 0.4910
# Epoch 84/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.5825 - accuracy: 0.7311 - auc_roc: 0.5064
# Epoch 85/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.5838 - accuracy: 0.7301 - auc_roc: 0.4960
# Epoch 86/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5902 - accuracy: 0.7238 - auc_roc: 0.5021
# Epoch 87/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5848 - accuracy: 0.7290 - auc_roc: 0.5011
# Epoch 88/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5807 - accuracy: 0.7350 - auc_roc: 0.4831
# Epoch 89/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5906 - accuracy: 0.7233 - auc_roc: 0.4834
# Epoch 90/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5887 - accuracy: 0.7250 - auc_roc: 0.4937
# Epoch 91/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.5866 - accuracy: 0.7271 - auc_roc: 0.4796
# Epoch 92/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.5884 - accuracy: 0.7275 - auc_roc: 0.4858
# Epoch 93/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5896 - accuracy: 0.7244 - auc_roc: 0.4861
# Epoch 94/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.5850 - accuracy: 0.7286 - auc_roc: 0.4858
# Epoch 95/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.5942 - accuracy: 0.7189 - auc_roc: 0.4975
# Epoch 96/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5814 - accuracy: 0.7331 - auc_roc: 0.4968
# Epoch 97/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5874 - accuracy: 0.7263 - auc_roc: 0.4925
# Epoch 98/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5890 - accuracy: 0.7245 - auc_roc: 0.4967
# Epoch 99/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.5848 - accuracy: 0.7287 - auc_roc: 0.4826
# Epoch 100/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.5820 - accuracy: 0.7319 - auc_roc: 0.4915
# Epoch 101/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.5909 - accuracy: 0.7231 - auc_roc: 0.4935
# Epoch 102/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.5782 - accuracy: 0.7382 - auc_roc: 0.4873
# Epoch 103/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.5909 - accuracy: 0.7242 - auc_roc: 0.5057
# Epoch 104/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5924 - accuracy: 0.7218 - auc_roc: 0.4973
# Epoch 105/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5984 - accuracy: 0.7178 - auc_roc: 0.4843
# Epoch 106/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.5776 - accuracy: 0.7360 - auc_roc: 0.4997
# Epoch 107/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5872 - accuracy: 0.7271 - auc_roc: 0.5031
# Epoch 108/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.5948 - accuracy: 0.7196 - auc_roc: 0.4980
# Epoch 109/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.5869 - accuracy: 0.7290 - auc_roc: 0.5084
# Epoch 110/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.5943 - accuracy: 0.7210 - auc_roc: 0.4885
# Epoch 111/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5842 - accuracy: 0.7306 - auc_roc: 0.4936
# Epoch 112/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.5839 - accuracy: 0.7300 - auc_roc: 0.4795
# Epoch 113/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.5918 - accuracy: 0.7218 - auc_roc: 0.4928
# Epoch 114/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5848 - accuracy: 0.7296 - auc_roc: 0.4881
# Epoch 115/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5982 - accuracy: 0.7151 - auc_roc: 0.4858
# Epoch 116/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.5827 - accuracy: 0.7310 - auc_roc: 0.4977
# Epoch 117/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.5924 - accuracy: 0.7209 - auc_roc: 0.4785
# Epoch 118/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.5809 - accuracy: 0.7330 - auc_roc: 0.4775
# Epoch 119/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5821 - accuracy: 0.7326 - auc_roc: 0.4778
# Epoch 120/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5938 - accuracy: 0.7194 - auc_roc: 0.4851
# Epoch 121/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.5905 - accuracy: 0.7254 - auc_roc: 0.4695
# Epoch 122/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5903 - accuracy: 0.7234 - auc_roc: 0.4951
# Epoch 123/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.5816 - accuracy: 0.7322 - auc_roc: 0.4896
# Epoch 124/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5812 - accuracy: 0.7328 - auc_roc: 0.4929
# Epoch 125/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.5815 - accuracy: 0.7330 - auc_roc: 0.4927
# Epoch 126/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.5832 - accuracy: 0.7316 - auc_roc: 0.4950
# Epoch 127/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5840 - accuracy: 0.7296 - auc_roc: 0.4947
# Epoch 128/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5843 - accuracy: 0.7296 - auc_roc: 0.4766
# Epoch 129/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.5811 - accuracy: 0.7332 - auc_roc: 0.4860
# Epoch 130/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.5891 - accuracy: 0.7264 - auc_roc: 0.5081
# Epoch 131/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.5961 - accuracy: 0.7212 - auc_roc: 0.4753
# Epoch 132/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5799 - accuracy: 0.7333 - auc_roc: 0.5106
# Epoch 133/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.5975 - accuracy: 0.7150 - auc_roc: 0.4941
# Epoch 134/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.5879 - accuracy: 0.7259 - auc_roc: 0.5001
# Epoch 135/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.5742 - accuracy: 0.7401 - auc_roc: 0.4833
# Epoch 136/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5922 - accuracy: 0.7207 - auc_roc: 0.5173
# Epoch 137/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5862 - accuracy: 0.7276 - auc_roc: 0.4978
# Epoch 138/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.5899 - accuracy: 0.7253 - auc_roc: 0.4668
# Epoch 139/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.5833 - accuracy: 0.7332 - auc_roc: 0.4948
# Epoch 140/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.5918 - accuracy: 0.7223 - auc_roc: 0.4999
# Epoch 141/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.5890 - accuracy: 0.7264 - auc_roc: 0.4841
# Epoch 142/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.5816 - accuracy: 0.7325 - auc_roc: 0.4863
# Epoch 143/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5943 - accuracy: 0.7187 - auc_roc: 0.4903
# Epoch 144/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.5890 - accuracy: 0.7245 - auc_roc: 0.4835
# Epoch 145/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.5828 - accuracy: 0.7316 - auc_roc: 0.4802
# Epoch 146/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5920 - accuracy: 0.7209 - auc_roc: 0.5020
# Epoch 147/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.5805 - accuracy: 0.7330 - auc_roc: 0.4911
# Epoch 148/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.5831 - accuracy: 0.7318 - auc_roc: 0.4956
# Epoch 149/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.5880 - accuracy: 0.7262 - auc_roc: 0.4935
# Epoch 150/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.5834 - accuracy: 0.7305 - auc_roc: 0.4750
# Epoch 151/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.5947 - accuracy: 0.7191 - auc_roc: 0.4880
# Epoch 152/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5907 - accuracy: 0.7240 - auc_roc: 0.4990
# Epoch 153/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.5825 - accuracy: 0.7316 - auc_roc: 0.4981
# Epoch 154/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.5804 - accuracy: 0.7359 - auc_roc: 0.4779
# Epoch 155/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.5901 - accuracy: 0.7234 - auc_roc: 0.5035
# Epoch 156/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5915 - accuracy: 0.7237 - auc_roc: 0.4842
# Epoch 157/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.5851 - accuracy: 0.7287 - auc_roc: 0.4894
# Epoch 158/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.5837 - accuracy: 0.7299 - auc_roc: 0.4871
# Epoch 159/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.5919 - accuracy: 0.7218 - auc_roc: 0.4922
# Epoch 160/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5766 - accuracy: 0.7370 - auc_roc: 0.4971
# Epoch 161/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.5922 - accuracy: 0.7214 - auc_roc: 0.5082
# Epoch 162/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.5890 - accuracy: 0.7247 - auc_roc: 0.4954
# Epoch 163/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5772 - accuracy: 0.7360 - auc_roc: 0.4920
# Epoch 164/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.5833 - accuracy: 0.7334 - auc_roc: 0.4953
# Epoch 165/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.5852 - accuracy: 0.7292 - auc_roc: 0.5021
# Epoch 166/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5757 - accuracy: 0.7375 - auc_roc: 0.4948
# Epoch 167/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5947 - accuracy: 0.7185 - auc_roc: 0.4973
# Epoch 168/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5769 - accuracy: 0.7370 - auc_roc: 0.4962
# Epoch 169/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.5929 - accuracy: 0.7225 - auc_roc: 0.4962
# Epoch 170/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.5910 - accuracy: 0.7232 - auc_roc: 0.4943
# Epoch 171/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.5844 - accuracy: 0.7292 - auc_roc: 0.5022
# Epoch 172/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5841 - accuracy: 0.7299 - auc_roc: 0.4862
# Epoch 173/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5916 - accuracy: 0.7220 - auc_roc: 0.5086
# Epoch 174/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.5782 - accuracy: 0.7354 - auc_roc: 0.4831
# Epoch 175/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.5891 - accuracy: 0.7252 - auc_roc: 0.4856
# Epoch 176/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.5829 - accuracy: 0.7304 - auc_roc: 0.5009
# Epoch 177/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.5914 - accuracy: 0.7237 - auc_roc: 0.4907
# Epoch 178/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.5915 - accuracy: 0.7225 - auc_roc: 0.4859
# Epoch 179/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.5903 - accuracy: 0.7232 - auc_roc: 0.4936
# Epoch 180/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.5894 - accuracy: 0.7241 - auc_roc: 0.4980
# Epoch 181/200
# 16/16 [==============================] - 1s 31ms/step - loss: 0.5814 - accuracy: 0.7320 - auc_roc: 0.5001
# Epoch 182/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.5898 - accuracy: 0.7237 - auc_roc: 0.4847
# Epoch 183/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.5848 - accuracy: 0.7285 - auc_roc: 0.5076
# Epoch 184/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.5782 - accuracy: 0.7355 - auc_roc: 0.5018
# Epoch 185/200
# 16/16 [==============================] - 0s 29ms/step - loss: 0.5897 - accuracy: 0.7251 - auc_roc: 0.4927
# Epoch 186/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.5947 - accuracy: 0.7199 - auc_roc: 0.4847
# Epoch 187/200
# 16/16 [==============================] - 0s 29ms/step - loss: 0.5917 - accuracy: 0.7229 - auc_roc: 0.5000
# Epoch 188/200
# 16/16 [==============================] - 0s 29ms/step - loss: 0.5939 - accuracy: 0.7201 - auc_roc: 0.5038
# Epoch 189/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.5867 - accuracy: 0.7274 - auc_roc: 0.4918
# Epoch 190/200
# 16/16 [==============================] - 0s 29ms/step - loss: 0.5846 - accuracy: 0.7297 - auc_roc: 0.4997
# Epoch 191/200
# 16/16 [==============================] - 0s 29ms/step - loss: 0.5871 - accuracy: 0.7275 - auc_roc: 0.4967
# Epoch 192/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.5841 - accuracy: 0.7296 - auc_roc: 0.4850
# Epoch 193/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.5888 - accuracy: 0.7257 - auc_roc: 0.4622
# Epoch 194/200
# 16/16 [==============================] - 0s 29ms/step - loss: 0.5945 - accuracy: 0.7183 - auc_roc: 0.4967
# Epoch 195/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.5877 - accuracy: 0.7265 - auc_roc: 0.4831
# Epoch 196/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.5900 - accuracy: 0.7237 - auc_roc: 0.4860
# Epoch 197/200
# 16/16 [==============================] - 0s 30ms/step - loss: 0.6010 - accuracy: 0.7126 - auc_roc: 0.4893
# Epoch 198/200
# 16/16 [==============================] - 0s 29ms/step - loss: 0.5828 - accuracy: 0.7315 - auc_roc: 0.5028
# Epoch 199/200
# 16/16 [==============================] - 0s 29ms/step - loss: 0.5795 - accuracy: 0.7351 - auc_roc: 0.4892
# Epoch 200/200
# 16/16 [==============================] - 0s 29ms/step - loss: 0.5876 - accuracy: 0.7269 - auc_roc: 0.4914

# %%
#Print results
print("Best ACC: ",random_search_results.best_score_,random_search_results.best_params_)
# Out:
# Best ACC:  0.7269412080446879 {'learning_rate': 0.1, 'epochs': 200, 'batch_size': 256, 'activation': 'relu'}

# %%
random_search_results.mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-9c56361c5878> in <module>
# ----> 1 random_search_results.mean()
#
# AttributeError: 'RandomizedSearchCV' object has no attribute 'mean'

# %%
#Now train with the best parameters
from sklearn.model_selection import cross_val_score
# Create a KerasClassifier
model = KerasClassifier(build_fn = create_model(learning_rate = 0.1, activation = 'relu'), epochs = 200, 
                        batch_size = 256, verbose = 0)

# Calculate the accuracy score for each fold
kfolds = cross_val_score(model, df_features, mind_wandered_label, cv = 3)

# Print the mean accuracy
print(kfolds.mean())
# Out:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     826             try:
# --> 827                 tasks = self._ready_batches.get(block=False)
#     828             except queue.Empty:
#
# ~/opt/anaconda3/lib/python3.8/queue.py in get(self, block, timeout)
#     166                 if not self._qsize():
# --> 167                     raise Empty
#     168             elif timeout is None:
#
# Empty:
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-b71e5cdbbbba> in <module>
#       6
#       7 # Calculate the accuracy score for each fold
# ----> 8 kfolds = cross_val_score(model, df_features, mind_wandered_label, cv = 3)
#       9
#      10 # Print the mean accuracy
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     438     scorer = check_scoring(estimator, scoring=scoring)
#     439
# --> 440     cv_results = cross_validate(estimator=estimator, X=X, y=y, groups=groups,
#     441                                 scoring={'score': scorer}, cv=cv,
#     442                                 n_jobs=n_jobs, verbose=verbose,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     244     parallel = Parallel(n_jobs=n_jobs, verbose=verbose,
#     245                         pre_dispatch=pre_dispatch)
# --> 246     results = parallel(
#     247         delayed(_fit_and_score)(
#     248             clone(estimator), X, y, scorers, train, test, verbose, None,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1046             # remaining jobs.
#    1047             self._iterating = False
# -> 1048             if self.dispatch_one_batch(iterator):
#    1049                 self._iterating = self._original_iterator is not None
#    1050
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     836                 big_batch_size = batch_size * n_jobs
#     837
# --> 838                 islice = list(itertools.islice(iterator, big_batch_size))
#     839                 if len(islice) == 0:
#     840                     return False
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py in <genexpr>(.0)
#     246     results = parallel(
#     247         delayed(_fit_and_score)(
# --> 248             clone(estimator), X, y, scorers, train, test, verbose, None,
#     249             fit_params, return_train_score=return_train_score,
#     250             return_times=True, return_estimator=return_estimator,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py in clone(estimator, safe)
#      74     new_object_params = estimator.get_params(deep=False)
#      75     for name, param in new_object_params.items():
# ---> 76         new_object_params[name] = clone(param, safe=False)
#      77     new_object = klass(**new_object_params)
#      78     params_set = new_object.get_params(deep=False)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py in clone(estimator, safe)
#      58     elif not hasattr(estimator, 'get_params') or isinstance(estimator, type):
#      59         if not safe:
# ---> 60             return copy.deepcopy(estimator)
#      61         else:
#      62             if isinstance(estimator, type):
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~/opt/anaconda3/lib/python3.8/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~/opt/anaconda3/lib/python3.8/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~/opt/anaconda3/lib/python3.8/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~/opt/anaconda3/lib/python3.8/copy.py in _deepcopy_tuple(x, memo, deepcopy)
#     208
#     209 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 210     y = [deepcopy(a, memo) for a in x]
#     211     # We're not going to put the tuple in the memo, but it's still important we
#     212     # check for it, in case the tuple contains recursive mutable structures.
#
# ~/opt/anaconda3/lib/python3.8/copy.py in <listcomp>(.0)
#     208
#     209 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 210     y = [deepcopy(a, memo) for a in x]
#     211     # We're not going to put the tuple in the memo, but it's still important we
#     212     # check for it, in case the tuple contains recursive mutable structures.
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~/opt/anaconda3/lib/python3.8/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~/opt/anaconda3/lib/python3.8/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~/opt/anaconda3/lib/python3.8/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~/opt/anaconda3/lib/python3.8/copy.py in _deepcopy_tuple(x, memo, deepcopy)
#     208
#     209 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 210     y = [deepcopy(a, memo) for a in x]
#     211     # We're not going to put the tuple in the memo, but it's still important we
#     212     # check for it, in case the tuple contains recursive mutable structures.
#
# ~/opt/anaconda3/lib/python3.8/copy.py in <listcomp>(.0)
#     208
#     209 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 210     y = [deepcopy(a, memo) for a in x]
#     211     # We're not going to put the tuple in the memo, but it's still important we
#     212     # check for it, in case the tuple contains recursive mutable structures.
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~/opt/anaconda3/lib/python3.8/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~/opt/anaconda3/lib/python3.8/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~/opt/anaconda3/lib/python3.8/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~/opt/anaconda3/lib/python3.8/copy.py in _deepcopy_list(x, memo, deepcopy)
#     203     append = y.append
#     204     for a in x:
# --> 205         append(deepcopy(a, memo))
#     206     return y
#     207 d[list] = _deepcopy_list
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~/opt/anaconda3/lib/python3.8/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~/opt/anaconda3/lib/python3.8/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~/opt/anaconda3/lib/python3.8/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~/opt/anaconda3/lib/python3.8/copy.py in _deepcopy_tuple(x, memo, deepcopy)
#     208
#     209 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 210     y = [deepcopy(a, memo) for a in x]
#     211     # We're not going to put the tuple in the memo, but it's still important we
#     212     # check for it, in case the tuple contains recursive mutable structures.
#
# ~/opt/anaconda3/lib/python3.8/copy.py in <listcomp>(.0)
#     208
#     209 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 210     y = [deepcopy(a, memo) for a in x]
#     211     # We're not going to put the tuple in the memo, but it's still important we
#     212     # check for it, in case the tuple contains recursive mutable structures.
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~/opt/anaconda3/lib/python3.8/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~/opt/anaconda3/lib/python3.8/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~/opt/anaconda3/lib/python3.8/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~/opt/anaconda3/lib/python3.8/copy.py in _deepcopy_tuple(x, memo, deepcopy)
#     208
#     209 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 210     y = [deepcopy(a, memo) for a in x]
#     211     # We're not going to put the tuple in the memo, but it's still important we
#     212     # check for it, in case the tuple contains recursive mutable structures.
#
# ~/opt/anaconda3/lib/python3.8/copy.py in <listcomp>(.0)
#     208
#     209 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 210     y = [deepcopy(a, memo) for a in x]
#     211     # We're not going to put the tuple in the memo, but it's still important we
#     212     # check for it, in case the tuple contains recursive mutable structures.
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~/opt/anaconda3/lib/python3.8/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~/opt/anaconda3/lib/python3.8/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~/opt/anaconda3/lib/python3.8/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~/opt/anaconda3/lib/python3.8/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~/opt/anaconda3/lib/python3.8/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~/opt/anaconda3/lib/python3.8/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~/opt/anaconda3/lib/python3.8/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~/opt/anaconda3/lib/python3.8/copy.py in deepcopy(x, memo, _nil)
#     159                     reductor = getattr(x, "__reduce_ex__", None)
#     160                     if reductor is not None:
# --> 161                         rv = reductor(4)
#     162                     else:
#     163                         reductor = getattr(x, "__reduce__", None)
#
# TypeError: cannot pickle '_thread.RLock' object
